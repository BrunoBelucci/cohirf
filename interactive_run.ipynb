# %%
from recursive_clustering.experiment.hpo_blob_clustering_experiment import HPOBlobClusteringExperiment
from recursive_clustering.experiment.hpo_classification_clustering_experiment import HPOClassificationClusteringExperiment
from recursive_clustering.experiment.hpo_open_ml_clustering_experiment import HPOOpenmlClusteringExperiment
from recursive_clustering.experiment.blob_clustering_experiment import BlobClusteringExperiment
import pandas as pd

# %%
datasets = pd.read_csv('recursive_clustering/openml_datasets.csv')

# %%
datasets
# Out:
#     task_id  dataset_id                       dataset_name  \
# 0    167124       40927                           CIFAR_10
# 1    146825       40996                      Fashion-MNIST
# 2     14969        4538  GesturePhaseSegmentationProcessed
# 3      3510         375                     JapaneseVowels
# 4    125921       40496          LED-display-domain-7digit
# ..      ...         ...                                ...
# 73   168331       41166                            volkert
# 74     3022         307                              vowel
# 75     9945        1509                   walking-activity
# 76     9960        1497              wall-robot-navigation
# 77   145793       40733                              yeast
#
#                     task_type       task_name target_name  evaluation_type  \
# 0   Supervised Classification  classification       class  crossvalidation
# 1   Supervised Classification  classification       class  crossvalidation
# 2   Supervised Classification  classification       Phase  crossvalidation
# 3   Supervised Classification  classification     speaker  crossvalidation
# 4   Supervised Classification  classification       Class  crossvalidation
# ..                        ...             ...         ...              ...
# 73  Supervised Classification  classification       class  crossvalidation
# 74  Supervised Classification  classification       Class  crossvalidation
# 75  Supervised Classification  classification       Class  crossvalidation
# 76  Supervised Classification  classification       Class  crossvalidation
# 77  Supervised Classification  classification       Class  crossvalidation
#
#     n_folds  n_instances  n_features  n_categorical_features  \
# 0        10      60000.0      3073.0                     1.0
# 1        10      70000.0       785.0                     1.0
# 2        10       9873.0        33.0                     1.0
# 3        10       9961.0        15.0                     1.0
# 4        10        500.0         8.0                     1.0
# ..      ...          ...         ...                     ...
# 73       10      58310.0       181.0                     1.0
# 74       10        990.0        13.0                     3.0
# 75       10     149332.0         5.0                     1.0
# 76       10       5456.0        25.0                     1.0
# 77       10       1269.0         9.0                     1.0
#
#     n_continuous_features  n_nans  n_rows_nans  n_classes  \
# 0                  3072.0     0.0          0.0         10
# 1                   784.0     0.0          0.0         10
# 2                    32.0     0.0          0.0          5
# 3                    14.0     0.0          0.0          9
# 4                     7.0     0.0          0.0         10
# ..                    ...     ...          ...        ...
# 73                  180.0     0.0          0.0         10
# 74                   10.0     0.0          0.0         11
# 75                    4.0     0.0          0.0         22
# 76                   24.0     0.0          0.0          4
# 77                    8.0     0.0          0.0          4
#
#                                url
# 0   https://www.openml.org/d/40927
# 1   https://www.openml.org/d/40996
# 2    https://www.openml.org/d/4538
# 3     https://www.openml.org/d/375
# 4   https://www.openml.org/d/40496
# ..                             ...
# 73  https://www.openml.org/d/41166
# 74    https://www.openml.org/d/307
# 75   https://www.openml.org/d/1509
# 76   https://www.openml.org/d/1497
# 77  https://www.openml.org/d/40733
#
# [78 rows x 16 columns]

# %%
experiment = BlobClusteringExperiment(check_if_exists=False)
model_nickname = 'RecursiveClustering'
seed_model = 0
seed_dataset = 0
model_params = dict()
fit_params = dict()
n_samples = int(1e3)
n_features = int(1e3)
centers = 10
cluster_std = 1
center_box = (-10, 10)
shuffle = True
experiment.run_blob_experiment_combination(model_nickname=model_nickname, seed_model=seed_model, seed_dataset=seed_dataset, model_params=model_params,
                                           fit_params=fit_params, n_samples=n_samples, n_features=n_features, centers=centers, cluster_std=cluster_std,
                                           center_box=center_box, shuffle=shuffle, return_results=False, log_to_mlflow=True)
# Out:
# Running...
# model_nickname: RecursiveClustering
# seed_model: 0
# seed_dataset: 0
# model_params: {}
# fit_params: {}
# n_samples: 1000
# n_features: 1000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.272299918004137
# model_nickname: RecursiveClustering
# seed_model: 0
# seed_dataset: 0
# model_params: {}
# fit_params: {}
# n_samples: 1000
# n_features: 1000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
# True

# %%
n_trials = 100
experiment = HPOBlobClusteringExperiment(n_trials=n_trials, sampler='grid', pruner=None, direction='maximize', check_if_exists=False)
model_nickname = 'RecursiveClustering'
seed_model = 0
seed_dataset = 0
model_params = dict()
fit_params = dict()
n_samples = int(1e3)
n_features = int(1e4)
centers = 10
cluster_std = 1
center_box = (-10, 10)
shuffle = True
experiment.run_blob_experiment_combination(model_nickname=model_nickname, seed_model=seed_model, seed_dataset=seed_dataset, model_params=model_params,
                                           fit_params=fit_params, n_samples=n_samples, n_features=n_features, centers=centers, cluster_std=cluster_std,
                                           center_box=center_box, shuffle=shuffle, return_results=False, log_to_mlflow=True)
# Out:
# [I 2024-11-28 18:57:42,323] A new study created in memory with name: no-name-b5ba74ef-2f8a-40e1-a7b1-f22a5c8c3935
# Running...
# model_nickname: RecursiveClustering
# seed_model: 0
# seed_dataset: 0
# model_params: {}
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
# Trials:   0%|          | 0/27 [00:00<?, ?it/s]
# /home/bbelucci/miniconda3/envs/clustering/lib/python3.13/site-packages/optuna/trial/_trial.py:652: UserWarning: Fixed parameter 'components_size' with value 10 is out of range for distribution IntDistribution(high=4, log=False, low=2, step=1).
#   warnings.warn(
# /home/bbelucci/miniconda3/envs/clustering/lib/python3.13/site-packages/optuna/trial/_trial.py:652: UserWarning: Fixed parameter 'repetitions' with value 10 is out of range for distribution IntDistribution(high=4, log=False, low=2, step=1).
#   warnings.warn(
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 10, 'repetitions': 10, 'kmeans_n_clusters': 3}
# seed_model: 2732
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.7197639890000573
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 10, 'repetitions': 10, 'kmeans_n_clusters': 3}
# seed_model: 2732
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 2, 'kmeans_n_clusters': 4}
# seed_model: 9845
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5731531940036803
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 2, 'kmeans_n_clusters': 4}
# seed_model: 9845
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 3264
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5505154200000106
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 3264
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 4859
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5412387320029666
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 4859
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 9225
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6121711579980911
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 9225
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 7891
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.647708247997798
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 7891
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 4373
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6023701029989752
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 4373
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 5874
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6883752350040595
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 5874
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6744
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6107569429950672
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6744
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 3468
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.621196609994513
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 3468
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 705
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5583175939973444
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 705
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2599
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5366083389963023
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2599
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2222
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6160825019978802
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2222
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 7768
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6101129789967672
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 7768
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 2897
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.538145065002027
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 2897
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 9893
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6479131369997049
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 9893
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 2, 'kmeans_n_clusters': 4}
# seed_model: 537
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5957031869984348
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 2, 'kmeans_n_clusters': 4}
# seed_model: 537
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 6216
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5906642560003093
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 6216
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 2, 'kmeans_n_clusters': 2}
# seed_model: 6921
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5905775319988606
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 2, 'kmeans_n_clusters': 2}
# seed_model: 6921
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 2, 'kmeans_n_clusters': 2}
# seed_model: 6036
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5407320109952707
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 2, 'kmeans_n_clusters': 2}
# seed_model: 6036
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 2163
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5887454120020266
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 2163
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 5072
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6082751889989595
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 5072
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 2, 'kmeans_n_clusters': 3}
# seed_model: 4851
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5330025410003145
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 2, 'kmeans_n_clusters': 3}
# seed_model: 4851
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 2, 'kmeans_n_clusters': 2}
# seed_model: 7877
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6321906269949977
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 2, 'repetitions': 2, 'kmeans_n_clusters': 2}
# seed_model: 7877
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 2, 'kmeans_n_clusters': 3}
# seed_model: 2046
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6047551779993228
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 4, 'repetitions': 2, 'kmeans_n_clusters': 3}
# seed_model: 2046
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 2, 'kmeans_n_clusters': 4}
# seed_model: 1871
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6168713359948015
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 2, 'kmeans_n_clusters': 4}
# seed_model: 1871
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 2, 'kmeans_n_clusters': 3}
# seed_model: 7599
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5844312599947443
# model_nickname: RecursiveClustering
# seed_dataset: 0
# model_params: {'components_size': 3, 'repetitions': 2, 'kmeans_n_clusters': 3}
# seed_model: 7599
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
#
# Finished!
# total_elapsed_time: 18.982460135994188
# model_nickname: RecursiveClustering
# seed_model: 0
# seed_dataset: 0
# model_params: {}
# fit_params: {}
# n_samples: 1000
# n_features: 10000
# centers: 10
# cluster_std: 1
# center_box: (-10, 10)
# shuffle: True
# True

# %%
n_trials = 100
experiment = HPOClassificationClusteringExperiment(n_trials=n_trials, sampler='tpe', pruner=None, direction='maximize', check_if_exists=False, raise_on_fit_error=True)
model_nickname = 'RecursiveClustering'
# seed_model = 0
# seed_dataset = 0
model_params = dict()
fit_params = dict()
n_samples = 1000
n_features = 10000
pct_random = 0.0
class_sep: float = 40
seed_unified = 0
# n_random = int(0)
# n_informative: int = int(1e5)
# n_redundant: int = 0
# n_repeated: int = 0
n_classes: int = 5
n_clusters_per_class: int = 1
weights = None
flip_y: float = 0.0
hypercube: bool = True
shift: float = 0.0
scale: float = 1.0
shuffle: bool = True
experiment.run_classification_experiment_combination(model_nickname=model_nickname, model_params=model_params,
                                                     fit_params=fit_params, n_samples=n_samples, n_classes=n_classes, n_clusters_per_class=n_clusters_per_class, 
                                                     weights=weights, flip_y=flip_y, class_sep=class_sep, hypercube=hypercube, shift=shift, scale=scale, shuffle=shuffle,
                                                     log_to_mlflow=True, return_results=False, pct_random=pct_random, seed_unified=seed_unified, n_features=n_features)
# Out:
# Running...
# model_nickname: RecursiveClustering
# seed_model: 0
# seed_dataset: 0
# model_params: {}
# fit_params: {}
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
# /home/bbelucci/miniconda3/envs/recursive_clustering/lib/python3.11/site-packages/optuna/_experimental.py:31: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# /home/bbelucci/miniconda3/envs/recursive_clustering/lib/python3.11/site-packages/optuna/_experimental.py:31: ExperimentalWarning: Argument ``constant_liar`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2025-01-14 13:52:37,018] A new study created in memory with name: no-name-41fd285f-0dea-4487-8511-8d864815098a
# Trials:   0%|          | 0/100 [00:00<?, ?it/s]
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 10, 'repetitions': 10, 'kmeans_n_clusters': 3}
# seed_model: 2732
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 3.4455666760004533
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 10, 'repetitions': 10, 'kmeans_n_clusters': 3}
# seed_model: 2732
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 8, 'kmeans_n_clusters': 7}
# seed_model: 9845
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 3.0128732780012797
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 8, 'kmeans_n_clusters': 7}
# seed_model: 9845
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 6, 'kmeans_n_clusters': 7}
# seed_model: 3264
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 4.257054703000904
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 6, 'kmeans_n_clusters': 7}
# seed_model: 3264
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 15, 'repetitions': 10, 'kmeans_n_clusters': 10}
# seed_model: 4859
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 25.8532059249992
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 15, 'repetitions': 10, 'kmeans_n_clusters': 10}
# seed_model: 4859
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 13, 'repetitions': 9, 'kmeans_n_clusters': 6}
# seed_model: 9225
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 6.310487339998872
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 13, 'repetitions': 9, 'kmeans_n_clusters': 6}
# seed_model: 9225
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 10, 'kmeans_n_clusters': 2}
# seed_model: 7891
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.557830603000184
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 10, 'kmeans_n_clusters': 2}
# seed_model: 7891
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 5, 'repetitions': 3, 'kmeans_n_clusters': 9}
# seed_model: 4373
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 2.522614262999923
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 5, 'repetitions': 3, 'kmeans_n_clusters': 9}
# seed_model: 4373
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 9, 'kmeans_n_clusters': 10}
# seed_model: 5874
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 6.746732637000605
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 9, 'kmeans_n_clusters': 10}
# seed_model: 5874
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 6, 'kmeans_n_clusters': 9}
# seed_model: 6744
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 4.760343321000619
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 6, 'kmeans_n_clusters': 9}
# seed_model: 6744
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 6, 'repetitions': 8, 'kmeans_n_clusters': 3}
# seed_model: 3468
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 4.5761632840003585
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 6, 'repetitions': 8, 'kmeans_n_clusters': 3}
# seed_model: 3468
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 8, 'kmeans_n_clusters': 2}
# seed_model: 705
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.1004547030006506
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 8, 'kmeans_n_clusters': 2}
# seed_model: 705
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 22, 'repetitions': 9, 'kmeans_n_clusters': 2}
# seed_model: 2599
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.036133047000476
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 22, 'repetitions': 9, 'kmeans_n_clusters': 2}
# seed_model: 2599
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 28, 'repetitions': 10, 'kmeans_n_clusters': 4}
# seed_model: 2222
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.8011189150001883
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 28, 'repetitions': 10, 'kmeans_n_clusters': 4}
# seed_model: 2222
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 17, 'repetitions': 10, 'kmeans_n_clusters': 3}
# seed_model: 7768
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 2.0504338549999375
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 17, 'repetitions': 10, 'kmeans_n_clusters': 3}
# seed_model: 7768
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 7, 'kmeans_n_clusters': 3}
# seed_model: 2897
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.685869177999848
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 7, 'kmeans_n_clusters': 3}
# seed_model: 2897
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 10, 'kmeans_n_clusters': 2}
# seed_model: 9893
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.0562973050000437
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 10, 'kmeans_n_clusters': 2}
# seed_model: 9893
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 13, 'repetitions': 6, 'kmeans_n_clusters': 2}
# seed_model: 537
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6664697889991658
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 13, 'repetitions': 6, 'kmeans_n_clusters': 2}
# seed_model: 537
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6216
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.31113131799975235
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6216
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 4, 'kmeans_n_clusters': 5}
# seed_model: 6921
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.0177639770008682
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 4, 'kmeans_n_clusters': 5}
# seed_model: 6921
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 6036
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.44748992399945564
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 6036
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 17, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 2163
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5677818429994659
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 17, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 2163
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 14, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 5072
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.42651705500065873
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 14, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 5072
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 16, 'repetitions': 3, 'kmeans_n_clusters': 6}
# seed_model: 4851
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.756751307999366
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 16, 'repetitions': 3, 'kmeans_n_clusters': 6}
# seed_model: 4851
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 7877
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.2948630390001199
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 7877
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 20, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2046
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.4795515189998696
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 20, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2046
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 1871
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.29474544799995783
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 1871
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 7599
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6307690290013852
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 7599
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 29, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2496
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.4126103309990867
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 29, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2496
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 6, 'kmeans_n_clusters': 2}
# seed_model: 8291
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5830526040008408
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 6, 'kmeans_n_clusters': 2}
# seed_model: 8291
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 8, 'kmeans_n_clusters': 4}
# seed_model: 755
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.2003974090002885
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 8, 'kmeans_n_clusters': 4}
# seed_model: 755
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 797
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3813913659996615
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 797
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 3, 'repetitions': 7, 'kmeans_n_clusters': 9}
# seed_model: 659
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.192401897000309
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 3, 'repetitions': 7, 'kmeans_n_clusters': 9}
# seed_model: 659
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 22, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 3219
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.6403166419986519
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 22, 'repetitions': 4, 'kmeans_n_clusters': 3}
# seed_model: 3219
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 23, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 8615
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3188318929987872
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 23, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 8615
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 7456
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3804886580001039
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 7456
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 3337
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.32070926900087215
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 3337
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 2745
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.5228753209994466
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 2745
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 15, 'repetitions': 4, 'kmeans_n_clusters': 10}
# seed_model: 4735
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 3.068848318000164
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 15, 'repetitions': 4, 'kmeans_n_clusters': 10}
# seed_model: 4735
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 5, 'kmeans_n_clusters': 4}
# seed_model: 8736
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.8873663840004156
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 5, 'kmeans_n_clusters': 4}
# seed_model: 8736
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 6, 'repetitions': 5, 'kmeans_n_clusters': 6}
# seed_model: 6687
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 5.6033165019998705
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 6, 'repetitions': 5, 'kmeans_n_clusters': 6}
# seed_model: 6687
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 714
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.4791678359997604
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 3, 'kmeans_n_clusters': 4}
# seed_model: 714
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 2292
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.37293450300057884
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 2292
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 8343
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.33588764300111507
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 8343
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 28, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 1207
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.281044755000039
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 28, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 1207
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6172
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3629003529986221
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6172
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 8, 'kmeans_n_clusters': 2}
# seed_model: 8994
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.2170613409998623
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 18, 'repetitions': 8, 'kmeans_n_clusters': 2}
# seed_model: 8994
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 7221
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.7401021550012956
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 3, 'kmeans_n_clusters': 3}
# seed_model: 7221
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 8, 'kmeans_n_clusters': 6}
# seed_model: 6021
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.731575548001274
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 8, 'kmeans_n_clusters': 6}
# seed_model: 6021
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 28, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 3622
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.30906951499855495
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 28, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 3622
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 8, 'kmeans_n_clusters': 3}
# seed_model: 3560
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.1331793540011859
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 8, 'kmeans_n_clusters': 3}
# seed_model: 3560
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 9, 'kmeans_n_clusters': 2}
# seed_model: 8948
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.5386715940003342
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 9, 'kmeans_n_clusters': 2}
# seed_model: 8948
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 6, 'repetitions': 10, 'kmeans_n_clusters': 5}
# seed_model: 1641
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 21.76806083200063
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 6, 'repetitions': 10, 'kmeans_n_clusters': 5}
# seed_model: 1641
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 4984
# fit_params: {}
# n_redundant: 2
# ...
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 9008
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2435
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3302874080000038
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2435
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 10, 'kmeans_n_clusters': 8}
# seed_model: 1634
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 3.6965072629991482
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 10, 'kmeans_n_clusters': 8}
# seed_model: 1634
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 10}
# seed_model: 973
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 1.220870521001416
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 10}
# seed_model: 973
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 4464
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.32606113600013487
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 4464
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 8393
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.33009861199934676
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 8393
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2418
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.28038663099869154
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2418
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 3455
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3547197239986417
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 3455
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6167
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.2990220699994097
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 26, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6167
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 5819
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3657115749992954
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 30, 'repetitions': 4, 'kmeans_n_clusters': 2}
# seed_model: 5819
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 9, 'kmeans_n_clusters': 2}
# seed_model: 6521
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.8061472949993913
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 9, 'kmeans_n_clusters': 2}
# seed_model: 6521
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6242
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3131867720003356
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6242
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 7742
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.2936401390015817
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 7742
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 9123
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.316078871001082
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 25, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 9123
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 23, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6738
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.26437324700054887
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 23, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 6738
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2787
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.2523009189990262
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 24, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 2787
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 7316
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.7255099560006784
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 21, 'repetitions': 4, 'kmeans_n_clusters': 4}
# seed_model: 7316
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Running...
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 4305
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 0.3061885869992693
# model_nickname: RecursiveClustering
# seed_dataset: 0
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# model_params: {'components_size': 27, 'repetitions': 3, 'kmeans_n_clusters': 2}
# seed_model: 4305
# fit_params: {}
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
#
# Finished!
# total_elapsed_time: 178.7065821140004
# model_nickname: RecursiveClustering
# seed_model: 0
# seed_dataset: 0
# model_params: {}
# fit_params: {}
# n_samples: 1000
# n_random: 16
# n_informative: 2
# class_sep: 40
# n_features: 10000
# pct_random: 0.0
# seed_unified: 0
# n_redundant: 2
# n_repeated: 0
# n_classes: 5
# n_clusters_per_class: 1
# weights: None
# flip_y: 0.0
# hypercube: True
# shift: 0.0
# scale: 1.0
# shuffle: True
# True

# %%
n_trials = 100
experiment = HPOOpenmlClusteringExperiment(n_trials=n_trials, sampler='tpe', pruner=None, direction='maximize', check_if_exists=False)
model_nickname = 'RecursiveClustering'
seed_model = 0
dataset_id = 40927
model_params = dict()
fit_params = dict()
experiment.run_openml_experiment_combination(model_nickname=model_nickname, seed_model=seed_model, dataset_id=dataset_id,
                                                     model_params=model_params,
                                                     fit_params=fit_params, log_to_mlflow=True,
                                                     return_results=False)
# Out:
# Running...
# model_nickname: RecursiveClustering
# seed_model: 0
# dataset_id: 40927
# model_params: {}
# fit_params: {}
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x78a257a6dad0>>
# Traceback (most recent call last):
#   File "/home/bbelucci/miniconda3/envs/recursive_clustering/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
#
# KeyboardInterrupt
