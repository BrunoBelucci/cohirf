# %%
import pandas as pd
from pathlib import Path

# %%
data_path = Path("/home/belucci/code/cohirf/data/user-behavior-100k")
csv_path = Path("/home/belucci/code/cohirf/data/user_behavior_100k.csv")
df = pd.read_csv(csv_path)

# %%
X = df.drop(columns=["user_id", "item_id", "category_id", "label", "behavior_type", "weights"])
y = df["label"]
X.to_csv(data_path / "X.csv", index=True)
y.to_csv(data_path / "y.csv", index=True)

# %%
X
# Out:
#        hour  dayofweek  user_is_pv  user_is_cart  user_is_fav  user_is_buy  \
# 0         8          6          21             0            0            0
# 1        13          4           8             0            0            0
# 2        15          0         291             0            0            0
# 3         7          5          12             0            0            0
# 4        14          2          15             0            0            0
# ...     ...        ...         ...           ...          ...          ...
# 99995    16          2           2             0            0            0
# 99996    20          1          42             0            0            0
# 99997     1          4         127             0            0            0
# 99998     2          4           9             0            0            0
# 99999     7          0          84             0            0            0
#
# ...
