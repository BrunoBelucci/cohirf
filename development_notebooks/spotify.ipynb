# %%
import pandas as pd
from pathlib import Path

# %%
data_dir = Path("/home/belucci/code/cohirf/data/spotify")
df = pd.read_csv("/home/belucci/code/cohirf/data/modified-spotify-dataset.csv")

# %%
for col in df.columns:
	print(col, end=", ")
# Out:
# track_genre_acoustic, track_genre_afrobeat, track_genre_alt-rock, track_genre_alternative, track_genre_ambient, track_genre_anime, track_genre_black-metal, track_genre_bluegrass, track_genre_blues, track_genre_brazil, track_genre_breakbeat, track_genre_british, track_genre_cantopop, track_genre_chicago-house, track_genre_children, track_genre_chill, track_genre_classical, track_genre_club, track_genre_comedy, track_genre_country, track_genre_dance, track_genre_dancehall, track_genre_death-metal, track_genre_deep-house, track_genre_detroit-techno, track_genre_disco, track_genre_disney, track_genre_drum-and-bass, track_genre_dub, track_genre_dubstep, track_genre_edm, track_genre_electro, track_genre_electronic, track_genre_emo, track_genre_folk, track_genre_forro, track_genre_french, track_genre_funk, track_genre_garage, track_genre_german, track_genre_gospel, track_genre_goth, track_genre_grindcore, track_genre_groove, track_genre_grunge, track_genre_guitar, track_genre_happy, track_g
# ...

# %%
columns_to_drop = ["track_genre_le"] + [col for col in df.columns if col.startswith("track_genre_")]
df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['duration_class_long', 'duration_class_mid_normal',
#        'duration_class_normal', 'duration_class_short',
#        'duration_class_very_long', 'loudness_level', 'popularity_level',
#        'tempo_class', 'popularity', 'time_signature', 'key_mode',
#        'artist_song_count', 'album_freq', 'danceability', 'loudness',
#        'speechiness', 'acousticness', 'valence', 'tempo', 'loudness_intensity',
#        'happy_dance', 'acoustics_instrumental', 'artists_avg_popularity',
#        'tempo_vs_genre', 'energy_rank_pct', 'loud_energy_ratio', 'mood_pca',
#        'mood_cluster', 'acoustic_valence_mood_cluster', 'explicit', 'energy',
#        'mode', 'instrumentalness', 'liveness', 'key_sin', 'key_cos',
#        'duration_log', 'duration_log_z', 'time_signature_class_boolean',
#        'loudness_yeo', 'is_instrumental', 'is_dance_hit', 'temp_zscore',
#        'track_genre'],
#       dtype='object')

# %%
columns_to_keep = [
    # "popularity",
    # "key_mode",
    # "danceability",
    # "energy",
    # "loudness",
    # "speechiness",
    # "acousticness",
    # "instrumentalness",
    # "liveness",
    # "valence",
    # "tempo",
    "danceability",
    "energy",
    "energy_rank_pct",  # normalized version
    "loud_energy_ratio",  # intensity balance
    "speechiness",
    "acousticness",
    "instrumentalness",
    "is_instrumental",  # binary version
    "valence",
    "tempo",
    "duration_log_z",  # normalized duration
    "mood_pca",  # captures composite mood
    "track_genre",
]
df = df[columns_to_keep]

# %%
# drop nans
df = df.dropna()
# drop duplicates
df = df.drop_duplicates(subset=columns_to_keep[:-1])

# %%
genre_map = {
    # --- Pop & Mainstream ---
    "pop": "Pop & Mainstream",
    "indie-pop": "Pop & Mainstream",
    "synth-pop": "Pop & Mainstream",
    "power-pop": "Pop & Mainstream",
    "pop-film": "Pop & Mainstream",
    "romance": "Pop & Mainstream",
    "spanish": "Pop & Mainstream",
    "swedish": "Pop & Mainstream",
    "study": "Pop & Mainstream",
    "happy": "Pop & Mainstream",
    "sad": "Pop & Mainstream",
    "sleep": "Pop & Mainstream",
    "chill": "Pop & Mainstream",
    "indie": "Pop & Mainstream",
    # --- Rock & Metal ---
    "rock": "Rock & Metal",
    "alt-rock": "Rock & Metal",
    "punk": "Rock & Metal",
    "punk-rock": "Rock & Metal",
    "grunge": "Rock & Metal",
    "hard-rock": "Rock & Metal",
    "rock-n-roll": "Rock & Metal",
    "rockabilly": "Rock & Metal",
    "metal": "Rock & Metal",
    "heavy-metal": "Rock & Metal",
    "black-metal": "Rock & Metal",
    "death-metal": "Rock & Metal",
    "metalcore": "Rock & Metal",
    "hardcore": "Rock & Metal",
    "grindcore": "Rock & Metal",
    "emo": "Rock & Metal",
    "goth": "Rock & Metal",
    "psych-rock": "Rock & Metal",
    # --- Electronic & Dance ---
    "edm": "Electronic & Dance",
    "electronic": "Electronic & Dance",
    "electro": "Electronic & Dance",
    "club": "Electronic & Dance",
    "dance": "Electronic & Dance",
    "dancehall": "Electronic & Dance",
    "house": "Electronic & Dance",
    "deep-house": "Electronic & Dance",
    "progressive-house": "Electronic & Dance",
    "detroit-techno": "Electronic & Dance",
    "chicago-house": "Electronic & Dance",
    "minimal-techno": "Electronic & Dance",
    "techno": "Electronic & Dance",
    "trance": "Electronic & Dance",
    "dubstep": "Electronic & Dance",
    "drum-and-bass": "Electronic & Dance",
    "garage": "Electronic & Dance",
    "idm": "Electronic & Dance",
    "breakbeat": "Electronic & Dance",
    "trip-hop": "Electronic & Dance",
    "disco": "Electronic & Dance",
    "hardstyle": "Electronic & Dance",
    # --- Hip-Hop & R&B ---
    "hip-hop": "Hip-Hop & R&B",
    "r-n-b": "Hip-Hop & R&B",
    "funk": "Hip-Hop & R&B",
    "soul": "Hip-Hop & R&B",
    "groove": "Hip-Hop & R&B",
    # --- Latin & Brazilian ---
    "latin": "Latin & Brazilian",
    "latino": "Latin & Brazilian",
    "brazil": "Latin & Brazilian",
    "samba": "Latin & Brazilian",
    "pagode": "Latin & Brazilian",
    "forro": "Latin & Brazilian",
    "mpb": "Latin & Brazilian",
    "sertanejo": "Latin & Brazilian",
    "salsa": "Latin & Brazilian",
    "tango": "Latin & Brazilian",
    # --- Jazz & Blues ---
    "jazz": "Jazz & Blues",
    "blues": "Jazz & Blues",
    "gospel": "Jazz & Blues",
    "bluegrass": "Jazz & Blues",
    # --- Folk, Country & Singer-Songwriter ---
    "folk": "Folk & Country",
    "country": "Folk & Country",
    "honky-tonk": "Folk & Country",
    "acoustic": "Folk & Country",
    "singer-songwriter": "Folk & Country",
    "songwriter": "Folk & Country",
    "guitar": "Folk & Country",
    # --- Classical & Instrumental ---
    "classical": "Classical & Instrumental",
    "opera": "Classical & Instrumental",
    "piano": "Classical & Instrumental",
    "ambient": "Classical & Instrumental",
    "new-age": "Classical & Instrumental",
    # --- World & Regional ---
    "indian": "World & Regional",
    "iranian": "World & Regional",
    "turkish": "World & Regional",
    "malay": "World & Regional",
    "world-music": "World & Regional",
    "french": "World & Regional",
    "german": "World & Regional",
    "british": "World & Regional",
    "mandopop": "World & Regional",
    "cantopop": "World & Regional",
    "j-pop": "World & Regional",
    "j-rock": "World & Regional",
    "j-idol": "World & Regional",
    "j-dance": "World & Regional",
    "anime": "World & Regional",
    "k-pop": "World & Regional",
    # --- Reggae & Afro styles ---
    "reggae": "Reggae & Afro",
    "reggaeton": "Reggae & Afro",
    "afrobeat": "Reggae & Afro",
    "dub": "Reggae & Afro",
    "ska": "Reggae & Afro",
    # --- Experimental & Alternative ---
    "alternative": "Experimental & Alternative",
    "industrial": "Experimental & Alternative",
    # --- Children & Special Use ---
    "kids": "Children & Special Use",
    "children": "Children & Special Use",
    "disney": "Children & Special Use",
    "comedy": "Children & Special Use",
    "party": "Children & Special Use",
    "show-tunes": "Children & Special Use",
}

# %%
# check if every track_genre has a genre_group
track_genres = set(df["track_genre"].unique())
track_genre_with_group = set(genre_map.keys())
missing_genres = track_genres - track_genre_with_group
# check if any genre_with_group is not in track_genres
not_in_track_genres = track_genre_with_group - track_genres

# %%
missing_genres
# Out:
# set()

# %%
not_in_track_genres
# Out:
# set()

# %%
df["genre_group"] = df["track_genre"].map(genre_map)

# %%
df["genre_group"].value_counts(normalize=True)
# Out:
# genre_group
# Electronic & Dance            0.196356
# World & Regional              0.158920
# Rock & Metal                  0.151181
# Pop & Mainstream              0.121137
# Latin & Brazilian             0.092362
# Children & Special Use        0.063875
# Folk & Country                0.055249
# Classical & Instrumental      0.050877
# Reggae & Afro                 0.034297
# Hip-Hop & R&B                 0.031530
# Jazz & Blues                  0.031278
# Experimental & Alternative    0.012938
# Name: proportion, dtype: float64

# %%
# keep only the 8 most frequent genre_group
top_genres = df["genre_group"].value_counts().nlargest(8).index
df = df[df["genre_group"].isin(top_genres)]

# %%
df
# Out:
#         danceability  energy  energy_rank_pct  loud_energy_ratio  speechiness  \
# 0           0.629239  0.4610        -0.900812          -0.009092     0.551843
# 1          -0.845908  0.1660        -1.544002          -0.008280    -0.078995
# 2          -0.742187  0.3590        -1.187727          -0.008948    -0.273827
# 3          -1.733301  0.0596        -1.666705          -0.005684    -0.457309
# 4           0.295026  0.4430        -0.957681          -0.009114    -0.303146
# ...              ...     ...              ...                ...          ...
# 113994     -2.274956  0.2350        -1.437358          -0.008706    -0.401507
# 113995     -2.263432  0.1170        -1.606250          -0.007704    -0.421369
# 113996      0.358411  0.3290        -1.254503          -0.008896    -0.403399
# 113997      0.116395  0.5060        -0.742556          -0.009222    -0.519731
# 113998     -0.235105  0.4870        -0.811671          -0.009187    -0.114935
#
# ...

# %%
# try autoencoder....
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler

# prepare data
X = df[
    [
        "danceability",
        "energy",
        "speechiness",
        "acousticness",
        "instrumentalness",
        "valence",
        "tempo",
        "duration_log_z",
        "loud_energy_ratio",
        "energy_rank_pct",
    ]
].values
X = StandardScaler().fit_transform(X)
X_tensor = torch.tensor(X, dtype=torch.float32)


# autoencoder model
class Autoencoder(nn.Module):
    def __init__(self, input_dim, latent_dim=16):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 64), nn.ReLU(), nn.Linear(64, 32), nn.ReLU(), nn.Linear(32, latent_dim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 32), nn.ReLU(), nn.Linear(32, 64), nn.ReLU(), nn.Linear(64, input_dim)
        )

    def forward(self, x):
        z = self.encoder(x)
        return self.decoder(z), z


model = Autoencoder(input_dim=X.shape[1], latent_dim=16)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-2)

# training
for epoch in range(100):
    optimizer.zero_grad()
    recon, z = model(X_tensor)
    loss = criterion(recon, X_tensor)
    loss.backward()
    optimizer.step()
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss {loss.item():.4f}")

# get embeddings
with torch.no_grad():
    _, Z = model(X_tensor)
Z = Z.numpy()
# Out:
# Epoch 0, Loss 1.0099
# Epoch 10, Loss 0.4972
# Epoch 20, Loss 0.2310
# Epoch 30, Loss 0.1353
# Epoch 40, Loss 0.0699
# Epoch 50, Loss 0.0460
# Epoch 60, Loss 0.0334
# Epoch 70, Loss 0.0287
# Epoch 80, Loss 0.0255
# Epoch 90, Loss 0.0193

# %%
pd.DataFrame(Z)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.235683 -0.799349 -1.953843 -0.374013  0.600948  2.604492  0.531568
# 1      0.611720 -0.395497 -2.593801  0.385203 -0.081538  2.594208  1.203783
# 2      0.181693 -0.022298 -3.114142 -0.278191 -0.029974  3.066036  0.225455
# 3      1.125232  0.523711 -4.855644 -0.672555 -0.781476  2.945393  0.867808
# 4      0.361854  0.306691 -1.786245 -0.021604  0.124914  1.287581  0.134561
# ...         ...       ...       ...       ...       ...       ...       ...
# 74285  0.903434  0.848434 -4.590699  0.169087  0.061523  4.025388 -1.311203
# 74286  1.149131  0.398485 -4.471927  0.755171  0.124154  4.430326 -0.969594
# 74287  1.535030 -0.853499 -2.730604  0.050238 -0.135048  2.372908  0.823637
# 74288  1.052205 -0.019108 -2.297035 -0.178803 -0.278181  1.656708 -0.056288
# 74289  1.071221 -0.736815 -1.985732  0.539875  0.004450  1.990127  0.636985
#
# ...

# %%
categorical_columns = ([col for col in df.columns if col.startswith("duration_class_")] 
					   + ["loudness_level", "popularity_level", "tempo_class", "explicit", "mode", "time_signature_class_boolean", "is_instrumental", "is_dance_hit",
		   "track_genre"])

# %%
categorical_indexes = [i for i, col in enumerate(df.columns) if col in categorical_columns]

# %%
categorical_indexes
# Out:
# [7, 12]

# %%
y = df["genre_group"]
X = pd.DataFrame(Z, index=y.index)
X.to_csv(data_dir / "X.csv")
y.to_csv(data_dir / "y.csv")

# %%
df.isna().any().any()
# Out:
# False

# %%
y.value_counts(normalize=True)
# Out:
# genre_group
# Electronic & Dance          0.220635
# World & Regional            0.178570
# Rock & Metal                0.169875
# Pop & Mainstream            0.136115
# Latin & Brazilian           0.103782
# Children & Special Use      0.071773
# Folk & Country              0.062081
# Classical & Instrumental    0.057168
# Name: proportion, dtype: float64

# %%
X.duplicated().any()
# Out:
# False

# %%
len(y.unique())
# Out:
# 8

# %%
y.unique()
# Out:
# array(['Folk & Country', 'Rock & Metal', 'Classical & Instrumental',
#        'World & Regional', 'Latin & Brazilian', 'Electronic & Dance',
#        'Children & Special Use', 'Pop & Mainstream'], dtype=object)

# %%
y
# Out:
# 0           Folk & Country
# 1           Folk & Country
# 2           Folk & Country
# 3           Folk & Country
# 4           Folk & Country
#                 ...
# 113994    World & Regional
# 113995    World & Regional
# 113996    World & Regional
# 113997    World & Regional
# 113998    World & Regional
# Name: genre_group, Length: 74290, dtype: object

# %%
X
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.214106 -0.741594  0.237274 -0.762969  0.239912  0.360340  0.136995
# 1     -0.156769 -0.672476 -0.358605 -0.930861  1.088521 -0.333134  0.558873
# 2      0.066747 -0.335674 -0.330454 -0.707794  0.464500 -0.378158  0.409559
# 3     -0.297576 -0.607657 -0.575511 -0.917287  1.040625 -0.579145  0.617857
# 4     -0.051330 -0.204878 -0.331392 -0.677808  0.340391 -0.231888  0.531042
# ...         ...       ...       ...       ...       ...       ...       ...
# 74285  0.105457 -0.481628 -0.733975 -0.778769  1.229719 -1.165582  0.217320
# 74286  0.180608 -0.689410 -0.876595 -1.033069  1.662741 -1.227089  0.473497
# 74287 -0.197899 -0.681390  0.022751 -1.010086  0.320549  0.072015  0.447803
# 74288 -0.033678 -0.197784 -0.148548 -0.617588 -0.116746 -0.071328  0.476121
# 74289 -0.204727 -0.592609  0.048556 -0.789819  0.348309  0.035785  0.255285
#
# ...
