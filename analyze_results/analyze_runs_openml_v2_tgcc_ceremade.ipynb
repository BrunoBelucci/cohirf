# %%
from sqlalchemy import create_engine, text
import pandas as pd
from ml_experiments.analyze import get_df_runs_from_mlflow_sql, get_missing_entries
from pathlib import Path
import os
import pickle
from functools import partial

# %% [markdown]
# # Save Results

# %% [markdown]
# ## Load mlflow runs

# %%
results_dir = Path.cwd().parent / "results" / "real"
os.makedirs(results_dir, exist_ok=True)

# %%
db_port = 5101
db_name = "cohirf"
url = f"postgresql://beluccib@localhost:{db_port}/{db_name}"
# url = f"postgresql://beluccib@clust5:{db_port}/{db_name}"
engine = create_engine(url)
query = "SELECT experiments.name from experiments"
experiment_names = pd.read_sql(query, engine)["name"].tolist()

# %%
experiments_names = [exp for exp in experiment_names if (exp.startswith("real-"))]

# %%
experiments_names
# Out:
# ['real-adjusted_rand-KernelRBFKMeans',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_rand-KMeans',
#  'real-adjusted_rand-DBSCAN',
#  'real-adjusted_rand-CoHiRF-DBSCAN',
#  'real-adjusted_rand-BatchCoHiRF',
#  'real-adjusted_rand-CoHiRF',
#  'real-adjusted_rand-CoHiRF-KernelRBF',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-1iter',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter',
#  'real-silhouette-BatchCoHiRF-1iter',
#  'real-silhouette-DBSCAN',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter',
#  'real-davies_bouldin_score-KernelRBFKMeans',
#  'real-silhouette-KMeans',
#  'real-davies_bouldin_score-KMeans',
#  'real-calinski_harabasz_score-CoHiRF',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_mutual_info-CoHiRF',
#  'real-adjusted_mutual_info-CoHiRF-KernelRBF',
#  'real-davies_bouldin_score-CoHiRF-DBSCAN',
#  'real-adjusted_mutual_info-CoHiRF-DBSCAN',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_rand-BatchCoHiRF-1iter',
#  'real-davies_bouldin_score-DBSCAN',
#  'real-silhouette-CoHiRF-KernelRBF',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter',
#  'real-calinski_harabasz_score-CoHiRF-DBSCAN',
#  'real-adjusted_mutual_info-KMeans',
#  'real-calinski_harabasz_score-CoHiRF-KernelRBF',
#  'real-davies_bouldin_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-adjusted_mutual_info-DBSCAN',
#  'real-silhouette-CoHiRF',
#  'real-adjusted_mutual_info-KernelRBFKMeans',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-calinski_harabasz_score-KMeans',
#  'real-davies_bouldin_score-CoHiRF',
#  'real-silhouette-KernelRBFKMeans',
#  'real-silhouette-CoHiRF-DBSCAN',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter',
#  'real-davies_bouldin_score-CoHiRF-KernelRBF',
#  'real-calinski_harabasz_score-KernelRBFKMeans',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter',
#  'real-calinski_harabasz_score-DBSCAN',
#  'real-silhouette-CoHiRF-SC-SRGF',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF',
#  'real-silhouette-SpectralSubspaceRandomization',
#  'real-calinski_harabasz_score-SpectralSubspaceRandomization',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF',
#  'real-davies_bouldin_score-SpectralSubspaceRandomization',
#  'real-adjusted_rand-SpectralSubspaceRandomization',
#  'real-adjusted_mutual_info-SpectralSubspaceRandomization',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_rand-CoHiRF-SC-SRGF',
#  'real-silhouette-BatchCoHiRF-SC-SRGF',
#  'real-silhouette-BatchCoHiRF-SC-SRGF-2',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF-2',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF-2',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-2',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF-2',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter-stratified',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter-stratified',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-1iter-stratified',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter-stratified',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-1iter',
#  'real-silhouette-CoHiRF-1000',
#  'real-adjusted_rand-CoHiRF-1000',
#  'real-davies_bouldin_score-CoHiRF-1000',
#  'real-calinski_harabasz_score-CoHiRF-1000',
#  'real-adjusted_mutual_info-CoHiRF-1000',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF-1iter',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF-1iter',
#  'real-silhouette-BatchCoHiRF-SC-SRGF-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF-1iter',
#  'real-davies_bouldin_score-CoHiRF-top-down',
#  'real-adjusted_mutual_info-CoHiRF-top-down',
#  'real-adjusted_rand-CoHiRF-top-down',
#  'real-adjusted_rand-CoHiRF-top-down-inv',
#  'real-calinski_harabasz_score-CoHiRF-top-down',
#  'real-davies_bouldin_score-CoHiRF-top-down-inv',
#  'real-calinski_harabasz_score-CoHiRF-top-down-inv',
#  'real-adjusted_mutual_info-CoHiRF-top-down-inv',
#  'real-silhouette-CoHiRF-top-down-inv',
#  'real-silhouette-CoHiRF-top-down']

# %%
query = "SELECT DISTINCT(key) FROM params WHERE key LIKE 'best/%%'"
best_params = pd.read_sql(query, engine)["key"].tolist()

# %%
params_columns = [
    "model",
    "dataset_id",
	"n_trials",
	"dataset_name",
	"standardize",
	"hpo_metric",
	"direction",
	"hpo_seed",
] + best_params

# %%
latest_metrics_columns = [
    "fit_model_return_elapsed_time",
    "max_memory_used_after_fit",
    "max_memory_used",
	"best/n_clusters_",
    "best/rand_score",
    "best/adjusted_rand",
    "best/mutual_info",
    "best/adjusted_mutual_info",
    "best/normalized_mutual_info",
    "best/homogeneity_completeness_v_measure",
    "best/silhouette",
    "best/calinski_harabasz_score",
    "best/davies_bouldin_score",
    "best/inertia_score",
    "best/homogeneity",
    "best/completeness",
    "best/v_measure",
    "best/elapsed_time",
]

# %%
tags_columns = ["raised_exception", "EXCEPTION", "mlflow.parentRunId", "Last step finished"]

# %%
runs_columns = ['run_uuid', 'status', 'start_time', 'end_time']
experiments_columns = []
other_table = 'params'
other_table_keys = params_columns

# %%
df_params = get_df_runs_from_mlflow_sql(engine, runs_columns=runs_columns, experiments_columns=experiments_columns, experiments_names=experiments_names, other_table=other_table, other_table_keys=other_table_keys)
df_latest_metrics = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='latest_metrics', other_table_keys=latest_metrics_columns)
df_tags = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='tags', other_table_keys=tags_columns)

# %%
dataset_characteristics = pd.read_csv(results_dir / "datasets_characteristics.csv", index_col=0)
dataset_characteristics.index = dataset_characteristics["openml_id"].astype(str)

# %%
df_runs_raw_1 = df_params.join(df_latest_metrics)
df_runs_raw_1 = df_runs_raw_1.join(df_tags)

# %%
db_port = 5001
db_name = "cohirf"
url = f"postgresql://belucci@localhost:{db_port}/{db_name}"
# url = f"postgresql://beluccib@clust5:{db_port}/{db_name}"
engine = create_engine(url)
query = "SELECT experiments.name from experiments"
experiment_names = pd.read_sql(query, engine)["name"].tolist()
experiments_names = [exp for exp in experiment_names if (exp.startswith('real-'))]

# %%
experiments_names
# Out:
# ['real-ari-BatchCoHiRF-1iter',
#  'real-ari-AverageAgglomerativeClustering',
#  'real-ari-BatchCoHiRF-DBSCAN-1iter',
#  'real-ari-AffinityPropagation',
#  'real-ari-BatchCoHiRF-SC-SRGF',
#  'real-ari-CoHiRF-DBSCAN',
#  'real-ari-CoHiRF-KernelRBF',
#  'real-ari-CoHiRF',
#  'real-ari-CompleteAgglomerativeClustering',
#  'real-ari-DBSCAN',
#  'real-ari-HDBSCAN',
#  'real-ari-IRFLLRR',
#  'real-ari-KMeans',
#  'real-ari-MeanShift',
#  'real-ari-OPTICS',
#  'real-ari-Proclus',
#  'real-ari-SingleAgglomerativeClustering',
#  'real-ari-SpectralClustering',
#  'real-ari-SpectralSubspaceRandomization',
#  'real-ari-WardAgglomerativeClustering',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter',
#  'real-adjusted_mutual_info-DBSCAN',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-CompleteAgglomerativeClustering',
#  'real-adjusted_mutual_info-AverageAgglomerativeClustering',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter',
#  'real-adjusted_mutual_info-CoHiRF',
#  'real-adjusted_mutual_info-CoHiRF-KernelRBF',
#  'real-adjusted_mutual_info-CoHiRF-DBSCAN',
#  'real-adjusted_mutual_info-AffinityPropagation',
#  'real-calinski_harabasz_score-CompleteAgglomerativeClustering',
#  'real-calinski_harabasz_score-AverageAgglomerativeClustering',
#  'real-calinski_harabasz_score-DBSCAN',
#  'real-calinski_harabasz_score-CoHiRF-DBSCAN',
#  'real-calinski_harabasz_score-CoHiRF-KernelRBF',
#  'real-calinski_harabasz_score-AffinityPropagation',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-calinski_harabasz_score-CoHiRF',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter',
#  'real-adjusted_mutual_info-IRFLLRR',
#  'real-adjusted_mutual_info-HDBSCAN',
#  'real-adjusted_mutual_info-KMeans',
#  'real-calinski_harabasz_score-HDBSCAN',
#  'real-calinski_harabasz_score-IRFLLRR',
#  'real-calinski_harabasz_score-KMeans',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-MeanShift',
#  'real-calinski_harabasz_score-MeanShift',
#  'real-adjusted_mutual_info-OPTICS',
#  'real-calinski_harabasz_score-OPTICS',
#  'real-adjusted_mutual_info-Proclus',
#  'real-calinski_harabasz_score-Proclus',
#  'real-adjusted_mutual_info-SingleAgglomerativeClustering',
#  'real-calinski_harabasz_score-SingleAgglomerativeClustering',
#  'real-adjusted_mutual_info-SpectralClustering',
#  'real-calinski_harabasz_score-SpectralClustering',
#  'real-adjusted_mutual_info-SpectralSubspaceRandomization',
#  'real-calinski_harabasz_score-SpectralSubspaceRandomization',
#  'real-adjusted_mutual_info-WardAgglomerativeClustering',
#  'real-silhouette-BatchCoHiRF-SC-SRGF',
#  'real-calinski_harabasz_score-WardAgglomerativeClustering',
#  'real-silhouette-CoHiRF-DBSCAN',
#  'real-adjusted_rand-SpectralClustering',
#  'real-silhouette-AverageAgglomerativeClustering',
#  'real-silhouette-BatchCoHiRF-1iter',
#  'real-silhouette-CoHiRF',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter',
#  'real-silhouette-CoHiRF-KernelRBF',
#  'real-silhouette-AffinityPropagation',
#  'real-davies_bouldin_score-AverageAgglomerativeClustering',
#  'real-davies_bouldin_score-AffinityPropagation',
#  'real-davies_bouldin_score-CoHiRF',
#  'real-davies_bouldin_score-CoHiRF-KernelRBF',
#  'real-davies_bouldin_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-1iter',
#  'real-davies_bouldin_score-CoHiRF-DBSCAN',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF',
#  'real-silhouette-CompleteAgglomerativeClustering',
#  'real-davies_bouldin_score-CompleteAgglomerativeClustering',
#  'real-silhouette-DBSCAN',
#  'real-davies_bouldin_score-DBSCAN',
#  'real-silhouette-HDBSCAN',
#  'real-davies_bouldin_score-HDBSCAN',
#  'real-silhouette-IRFLLRR',
#  'real-silhouette-KMeans',
#  'real-davies_bouldin_score-KMeans',
#  'real-davies_bouldin_score-IRFLLRR',
#  'real-silhouette-MeanShift',
#  'real-davies_bouldin_score-MeanShift',
#  'real-silhouette-OPTICS',
#  'real-silhouette-Proclus',
#  'real-davies_bouldin_score-Proclus',
#  'real-davies_bouldin_score-OPTICS',
#  'real-silhouette-SingleAgglomerativeClustering',
#  'real-davies_bouldin_score-SingleAgglomerativeClustering',
#  'real-silhouette-SpectralClustering',
#  'real-davies_bouldin_score-SpectralClustering',
#  'real-silhouette-SpectralSubspaceRandomization',
#  'real-davies_bouldin_score-SpectralSubspaceRandomization',
#  'real-silhouette-WardAgglomerativeClustering',
#  'real-davies_bouldin_score-WardAgglomerativeClustering',
#  'real-normalized_mutual_info-AffinityPropagation',
#  'real-normalized_mutual_info-AverageAgglomerativeClustering',
#  'real-normalized_mutual_info-BatchCoHiRF-1iter',
#  'real-normalized_mutual_info-BatchCoHiRF-DBSCAN-1iter',
#  'real-normalized_mutual_info-BatchCoHiRF-SC-SRGF',
#  'real-normalized_mutual_info-CoHiRF-DBSCAN',
#  'real-normalized_mutual_info-CoHiRF-KernelRBF',
#  'real-normalized_mutual_info-CoHiRF',
#  'real-normalized_mutual_info-CompleteAgglomerativeClustering',
#  'real-normalized_mutual_info-DBSCAN',
#  'real-normalized_mutual_info-HDBSCAN',
#  'real-normalized_mutual_info-IRFLLRR',
#  'real-normalized_mutual_info-KMeans',
#  'real-normalized_mutual_info-MeanShift',
#  'real-normalized_mutual_info-OPTICS',
#  'real-normalized_mutual_info-Proclus',
#  'real-normalized_mutual_info-SingleAgglomerativeClustering',
#  'real-normalized_mutual_info-SpectralClustering',
#  'real-normalized_mutual_info-SpectralSubspaceRandomization',
#  'real-normalized_mutual_info-WardAgglomerativeClustering',
#  'real-adjusted_rand-BatchCoHiRF-1iter',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_rand-CoHiRF-DBSCAN',
#  'real-adjusted_rand-CoHiRF-KernelRBF',
#  'real-adjusted_rand-CoHiRF',
#  'real-adjusted_rand-DBSCAN',
#  'real-adjusted_rand-KMeans',
#  'real-adjusted_rand-SpectralSubspaceRandomization',
#  'real-adjusted_rand-KernelRBFKMeans',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_mutual_info-KernelRBFKMeans',
#  'real-calinski_harabasz_score-KernelRBFKMeans',
#  'real-normalized_mutual_info-KernelRBFKMeans',
#  'real-silhouette-KernelRBFKMeans',
#  'real-davies_bouldin_score-KernelRBFKMeans',
#  'real-normalized_mutual_info-BatchCoHiRF-KernelRBF-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_rand-CoHiRF-SC-SRGF',
#  'real-normalized_mutual_info-CoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF',
#  'real-silhouette-CoHiRF-SC-SRGF',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-1iter',
#  'real-adjusted_rand-CoHiRF-SC-SRGF-1R',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF-1R',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF-1R',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF-1R',
#  'real-silhouette-CoHiRF-SC-SRGF-1R',
#  'real-adjusted_rand-CoHiRF-SC-SRGF-2R',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF-2R',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF-2R',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF-2R',
#  'real-silhouette-CoHiRF-SC-SRGF-2R']

# %%
df_params = get_df_runs_from_mlflow_sql(engine, runs_columns=runs_columns, experiments_columns=experiments_columns, experiments_names=experiments_names, other_table=other_table, other_table_keys=other_table_keys)
df_latest_metrics = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='latest_metrics', other_table_keys=latest_metrics_columns)
df_tags = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='tags', other_table_keys=tags_columns)

# %%
df_runs_raw_2 = df_params.join(df_latest_metrics)
df_runs_raw_2 = df_runs_raw_2.join(df_tags)

# %%
df_runs_raw_2
# Out:
# key                                 status     start_time      end_time  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8  FINISHED  1753568824186  1.753569e+12
# 00028713c8e04978932ece53e8c94e09  FINISHED  1751922488822  1.751923e+12
# 0002f1471a6f4a639bcfd8a3d7c90f1f    FAILED  1752675967607  1.752676e+12
# 0002f564f6e3405d859abc0abd6c448e    FAILED  1752593974468  1.752594e+12
# 000303ea6e564058a7def8cddeeda1b0    FAILED  1752585530524  1.752586e+12
# ...                                    ...            ...           ...
# fffd925b0d5343ec8ed94789c9587fae  FINISHED  1753589038574  1.753589e+12
# fffe9e46b22949c48aa2eaffc64b7028    FAILED  1752689067271  1.752689e+12
# fffee9233db84b49b5fa6003f8f89366  FINISHED  1753549823592  1.753550e+12
# ffff2ab265274063bd33d808a0f27dfe    FAILED  1752657881361  1.752658e+12
# ffffb0e8e9074c5bad3225e8a1a08ade    FAILED  1752586642259  1.752587e+12
#
# key                              best/base_model_kwargs/eps  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                        NaN
# 00028713c8e04978932ece53e8c94e09                        NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f                        NaN
# 0002f564f6e3405d859abc0abd6c448e                        NaN
# 000303ea6e564058a7def8cddeeda1b0                        NaN
# ...                                                     ...
# fffd925b0d5343ec8ed94789c9587fae                        NaN
# fffe9e46b22949c48aa2eaffc64b7028                        NaN
# fffee9233db84b49b5fa6003f8f89366                        NaN
# ffff2ab265274063bd33d808a0f27dfe                        NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                        NaN
#
# key                              best/base_model_kwargs/min_samples  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                                NaN
# 00028713c8e04978932ece53e8c94e09                                NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                NaN
# 0002f564f6e3405d859abc0abd6c448e                                NaN
# 000303ea6e564058a7def8cddeeda1b0                                NaN
# ...                                                             ...
# fffd925b0d5343ec8ed94789c9587fae                                NaN
# fffe9e46b22949c48aa2eaffc64b7028                                NaN
# fffee9233db84b49b5fa6003f8f89366                                NaN
# ffff2ab265274063bd33d808a0f27dfe                                NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                NaN
#
# key                              best/base_model_kwargs/n_clusters  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                               NaN
# 00028713c8e04978932ece53e8c94e09                               NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f                               NaN
# 0002f564f6e3405d859abc0abd6c448e                               NaN
# 000303ea6e564058a7def8cddeeda1b0                               NaN
# ...                                                            ...
# fffd925b0d5343ec8ed94789c9587fae                               NaN
# fffe9e46b22949c48aa2eaffc64b7028                               NaN
# fffee9233db84b49b5fa6003f8f89366                               NaN
# ffff2ab265274063bd33d808a0f27dfe                               NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                               NaN
#
# key                              best/base_model_kwargs/n_similarities  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                                   NaN
# 00028713c8e04978932ece53e8c94e09                                   NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                   NaN
# 0002f564f6e3405d859abc0abd6c448e                                   NaN
# 000303ea6e564058a7def8cddeeda1b0                                   NaN
# ...                                                                ...
# fffd925b0d5343ec8ed94789c9587fae                                   NaN
# fffe9e46b22949c48aa2eaffc64b7028                                   NaN
# fffee9233db84b49b5fa6003f8f89366                                   NaN
# ffff2ab265274063bd33d808a0f27dfe                                   NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                   NaN
#
# key                              best/base_model_kwargs/sampling_ratio  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                                   NaN
# 00028713c8e04978932ece53e8c94e09                                   NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                   NaN
# 0002f564f6e3405d859abc0abd6c448e                                   NaN
# 000303ea6e564058a7def8cddeeda1b0                                   NaN
# ...                                                                ...
# fffd925b0d5343ec8ed94789c9587fae                                   NaN
# fffe9e46b22949c48aa2eaffc64b7028                                   NaN
# fffee9233db84b49b5fa6003f8f89366                                   NaN
# ffff2ab265274063bd33d808a0f27dfe                                   NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                   NaN
#
# key                              best/base_model_kwargs/sc_n_clusters  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                                  NaN
# 00028713c8e04978932ece53e8c94e09                                  NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                  NaN
# 0002f564f6e3405d859abc0abd6c448e                                  NaN
# 000303ea6e564058a7def8cddeeda1b0                                  NaN
# ...                                                               ...
# fffd925b0d5343ec8ed94789c9587fae                                  NaN
# fffe9e46b22949c48aa2eaffc64b7028                                  NaN
# fffee9233db84b49b5fa6003f8f89366                                  NaN
# ffff2ab265274063bd33d808a0f27dfe                                  NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                  NaN
#
# key                              best/child_run_id  ... best/rand_score  \
# run_uuid                                            ...
# 0000158194df4bbc83acad810a6126e8               NaN  ...             NaN
# 00028713c8e04978932ece53e8c94e09               NaN  ...             NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f               NaN  ...             NaN
# 0002f564f6e3405d859abc0abd6c448e               NaN  ...             NaN
# 000303ea6e564058a7def8cddeeda1b0               NaN  ...             NaN
# ...                                            ...  ...             ...
# fffd925b0d5343ec8ed94789c9587fae               NaN  ...             NaN
# fffe9e46b22949c48aa2eaffc64b7028               NaN  ...             NaN
# fffee9233db84b49b5fa6003f8f89366               NaN  ...             NaN
# ffff2ab265274063bd33d808a0f27dfe               NaN  ...             NaN
# ffffb0e8e9074c5bad3225e8a1a08ade               NaN  ...             NaN
#
# key                              best/silhouette best/v_measure  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8             NaN            NaN
# 00028713c8e04978932ece53e8c94e09             NaN            NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f             NaN            NaN
# 0002f564f6e3405d859abc0abd6c448e             NaN            NaN
# 000303ea6e564058a7def8cddeeda1b0             NaN            NaN
# ...                                          ...            ...
# fffd925b0d5343ec8ed94789c9587fae             NaN            NaN
# fffe9e46b22949c48aa2eaffc64b7028             NaN            NaN
# fffee9233db84b49b5fa6003f8f89366             NaN            NaN
# ffff2ab265274063bd33d808a0f27dfe             NaN            NaN
# ffffb0e8e9074c5bad3225e8a1a08ade             NaN            NaN
#
# key                              fit_model_return_elapsed_time  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                      0.220166
# 00028713c8e04978932ece53e8c94e09                      0.007838
# 0002f1471a6f4a639bcfd8a3d7c90f1f                     21.065334
# 0002f564f6e3405d859abc0abd6c448e                      0.013465
# 000303ea6e564058a7def8cddeeda1b0                      0.025954
# ...                                                        ...
# fffd925b0d5343ec8ed94789c9587fae                      0.137964
# fffe9e46b22949c48aa2eaffc64b7028                      0.067094
# fffee9233db84b49b5fa6003f8f89366                      0.073361
# ffff2ab265274063bd33d808a0f27dfe                      0.343937
# ffffb0e8e9074c5bad3225e8a1a08ade                      0.014669
#
# key                              max_memory_used max_memory_used_after_fit  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8         499.724                   499.724
# 00028713c8e04978932ece53e8c94e09         434.324                   434.324
# 0002f1471a6f4a639bcfd8a3d7c90f1f        1492.632                  1492.632
# 0002f564f6e3405d859abc0abd6c448e         455.484                   455.484
# 000303ea6e564058a7def8cddeeda1b0         595.816                   595.816
# ...                                          ...                       ...
# fffd925b0d5343ec8ed94789c9587fae         449.936                   449.936
# fffe9e46b22949c48aa2eaffc64b7028         485.088                   485.088
# fffee9233db84b49b5fa6003f8f89366         480.604                   480.604
# ffff2ab265274063bd33d808a0f27dfe         404.880                   404.760
# ffffb0e8e9074c5bad3225e8a1a08ade         377.132                   377.132
#
# key                                                                       EXCEPTION  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                                                NaN
# 00028713c8e04978932ece53e8c94e09                                                NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f  Expected a 2-dimensional container but got <cl...
# 0002f564f6e3405d859abc0abd6c448e            could not convert string to float: 'OG'
# 000303ea6e564058a7def8cddeeda1b0         could not convert string to float: '"SCC"'
# ...                                                                             ...
# fffd925b0d5343ec8ed94789c9587fae                                                NaN
# fffe9e46b22949c48aa2eaffc64b7028         could not convert string to float: '"ML2"'
# fffee9233db84b49b5fa6003f8f89366                                                NaN
# ffff2ab265274063bd33d808a0f27dfe             could not convert string to float: 'A'
# ffffb0e8e9074c5bad3225e8a1a08ade  Expected a 2-dimensional container but got <cl...
#
# key                              Last step finished  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8                NaN
# 00028713c8e04978932ece53e8c94e09                NaN
# 0002f1471a6f4a639bcfd8a3d7c90f1f                NaN
# 0002f564f6e3405d859abc0abd6c448e                NaN
# 000303ea6e564058a7def8cddeeda1b0                NaN
# ...                                             ...
# fffd925b0d5343ec8ed94789c9587fae                NaN
# fffe9e46b22949c48aa2eaffc64b7028                NaN
# fffee9233db84b49b5fa6003f8f89366                NaN
# ffff2ab265274063bd33d808a0f27dfe                NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                NaN
#
# key                                             mlflow.parentRunId  \
# run_uuid
# 0000158194df4bbc83acad810a6126e8  35bc54052da54c98b5c8f43b71499982
# 00028713c8e04978932ece53e8c94e09  5137e2db30a34de0bcb91ab235fccc78
# 0002f1471a6f4a639bcfd8a3d7c90f1f  4b3d5799ec4448719f0a0c5c291eda0c
# 0002f564f6e3405d859abc0abd6c448e  742cb3f363ef47a79da84cc6e4086844
# 000303ea6e564058a7def8cddeeda1b0  67862e364b9e4bf9a3a723cf9fae0873
# ...                                                            ...
# fffd925b0d5343ec8ed94789c9587fae  b879ef07b7274308be2412b2655075e1
# fffe9e46b22949c48aa2eaffc64b7028  8c5ee25a49bc4dd4a8c0f5960653aba4
# fffee9233db84b49b5fa6003f8f89366  c462b7097d5e4812bc69f5eb17bf69f7
# ffff2ab265274063bd33d808a0f27dfe  09a7b833676745ce8fd47a6c5048db70
# ffffb0e8e9074c5bad3225e8a1a08ade  7d3074b2b45142f38aaf137e18a3e6f9
#
# key                              raised_exception
# run_uuid
# 0000158194df4bbc83acad810a6126e8            False
# 00028713c8e04978932ece53e8c94e09            False
# 0002f1471a6f4a639bcfd8a3d7c90f1f             True
# 0002f564f6e3405d859abc0abd6c448e             True
# 000303ea6e564058a7def8cddeeda1b0             True
# ...                                           ...
# fffd925b0d5343ec8ed94789c9587fae            False
# fffe9e46b22949c48aa2eaffc64b7028             True
# fffee9233db84b49b5fa6003f8f89366            False
# ffff2ab265274063bd33d808a0f27dfe             True
# ffffb0e8e9074c5bad3225e8a1a08ade             True
#
# [176969 rows x 58 columns]

# %%
df_runs_raw_2["start_time"] = pd.to_datetime(df_runs_raw_2["start_time"], unit='ms')
df_runs_raw_2 = df_runs_raw_2.loc[df_runs_raw_2["start_time"] > "2025-11-01"] # to filter out old runs

# %%
df_runs_raw_2
# Out:
# key                                 status              start_time  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b  FINISHED 2025-11-06 19:17:27.877
# 00076f100a1b45c48445040322e4623d  FINISHED 2025-11-06 19:51:49.007
# 000c233cf5ac453db6785ebb677e64c2  FINISHED 2025-11-06 18:40:30.894
# 000cdafad08c47e78d0a424e8e135071  FINISHED 2025-11-06 19:22:42.851
# 000fa0cf9759482ba8b3edec3e133db7  FINISHED 2025-11-06 19:07:15.184
# ...                                    ...                     ...
# fff657133e5948e1b4a3deb21a8b2a3f  FINISHED 2025-11-06 19:04:34.537
# fff6a206756f4e0db1836b9c1d7b3ce0  FINISHED 2025-11-06 20:58:54.147
# fff74c1d2e7f48e18880666740b7b23d  FINISHED 2025-11-06 19:48:04.373
# fffc589efa744f54b3378fcda6ccbcfe    FAILED 2025-11-06 11:50:01.603
# fffcef94e6ac428d81db8bf58089f2a2  FINISHED 2025-11-06 19:10:54.512
#
# key                                   end_time best/base_model_kwargs/eps  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b  1.762457e+12                        NaN
# 00076f100a1b45c48445040322e4623d  1.762459e+12                        NaN
# 000c233cf5ac453db6785ebb677e64c2  1.762455e+12                        NaN
# 000cdafad08c47e78d0a424e8e135071  1.762457e+12                        NaN
# 000fa0cf9759482ba8b3edec3e133db7  1.762456e+12                        NaN
# ...                                        ...                        ...
# fff657133e5948e1b4a3deb21a8b2a3f  1.762456e+12                        NaN
# fff6a206756f4e0db1836b9c1d7b3ce0  1.762463e+12                        NaN
# fff74c1d2e7f48e18880666740b7b23d  1.762459e+12                        NaN
# fffc589efa744f54b3378fcda6ccbcfe  1.762430e+12                        NaN
# fffcef94e6ac428d81db8bf58089f2a2  1.762457e+12                        NaN
#
# key                              best/base_model_kwargs/min_samples  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b                                NaN
# 00076f100a1b45c48445040322e4623d                                NaN
# 000c233cf5ac453db6785ebb677e64c2                                NaN
# 000cdafad08c47e78d0a424e8e135071                                NaN
# 000fa0cf9759482ba8b3edec3e133db7                                NaN
# ...                                                             ...
# fff657133e5948e1b4a3deb21a8b2a3f                                NaN
# fff6a206756f4e0db1836b9c1d7b3ce0                                NaN
# fff74c1d2e7f48e18880666740b7b23d                                NaN
# fffc589efa744f54b3378fcda6ccbcfe                                NaN
# fffcef94e6ac428d81db8bf58089f2a2                                NaN
#
# key                              best/base_model_kwargs/n_clusters  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b                               NaN
# 00076f100a1b45c48445040322e4623d                               NaN
# 000c233cf5ac453db6785ebb677e64c2                               NaN
# 000cdafad08c47e78d0a424e8e135071                               NaN
# 000fa0cf9759482ba8b3edec3e133db7                               NaN
# ...                                                            ...
# fff657133e5948e1b4a3deb21a8b2a3f                               NaN
# fff6a206756f4e0db1836b9c1d7b3ce0                               NaN
# fff74c1d2e7f48e18880666740b7b23d                               NaN
# fffc589efa744f54b3378fcda6ccbcfe                               NaN
# fffcef94e6ac428d81db8bf58089f2a2                               NaN
#
# key                              best/base_model_kwargs/n_similarities  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b                                   NaN
# 00076f100a1b45c48445040322e4623d                                   NaN
# 000c233cf5ac453db6785ebb677e64c2                                   NaN
# 000cdafad08c47e78d0a424e8e135071                                   NaN
# 000fa0cf9759482ba8b3edec3e133db7                                   NaN
# ...                                                                ...
# fff657133e5948e1b4a3deb21a8b2a3f                                   NaN
# fff6a206756f4e0db1836b9c1d7b3ce0                                   NaN
# fff74c1d2e7f48e18880666740b7b23d                                   NaN
# fffc589efa744f54b3378fcda6ccbcfe                                   NaN
# fffcef94e6ac428d81db8bf58089f2a2                                   NaN
#
# key                              best/base_model_kwargs/sampling_ratio  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b                                   NaN
# 00076f100a1b45c48445040322e4623d                                   NaN
# 000c233cf5ac453db6785ebb677e64c2                                   NaN
# 000cdafad08c47e78d0a424e8e135071                                   NaN
# 000fa0cf9759482ba8b3edec3e133db7                                   NaN
# ...                                                                ...
# fff657133e5948e1b4a3deb21a8b2a3f                                   NaN
# fff6a206756f4e0db1836b9c1d7b3ce0                                   NaN
# fff74c1d2e7f48e18880666740b7b23d                                   NaN
# fffc589efa744f54b3378fcda6ccbcfe                                   NaN
# fffcef94e6ac428d81db8bf58089f2a2                                   NaN
#
# key                              best/base_model_kwargs/sc_n_clusters  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b                                  NaN
# 00076f100a1b45c48445040322e4623d                                  NaN
# 000c233cf5ac453db6785ebb677e64c2                                  NaN
# 000cdafad08c47e78d0a424e8e135071                                  NaN
# 000fa0cf9759482ba8b3edec3e133db7                                  NaN
# ...                                                               ...
# fff657133e5948e1b4a3deb21a8b2a3f                                  NaN
# fff6a206756f4e0db1836b9c1d7b3ce0                                  NaN
# fff74c1d2e7f48e18880666740b7b23d                                  NaN
# fffc589efa744f54b3378fcda6ccbcfe                                  NaN
# fffcef94e6ac428d81db8bf58089f2a2                                  NaN
#
# key                              best/child_run_id  ... best/rand_score  \
# run_uuid                                            ...
# 00076ddeca7b47d98725ca5d9b55540b               NaN  ...             NaN
# 00076f100a1b45c48445040322e4623d               NaN  ...             NaN
# 000c233cf5ac453db6785ebb677e64c2               NaN  ...             NaN
# 000cdafad08c47e78d0a424e8e135071               NaN  ...             NaN
# 000fa0cf9759482ba8b3edec3e133db7               NaN  ...             NaN
# ...                                            ...  ...             ...
# fff657133e5948e1b4a3deb21a8b2a3f               NaN  ...             NaN
# fff6a206756f4e0db1836b9c1d7b3ce0               NaN  ...             NaN
# fff74c1d2e7f48e18880666740b7b23d               NaN  ...             NaN
# fffc589efa744f54b3378fcda6ccbcfe               NaN  ...             NaN
# fffcef94e6ac428d81db8bf58089f2a2               NaN  ...             NaN
#
# key                              best/silhouette best/v_measure  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b             NaN            NaN
# 00076f100a1b45c48445040322e4623d             NaN            NaN
# 000c233cf5ac453db6785ebb677e64c2             NaN            NaN
# 000cdafad08c47e78d0a424e8e135071             NaN            NaN
# 000fa0cf9759482ba8b3edec3e133db7             NaN            NaN
# ...                                          ...            ...
# fff657133e5948e1b4a3deb21a8b2a3f             NaN            NaN
# fff6a206756f4e0db1836b9c1d7b3ce0             NaN            NaN
# fff74c1d2e7f48e18880666740b7b23d             NaN            NaN
# fffc589efa744f54b3378fcda6ccbcfe             NaN            NaN
# fffcef94e6ac428d81db8bf58089f2a2             NaN            NaN
#
# key                              fit_model_return_elapsed_time  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b                      0.476819
# 00076f100a1b45c48445040322e4623d                      0.480747
# 000c233cf5ac453db6785ebb677e64c2                      1.535595
# 000cdafad08c47e78d0a424e8e135071                      0.547577
# 000fa0cf9759482ba8b3edec3e133db7                      2.494779
# ...                                                        ...
# fff657133e5948e1b4a3deb21a8b2a3f                      1.710222
# fff6a206756f4e0db1836b9c1d7b3ce0                      2.179803
# fff74c1d2e7f48e18880666740b7b23d                      6.059326
# fffc589efa744f54b3378fcda6ccbcfe                           NaN
# fffcef94e6ac428d81db8bf58089f2a2                      1.535813
#
# key                              max_memory_used max_memory_used_after_fit  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b         448.860                   448.860
# 00076f100a1b45c48445040322e4623d         602.064                   602.064
# 000c233cf5ac453db6785ebb677e64c2         467.380                   467.380
# 000cdafad08c47e78d0a424e8e135071         379.724                   379.724
# 000fa0cf9759482ba8b3edec3e133db7         467.056                   467.056
# ...                                          ...                       ...
# fff657133e5948e1b4a3deb21a8b2a3f         464.168                   464.168
# fff6a206756f4e0db1836b9c1d7b3ce0         415.036                   415.036
# fff74c1d2e7f48e18880666740b7b23d         372.436                   372.436
# fffc589efa744f54b3378fcda6ccbcfe         359.500                       NaN
# fffcef94e6ac428d81db8bf58089f2a2         446.140                   446.140
#
# key                                               EXCEPTION  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b                        NaN
# 00076f100a1b45c48445040322e4623d                        NaN
# 000c233cf5ac453db6785ebb677e64c2                        NaN
# 000cdafad08c47e78d0a424e8e135071                        NaN
# 000fa0cf9759482ba8b3edec3e133db7                        NaN
# ...                                                     ...
# fff657133e5948e1b4a3deb21a8b2a3f                        NaN
# fff6a206756f4e0db1836b9c1d7b3ce0                        NaN
# fff74c1d2e7f48e18880666740b7b23d                        NaN
# fffc589efa744f54b3378fcda6ccbcfe  kth(=3) out of bounds (3)
# fffcef94e6ac428d81db8bf58089f2a2                        NaN
#
# key                              Last step finished  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b      _on_train_end
# 00076f100a1b45c48445040322e4623d      _on_train_end
# 000c233cf5ac453db6785ebb677e64c2      _on_train_end
# 000cdafad08c47e78d0a424e8e135071      _on_train_end
# 000fa0cf9759482ba8b3edec3e133db7      _on_train_end
# ...                                             ...
# fff657133e5948e1b4a3deb21a8b2a3f      _on_train_end
# fff6a206756f4e0db1836b9c1d7b3ce0      _on_train_end
# fff74c1d2e7f48e18880666740b7b23d      _on_train_end
# fffc589efa744f54b3378fcda6ccbcfe  _before_fit_model
# fffcef94e6ac428d81db8bf58089f2a2      _on_train_end
#
# key                                             mlflow.parentRunId  \
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b  7efea00adc674d8784479417e9e429f0
# 00076f100a1b45c48445040322e4623d  553d6499305a48bfadfe5c78651cca55
# 000c233cf5ac453db6785ebb677e64c2  d89d4f7095c64f9db665822c8597f06c
# 000cdafad08c47e78d0a424e8e135071  e315e659a4b045d29de7aa2459943764
# 000fa0cf9759482ba8b3edec3e133db7  ea2ee81c7795407b8fa8cfb164327cd9
# ...                                                            ...
# fff657133e5948e1b4a3deb21a8b2a3f  0019c00fbd4243f79f5c61c50650227f
# fff6a206756f4e0db1836b9c1d7b3ce0  f3d4d5af78864b27a73b0091d2791fb9
# fff74c1d2e7f48e18880666740b7b23d  b9fdde667dc94d82a939ca8512da2f2b
# fffc589efa744f54b3378fcda6ccbcfe  bff12221a1684a2f88776ab5859934c6
# fffcef94e6ac428d81db8bf58089f2a2  03bdd5ab04664a3b87b9e67923b842b2
#
# key                              raised_exception
# run_uuid
# 00076ddeca7b47d98725ca5d9b55540b            False
# 00076f100a1b45c48445040322e4623d            False
# 000c233cf5ac453db6785ebb677e64c2            False
# 000cdafad08c47e78d0a424e8e135071            False
# 000fa0cf9759482ba8b3edec3e133db7            False
# ...                                           ...
# fff657133e5948e1b4a3deb21a8b2a3f            False
# fff6a206756f4e0db1836b9c1d7b3ce0            False
# fff74c1d2e7f48e18880666740b7b23d            False
# fffc589efa744f54b3378fcda6ccbcfe             True
# fffcef94e6ac428d81db8bf58089f2a2            False
#
# [39222 rows x 58 columns]

# %%
df_runs_raw = pd.concat([df_runs_raw_1, df_runs_raw_2], axis=0)
df_runs_raw = df_runs_raw.join(dataset_characteristics, on="dataset_id", rsuffix="_dataset")
df_runs_raw.to_csv(results_dir / 'df_runs_raw_cer_tgcc.csv', index=True)

# %%
df_runs_raw = pd.read_csv(results_dir / "df_runs_raw_cer_tgcc.csv", index_col=0, low_memory=False)
df_runs_raw["model"] = df_runs_raw["model"] + "-" + df_runs_raw["n_trials"].astype(int).astype(str)
df_runs_raw_parents = df_runs_raw.copy()
df_runs_raw_parents = df_runs_raw_parents.loc[df_runs_raw_parents["mlflow.parentRunId"].isna()]

# %%
df_runs_raw_parents.head(5)
# Out:
#                                     status     start_time      end_time  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea  FINISHED  1757511120768  1.757511e+12
# 00027aa26863479689cb9159eb05d27d  FINISHED  1759251752094  1.759254e+12
# 000ed0a4c2254d48a2ea293ecf9480b9  FINISHED  1761159995601  1.761160e+12
# 0016b21b09e44c7595b26130cbf448f9  FINISHED  1757524956961  1.757525e+12
# 001b3f77c3e44c12b14761e15c808ec9  FINISHED  1757510889568  1.757511e+12
#
#                                   best/base_model_kwargs/eps  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                         NaN
# 00027aa26863479689cb9159eb05d27d                         NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                         NaN
# 0016b21b09e44c7595b26130cbf448f9                         NaN
# 001b3f77c3e44c12b14761e15c808ec9                         NaN
#
#                                   best/base_model_kwargs/min_samples  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                 NaN
# 00027aa26863479689cb9159eb05d27d                                 NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                 NaN
# 0016b21b09e44c7595b26130cbf448f9                                 NaN
# 001b3f77c3e44c12b14761e15c808ec9                                 NaN
#
#                                   best/base_model_kwargs/n_clusters  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                NaN
# 00027aa26863479689cb9159eb05d27d                               21.0
# 000ed0a4c2254d48a2ea293ecf9480b9                                NaN
# 0016b21b09e44c7595b26130cbf448f9                                3.0
# 001b3f77c3e44c12b14761e15c808ec9                                NaN
#
#                                   best/base_model_kwargs/n_similarities  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                    NaN
# 00027aa26863479689cb9159eb05d27d                                    NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                    NaN
# 0016b21b09e44c7595b26130cbf448f9                                    NaN
# 001b3f77c3e44c12b14761e15c808ec9                                    NaN
#
#                                   best/base_model_kwargs/sampling_ratio  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                    NaN
# 00027aa26863479689cb9159eb05d27d                                    NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                    NaN
# 0016b21b09e44c7595b26130cbf448f9                                    NaN
# 001b3f77c3e44c12b14761e15c808ec9                                    NaN
#
#                                   best/base_model_kwargs/sc_n_clusters  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                   NaN
# 00027aa26863479689cb9159eb05d27d                                   NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                   NaN
# 0016b21b09e44c7595b26130cbf448f9                                   NaN
# 001b3f77c3e44c12b14761e15c808ec9                                   NaN
#
#                                                  best/child_run_id  ...  \
# run_uuid                                                            ...
# 0001f124c40c40b6b902fcabc76e7eea  c854172d93d945b5b98d1d2e7f8b8244  ...
# 00027aa26863479689cb9159eb05d27d  c968bd4c602b4cc1b80ea7ebf3ef514a  ...
# 000ed0a4c2254d48a2ea293ecf9480b9  775080a847654e7885ed3003bbb9d622  ...
# 0016b21b09e44c7595b26130cbf448f9  318c5fee63ac48ee93c0f8897a15e567  ...
# 001b3f77c3e44c12b14761e15c808ec9  c3df07fdb54f487a922cb765d3b9c0a7  ...
#
#                                   EXCEPTION  Last step finished  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea        NaN                 NaN
# 00027aa26863479689cb9159eb05d27d        NaN                 NaN
# 000ed0a4c2254d48a2ea293ecf9480b9        NaN       _on_train_end
# 0016b21b09e44c7595b26130cbf448f9        NaN                 NaN
# 001b3f77c3e44c12b14761e15c808ec9        NaN                 NaN
#
#                                   mlflow.parentRunId  raised_exception  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                 NaN             False
# 00027aa26863479689cb9159eb05d27d                 NaN             False
# 000ed0a4c2254d48a2ea293ecf9480b9                 NaN             False
# 0016b21b09e44c7595b26130cbf448f9                 NaN             False
# 001b3f77c3e44c12b14761e15c808ec9                 NaN             False
#
#                                         dataset  openml_id  n_instances  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea           iris         61          150
# 00027aa26863479689cb9159eb05d27d      mnist_784        554        70000
# 000ed0a4c2254d48a2ea293ecf9480b9        nursery       1568        12958
# 0016b21b09e44c7595b26130cbf448f9  golub-1999-v2      46780           72
# 001b3f77c3e44c12b14761e15c808ec9          ecoli         39          336
#
#                                   n_features  n_classes  n_categorical
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea           5          3              1
# 00027aa26863479689cb9159eb05d27d         785         10              1
# 000ed0a4c2254d48a2ea293ecf9480b9           9          4              9
# 0016b21b09e44c7595b26130cbf448f9        1869          3              0
# 001b3f77c3e44c12b14761e15c808ec9           8          8              1
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Delete duplicate runs (if any) and complete some models that cannot run with some datasets

# %%
non_duplicate_columns = [
    "model",
    "dataset_id",
	"standardize",
	"hpo_metric",
	"hpo_seed",
]
# df_runs_parents.loc[df_runs_parents["best/n_clusters_"]*0.5 > df_runs_parents["n_instances"], "best/adjusted_rand"] = 
df_runs_parents = df_runs_raw_parents.dropna(axis=0, how="all", subset=["best/adjusted_rand"]).copy()
# add back runs that were not evaluated because we judged too many clusters (but they run anyway)
# df_valid_runs = df_runs_raw_parents.loc[df_runs_raw_parents["best/n_clusters_"] > df_runs_raw_parents["n_instances"]*0.5].copy()
# df_runs_parents = pd.concat([df_runs_parents, df_valid_runs], axis=0)
df_runs_parents = df_runs_parents.loc[(~df_runs_parents.duplicated(non_duplicate_columns))]
# fill missing values with "None"
df_runs_parents = df_runs_parents.fillna("None")

# %%
# get number of children runs that raised exception for each parent run
children_exceptions = df_runs_raw.groupby("mlflow.parentRunId")["raised_exception"].sum()
df_runs_parents["n_children_raised_exception"] = df_runs_parents.index.map(children_exceptions).fillna(0)

# %%
df_runs_parents.loc[(df_runs_parents["n_children_raised_exception"] > 0) & (df_runs_parents["raised_exception"] == False) & (df_runs_parents["model"].str.find("SC-SRGF") == -1), ["dataset_id", "model", "hpo_metric", "n_children_raised_exception"]]
# Out:
#                                   dataset_id                 model  \
# run_uuid
# 0523d99695664a3294fa128a1eae79af         554      CoHiRF-DBSCAN-60
# 075cbb1e8b9f41a0b1b1cb54ff6673af          39    CoHiRF-top-down-60
# 08433992474241cdbe44aca2692cd7df         554      CoHiRF-DBSCAN-60
# 086989a27cdb467b85ed2248ce8b32d3         554      CoHiRF-DBSCAN-60
# 0abf67098276481cabbcb002ae6bdf84        1568    CoHiRF-top-down-60
# ...                                      ...                   ...
# f7504ad3ccad429e82fb12541282747b       40685    CoHiRF-top-down-60
# f84f03dfb6964911a05142a3072c699f        1568    CoHiRF-top-down-60
# fa554932b2f842d6833bc8331388e3f7       47039  BatchCoHiRF-1iter-60
# fe81e6a0ceac403db992df84e6e5d682          39    CoHiRF-top-down-60
# fe849da24195456587a6ea02aab9a0f3        1568    CoHiRF-top-down-60
#
#                                                hpo_metric  \
# run_uuid
# 0523d99695664a3294fa128a1eae79af  calinski_harabasz_score
# 075cbb1e8b9f41a0b1b1cb54ff6673af     davies_bouldin_score
# 08433992474241cdbe44aca2692cd7df     davies_bouldin_score
# 086989a27cdb467b85ed2248ce8b32d3  calinski_harabasz_score
# 0abf67098276481cabbcb002ae6bdf84  calinski_harabasz_score
# ...                                                   ...
# f7504ad3ccad429e82fb12541282747b  calinski_harabasz_score
# f84f03dfb6964911a05142a3072c699f     adjusted_mutual_info
# fa554932b2f842d6833bc8331388e3f7            adjusted_rand
# fe81e6a0ceac403db992df84e6e5d682     davies_bouldin_score
# fe849da24195456587a6ea02aab9a0f3               silhouette
#
#                                   n_children_raised_exception
# run_uuid
# 0523d99695664a3294fa128a1eae79af                            9
# 075cbb1e8b9f41a0b1b1cb54ff6673af                            4
# 08433992474241cdbe44aca2692cd7df                            2
# 086989a27cdb467b85ed2248ce8b32d3                            8
# 0abf67098276481cabbcb002ae6bdf84                            2
# ...                                                       ...
# f7504ad3ccad429e82fb12541282747b                            1
# f84f03dfb6964911a05142a3072c699f                            3
# fa554932b2f842d6833bc8331388e3f7                            7
# fe81e6a0ceac403db992df84e6e5d682                            4
# fe849da24195456587a6ea02aab9a0f3                            1
#
# [164 rows x 4 columns]

# %%
df_to_cat = []
hpo_metrics = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    "silhouette",
    "davies_bouldin_score",
    "normalized_mutual_info",
]
standardize = [True]
hpo_seed = [i for i in range(5)]
fill_value = pd.NA
fill_columns = ["best/adjusted_rand", "best/adjusted_mutual_info", "best/calinski_harabasz_score", "best/silhouette", "best/davies_bouldin_score", "best/normalized_mutual_info"]

# %%
# Too memory intensive
dataset_ids_to_complete = [182, 554, 1478, 1568, 40685]
model_names = [
    "CoHiRF-SC-SRGF-60",
    "CoHiRF-SC-SRGF-top-down-60",
    "CoHiRF-SC-SRGF-top-down-inv-60",
    "SpectralSubspaceRandomization-60",
    "CoHiRF-SC-SRGF-1R-60",
    "CoHiRF-SC-SRGF-top-down-1R-60",
    "CoHiRF-SC-SRGF-top-down-inv-1R-60",
    "CoHiRF-SC-SRGF-2R-60",
    "CoHiRF-SC-SRGF-top-down-2R-60",
	"CoHiRF-SC-SRGF-top-down-inv-2R-60",
]
for dataset_id in dataset_ids_to_complete:
    for model_name in model_names:
        for hpo_metric in hpo_metrics:
            for std in standardize:
                for seed in hpo_seed:
                    new_row = {
						"dataset_id": dataset_id,
						"model": model_name,
						"hpo_metric": hpo_metric,
						"standardize": std,
						"hpo_seed": seed
					}
                    for col in fill_columns:
                        new_row[col] = fill_value
                    df_to_cat.append(new_row)

# %%
# # Too few examples (<100) to run in batch
# dataset_ids_to_complete = [46773, 46774, 46775, 46776, 46777, 46779, 46780, 46781]
# model_names = [
#     "BatchCoHiRF-1iter-30",
#     "BatchCoHiRF-DBSCAN-1iter-30",
#     "BatchCoHiRF-SC-SRGF-30",
#     "BatchCoHiRF-KernelRBF-1iter-30",
#     "BatchCoHiRF-1iter-60",
# 	"BatchCoHiRF-DBSCAN-1iter-60",
# 	# "BatchCoHiRF-SC-SRGF-60",
# 	# "BatchCoHiRF-KernelRBF-1iter-60",
# ]
# for dataset_id in dataset_ids_to_complete:
# 	for model_name in model_names:
# 		for hpo_metric in hpo_metrics:
# 			for std in standardize:
# 				mask = (df_runs_parents["dataset_id"] == dataset_id) & (df_runs_parents["model"] == model_name) & (df_runs_parents["hpo_metric"] == hpo_metric) & (df_runs_parents["standardize"] == std)
# 				if not mask.any():
# 					new_row = {
# 						"dataset_id": dataset_id,
# 						"model": model_name,
# 						"hpo_metric": hpo_metric,
# 						"standardize": std,
# 					}
# 					for col in fill_columns:
# 						new_row[col] = fill_value
# 					df_to_cat.append(new_row)

# %%
# # Too many examples for IRFLLRR
# dataset_ids_to_complete = [40685]
# model_names = [
#     "IRFLLRR-30",
#     "IRFLLRR-60",
# ]
# hpo_metrics = ["adjusted_rand", "adjusted_mutual_info", "calinski_harabasz_score", "silhouette", "davies_bouldin_score", "normalized_mutual_info"]
# standardize = [True]
# fill_value = pd.NA
# fill_columns = ["best/adjusted_rand", "best/adjusted_mutual_info", "best/calinski_harabasz_score", "best/silhouette", "best/davies_bouldin_score", "best/normalized_mutual_info"]
# for dataset_id in dataset_ids_to_complete:
#     for model_name in model_names:
#         for hpo_metric in hpo_metrics:
#             for std in standardize:
#                 mask = (
#                     (df_runs_parents["dataset_id"] == dataset_id)
#                     & (df_runs_parents["model"] == model_name)
#                     & (df_runs_parents["hpo_metric"] == hpo_metric)
#                     & (df_runs_parents["standardize"] == std)
#                 )
#                 if not mask.any():
#                     new_row = {
#                         "dataset_id": dataset_id,
#                         "model": model_name,
#                         "hpo_metric": hpo_metric,
#                         "standardize": std,
#                     }
#                     for col in fill_columns:
#                         new_row[col] = fill_value
#                     df_to_cat.append(new_row)

# %%
df_runs_parents = pd.concat([df_runs_parents, pd.DataFrame(df_to_cat)], axis=0)

# %% [markdown]
# # Missing

# %%
model_nickname = df_runs_parents['model'].unique().tolist()
model_nickname.sort()
model_nickname
# Out:
# ['BatchCoHiRF-1iter-60',
#  'BatchCoHiRF-1iter-random-60',
#  'BatchCoHiRF-1iter-stratified-60',
#  'BatchCoHiRF-60',
#  'BatchCoHiRF-DBSCAN-1iter-60',
#  'BatchCoHiRF-DBSCAN-1iter-random-60',
#  'BatchCoHiRF-DBSCAN-1iter-stratified-60',
#  'BatchCoHiRF-KernelRBF-1iter-60',
#  'BatchCoHiRF-KernelRBF-1iter-random-60',
#  'BatchCoHiRF-KernelRBF-1iter-stratified-60',
#  'BatchCoHiRF-SC-SRGF-1iter-60',
#  'BatchCoHiRF-SC-SRGF-2-60',
#  'CoHiRF-1000-60',
#  'CoHiRF-60',
#  'CoHiRF-DBSCAN-60',
#  'CoHiRF-KernelRBF-60',
#  'CoHiRF-SC-SRGF-1R-60',
#  'CoHiRF-SC-SRGF-2R-60',
#  'CoHiRF-SC-SRGF-60',
#  'CoHiRF-SC-SRGF-top-down-1R-60',
#  'CoHiRF-SC-SRGF-top-down-2R-60',
#  'CoHiRF-SC-SRGF-top-down-60',
#  'CoHiRF-SC-SRGF-top-down-inv-1R-60',
#  'CoHiRF-SC-SRGF-top-down-inv-2R-60',
#  'CoHiRF-SC-SRGF-top-down-inv-60',
#  'CoHiRF-top-down-60',
#  'CoHiRF-top-down-inv-60',
#  'DBSCAN-60',
#  'KMeans-60',
#  'KernelRBFKMeans-60',
#  'SpectralSubspaceRandomization-60']

# %%
non_duplicate_columns = [
	"model",
	"dataset_id",
	"standardize",
	"hpo_metric",
	"hpo_seed",
]

# %%
model_nickname = [
    "BatchCoHiRF-1iter-60",
    # "BatchCoHiRF-1iter-random-60",
    # "BatchCoHiRF-1iter-stratified-60",
    "BatchCoHiRF-DBSCAN-1iter-60",
    # "BatchCoHiRF-DBSCAN-1iter-random-60",
    # "BatchCoHiRF-DBSCAN-1iter-stratified-60",
    "BatchCoHiRF-KernelRBF-1iter-60",
    # "BatchCoHiRF-KernelRBF-1iter-random-60",
    # "BatchCoHiRF-KernelRBF-1iter-stratified-60",
    "BatchCoHiRF-SC-SRGF-1iter-60",
    # "BatchCoHiRF-SC-SRGF-1iter-random-60",
    # "BatchCoHiRF-SC-SRGF-1iter-stratified-60",
    # "BatchCoHiRF-SC-SRGF-2-60",
    "CoHiRF-60",
    "CoHiRF-top-down-60",
    "CoHiRF-top-down-inv-60",
    # "CoHiRF-1000-60",
    "CoHiRF-DBSCAN-60",
    "CoHiRF-DBSCAN-top-down-60",
    "CoHiRF-DBSCAN-top-down-inv-60",
    "CoHiRF-KernelRBF-60",
	"CoHiRF-KernelRBF-top-down-60",
    "CoHiRF-KernelRBF-top-down-inv-60",
    "CoHiRF-SC-SRGF-60",
    "CoHiRF-SC-SRGF-1R-60",
    "CoHiRF-SC-SRGF-1R-top-down-60",
    "CoHiRF-SC-SRGF-1R-top-down-inv-60",
    "DBSCAN-60",
    "KMeans-60",
    "KernelRBFKMeans-60",
    "SpectralSubspaceRandomization-60",
]
dataset_id = [
    39,
    61,
    182,
    1478,
    1568,
    40685,
    40984,
    46773,
    46774,
    46775,
    46776,
    46777,
    46778,
    46779,
    46780,
    46781,
    46782,
    46783,
    554,
    # 1110,
    # 47039
]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    # "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    # "davies_bouldin_score",
    "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
#                                   model  dataset_id  standardize  \
# 0             CoHiRF-DBSCAN-top-down-60          39         True
# 1             CoHiRF-DBSCAN-top-down-60          39         True
# 2             CoHiRF-DBSCAN-top-down-60          39         True
# 3             CoHiRF-DBSCAN-top-down-60          39         True
# 4             CoHiRF-DBSCAN-top-down-60          39         True
# ...                                 ...         ...          ...
# 1750  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 1751  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 1752  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 1753  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 1754  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
#
#          hpo_metric  hpo_seed
# 0     adjusted_rand         0
# 1     adjusted_rand         1
# 2     adjusted_rand         2
# 3     adjusted_rand         3
# 4     adjusted_rand         4
# ...             ...       ...
# 1750     silhouette         0
# 1751     silhouette         1
# 1752     silhouette         2
# 1753     silhouette         3
# 1754     silhouette         4
#
# [1755 rows x 5 columns]

# %%
model_nickname = [
    "BatchCoHiRF-1iter-60",
    # "BatchCoHiRF-1iter-random-60",
    # "BatchCoHiRF-1iter-stratified-60",
    "BatchCoHiRF-DBSCAN-1iter-60",
    # "BatchCoHiRF-DBSCAN-1iter-random-60",
    # "BatchCoHiRF-DBSCAN-1iter-stratified-60",
    "BatchCoHiRF-KernelRBF-1iter-60",
    # "BatchCoHiRF-KernelRBF-1iter-random-60",
    # "BatchCoHiRF-KernelRBF-1iter-stratified-60",
    "BatchCoHiRF-SC-SRGF-1iter-60",
    # "BatchCoHiRF-SC-SRGF-1iter-random-60",
    # "BatchCoHiRF-SC-SRGF-1iter-stratified-60",
    # "BatchCoHiRF-SC-SRGF-2-60",
    "CoHiRF-60",
    "CoHiRF-top-down-60",
    "CoHiRF-top-down-inv-60",
    # "CoHiRF-1000-60",
    "CoHiRF-DBSCAN-60",
    "CoHiRF-KernelRBF-60",
    "CoHiRF-SC-SRGF-60",
    "DBSCAN-60",
    "KMeans-60",
    "KernelRBFKMeans-60",
    "SpectralSubspaceRandomization-60",
]
dataset_id = [
    39,
    61,
    182,
    1478,
    1568,
    40685,
    40984,
    46773,
    46774,
    46775,
    46776,
    46777,
    46778,
    46779,
    46780,
    46781,
    46782,
    46783,
    554,
    # 1110,
    # 47039
]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    "davies_bouldin_score",
    "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
# Empty DataFrame
# Columns: [model, dataset_id, standardize, hpo_metric, hpo_seed]
# Index: []

# %%
model_nickname = [
    "CoHiRF-1000-60",
]
dataset_id = [
    182,
    1478,
    1568,
    40685,
    40984,
    46782,
    46783,
    554,
]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    "davies_bouldin_score",
    "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
# Empty DataFrame
# Columns: [model, dataset_id, standardize, hpo_metric, hpo_seed]
# Index: []

# %%
model_nickname = [
    "BatchCoHiRF-1iter-60",
    # "BatchCoHiRF-1iter-random-60",
    # "BatchCoHiRF-1iter-stratified-60",
    "BatchCoHiRF-DBSCAN-1iter-60",
    # "BatchCoHiRF-DBSCAN-1iter-random-60",
    # "BatchCoHiRF-DBSCAN-1iter-stratified-60",
    "BatchCoHiRF-KernelRBF-1iter-60",
    # "BatchCoHiRF-KernelRBF-1iter-random-60",
    # "BatchCoHiRF-KernelRBF-1iter-stratified-60",
    "BatchCoHiRF-SC-SRGF-1iter-60",
    # "BatchCoHiRF-SC-SRGF-1iter-random-60",
    # "BatchCoHiRF-SC-SRGF-1iter-stratified-60",
    # "BatchCoHiRF-SC-SRGF-2-60",
    # "CoHiRF-60",
    # "CoHiRF-1000-60",
    # "CoHiRF-DBSCAN-60",
    # "CoHiRF-KernelRBF-60",
    # "CoHiRF-SC-SRGF-60",
    # "DBSCAN-60",
    "KMeans-60",
    # "KernelRBFKMeans-60",
    # "SpectralSubspaceRandomization-60",
]
dataset_id = [47039]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    # "davies_bouldin_score",
    # "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
#                            model  dataset_id  standardize  \
# 0   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 1   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 2   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 3   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 4   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 5   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 6   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 7   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 8   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 9   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 10  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 11  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 12  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 13  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 14  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
#
#                  hpo_metric  hpo_seed
# 0             adjusted_rand         0
# 1             adjusted_rand         1
# 2             adjusted_rand         2
# 3             adjusted_rand         3
# 4             adjusted_rand         4
# 5      adjusted_mutual_info         0
# 6      adjusted_mutual_info         1
# 7      adjusted_mutual_info         2
# 8      adjusted_mutual_info         3
# 9      adjusted_mutual_info         4
# 10  calinski_harabasz_score         0
# 11  calinski_harabasz_score         1
# 12  calinski_harabasz_score         2
# 13  calinski_harabasz_score         3
# 14  calinski_harabasz_score         4

# %%
model_nickname = ["CoHiRF-SC-SRGF-1R-60", "CoHiRF-SC-SRGF-2R-60", "CoHiRF-SC-SRGF-60", "SpectralSubspaceRandomization-60"]
dataset_id = [
    39,
    61,
    46773,
    46774,
    46775,
    46776,
    46777,
    46778,
    46779,
    46780,
    46781,
]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    "davies_bouldin_score",
    "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
#                   model  dataset_id  standardize     hpo_metric  hpo_seed
# 0  CoHiRF-SC-SRGF-2R-60          39         True  adjusted_rand         2

# %%
# Join df_runs_raw_parents into df_missing using non_duplicate_columns to get the EXCEPTION column
df_missing_with_exception = df_missing.merge(
    df_runs_raw_parents[non_duplicate_columns + ["raised_exception", "EXCEPTION", "Last step finished"]],
    how="left",
    left_on=["model", "dataset_id", "standardize", "hpo_metric", "hpo_seed"],
    right_on=["model", "dataset_id", "standardize", "hpo_metric", "hpo_seed"],
)
df_missing_with_exception[
    [
        "model",
        "dataset_id",
        "standardize",
        "hpo_metric",
        "hpo_seed",
        "raised_exception",
        "EXCEPTION",
        "Last step finished",
    ]
]
# Out:
#                                   model  dataset_id  standardize  \
# 0             CoHiRF-DBSCAN-top-down-60          39         True
# 1             CoHiRF-DBSCAN-top-down-60          39         True
# 2             CoHiRF-DBSCAN-top-down-60          39         True
# 3             CoHiRF-DBSCAN-top-down-60          39         True
# 4             CoHiRF-DBSCAN-top-down-60          39         True
# ...                                 ...         ...          ...
# 2920  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 2921  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 2922  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 2923  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
# 2924  CoHiRF-SC-SRGF-1R-top-down-inv-60         554         True
#
#          hpo_metric  hpo_seed raised_exception EXCEPTION Last step finished
# 0     adjusted_rand         0              NaN       NaN                NaN
# 1     adjusted_rand         1              NaN       NaN                NaN
# 2     adjusted_rand         2              NaN       NaN                NaN
# 3     adjusted_rand         3              NaN       NaN                NaN
# 4     adjusted_rand         4              NaN       NaN                NaN
# ...             ...       ...              ...       ...                ...
# 2920     silhouette         0              NaN       NaN                NaN
# 2921     silhouette         1              NaN       NaN                NaN
# 2922     silhouette         2              NaN       NaN                NaN
# 2923     silhouette         3              NaN       NaN                NaN
# 2924     silhouette         4              NaN       NaN                NaN
#
# [2925 rows x 8 columns]

# %%
df_missing_dict = df_missing.copy()
# get only rows from high_mem_tuples
# df_missing_dict = df_missing_dict.merge(high_mem_tuples, on=["model", "dataset_id"], how="left", indicator=True)
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "both"].drop(columns="_merge")
# exclude rows that are in missing_ari_tuples
# df_missing_dict = df_missing_dict.merge(
# 	missing_ari_tuples, on=["model", "dataset_id"], how="left", indicator=True
# )|
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "left_only"].drop(columns="_merge")
# exclude rows that are in high_mem_tuples
# df_missing_dict = df_missing_dict.merge(
# 	high_mem_tuples, on=["model", "dataset_id"], how="left", indicator=True
# )
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "left_only"].drop(columns="_merge")
# to_drop = pd.concat([missing_ari_tuples, high_mem_tuples], ignore_index=True)
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "left_only"].drop(columns="_merge")

# %%
# get rid of -60
df_missing_dict["model"] = df_missing_dict["model"].str.replace("-60", "")
df_missing_dict["seed_dataset_order"] = df_missing_dict["hpo_seed"]
df_missing_dict = df_missing_dict.loc[~df_missing_dict["dataset_id"].isin([46782, 46783, 1478, 1568, 40984, 40685])]
df_missing_dict.to_csv(results_dir / "df_missing_dict.csv", index=False)

# %%
df_missing_dict
# Out:
#                                model  dataset_id  standardize     hpo_metric  \
# 0             CoHiRF-DBSCAN-top-down          39         True  adjusted_rand
# 1             CoHiRF-DBSCAN-top-down          39         True  adjusted_rand
# 2             CoHiRF-DBSCAN-top-down          39         True  adjusted_rand
# 3             CoHiRF-DBSCAN-top-down          39         True  adjusted_rand
# 4             CoHiRF-DBSCAN-top-down          39         True  adjusted_rand
# ...                              ...         ...          ...            ...
# 1750  CoHiRF-SC-SRGF-1R-top-down-inv         554         True     silhouette
# 1751  CoHiRF-SC-SRGF-1R-top-down-inv         554         True     silhouette
# 1752  CoHiRF-SC-SRGF-1R-top-down-inv         554         True     silhouette
# 1753  CoHiRF-SC-SRGF-1R-top-down-inv         554         True     silhouette
# 1754  CoHiRF-SC-SRGF-1R-top-down-inv         554         True     silhouette
#
#       hpo_seed  seed_dataset_order
# 0            0                   0
# 1            1                   1
# 2            2                   2
# 3            3                   3
# 4            4                   4
# ...        ...                 ...
# 1750         0                   0
# 1751         1                   1
# 1752         2                   2
# 1753         3                   3
# 1754         4                   4
#
# [1170 rows x 6 columns]

# %% [markdown]
# # Tables

# %%
def get_parameters_string(row):
    parameter_names = {
		"best/alpha": "\\alpha",
		"best/avg_dims": "d",
		"best/base_model_kwargs/eps": "\\epsilon",
		"best/base_model_kwargs/min_samples": "n_{\\text{min}}",
		"best/base_model_kwargs/n_clusters": "C",
		"best/c": "c",
		"best/cohirf_kwargs/base_model_kwargs/eps": "\\epsilon",
		"best/cohirf_kwargs/base_model_kwargs/min_samples": "n_{\\text{min}}",
		"best/cohirf_kwargs/kmeans_n_clusters": "C",
		"best/cohirf_kwargs/n_features": "q",
		"best/cohirf_kwargs/repetitions": "R",
		"best/damping": "\\lambda",
		# "best/density_threshold": "\\tau",
		"best/eps": "\\epsilon",
		"best/kmeans_n_clusters": "C",
		"best/lambda_": "\\lambda",
		"best/min_bin_freq": "bin_{\\text{min}}",
		"best/min_cluster_size": "C_{\\text{min}}",
		"best/min_samples": "n_{\\text{min}}",
		"best/n_clusters": "C",
		"best/n_features": "q",
		# "best/n_partitions": "P",
		"best/n_similarities": "m",
		"best/p": "p",
		"best/repetitions": "R",
		"best/sampling_ratio": "r",
		"best/sc_n_clusters": "C",
		"best/transform_kwargs/gamma": "\\gamma",
	}
    first = True
    str = ""
    for p in parameter_names.keys():
        if not pd.isna(row[p]) and row[p] != "None":
            if not first:
                str += "; "
            else:
                first = False
            value = float(row[p])
            if value.is_integer():
                value = int(value)
                str += f"${parameter_names[p]}={value}$"
            else:
                str += f"${parameter_names[p]}={value:0.2f}$"
    return str

# %%
def highlight_max(df, column_name, level=0):
    df_column = df[column_name]
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_highlighted] = 'font-weight: bold'
    return df_css

# %%
def highlight_min(df, column_name, level=0):
    df_column = df[column_name]
    min_values = df_column.groupby(level=level).transform("min")
    is_highlighted = df_column.round(3) == min_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ""
    df_css[is_highlighted] = "font-weight: bold"
    return df_css

# %%
def highlight_max_index(series_index, df_column, level=0):
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css[:] = ''
    series_css[is_highlighted.values] = 'font-weight: bold'
    return series_css

# %%
def underline_2nd_max(df, column_name, level=0):
    df_column = df[column_name]
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.round(3).drop_duplicates().nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_underlined] = 'underline: --latex--rwrap'
    return df_css

# %%
def underline_2nd_min(df, column_name, level=0):
    df_column = df[column_name]
    # get the second min value
    second_min_values = df_column.groupby(level=level).transform(
        lambda x: x.round(3).drop_duplicates().nsmallest(2).iloc[-1]
    )
    is_underlined = df_column.round(3) == second_min_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ""
    df_css[is_underlined] = "underline: --latex--rwrap"
    return df_css

# %%
def underline_2nd_max_index(series_index, df_column, level=0):
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css.loc[:] = ''
    series_css[is_underlined.values] = 'underline: --latex--rwrap'
    return series_css

# %% [markdown]
# ## Some Models

# %%
print(*df_runs_parents['model'].unique(), sep="\n")
# Out:
# CoHiRF-SC-SRGF-60
# BatchCoHiRF-SC-SRGF-1iter-60
# SpectralSubspaceRandomization-60
# BatchCoHiRF-SC-SRGF-2-60
# CoHiRF-SC-SRGF-2R-60
# CoHiRF-SC-SRGF-1R-60

# %%
model_names = {
    'CoHiRF-SC-SRGF-60': 'CoHiRF-SC-SRGF',
    'SpectralSubspaceRandomization-60': "SC-SRGF",
    'CoHiRF-SC-SRGF-2R-60': 'CoHiRF-SC-SRGF-2R',
    'CoHiRF-SC-SRGF-1R-60': 'CoHiRF-SC-SRGF-1R',
}

dataset_names = {
    "binary_alpha_digits": "binary-alpha-digits",
	"mnist_784": "mnist",
}  # otherwise we get an error in latex

dataset_id = [
    39,
    61,
    46773,
    46774,
    46775,
    46776,
    46777,
    46778,
    46779,
    46780,
    46781,
]

# Filter to only standardized runs
df = df_runs_parents.copy()
df = df.loc[df['standardize'] == True]
df = df.loc[df['model'].isin(model_names.keys())]
df = df.loc[df["dataset_id"].isin(dataset_id)]
df = df.replace({"model": model_names})
df = df.replace({"dataset_name": dataset_names})

# Filter to only runs with hpo_seed in range(5)
df = df.loc[df['hpo_seed'].isin(range(5))]

# %%
hpo_metrics = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    "silhouette",
    "davies_bouldin_score",
    "normalized_mutual_info",
]

hpo_metrics_rename = [
    "ARI",
    "AMI",
    "Calinski",
    "Silhouette",
    "Davies-Bouldin",
    "NMI",
]

dfs_metrics = {}

for hpo_metric, hpo_metric_rename in zip(hpo_metrics, hpo_metrics_rename):
    df_metric = df.loc[df['hpo_metric'] == hpo_metric][
        ['dataset_name', 'model', 'hpo_seed', f'best/{hpo_metric}']
    ].rename(columns={f'best/{hpo_metric}': hpo_metric_rename})
    df_metric = df_metric.dropna(subset=[hpo_metric_rename])
    df_metric = df_metric.set_index(['dataset_name', 'model', 'hpo_seed'])
    df_metric = df_metric.astype({hpo_metric_rename: float})
    dfs_metrics[hpo_metric_rename] = df_metric

df_metrics = pd.concat(dfs_metrics.values(), axis=1, join="outer")
df_metrics = df_metrics.reset_index()

# calculate mean and std
df_metrics = df_metrics.groupby(['dataset_name', 'model']).agg(['mean', 'std'])
# flatten multiindex columns
df_metrics.columns = [' '.join(col).strip() for col in df_metrics.columns.values]
# drop hpo_seed level
df_metrics = df_metrics.drop(columns=['hpo_seed mean', 'hpo_seed std'])
# Rename index levels
df_metrics.index.names = ["Dataset", "Model"]
# df_metrics["Davies-Bouldin"] = df_metrics["Davies-Bouldin"].astype(float)
# create columns Metric (Mean ± Std)
# for metric in hpo_metrics_rename:
#     df_metrics[f"{metric}"] = df_metrics[f"{metric} mean"].round(3).astype(str) + " $\\pm$ " + df_metrics[f"{metric} std"].round(3).astype(str)

for metric in hpo_metrics_rename:
    df_metrics[f"{metric}"] = (
        df_metrics[f"{metric} mean"].apply(lambda x: f"{x:.3f}" if not pd.isna(x) else "No Run")
        + " $\\pm$ "
        + df_metrics[f"{metric} std"].apply(lambda x: f"{x:.3f}" if not pd.isna(x) else "No Run")
    )


# Reset Seed level
# df_metrics = df_metrics.reset_index(level="Seed")

# %%
df_metrics
# Out:
#                                      ARI mean   ARI std  AMI mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     0.632841  0.042223  0.757751
#                   CoHiRF-SC-SRGF-1R  0.947128  0.000000  0.922018
#                   CoHiRF-SC-SRGF-2R  0.947128  0.000000  0.922018
#                   SC-SRGF            0.891422  0.124562  0.854421
# alizadeh-2000-v3  CoHiRF-SC-SRGF     0.442624  0.012813  0.627770
#                   CoHiRF-SC-SRGF-1R  0.519160  0.000000  0.723841
#                   CoHiRF-SC-SRGF-2R  0.519160  0.000000  0.723841
#                   SC-SRGF            0.519160  0.000000  0.702416
# armstrong-2002-v1 CoHiRF-SC-SRGF     0.371617  0.039012  0.444932
#                   CoHiRF-SC-SRGF-1R  0.462629  0.116528  0.402909
#                   CoHiRF-SC-SRGF-2R  0.445998  0.110654  0.419080
#                   SC-SRGF            0.313416  0.045964  0.420515
# bittner-2000      CoHiRF-SC-SRGF     0.057890  0.022848  0.103082
#                   CoHiRF-SC-SRGF-1R  0.169038  0.019309  0.223727
#                   CoHiRF-SC-SRGF-2R  0.140731  0.010381  0.190714
#                   SC-SRGF            0.131626  0.034718  0.204931
# bredel-2005       CoHiRF-SC-SRGF     0.326251  0.024664  0.413455
#                   CoHiRF-SC-SRGF-1R  0.655139  0.036821  0.524535
#                   CoHiRF-SC-SRGF-2R  0.653397  0.035275  0.530495
#                   SC-SRGF            0.639952  0.034435  0.538158
# chowdary-2006     CoHiRF-SC-SRGF     0.702278  0.041618  0.646869
#                   CoHiRF-SC-SRGF-1R  0.923766  0.000000  0.858643
#                   CoHiRF-SC-SRGF-2R  0.923766  0.000000  0.858643
#                   SC-SRGF            0.923766  0.000000  0.858643
# ecoli             CoHiRF-SC-SRGF     0.723492  0.011082  0.667921
#                   CoHiRF-SC-SRGF-1R  0.723821  0.002943  0.681983
#                   CoHiRF-SC-SRGF-2R  0.729594  0.010561  0.695410
#                   SC-SRGF            0.713038  0.007713  0.676466
# garber-2001       CoHiRF-SC-SRGF     0.437160  0.054210  0.323151
#                   CoHiRF-SC-SRGF-1R  0.235458  0.012791  0.264929
#                   CoHiRF-SC-SRGF-2R  0.454286  0.033884  0.332909
#                   SC-SRGF            0.204396  0.035002  0.251175
# golub-1999-v2     CoHiRF-SC-SRGF     0.352280  0.043072  0.451229
#                   CoHiRF-SC-SRGF-1R  0.377647  0.053731  0.466433
#                   CoHiRF-SC-SRGF-2R  0.367010  0.054796  0.452678
#                   SC-SRGF            0.298271  0.030361  0.454763
# iris              CoHiRF-SC-SRGF     0.726146  0.031791  0.717521
#                   CoHiRF-SC-SRGF-1R  0.885958  0.008285  0.860005
#                   CoHiRF-SC-SRGF-2R  0.826558  0.036383  0.803129
#                   SC-SRGF            0.776839  0.077965  0.849873
# khan-2001         CoHiRF-SC-SRGF     0.403977  0.017035  0.552097
#                   CoHiRF-SC-SRGF-1R  0.405887  0.000000  0.555187
#                   CoHiRF-SC-SRGF-2R  0.423957  0.006823  0.573815
#                   SC-SRGF            0.364275  0.038585  0.522855
#
#                                           AMI std  Calinski mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     3.062353e-02       7.421898
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      12.338328
#                   CoHiRF-SC-SRGF-2R  0.000000e+00      12.338328
#                   SC-SRGF            9.259718e-02      12.338328
# alizadeh-2000-v3  CoHiRF-SC-SRGF     1.897289e-02       7.411181
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      12.340749
#                   CoHiRF-SC-SRGF-2R  0.000000e+00      12.340749
#                   SC-SRGF            4.790779e-02      12.340749
# armstrong-2002-v1 CoHiRF-SC-SRGF     1.701540e-02       3.423828
#                   CoHiRF-SC-SRGF-1R  1.630933e-02       4.856990
#                   CoHiRF-SC-SRGF-2R  1.638856e-02       4.812556
#                   SC-SRGF            9.553470e-02       4.812231
# bittner-2000      CoHiRF-SC-SRGF     2.272839e-02       2.998462
#                   CoHiRF-SC-SRGF-1R  2.745631e-02       5.053514
#                   CoHiRF-SC-SRGF-2R  3.830064e-02       5.089498
#                   SC-SRGF            4.611471e-02       4.981545
# bredel-2005       CoHiRF-SC-SRGF     2.679214e-02       2.969625
#                   CoHiRF-SC-SRGF-1R  5.852944e-02       4.653231
#                   CoHiRF-SC-SRGF-2R  3.419096e-02       4.647929
#                   SC-SRGF            4.658337e-02       4.630272
# chowdary-2006     CoHiRF-SC-SRGF     5.751890e-02      30.347677
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      27.736850
#                   CoHiRF-SC-SRGF-2R  0.000000e+00      37.210669
#                   SC-SRGF            0.000000e+00      23.008710
# ecoli             CoHiRF-SC-SRGF     1.532071e-02      99.575711
#                   CoHiRF-SC-SRGF-1R  1.302474e-02     129.588413
#                   CoHiRF-SC-SRGF-2R  1.417223e-02     129.008066
#                   SC-SRGF            7.898930e-03     128.086692
# garber-2001       CoHiRF-SC-SRGF     1.588123e-02       3.921558
#                   CoHiRF-SC-SRGF-1R  1.518644e-02       4.993872
#                   CoHiRF-SC-SRGF-2R  9.085775e-03       4.995207
#                   SC-SRGF            2.307501e-02       4.965666
# golub-1999-v2     CoHiRF-SC-SRGF     3.454543e-02       3.163228
#                   CoHiRF-SC-SRGF-1R  2.266754e-02       4.443568
#                   CoHiRF-SC-SRGF-2R  5.820559e-02       4.395087
#                   SC-SRGF            2.180795e-02       4.402151
# iris              CoHiRF-SC-SRGF     2.972941e-02     160.845745
#                   CoHiRF-SC-SRGF-1R  5.551115e-17     241.038012
#                   CoHiRF-SC-SRGF-2R  3.658181e-02     241.038012
#                   SC-SRGF            2.486606e-02     241.038012
# khan-2001         CoHiRF-SC-SRGF     3.358029e-02       9.080538
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      11.001255
#                   CoHiRF-SC-SRGF-2R  4.514173e-03      11.378662
#                   SC-SRGF            7.327565e-03      10.359436
#
#                                      Calinski std  Silhouette mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     4.138251e-02         0.094015
#                   CoHiRF-SC-SRGF-1R  1.986027e-15         0.194047
#                   CoHiRF-SC-SRGF-2R  1.986027e-15         0.194047
#                   SC-SRGF            1.776357e-15         0.194047
# alizadeh-2000-v3  CoHiRF-SC-SRGF     6.035958e-02         0.093085
#                   CoHiRF-SC-SRGF-1R  1.256074e-15         0.194082
#                   CoHiRF-SC-SRGF-2R  1.256074e-15         0.194082
#                   SC-SRGF            1.256074e-15         0.194082
# armstrong-2002-v1 CoHiRF-SC-SRGF     5.511633e-02         0.026715
#                   CoHiRF-SC-SRGF-1R  2.028902e-02         0.066142
#                   CoHiRF-SC-SRGF-2R  1.799357e-02         0.071776
#                   SC-SRGF            2.863784e-02         0.067216
# bittner-2000      CoHiRF-SC-SRGF     1.247246e-01         0.057493
#                   CoHiRF-SC-SRGF-1R  8.046364e-02         0.080704
#                   CoHiRF-SC-SRGF-2R  6.280370e-16         0.081110
#                   SC-SRGF            9.854743e-02         0.074675
# bredel-2005       CoHiRF-SC-SRGF     1.819568e-01         0.035537
#                   CoHiRF-SC-SRGF-1R  1.009697e-01         0.071605
#                   CoHiRF-SC-SRGF-2R  9.674341e-02         0.071164
#                   SC-SRGF            8.818444e-02         0.070943
# chowdary-2006     CoHiRF-SC-SRGF     5.508327e+00         0.174320
#                   CoHiRF-SC-SRGF-1R  2.648732e-02         0.174796
#                   CoHiRF-SC-SRGF-2R  6.023946e+00         0.273316
#                   SC-SRGF            4.972592e+00         0.221640
# ecoli             CoHiRF-SC-SRGF     1.266037e+01         0.346749
#                   CoHiRF-SC-SRGF-1R  1.004669e+01         0.487583
#                   CoHiRF-SC-SRGF-2R  7.999129e+00         0.577906
#                   SC-SRGF            1.090829e+01         0.481805
# garber-2001       CoHiRF-SC-SRGF     1.067011e-01         0.053767
#                   CoHiRF-SC-SRGF-1R  2.971863e-02         0.060161
#                   CoHiRF-SC-SRGF-2R  5.474794e-02         0.229234
#                   SC-SRGF            6.619006e-02         0.058948
# golub-1999-v2     CoHiRF-SC-SRGF     7.133733e-02         0.045561
#                   CoHiRF-SC-SRGF-1R  4.440892e-16         0.091086
#                   CoHiRF-SC-SRGF-2R  1.084056e-01         0.085378
#                   SC-SRGF            1.133907e-01         0.087011
# iris              CoHiRF-SC-SRGF     1.429415e+01         0.343801
#                   CoHiRF-SC-SRGF-1R  0.000000e+00         0.579209
#                   CoHiRF-SC-SRGF-2R  0.000000e+00         0.579209
#                   SC-SRGF            0.000000e+00         0.579209
# khan-2001         CoHiRF-SC-SRGF     0.000000e+00         0.122798
#                   CoHiRF-SC-SRGF-1R  9.860928e-01         0.128997
#                   CoHiRF-SC-SRGF-2R  1.167981e+00         0.136207
#                   SC-SRGF            4.822360e-01         0.128862
#
#                                      Silhouette std  Davies-Bouldin mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF       6.256498e-04             1.549682
#                   CoHiRF-SC-SRGF-1R    0.000000e+00             2.459820
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             2.786090
#                   SC-SRGF              0.000000e+00             0.936257
# alizadeh-2000-v3  CoHiRF-SC-SRGF       1.500483e-03             1.562203
#                   CoHiRF-SC-SRGF-1R    0.000000e+00             2.495902
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             2.745695
#                   SC-SRGF              3.671718e-17             0.931108
# armstrong-2002-v1 CoHiRF-SC-SRGF       5.488241e-03             2.003172
#                   CoHiRF-SC-SRGF-1R    3.292243e-03             3.431147
#                   CoHiRF-SC-SRGF-2R    7.247687e-03             3.514438
#                   SC-SRGF              3.519943e-03             1.343946
# bittner-2000      CoHiRF-SC-SRGF       5.173630e-03             1.637918
#                   CoHiRF-SC-SRGF-1R    9.071594e-04             3.237038
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             3.295507
#                   SC-SRGF              1.328431e-02             0.644103
# bredel-2005       CoHiRF-SC-SRGF       4.392912e-03             1.979423
#                   CoHiRF-SC-SRGF-1R    8.165804e-04             3.383978
#                   CoHiRF-SC-SRGF-2R    9.457065e-04             3.398186
#                   SC-SRGF              1.032884e-03             0.948371
# chowdary-2006     CoHiRF-SC-SRGF       5.975853e-03             1.450481
#                   CoHiRF-SC-SRGF-1R    9.355356e-04             2.400669
#                   CoHiRF-SC-SRGF-2R    2.227498e-01             2.227285
#                   SC-SRGF              6.553076e-03             1.100553
# ecoli             CoHiRF-SC-SRGF       2.129687e-02             1.096253
#                   CoHiRF-SC-SRGF-1R    1.209362e-01             9.193001
#                   CoHiRF-SC-SRGF-2R    4.830082e-02             8.175701
#                   SC-SRGF              1.263268e-01             1.047816
# garber-2001       CoHiRF-SC-SRGF       1.922729e-02             1.908842
#                   CoHiRF-SC-SRGF-1R    1.797828e-03             3.883028
#                   CoHiRF-SC-SRGF-2R    9.672256e-02             5.632656
#                   SC-SRGF              2.878986e-03             1.130310
# golub-1999-v2     CoHiRF-SC-SRGF       1.000275e-02             2.577472
#                   CoHiRF-SC-SRGF-1R    5.637184e-17             4.358803
#                   CoHiRF-SC-SRGF-2R    7.891673e-03             4.356858
#                   SC-SRGF              9.113923e-03             1.345687
# iris              CoHiRF-SC-SRGF       2.805589e-02             0.666271
#                   CoHiRF-SC-SRGF-1R    0.000000e+00             5.785856
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             3.508103
#                   SC-SRGF              0.000000e+00             0.594499
# khan-2001         CoHiRF-SC-SRGF       5.099025e-17             1.495907
#                   CoHiRF-SC-SRGF-1R    1.215729e-02             3.077382
#                   CoHiRF-SC-SRGF-2R    1.578086e-02             3.137772
#                   SC-SRGF              2.943570e-03             1.067821
#
#                                      Davies-Bouldin std  NMI mean  NMI std  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF               0.019373       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.008165       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.099667       NaN      NaN
#                   SC-SRGF                      0.014104       NaN      NaN
# alizadeh-2000-v3  CoHiRF-SC-SRGF               0.046857       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.088336       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.049966       NaN      NaN
#                   SC-SRGF                      0.011096       NaN      NaN
# armstrong-2002-v1 CoHiRF-SC-SRGF               0.224128       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.056583       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.128369       NaN      NaN
#                   SC-SRGF                      0.021995       NaN      NaN
# bittner-2000      CoHiRF-SC-SRGF               0.059929       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.209887       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.073743       NaN      NaN
#                   SC-SRGF                      0.000000       NaN      NaN
# bredel-2005       CoHiRF-SC-SRGF               0.128111       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.036691       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.042970       NaN      NaN
#                   SC-SRGF                      0.004061       NaN      NaN
# chowdary-2006     CoHiRF-SC-SRGF               0.044479       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.007784       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.082465       NaN      NaN
#                   SC-SRGF                      0.022429       NaN      NaN
# ecoli             CoHiRF-SC-SRGF               0.079678       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            1.834830       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.698899       NaN      NaN
#                   SC-SRGF                      0.168471       NaN      NaN
# garber-2001       CoHiRF-SC-SRGF               0.117843       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.018760       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.330822       NaN      NaN
#                   SC-SRGF                      0.016465       NaN      NaN
# golub-1999-v2     CoHiRF-SC-SRGF               0.146068       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.016301       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.019661       NaN      NaN
#                   SC-SRGF                      0.009644       NaN      NaN
# iris              CoHiRF-SC-SRGF               0.046894       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            2.522062       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.801687       NaN      NaN
#                   SC-SRGF                      0.000870       NaN      NaN
# khan-2001         CoHiRF-SC-SRGF               0.001157       NaN      NaN
#                   CoHiRF-SC-SRGF-1R            0.154970       NaN      NaN
#                   CoHiRF-SC-SRGF-2R            0.147706       NaN      NaN
#                   SC-SRGF                      0.014631       NaN      NaN
#
#                                                    ARI                AMI  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     0.633 $\pm$ 0.042  0.758 $\pm$ 0.031
#                   CoHiRF-SC-SRGF-1R  0.947 $\pm$ 0.000  0.922 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R  0.947 $\pm$ 0.000  0.922 $\pm$ 0.000
#                   SC-SRGF            0.891 $\pm$ 0.125  0.854 $\pm$ 0.093
# alizadeh-2000-v3  CoHiRF-SC-SRGF     0.443 $\pm$ 0.013  0.628 $\pm$ 0.019
#                   CoHiRF-SC-SRGF-1R  0.519 $\pm$ 0.000  0.724 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R  0.519 $\pm$ 0.000  0.724 $\pm$ 0.000
#                   SC-SRGF            0.519 $\pm$ 0.000  0.702 $\pm$ 0.048
# armstrong-2002-v1 CoHiRF-SC-SRGF     0.372 $\pm$ 0.039  0.445 $\pm$ 0.017
#                   CoHiRF-SC-SRGF-1R  0.463 $\pm$ 0.117  0.403 $\pm$ 0.016
#                   CoHiRF-SC-SRGF-2R  0.446 $\pm$ 0.111  0.419 $\pm$ 0.016
#                   SC-SRGF            0.313 $\pm$ 0.046  0.421 $\pm$ 0.096
# bittner-2000      CoHiRF-SC-SRGF     0.058 $\pm$ 0.023  0.103 $\pm$ 0.023
#                   CoHiRF-SC-SRGF-1R  0.169 $\pm$ 0.019  0.224 $\pm$ 0.027
#                   CoHiRF-SC-SRGF-2R  0.141 $\pm$ 0.010  0.191 $\pm$ 0.038
#                   SC-SRGF            0.132 $\pm$ 0.035  0.205 $\pm$ 0.046
# bredel-2005       CoHiRF-SC-SRGF     0.326 $\pm$ 0.025  0.413 $\pm$ 0.027
#                   CoHiRF-SC-SRGF-1R  0.655 $\pm$ 0.037  0.525 $\pm$ 0.059
#                   CoHiRF-SC-SRGF-2R  0.653 $\pm$ 0.035  0.530 $\pm$ 0.034
#                   SC-SRGF            0.640 $\pm$ 0.034  0.538 $\pm$ 0.047
# chowdary-2006     CoHiRF-SC-SRGF     0.702 $\pm$ 0.042  0.647 $\pm$ 0.058
#                   CoHiRF-SC-SRGF-1R  0.924 $\pm$ 0.000  0.859 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R  0.924 $\pm$ 0.000  0.859 $\pm$ 0.000
#                   SC-SRGF            0.924 $\pm$ 0.000  0.859 $\pm$ 0.000
# ecoli             CoHiRF-SC-SRGF     0.723 $\pm$ 0.011  0.668 $\pm$ 0.015
#                   CoHiRF-SC-SRGF-1R  0.724 $\pm$ 0.003  0.682 $\pm$ 0.013
#                   CoHiRF-SC-SRGF-2R  0.730 $\pm$ 0.011  0.695 $\pm$ 0.014
#                   SC-SRGF            0.713 $\pm$ 0.008  0.676 $\pm$ 0.008
# garber-2001       CoHiRF-SC-SRGF     0.437 $\pm$ 0.054  0.323 $\pm$ 0.016
#                   CoHiRF-SC-SRGF-1R  0.235 $\pm$ 0.013  0.265 $\pm$ 0.015
#                   CoHiRF-SC-SRGF-2R  0.454 $\pm$ 0.034  0.333 $\pm$ 0.009
#                   SC-SRGF            0.204 $\pm$ 0.035  0.251 $\pm$ 0.023
# golub-1999-v2     CoHiRF-SC-SRGF     0.352 $\pm$ 0.043  0.451 $\pm$ 0.035
#                   CoHiRF-SC-SRGF-1R  0.378 $\pm$ 0.054  0.466 $\pm$ 0.023
#                   CoHiRF-SC-SRGF-2R  0.367 $\pm$ 0.055  0.453 $\pm$ 0.058
#                   SC-SRGF            0.298 $\pm$ 0.030  0.455 $\pm$ 0.022
# iris              CoHiRF-SC-SRGF     0.726 $\pm$ 0.032  0.718 $\pm$ 0.030
#                   CoHiRF-SC-SRGF-1R  0.886 $\pm$ 0.008  0.860 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R  0.827 $\pm$ 0.036  0.803 $\pm$ 0.037
#                   SC-SRGF            0.777 $\pm$ 0.078  0.850 $\pm$ 0.025
# khan-2001         CoHiRF-SC-SRGF     0.404 $\pm$ 0.017  0.552 $\pm$ 0.034
#                   CoHiRF-SC-SRGF-1R  0.406 $\pm$ 0.000  0.555 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R  0.424 $\pm$ 0.007  0.574 $\pm$ 0.005
#                   SC-SRGF            0.364 $\pm$ 0.039  0.523 $\pm$ 0.007
#
#                                                  Calinski         Silhouette  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF        7.422 $\pm$ 0.041  0.094 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-1R    12.338 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R    12.338 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   SC-SRGF              12.338 $\pm$ 0.000  0.194 $\pm$ 0.000
# alizadeh-2000-v3  CoHiRF-SC-SRGF        7.411 $\pm$ 0.060  0.093 $\pm$ 0.002
#                   CoHiRF-SC-SRGF-1R    12.341 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R    12.341 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   SC-SRGF              12.341 $\pm$ 0.000  0.194 $\pm$ 0.000
# armstrong-2002-v1 CoHiRF-SC-SRGF        3.424 $\pm$ 0.055  0.027 $\pm$ 0.005
#                   CoHiRF-SC-SRGF-1R     4.857 $\pm$ 0.020  0.066 $\pm$ 0.003
#                   CoHiRF-SC-SRGF-2R     4.813 $\pm$ 0.018  0.072 $\pm$ 0.007
#                   SC-SRGF               4.812 $\pm$ 0.029  0.067 $\pm$ 0.004
# bittner-2000      CoHiRF-SC-SRGF        2.998 $\pm$ 0.125  0.057 $\pm$ 0.005
#                   CoHiRF-SC-SRGF-1R     5.054 $\pm$ 0.080  0.081 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-2R     5.089 $\pm$ 0.000  0.081 $\pm$ 0.000
#                   SC-SRGF               4.982 $\pm$ 0.099  0.075 $\pm$ 0.013
# bredel-2005       CoHiRF-SC-SRGF        2.970 $\pm$ 0.182  0.036 $\pm$ 0.004
#                   CoHiRF-SC-SRGF-1R     4.653 $\pm$ 0.101  0.072 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-2R     4.648 $\pm$ 0.097  0.071 $\pm$ 0.001
#                   SC-SRGF               4.630 $\pm$ 0.088  0.071 $\pm$ 0.001
# chowdary-2006     CoHiRF-SC-SRGF       30.348 $\pm$ 5.508  0.174 $\pm$ 0.006
#                   CoHiRF-SC-SRGF-1R    27.737 $\pm$ 0.026  0.175 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-2R    37.211 $\pm$ 6.024  0.273 $\pm$ 0.223
#                   SC-SRGF              23.009 $\pm$ 4.973  0.222 $\pm$ 0.007
# ecoli             CoHiRF-SC-SRGF      99.576 $\pm$ 12.660  0.347 $\pm$ 0.021
#                   CoHiRF-SC-SRGF-1R  129.588 $\pm$ 10.047  0.488 $\pm$ 0.121
#                   CoHiRF-SC-SRGF-2R   129.008 $\pm$ 7.999  0.578 $\pm$ 0.048
#                   SC-SRGF            128.087 $\pm$ 10.908  0.482 $\pm$ 0.126
# garber-2001       CoHiRF-SC-SRGF        3.922 $\pm$ 0.107  0.054 $\pm$ 0.019
#                   CoHiRF-SC-SRGF-1R     4.994 $\pm$ 0.030  0.060 $\pm$ 0.002
#                   CoHiRF-SC-SRGF-2R     4.995 $\pm$ 0.055  0.229 $\pm$ 0.097
#                   SC-SRGF               4.966 $\pm$ 0.066  0.059 $\pm$ 0.003
# golub-1999-v2     CoHiRF-SC-SRGF        3.163 $\pm$ 0.071  0.046 $\pm$ 0.010
#                   CoHiRF-SC-SRGF-1R     4.444 $\pm$ 0.000  0.091 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R     4.395 $\pm$ 0.108  0.085 $\pm$ 0.008
#                   SC-SRGF               4.402 $\pm$ 0.113  0.087 $\pm$ 0.009
# iris              CoHiRF-SC-SRGF     160.846 $\pm$ 14.294  0.344 $\pm$ 0.028
#                   CoHiRF-SC-SRGF-1R   241.038 $\pm$ 0.000  0.579 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R   241.038 $\pm$ 0.000  0.579 $\pm$ 0.000
#                   SC-SRGF             241.038 $\pm$ 0.000  0.579 $\pm$ 0.000
# khan-2001         CoHiRF-SC-SRGF        9.081 $\pm$ 0.000  0.123 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-1R    11.001 $\pm$ 0.986  0.129 $\pm$ 0.012
#                   CoHiRF-SC-SRGF-2R    11.379 $\pm$ 1.168  0.136 $\pm$ 0.016
#                   SC-SRGF              10.359 $\pm$ 0.482  0.129 $\pm$ 0.003
#
#                                         Davies-Bouldin                  NMI
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     1.550 $\pm$ 0.019  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  2.460 $\pm$ 0.008  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  2.786 $\pm$ 0.100  No Run $\pm$ No Run
#                   SC-SRGF            0.936 $\pm$ 0.014  No Run $\pm$ No Run
# alizadeh-2000-v3  CoHiRF-SC-SRGF     1.562 $\pm$ 0.047  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  2.496 $\pm$ 0.088  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  2.746 $\pm$ 0.050  No Run $\pm$ No Run
#                   SC-SRGF            0.931 $\pm$ 0.011  No Run $\pm$ No Run
# armstrong-2002-v1 CoHiRF-SC-SRGF     2.003 $\pm$ 0.224  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.431 $\pm$ 0.057  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.514 $\pm$ 0.128  No Run $\pm$ No Run
#                   SC-SRGF            1.344 $\pm$ 0.022  No Run $\pm$ No Run
# bittner-2000      CoHiRF-SC-SRGF     1.638 $\pm$ 0.060  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.237 $\pm$ 0.210  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.296 $\pm$ 0.074  No Run $\pm$ No Run
#                   SC-SRGF            0.644 $\pm$ 0.000  No Run $\pm$ No Run
# bredel-2005       CoHiRF-SC-SRGF     1.979 $\pm$ 0.128  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.384 $\pm$ 0.037  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.398 $\pm$ 0.043  No Run $\pm$ No Run
#                   SC-SRGF            0.948 $\pm$ 0.004  No Run $\pm$ No Run
# chowdary-2006     CoHiRF-SC-SRGF     1.450 $\pm$ 0.044  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  2.401 $\pm$ 0.008  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  2.227 $\pm$ 0.082  No Run $\pm$ No Run
#                   SC-SRGF            1.101 $\pm$ 0.022  No Run $\pm$ No Run
# ecoli             CoHiRF-SC-SRGF     1.096 $\pm$ 0.080  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  9.193 $\pm$ 1.835  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  8.176 $\pm$ 0.699  No Run $\pm$ No Run
#                   SC-SRGF            1.048 $\pm$ 0.168  No Run $\pm$ No Run
# garber-2001       CoHiRF-SC-SRGF     1.909 $\pm$ 0.118  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.883 $\pm$ 0.019  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  5.633 $\pm$ 0.331  No Run $\pm$ No Run
#                   SC-SRGF            1.130 $\pm$ 0.016  No Run $\pm$ No Run
# golub-1999-v2     CoHiRF-SC-SRGF     2.577 $\pm$ 0.146  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  4.359 $\pm$ 0.016  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  4.357 $\pm$ 0.020  No Run $\pm$ No Run
#                   SC-SRGF            1.346 $\pm$ 0.010  No Run $\pm$ No Run
# iris              CoHiRF-SC-SRGF     0.666 $\pm$ 0.047  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  5.786 $\pm$ 2.522  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.508 $\pm$ 0.802  No Run $\pm$ No Run
#                   SC-SRGF            0.594 $\pm$ 0.001  No Run $\pm$ No Run
# khan-2001         CoHiRF-SC-SRGF     1.496 $\pm$ 0.001  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.077 $\pm$ 0.155  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.138 $\pm$ 0.148  No Run $\pm$ No Run
#                   SC-SRGF            1.068 $\pm$ 0.015  No Run $\pm$ No Run

# %%
# Add mean time columns to the existing df_metrics dataframe
# Using the same filtering approach as the original df_metrics
# df = df_runs_parents.copy()
# df = df.loc[df["standardize"] == True]
# df = df.loc[df["model"].isin(model_names.keys())]
# df = df.replace({"model": model_names})
# df = df.replace({"dataset_name": dataset_names})
# # Filter to only runs with hpo_seed in range(5)
# df = df.loc[df["hpo_seed"].isin(range(5))]

# Calculate mean and std times for each dataset-model combination across all metrics
df_times = (
    df.groupby(["dataset_name", "model"])
    .agg({"best/elapsed_time": ["mean", "std"], "fit_model_return_elapsed_time": ["mean", "std"]})
    .rename(columns={"best/elapsed_time": "Best Time", "fit_model_return_elapsed_time": "HPO Time"})
)

# Flatten multiindex columns
df_times.columns = [' '.join(col).strip() for col in df_times.columns.values]
# Set the same index structure as df_metrics
df_times.index.names = ["Dataset", "Model"]

df_times["Best Time"] = (
	df_times["Best Time mean"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
	+ " $\\pm$ " 
	+ df_times["Best Time std"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
)
df_times["HPO Time"] = (
	df_times["HPO Time mean"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
	+ " $\\pm$ "
	+ df_times["HPO Time std"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
)

# Join with the existing df_metrics (verify we have the same number of rows!)
df_metrics = df_metrics.join(df_times, how="outer")

# %%
# # Create a time-based dataframe with elapsed times for each metric optimization
# # Using the same filtering approach as the original df_metrics
# df_filtered = df_runs_parents.loc[df_runs_parents['standardize'] == True].copy()
# df_filtered = df_filtered.loc[df_filtered['model'].isin(model_names.keys())]
# df_filtered = df_filtered.replace({"model": model_names})
# df_filtered = df_filtered.replace({"dataset_name": dataset_names})

# # Create separate dataframes for each metric optimization with time columns
# df_ari_time = df_filtered.loc[df_filtered['hpo_metric'] == 'adjusted_rand'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'ARI_best_time', 'fit_model_return_elapsed_time': 'ARI_total_time'})

# df_ami_time = df_filtered.loc[df_filtered['hpo_metric'] == 'adjusted_mutual_info'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'AMI_best_time', 'fit_model_return_elapsed_time': 'AMI_total_time'})

# df_nmi_time = df_filtered.loc[df_filtered['hpo_metric'] == 'normalized_mutual_info'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'NMI_best_time', 'fit_model_return_elapsed_time': 'NMI_total_time'})

# df_calinski_time = df_filtered.loc[df_filtered['hpo_metric'] == 'calinski_harabasz_score'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'Calinski_best_time', 'fit_model_return_elapsed_time': 'Calinski_total_time'})

# df_silhouette_time = df_filtered.loc[df_filtered['hpo_metric'] == 'silhouette'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'Silhouette_best_time', 'fit_model_return_elapsed_time': 'Silhouette_total_time'})

# df_davies_bouldin_time = df_filtered.loc[df_filtered['hpo_metric'] == 'davies_bouldin_score'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'Davies-Bouldin_best_time', 'fit_model_return_elapsed_time': 'Davies-Bouldin_total_time'})

# # Remove missing values before setting index
# df_ari_time = df_ari_time.dropna(subset=["ARI_best_time", "ARI_total_time"])
# df_ami_time = df_ami_time.dropna(subset=["AMI_best_time", "AMI_total_time"])
# df_nmi_time = df_nmi_time.dropna(subset=["NMI_best_time", "NMI_total_time"])
# df_calinski_time = df_calinski_time.dropna(subset=["Calinski_best_time", "Calinski_total_time"])
# df_silhouette_time = df_silhouette_time.dropna(subset=["Silhouette_best_time", "Silhouette_total_time"])
# df_davies_bouldin_time = df_davies_bouldin_time.dropna(subset=["Davies-Bouldin_best_time", "Davies-Bouldin_total_time"])

# # Set multi-index for all dataframes
# df_ari_time = df_ari_time.set_index(["dataset_name", "model"])
# df_ami_time = df_ami_time.set_index(["dataset_name", "model"])
# df_nmi_time = df_nmi_time.set_index(["dataset_name", "model"])
# df_calinski_time = df_calinski_time.set_index(["dataset_name", "model"])
# df_silhouette_time = df_silhouette_time.set_index(["dataset_name", "model"])
# df_davies_bouldin_time = df_davies_bouldin_time.set_index(["dataset_name", "model"])

# # Combine all time metrics into a single dataframe using outer join
# df_time_metrics = df_ari_time.join(df_ami_time, how="outer").join(df_nmi, how="outer").join(df_calinski_time, how="outer").join(df_silhouette_time, how="outer").join(df_davies_bouldin_time, how="outer")

# # Rename index levels
# df_time_metrics.index.names = ["Dataset", "Model"]

# %%
df_metrics
# Out:
#                                      ARI mean   ARI std  AMI mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     0.632841  0.042223  0.757751
#                   CoHiRF-SC-SRGF-1R  0.947128  0.000000  0.922018
#                   CoHiRF-SC-SRGF-2R  0.947128  0.000000  0.922018
#                   SC-SRGF            0.891422  0.124562  0.854421
# alizadeh-2000-v3  CoHiRF-SC-SRGF     0.442624  0.012813  0.627770
#                   CoHiRF-SC-SRGF-1R  0.519160  0.000000  0.723841
#                   CoHiRF-SC-SRGF-2R  0.519160  0.000000  0.723841
#                   SC-SRGF            0.519160  0.000000  0.702416
# armstrong-2002-v1 CoHiRF-SC-SRGF     0.371617  0.039012  0.444932
#                   CoHiRF-SC-SRGF-1R  0.462629  0.116528  0.402909
#                   CoHiRF-SC-SRGF-2R  0.445998  0.110654  0.419080
#                   SC-SRGF            0.313416  0.045964  0.420515
# bittner-2000      CoHiRF-SC-SRGF     0.057890  0.022848  0.103082
#                   CoHiRF-SC-SRGF-1R  0.169038  0.019309  0.223727
#                   CoHiRF-SC-SRGF-2R  0.140731  0.010381  0.190714
#                   SC-SRGF            0.131626  0.034718  0.204931
# bredel-2005       CoHiRF-SC-SRGF     0.326251  0.024664  0.413455
#                   CoHiRF-SC-SRGF-1R  0.655139  0.036821  0.524535
#                   CoHiRF-SC-SRGF-2R  0.653397  0.035275  0.530495
#                   SC-SRGF            0.639952  0.034435  0.538158
# chowdary-2006     CoHiRF-SC-SRGF     0.702278  0.041618  0.646869
#                   CoHiRF-SC-SRGF-1R  0.923766  0.000000  0.858643
#                   CoHiRF-SC-SRGF-2R  0.923766  0.000000  0.858643
#                   SC-SRGF            0.923766  0.000000  0.858643
# ecoli             CoHiRF-SC-SRGF     0.723492  0.011082  0.667921
#                   CoHiRF-SC-SRGF-1R  0.723821  0.002943  0.681983
#                   CoHiRF-SC-SRGF-2R  0.729594  0.010561  0.695410
#                   SC-SRGF            0.713038  0.007713  0.676466
# garber-2001       CoHiRF-SC-SRGF     0.437160  0.054210  0.323151
#                   CoHiRF-SC-SRGF-1R  0.235458  0.012791  0.264929
#                   CoHiRF-SC-SRGF-2R  0.454286  0.033884  0.332909
#                   SC-SRGF            0.204396  0.035002  0.251175
# golub-1999-v2     CoHiRF-SC-SRGF     0.352280  0.043072  0.451229
#                   CoHiRF-SC-SRGF-1R  0.377647  0.053731  0.466433
#                   CoHiRF-SC-SRGF-2R  0.367010  0.054796  0.452678
#                   SC-SRGF            0.298271  0.030361  0.454763
# iris              CoHiRF-SC-SRGF     0.726146  0.031791  0.717521
#                   CoHiRF-SC-SRGF-1R  0.885958  0.008285  0.860005
#                   CoHiRF-SC-SRGF-2R  0.826558  0.036383  0.803129
#                   SC-SRGF            0.776839  0.077965  0.849873
# khan-2001         CoHiRF-SC-SRGF     0.403977  0.017035  0.552097
#                   CoHiRF-SC-SRGF-1R  0.405887  0.000000  0.555187
#                   CoHiRF-SC-SRGF-2R  0.423957  0.006823  0.573815
#                   SC-SRGF            0.364275  0.038585  0.522855
#
#                                           AMI std  Calinski mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     3.062353e-02       7.421898
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      12.338328
#                   CoHiRF-SC-SRGF-2R  0.000000e+00      12.338328
#                   SC-SRGF            9.259718e-02      12.338328
# alizadeh-2000-v3  CoHiRF-SC-SRGF     1.897289e-02       7.411181
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      12.340749
#                   CoHiRF-SC-SRGF-2R  0.000000e+00      12.340749
#                   SC-SRGF            4.790779e-02      12.340749
# armstrong-2002-v1 CoHiRF-SC-SRGF     1.701540e-02       3.423828
#                   CoHiRF-SC-SRGF-1R  1.630933e-02       4.856990
#                   CoHiRF-SC-SRGF-2R  1.638856e-02       4.812556
#                   SC-SRGF            9.553470e-02       4.812231
# bittner-2000      CoHiRF-SC-SRGF     2.272839e-02       2.998462
#                   CoHiRF-SC-SRGF-1R  2.745631e-02       5.053514
#                   CoHiRF-SC-SRGF-2R  3.830064e-02       5.089498
#                   SC-SRGF            4.611471e-02       4.981545
# bredel-2005       CoHiRF-SC-SRGF     2.679214e-02       2.969625
#                   CoHiRF-SC-SRGF-1R  5.852944e-02       4.653231
#                   CoHiRF-SC-SRGF-2R  3.419096e-02       4.647929
#                   SC-SRGF            4.658337e-02       4.630272
# chowdary-2006     CoHiRF-SC-SRGF     5.751890e-02      30.347677
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      27.736850
#                   CoHiRF-SC-SRGF-2R  0.000000e+00      37.210669
#                   SC-SRGF            0.000000e+00      23.008710
# ecoli             CoHiRF-SC-SRGF     1.532071e-02      99.575711
#                   CoHiRF-SC-SRGF-1R  1.302474e-02     129.588413
#                   CoHiRF-SC-SRGF-2R  1.417223e-02     129.008066
#                   SC-SRGF            7.898930e-03     128.086692
# garber-2001       CoHiRF-SC-SRGF     1.588123e-02       3.921558
#                   CoHiRF-SC-SRGF-1R  1.518644e-02       4.993872
#                   CoHiRF-SC-SRGF-2R  9.085775e-03       4.995207
#                   SC-SRGF            2.307501e-02       4.965666
# golub-1999-v2     CoHiRF-SC-SRGF     3.454543e-02       3.163228
#                   CoHiRF-SC-SRGF-1R  2.266754e-02       4.443568
#                   CoHiRF-SC-SRGF-2R  5.820559e-02       4.395087
#                   SC-SRGF            2.180795e-02       4.402151
# iris              CoHiRF-SC-SRGF     2.972941e-02     160.845745
#                   CoHiRF-SC-SRGF-1R  5.551115e-17     241.038012
#                   CoHiRF-SC-SRGF-2R  3.658181e-02     241.038012
#                   SC-SRGF            2.486606e-02     241.038012
# khan-2001         CoHiRF-SC-SRGF     3.358029e-02       9.080538
#                   CoHiRF-SC-SRGF-1R  0.000000e+00      11.001255
#                   CoHiRF-SC-SRGF-2R  4.514173e-03      11.378662
#                   SC-SRGF            7.327565e-03      10.359436
#
#                                      Calinski std  Silhouette mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     4.138251e-02         0.094015
#                   CoHiRF-SC-SRGF-1R  1.986027e-15         0.194047
#                   CoHiRF-SC-SRGF-2R  1.986027e-15         0.194047
#                   SC-SRGF            1.776357e-15         0.194047
# alizadeh-2000-v3  CoHiRF-SC-SRGF     6.035958e-02         0.093085
#                   CoHiRF-SC-SRGF-1R  1.256074e-15         0.194082
#                   CoHiRF-SC-SRGF-2R  1.256074e-15         0.194082
#                   SC-SRGF            1.256074e-15         0.194082
# armstrong-2002-v1 CoHiRF-SC-SRGF     5.511633e-02         0.026715
#                   CoHiRF-SC-SRGF-1R  2.028902e-02         0.066142
#                   CoHiRF-SC-SRGF-2R  1.799357e-02         0.071776
#                   SC-SRGF            2.863784e-02         0.067216
# bittner-2000      CoHiRF-SC-SRGF     1.247246e-01         0.057493
#                   CoHiRF-SC-SRGF-1R  8.046364e-02         0.080704
#                   CoHiRF-SC-SRGF-2R  6.280370e-16         0.081110
#                   SC-SRGF            9.854743e-02         0.074675
# bredel-2005       CoHiRF-SC-SRGF     1.819568e-01         0.035537
#                   CoHiRF-SC-SRGF-1R  1.009697e-01         0.071605
#                   CoHiRF-SC-SRGF-2R  9.674341e-02         0.071164
#                   SC-SRGF            8.818444e-02         0.070943
# chowdary-2006     CoHiRF-SC-SRGF     5.508327e+00         0.174320
#                   CoHiRF-SC-SRGF-1R  2.648732e-02         0.174796
#                   CoHiRF-SC-SRGF-2R  6.023946e+00         0.273316
#                   SC-SRGF            4.972592e+00         0.221640
# ecoli             CoHiRF-SC-SRGF     1.266037e+01         0.346749
#                   CoHiRF-SC-SRGF-1R  1.004669e+01         0.487583
#                   CoHiRF-SC-SRGF-2R  7.999129e+00         0.577906
#                   SC-SRGF            1.090829e+01         0.481805
# garber-2001       CoHiRF-SC-SRGF     1.067011e-01         0.053767
#                   CoHiRF-SC-SRGF-1R  2.971863e-02         0.060161
#                   CoHiRF-SC-SRGF-2R  5.474794e-02         0.229234
#                   SC-SRGF            6.619006e-02         0.058948
# golub-1999-v2     CoHiRF-SC-SRGF     7.133733e-02         0.045561
#                   CoHiRF-SC-SRGF-1R  4.440892e-16         0.091086
#                   CoHiRF-SC-SRGF-2R  1.084056e-01         0.085378
#                   SC-SRGF            1.133907e-01         0.087011
# iris              CoHiRF-SC-SRGF     1.429415e+01         0.343801
#                   CoHiRF-SC-SRGF-1R  0.000000e+00         0.579209
#                   CoHiRF-SC-SRGF-2R  0.000000e+00         0.579209
#                   SC-SRGF            0.000000e+00         0.579209
# khan-2001         CoHiRF-SC-SRGF     0.000000e+00         0.122798
#                   CoHiRF-SC-SRGF-1R  9.860928e-01         0.128997
#                   CoHiRF-SC-SRGF-2R  1.167981e+00         0.136207
#                   SC-SRGF            4.822360e-01         0.128862
#
#                                      Silhouette std  Davies-Bouldin mean  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF       6.256498e-04             1.549682
#                   CoHiRF-SC-SRGF-1R    0.000000e+00             2.459820
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             2.786090
#                   SC-SRGF              0.000000e+00             0.936257
# alizadeh-2000-v3  CoHiRF-SC-SRGF       1.500483e-03             1.562203
#                   CoHiRF-SC-SRGF-1R    0.000000e+00             2.495902
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             2.745695
#                   SC-SRGF              3.671718e-17             0.931108
# armstrong-2002-v1 CoHiRF-SC-SRGF       5.488241e-03             2.003172
#                   CoHiRF-SC-SRGF-1R    3.292243e-03             3.431147
#                   CoHiRF-SC-SRGF-2R    7.247687e-03             3.514438
#                   SC-SRGF              3.519943e-03             1.343946
# bittner-2000      CoHiRF-SC-SRGF       5.173630e-03             1.637918
#                   CoHiRF-SC-SRGF-1R    9.071594e-04             3.237038
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             3.295507
#                   SC-SRGF              1.328431e-02             0.644103
# bredel-2005       CoHiRF-SC-SRGF       4.392912e-03             1.979423
#                   CoHiRF-SC-SRGF-1R    8.165804e-04             3.383978
#                   CoHiRF-SC-SRGF-2R    9.457065e-04             3.398186
#                   SC-SRGF              1.032884e-03             0.948371
# chowdary-2006     CoHiRF-SC-SRGF       5.975853e-03             1.450481
#                   CoHiRF-SC-SRGF-1R    9.355356e-04             2.400669
#                   CoHiRF-SC-SRGF-2R    2.227498e-01             2.227285
#                   SC-SRGF              6.553076e-03             1.100553
# ecoli             CoHiRF-SC-SRGF       2.129687e-02             1.096253
#                   CoHiRF-SC-SRGF-1R    1.209362e-01             9.193001
#                   CoHiRF-SC-SRGF-2R    4.830082e-02             8.175701
#                   SC-SRGF              1.263268e-01             1.047816
# garber-2001       CoHiRF-SC-SRGF       1.922729e-02             1.908842
#                   CoHiRF-SC-SRGF-1R    1.797828e-03             3.883028
#                   CoHiRF-SC-SRGF-2R    9.672256e-02             5.632656
#                   SC-SRGF              2.878986e-03             1.130310
# golub-1999-v2     CoHiRF-SC-SRGF       1.000275e-02             2.577472
#                   CoHiRF-SC-SRGF-1R    5.637184e-17             4.358803
#                   CoHiRF-SC-SRGF-2R    7.891673e-03             4.356858
#                   SC-SRGF              9.113923e-03             1.345687
# iris              CoHiRF-SC-SRGF       2.805589e-02             0.666271
#                   CoHiRF-SC-SRGF-1R    0.000000e+00             5.785856
#                   CoHiRF-SC-SRGF-2R    0.000000e+00             3.508103
#                   SC-SRGF              0.000000e+00             0.594499
# khan-2001         CoHiRF-SC-SRGF       5.099025e-17             1.495907
#                   CoHiRF-SC-SRGF-1R    1.215729e-02             3.077382
#                   CoHiRF-SC-SRGF-2R    1.578086e-02             3.137772
#                   SC-SRGF              2.943570e-03             1.067821
#
#                                      Davies-Bouldin std  ...  \
# Dataset           Model                                  ...
# alizadeh-2000-v2  CoHiRF-SC-SRGF               0.019373  ...
#                   CoHiRF-SC-SRGF-1R            0.008165  ...
#                   CoHiRF-SC-SRGF-2R            0.099667  ...
#                   SC-SRGF                      0.014104  ...
# alizadeh-2000-v3  CoHiRF-SC-SRGF               0.046857  ...
#                   CoHiRF-SC-SRGF-1R            0.088336  ...
#                   CoHiRF-SC-SRGF-2R            0.049966  ...
#                   SC-SRGF                      0.011096  ...
# armstrong-2002-v1 CoHiRF-SC-SRGF               0.224128  ...
#                   CoHiRF-SC-SRGF-1R            0.056583  ...
#                   CoHiRF-SC-SRGF-2R            0.128369  ...
#                   SC-SRGF                      0.021995  ...
# bittner-2000      CoHiRF-SC-SRGF               0.059929  ...
#                   CoHiRF-SC-SRGF-1R            0.209887  ...
#                   CoHiRF-SC-SRGF-2R            0.073743  ...
#                   SC-SRGF                      0.000000  ...
# bredel-2005       CoHiRF-SC-SRGF               0.128111  ...
#                   CoHiRF-SC-SRGF-1R            0.036691  ...
#                   CoHiRF-SC-SRGF-2R            0.042970  ...
#                   SC-SRGF                      0.004061  ...
# chowdary-2006     CoHiRF-SC-SRGF               0.044479  ...
#                   CoHiRF-SC-SRGF-1R            0.007784  ...
#                   CoHiRF-SC-SRGF-2R            0.082465  ...
#                   SC-SRGF                      0.022429  ...
# ecoli             CoHiRF-SC-SRGF               0.079678  ...
#                   CoHiRF-SC-SRGF-1R            1.834830  ...
#                   CoHiRF-SC-SRGF-2R            0.698899  ...
#                   SC-SRGF                      0.168471  ...
# garber-2001       CoHiRF-SC-SRGF               0.117843  ...
#                   CoHiRF-SC-SRGF-1R            0.018760  ...
#                   CoHiRF-SC-SRGF-2R            0.330822  ...
#                   SC-SRGF                      0.016465  ...
# golub-1999-v2     CoHiRF-SC-SRGF               0.146068  ...
#                   CoHiRF-SC-SRGF-1R            0.016301  ...
#                   CoHiRF-SC-SRGF-2R            0.019661  ...
#                   SC-SRGF                      0.009644  ...
# iris              CoHiRF-SC-SRGF               0.046894  ...
#                   CoHiRF-SC-SRGF-1R            2.522062  ...
#                   CoHiRF-SC-SRGF-2R            0.801687  ...
#                   SC-SRGF                      0.000870  ...
# khan-2001         CoHiRF-SC-SRGF               0.001157  ...
#                   CoHiRF-SC-SRGF-1R            0.154970  ...
#                   CoHiRF-SC-SRGF-2R            0.147706  ...
#                   SC-SRGF                      0.014631  ...
#
#                                                  Calinski         Silhouette  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF        7.422 $\pm$ 0.041  0.094 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-1R    12.338 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R    12.338 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   SC-SRGF              12.338 $\pm$ 0.000  0.194 $\pm$ 0.000
# alizadeh-2000-v3  CoHiRF-SC-SRGF        7.411 $\pm$ 0.060  0.093 $\pm$ 0.002
#                   CoHiRF-SC-SRGF-1R    12.341 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R    12.341 $\pm$ 0.000  0.194 $\pm$ 0.000
#                   SC-SRGF              12.341 $\pm$ 0.000  0.194 $\pm$ 0.000
# armstrong-2002-v1 CoHiRF-SC-SRGF        3.424 $\pm$ 0.055  0.027 $\pm$ 0.005
#                   CoHiRF-SC-SRGF-1R     4.857 $\pm$ 0.020  0.066 $\pm$ 0.003
#                   CoHiRF-SC-SRGF-2R     4.813 $\pm$ 0.018  0.072 $\pm$ 0.007
#                   SC-SRGF               4.812 $\pm$ 0.029  0.067 $\pm$ 0.004
# bittner-2000      CoHiRF-SC-SRGF        2.998 $\pm$ 0.125  0.057 $\pm$ 0.005
#                   CoHiRF-SC-SRGF-1R     5.054 $\pm$ 0.080  0.081 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-2R     5.089 $\pm$ 0.000  0.081 $\pm$ 0.000
#                   SC-SRGF               4.982 $\pm$ 0.099  0.075 $\pm$ 0.013
# bredel-2005       CoHiRF-SC-SRGF        2.970 $\pm$ 0.182  0.036 $\pm$ 0.004
#                   CoHiRF-SC-SRGF-1R     4.653 $\pm$ 0.101  0.072 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-2R     4.648 $\pm$ 0.097  0.071 $\pm$ 0.001
#                   SC-SRGF               4.630 $\pm$ 0.088  0.071 $\pm$ 0.001
# chowdary-2006     CoHiRF-SC-SRGF       30.348 $\pm$ 5.508  0.174 $\pm$ 0.006
#                   CoHiRF-SC-SRGF-1R    27.737 $\pm$ 0.026  0.175 $\pm$ 0.001
#                   CoHiRF-SC-SRGF-2R    37.211 $\pm$ 6.024  0.273 $\pm$ 0.223
#                   SC-SRGF              23.009 $\pm$ 4.973  0.222 $\pm$ 0.007
# ecoli             CoHiRF-SC-SRGF      99.576 $\pm$ 12.660  0.347 $\pm$ 0.021
#                   CoHiRF-SC-SRGF-1R  129.588 $\pm$ 10.047  0.488 $\pm$ 0.121
#                   CoHiRF-SC-SRGF-2R   129.008 $\pm$ 7.999  0.578 $\pm$ 0.048
#                   SC-SRGF            128.087 $\pm$ 10.908  0.482 $\pm$ 0.126
# garber-2001       CoHiRF-SC-SRGF        3.922 $\pm$ 0.107  0.054 $\pm$ 0.019
#                   CoHiRF-SC-SRGF-1R     4.994 $\pm$ 0.030  0.060 $\pm$ 0.002
#                   CoHiRF-SC-SRGF-2R     4.995 $\pm$ 0.055  0.229 $\pm$ 0.097
#                   SC-SRGF               4.966 $\pm$ 0.066  0.059 $\pm$ 0.003
# golub-1999-v2     CoHiRF-SC-SRGF        3.163 $\pm$ 0.071  0.046 $\pm$ 0.010
#                   CoHiRF-SC-SRGF-1R     4.444 $\pm$ 0.000  0.091 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R     4.395 $\pm$ 0.108  0.085 $\pm$ 0.008
#                   SC-SRGF               4.402 $\pm$ 0.113  0.087 $\pm$ 0.009
# iris              CoHiRF-SC-SRGF     160.846 $\pm$ 14.294  0.344 $\pm$ 0.028
#                   CoHiRF-SC-SRGF-1R   241.038 $\pm$ 0.000  0.579 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-2R   241.038 $\pm$ 0.000  0.579 $\pm$ 0.000
#                   SC-SRGF             241.038 $\pm$ 0.000  0.579 $\pm$ 0.000
# khan-2001         CoHiRF-SC-SRGF        9.081 $\pm$ 0.000  0.123 $\pm$ 0.000
#                   CoHiRF-SC-SRGF-1R    11.001 $\pm$ 0.986  0.129 $\pm$ 0.012
#                   CoHiRF-SC-SRGF-2R    11.379 $\pm$ 1.168  0.136 $\pm$ 0.016
#                   SC-SRGF              10.359 $\pm$ 0.482  0.129 $\pm$ 0.003
#
#                                         Davies-Bouldin                  NMI  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     1.550 $\pm$ 0.019  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  2.460 $\pm$ 0.008  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  2.786 $\pm$ 0.100  No Run $\pm$ No Run
#                   SC-SRGF            0.936 $\pm$ 0.014  No Run $\pm$ No Run
# alizadeh-2000-v3  CoHiRF-SC-SRGF     1.562 $\pm$ 0.047  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  2.496 $\pm$ 0.088  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  2.746 $\pm$ 0.050  No Run $\pm$ No Run
#                   SC-SRGF            0.931 $\pm$ 0.011  No Run $\pm$ No Run
# armstrong-2002-v1 CoHiRF-SC-SRGF     2.003 $\pm$ 0.224  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.431 $\pm$ 0.057  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.514 $\pm$ 0.128  No Run $\pm$ No Run
#                   SC-SRGF            1.344 $\pm$ 0.022  No Run $\pm$ No Run
# bittner-2000      CoHiRF-SC-SRGF     1.638 $\pm$ 0.060  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.237 $\pm$ 0.210  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.296 $\pm$ 0.074  No Run $\pm$ No Run
#                   SC-SRGF            0.644 $\pm$ 0.000  No Run $\pm$ No Run
# bredel-2005       CoHiRF-SC-SRGF     1.979 $\pm$ 0.128  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.384 $\pm$ 0.037  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.398 $\pm$ 0.043  No Run $\pm$ No Run
#                   SC-SRGF            0.948 $\pm$ 0.004  No Run $\pm$ No Run
# chowdary-2006     CoHiRF-SC-SRGF     1.450 $\pm$ 0.044  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  2.401 $\pm$ 0.008  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  2.227 $\pm$ 0.082  No Run $\pm$ No Run
#                   SC-SRGF            1.101 $\pm$ 0.022  No Run $\pm$ No Run
# ecoli             CoHiRF-SC-SRGF     1.096 $\pm$ 0.080  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  9.193 $\pm$ 1.835  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  8.176 $\pm$ 0.699  No Run $\pm$ No Run
#                   SC-SRGF            1.048 $\pm$ 0.168  No Run $\pm$ No Run
# garber-2001       CoHiRF-SC-SRGF     1.909 $\pm$ 0.118  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.883 $\pm$ 0.019  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  5.633 $\pm$ 0.331  No Run $\pm$ No Run
#                   SC-SRGF            1.130 $\pm$ 0.016  No Run $\pm$ No Run
# golub-1999-v2     CoHiRF-SC-SRGF     2.577 $\pm$ 0.146  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  4.359 $\pm$ 0.016  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  4.357 $\pm$ 0.020  No Run $\pm$ No Run
#                   SC-SRGF            1.346 $\pm$ 0.010  No Run $\pm$ No Run
# iris              CoHiRF-SC-SRGF     0.666 $\pm$ 0.047  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  5.786 $\pm$ 2.522  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.508 $\pm$ 0.802  No Run $\pm$ No Run
#                   SC-SRGF            0.594 $\pm$ 0.001  No Run $\pm$ No Run
# khan-2001         CoHiRF-SC-SRGF     1.496 $\pm$ 0.001  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-1R  3.077 $\pm$ 0.155  No Run $\pm$ No Run
#                   CoHiRF-SC-SRGF-2R  3.138 $\pm$ 0.148  No Run $\pm$ No Run
#                   SC-SRGF            1.068 $\pm$ 0.015  No Run $\pm$ No Run
#
#                                     Best Time mean Best Time std  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF          1.502521      1.527316
#                   CoHiRF-SC-SRGF-1R       2.728309      1.494230
#                   CoHiRF-SC-SRGF-2R       1.139747      0.893580
#                   SC-SRGF                 0.132367      0.060518
# alizadeh-2000-v3  CoHiRF-SC-SRGF          0.927956      1.145873
#                   CoHiRF-SC-SRGF-1R       2.690607      1.493027
#                   CoHiRF-SC-SRGF-2R       1.710233      1.350194
#                   SC-SRGF                 0.124241      0.055440
# armstrong-2002-v1 CoHiRF-SC-SRGF          2.140431      1.544010
#                   CoHiRF-SC-SRGF-1R       1.248730      1.040931
#                   CoHiRF-SC-SRGF-2R       1.535638      1.150990
#                   SC-SRGF                 0.125167      0.048224
# bittner-2000      CoHiRF-SC-SRGF          1.282099      1.412894
#                   CoHiRF-SC-SRGF-1R       0.878542      0.715287
#                   CoHiRF-SC-SRGF-2R       1.490394      1.358471
#                   SC-SRGF                 0.105343      0.036229
# bredel-2005       CoHiRF-SC-SRGF          1.668421      1.462455
#                   CoHiRF-SC-SRGF-1R       1.496681      1.317406
#                   CoHiRF-SC-SRGF-2R       1.427503      0.858615
#                   SC-SRGF                 0.130454      0.056565
# chowdary-2006     CoHiRF-SC-SRGF          1.712733      1.667703
#                   CoHiRF-SC-SRGF-1R       1.658108      1.271078
#                   CoHiRF-SC-SRGF-2R       1.534043      1.448606
#                   SC-SRGF                 0.179057      0.093283
# ecoli             CoHiRF-SC-SRGF          4.822936      2.436954
#                   CoHiRF-SC-SRGF-1R       7.849057      4.694561
#                   CoHiRF-SC-SRGF-2R       6.285974      4.053049
#                   SC-SRGF                 1.712211      0.620544
# garber-2001       CoHiRF-SC-SRGF          1.612772      1.551317
#                   CoHiRF-SC-SRGF-1R       1.043650      0.719110
#                   CoHiRF-SC-SRGF-2R       1.950651      1.524166
#                   SC-SRGF                 0.156353      0.065674
# golub-1999-v2     CoHiRF-SC-SRGF          2.415331      1.679461
#                   CoHiRF-SC-SRGF-1R       1.360296      0.868320
#                   CoHiRF-SC-SRGF-2R       1.836284      1.073775
#                   SC-SRGF                 0.153527      0.060466
# iris              CoHiRF-SC-SRGF          2.021998      1.544135
#                   CoHiRF-SC-SRGF-1R       2.558706      1.658375
#                   CoHiRF-SC-SRGF-2R       2.967172      1.467916
#                   SC-SRGF                 0.507478      0.202236
# khan-2001         CoHiRF-SC-SRGF          1.721322      1.493175
#                   CoHiRF-SC-SRGF-1R       1.784251      1.222033
#                   CoHiRF-SC-SRGF-2R       1.465407      0.860669
#                   SC-SRGF                 0.181645      0.077768
#
#                                     HPO Time mean HPO Time std  \
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF       254.263677    14.525489
#                   CoHiRF-SC-SRGF-1R    465.764812    12.556021
#                   CoHiRF-SC-SRGF-2R    464.901043    13.335319
#                   SC-SRGF              142.764289     4.481168
# alizadeh-2000-v3  CoHiRF-SC-SRGF       245.332303    13.850124
#                   CoHiRF-SC-SRGF-1R    472.987630    16.824960
#                   CoHiRF-SC-SRGF-2R    467.785453    11.040683
#                   SC-SRGF              144.219011     6.543856
# armstrong-2002-v1 CoHiRF-SC-SRGF       190.755878    11.710467
#                   CoHiRF-SC-SRGF-1R    375.496893    13.205821
#                   CoHiRF-SC-SRGF-2R    387.586552    22.559058
#                   SC-SRGF               82.755206     2.381323
# bittner-2000      CoHiRF-SC-SRGF       259.234083    12.459740
#                   CoHiRF-SC-SRGF-1R    471.789932    15.727003
#                   CoHiRF-SC-SRGF-2R    480.290878    19.577892
#                   SC-SRGF              149.117562     7.487919
# bredel-2005       CoHiRF-SC-SRGF       231.742947    12.202084
#                   CoHiRF-SC-SRGF-1R    433.777673    11.010551
#                   CoHiRF-SC-SRGF-2R    436.323326    13.524715
#                   SC-SRGF              118.755112     3.830431
# chowdary-2006     CoHiRF-SC-SRGF       130.319966    11.670350
#                   CoHiRF-SC-SRGF-1R    315.541232    19.913437
#                   CoHiRF-SC-SRGF-2R    323.274716    23.905327
#                   SC-SRGF               29.309950     2.844865
# ecoli             CoHiRF-SC-SRGF       299.833662    37.448043
#                   CoHiRF-SC-SRGF-1R    673.787801   112.311175
#                   CoHiRF-SC-SRGF-2R    629.631519    93.896784
#                   SC-SRGF              107.123338    15.567436
# garber-2001       CoHiRF-SC-SRGF       462.721112    15.302741
#                   CoHiRF-SC-SRGF-1R    757.733812    22.020861
#                   CoHiRF-SC-SRGF-2R    781.040642    29.082376
#                   SC-SRGF              339.446672    12.269810
# golub-1999-v2     CoHiRF-SC-SRGF       257.774426    12.362427
#                   CoHiRF-SC-SRGF-1R    458.188628    17.175794
#                   CoHiRF-SC-SRGF-2R    480.858125    20.513361
#                   SC-SRGF              139.055884     4.958236
# iris              CoHiRF-SC-SRGF       176.195428    26.379460
#                   CoHiRF-SC-SRGF-1R    348.785974    25.574185
#                   CoHiRF-SC-SRGF-2R    371.337067    26.004133
#                   SC-SRGF               38.979112     4.576524
# khan-2001         CoHiRF-SC-SRGF       200.454636     9.112512
#                   CoHiRF-SC-SRGF-1R    389.499703    17.669403
#                   CoHiRF-SC-SRGF-2R    387.903977    22.471055
#                   SC-SRGF               94.799463     3.027056
#
#                                              Best Time               HPO Time
# Dataset           Model
# alizadeh-2000-v2  CoHiRF-SC-SRGF     1.503 $\pm$ 1.527   254.264 $\pm$ 14.525
#                   CoHiRF-SC-SRGF-1R  2.728 $\pm$ 1.494   465.765 $\pm$ 12.556
#                   CoHiRF-SC-SRGF-2R  1.140 $\pm$ 0.894   464.901 $\pm$ 13.335
#                   SC-SRGF            0.132 $\pm$ 0.061    142.764 $\pm$ 4.481
# alizadeh-2000-v3  CoHiRF-SC-SRGF     0.928 $\pm$ 1.146   245.332 $\pm$ 13.850
#                   CoHiRF-SC-SRGF-1R  2.691 $\pm$ 1.493   472.988 $\pm$ 16.825
#                   CoHiRF-SC-SRGF-2R  1.710 $\pm$ 1.350   467.785 $\pm$ 11.041
#                   SC-SRGF            0.124 $\pm$ 0.055    144.219 $\pm$ 6.544
# armstrong-2002-v1 CoHiRF-SC-SRGF     2.140 $\pm$ 1.544   190.756 $\pm$ 11.710
#                   CoHiRF-SC-SRGF-1R  1.249 $\pm$ 1.041   375.497 $\pm$ 13.206
#                   CoHiRF-SC-SRGF-2R  1.536 $\pm$ 1.151   387.587 $\pm$ 22.559
#                   SC-SRGF            0.125 $\pm$ 0.048     82.755 $\pm$ 2.381
# bittner-2000      CoHiRF-SC-SRGF     1.282 $\pm$ 1.413   259.234 $\pm$ 12.460
#                   CoHiRF-SC-SRGF-1R  0.879 $\pm$ 0.715   471.790 $\pm$ 15.727
#                   CoHiRF-SC-SRGF-2R  1.490 $\pm$ 1.358   480.291 $\pm$ 19.578
#                   SC-SRGF            0.105 $\pm$ 0.036    149.118 $\pm$ 7.488
# bredel-2005       CoHiRF-SC-SRGF     1.668 $\pm$ 1.462   231.743 $\pm$ 12.202
#                   CoHiRF-SC-SRGF-1R  1.497 $\pm$ 1.317   433.778 $\pm$ 11.011
#                   CoHiRF-SC-SRGF-2R  1.428 $\pm$ 0.859   436.323 $\pm$ 13.525
#                   SC-SRGF            0.130 $\pm$ 0.057    118.755 $\pm$ 3.830
# chowdary-2006     CoHiRF-SC-SRGF     1.713 $\pm$ 1.668   130.320 $\pm$ 11.670
#                   CoHiRF-SC-SRGF-1R  1.658 $\pm$ 1.271   315.541 $\pm$ 19.913
#                   CoHiRF-SC-SRGF-2R  1.534 $\pm$ 1.449   323.275 $\pm$ 23.905
#                   SC-SRGF            0.179 $\pm$ 0.093     29.310 $\pm$ 2.845
# ecoli             CoHiRF-SC-SRGF     4.823 $\pm$ 2.437   299.834 $\pm$ 37.448
#                   CoHiRF-SC-SRGF-1R  7.849 $\pm$ 4.695  673.788 $\pm$ 112.311
#                   CoHiRF-SC-SRGF-2R  6.286 $\pm$ 4.053   629.632 $\pm$ 93.897
#                   SC-SRGF            1.712 $\pm$ 0.621   107.123 $\pm$ 15.567
# garber-2001       CoHiRF-SC-SRGF     1.613 $\pm$ 1.551   462.721 $\pm$ 15.303
#                   CoHiRF-SC-SRGF-1R  1.044 $\pm$ 0.719   757.734 $\pm$ 22.021
#                   CoHiRF-SC-SRGF-2R  1.951 $\pm$ 1.524   781.041 $\pm$ 29.082
#                   SC-SRGF            0.156 $\pm$ 0.066   339.447 $\pm$ 12.270
# golub-1999-v2     CoHiRF-SC-SRGF     2.415 $\pm$ 1.679   257.774 $\pm$ 12.362
#                   CoHiRF-SC-SRGF-1R  1.360 $\pm$ 0.868   458.189 $\pm$ 17.176
#                   CoHiRF-SC-SRGF-2R  1.836 $\pm$ 1.074   480.858 $\pm$ 20.513
#                   SC-SRGF            0.154 $\pm$ 0.060    139.056 $\pm$ 4.958
# iris              CoHiRF-SC-SRGF     2.022 $\pm$ 1.544   176.195 $\pm$ 26.379
#                   CoHiRF-SC-SRGF-1R  2.559 $\pm$ 1.658   348.786 $\pm$ 25.574
#                   CoHiRF-SC-SRGF-2R  2.967 $\pm$ 1.468   371.337 $\pm$ 26.004
#                   SC-SRGF            0.507 $\pm$ 0.202     38.979 $\pm$ 4.577
# khan-2001         CoHiRF-SC-SRGF     1.721 $\pm$ 1.493    200.455 $\pm$ 9.113
#                   CoHiRF-SC-SRGF-1R  1.784 $\pm$ 1.222   389.500 $\pm$ 17.669
#                   CoHiRF-SC-SRGF-2R  1.465 $\pm$ 0.861   387.904 $\pm$ 22.471
#                   SC-SRGF            0.182 $\pm$ 0.078     94.799 $\pm$ 3.027
#
# [44 rows x 24 columns]

# %% [markdown]
# The following will provide the latex code for a clean table, we only need to make a little adjustement in the first line to delete the "key" and have only one header. For the longtable environment (full data) we need to add the "\*" at the end of lines we dont want to have a page break. We also should replace the entire begin{table} ... end{table} by begin{longtable} ... end{longtable} in the latex file, if you want to put caption and labels you should break the line after with '\\' (put both on the same line!)

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{4}{*}{alizadeh-2000-v2} & CoHiRF-SC-SRGF & 0.633 $\pm$ 0.042 & 0.758 $\pm$ 0.031 & \underline{7.422 $\pm$ 0.041} & \underline{0.094 $\pm$ 0.001} & \underline{1.550 $\pm$ 0.019} & 1.503 $\pm$ 1.527 & 254.264 $\pm$ 14.525 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.947 $\pm$ 0.000 & \bfseries 0.922 $\pm$ 0.000 & \bfseries 12.338 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & 2.460 $\pm$ 0.008 & 2.728 $\pm$ 1.494 & 465.765 $\pm$ 12.556 \\
#  & CoHiRF-SC-SRGF-2R & \bfseries 0.947 $\pm$ 0.000 & \bfseries 0.922 $\pm$ 0.000 & \bfseries 12.338 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & 2.786 $\pm$ 0.100 & 1.140 $\pm$ 0.894 & 464.901 $\pm$ 13.335 \\
#  & SC-SRGF & \underline{0.891 $\pm$ 0.125} & \underline{0.854 $\pm$ 0.093} & \bfseries 12.338 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & \bfseries 0.936 $\pm$ 0.014 & 0.132 $\pm$ 0.061 & 142.764 $\pm$ 4.481 \\
# \cline{1-9}
# \multirow[c]{4}{*}{alizadeh-2000-v3} & CoHiRF-SC-SRGF & \underline{0.443 $\pm$ 0.013} & 0.628 $\pm$ 0.019 & \underline{7.411 $\pm$ 0.060} & \underline{0.093 $\pm$ 0.002} & \underline{1.562 $\pm$ 0.047} & 0.928 $\pm$ 1.146 & 245.332 $\pm$ 13.850 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.519 $\pm$ 0.000 & \bfseries 0.724 $\pm$ 0.000 & \bfseries 12.341 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & 2.496 $\pm$ 0.088 & 2.691 $\pm$ 1.493 & 472.988 $\pm$ 16.825 \\
#  & CoHiRF-SC-SRGF-2R & \bfseries 0.519 $\pm$ 0.000 & \bfseries 0.724 $\pm$ 0.000 & \bfseries 12.341 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & 2.746 $\pm$ 0.050 & 1.710 $\pm$ 1.350 & 467.785 $\pm$ 11.041 \\
#  & SC-SRGF & \bfseries 0.519 $\pm$ 0.000 & \underline{0.702 $\pm$ 0.048} & \bfseries 12.341 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & \bfseries 0.931 $\pm$ 0.011 & 0.124 $\pm$ 0.055 & 144.219 $\pm$ 6.544 \\
# \cline{1-9}
# \multirow[c]{4}{*}{armstrong-2002-v1} & CoHiRF-SC-SRGF & 0.372 $\pm$ 0.039 & \bfseries 0.445 $\pm$ 0.017 & 3.424 $\pm$ 0.055 & 0.027 $\pm$ 0.005 & \underline{2.003 $\pm$ 0.224} & 2.140 $\pm$ 1.544 & 190.756 $\pm$ 11.710 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.463 $\pm$ 0.117 & 0.403 $\pm$ 0.016 & \bfseries 4.857 $\pm$ 0.020 & 0.066 $\pm$ 0.003 & 3.431 $\pm$ 0.057 & 1.249 $\pm$ 1.041 & 375.497 $\pm$ 13.206 \\
#  & CoHiRF-SC-SRGF-2R & \underline{0.446 $\pm$ 0.111} & 0.419 $\pm$ 0.016 & \underline{4.813 $\pm$ 0.018} & \bfseries 0.072 $\pm$ 0.007 & 3.514 $\pm$ 0.128 & 1.536 $\pm$ 1.151 & 387.587 $\pm$ 22.559 \\
#  & SC-SRGF & 0.313 $\pm$ 0.046 & \underline{0.421 $\pm$ 0.096} & 4.812 $\pm$ 0.029 & \underline{0.067 $\pm$ 0.004} & \bfseries 1.344 $\pm$ 0.022 & 0.125 $\pm$ 0.048 & 82.755 $\pm$ 2.381 \\
# \cline{1-9}
# \multirow[c]{4}{*}{bittner-2000} & CoHiRF-SC-SRGF & 0.058 $\pm$ 0.023 & 0.103 $\pm$ 0.023 & 2.998 $\pm$ 0.125 & 0.057 $\pm$ 0.005 & \underline{1.638 $\pm$ 0.060} & 1.282 $\pm$ 1.413 & 259.234 $\pm$ 12.460 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.169 $\pm$ 0.019 & \bfseries 0.224 $\pm$ 0.027 & \underline{5.054 $\pm$ 0.080} & \bfseries 0.081 $\pm$ 0.001 & 3.237 $\pm$ 0.210 & 0.879 $\pm$ 0.715 & 471.790 $\pm$ 15.727 \\
#  & CoHiRF-SC-SRGF-2R & \underline{0.141 $\pm$ 0.010} & 0.191 $\pm$ 0.038 & \bfseries 5.089 $\pm$ 0.000 & \bfseries 0.081 $\pm$ 0.000 & 3.296 $\pm$ 0.074 & 1.490 $\pm$ 1.358 & 480.291 $\pm$ 19.578 \\
#  & SC-SRGF & 0.132 $\pm$ 0.035 & \underline{0.205 $\pm$ 0.046} & 4.982 $\pm$ 0.099 & \underline{0.075 $\pm$ 0.013} & \bfseries 0.644 $\pm$ 0.000 & 0.105 $\pm$ 0.036 & 149.118 $\pm$ 7.488 \\
# \cline{1-9}
# \multirow[c]{4}{*}{bredel-2005} & CoHiRF-SC-SRGF & 0.326 $\pm$ 0.025 & 0.413 $\pm$ 0.027 & 2.970 $\pm$ 0.182 & 0.036 $\pm$ 0.004 & \underline{1.979 $\pm$ 0.128} & 1.668 $\pm$ 1.462 & 231.743 $\pm$ 12.202 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.655 $\pm$ 0.037 & 0.525 $\pm$ 0.059 & \bfseries 4.653 $\pm$ 0.101 & \bfseries 0.072 $\pm$ 0.001 & 3.384 $\pm$ 0.037 & 1.497 $\pm$ 1.317 & 433.778 $\pm$ 11.011 \\
#  & CoHiRF-SC-SRGF-2R & \underline{0.653 $\pm$ 0.035} & \underline{0.530 $\pm$ 0.034} & \underline{4.648 $\pm$ 0.097} & \underline{0.071 $\pm$ 0.001} & 3.398 $\pm$ 0.043 & 1.428 $\pm$ 0.859 & 436.323 $\pm$ 13.525 \\
#  & SC-SRGF & 0.640 $\pm$ 0.034 & \bfseries 0.538 $\pm$ 0.047 & 4.630 $\pm$ 0.088 & \underline{0.071 $\pm$ 0.001} & \bfseries 0.948 $\pm$ 0.004 & 0.130 $\pm$ 0.057 & 118.755 $\pm$ 3.830 \\
# \cline{1-9}
# \multirow[c]{4}{*}{chowdary-2006} & CoHiRF-SC-SRGF & \underline{0.702 $\pm$ 0.042} & \underline{0.647 $\pm$ 0.058} & \underline{30.348 $\pm$ 5.508} & 0.174 $\pm$ 0.006 & \underline{1.450 $\pm$ 0.044} & 1.713 $\pm$ 1.668 & 130.320 $\pm$ 11.670 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.924 $\pm$ 0.000 & \bfseries 0.859 $\pm$ 0.000 & 27.737 $\pm$ 0.026 & 0.175 $\pm$ 0.001 & 2.401 $\pm$ 0.008 & 1.658 $\pm$ 1.271 & 315.541 $\pm$ 19.913 \\
#  & CoHiRF-SC-SRGF-2R & \bfseries 0.924 $\pm$ 0.000 & \bfseries 0.859 $\pm$ 0.000 & \bfseries 37.211 $\pm$ 6.024 & \bfseries 0.273 $\pm$ 0.223 & 2.227 $\pm$ 0.082 & 1.534 $\pm$ 1.449 & 323.275 $\pm$ 23.905 \\
#  & SC-SRGF & \bfseries 0.924 $\pm$ 0.000 & \bfseries 0.859 $\pm$ 0.000 & 23.009 $\pm$ 4.973 & \underline{0.222 $\pm$ 0.007} & \bfseries 1.101 $\pm$ 0.022 & 0.179 $\pm$ 0.093 & 29.310 $\pm$ 2.845 \\
# \cline{1-9}
# \multirow[c]{4}{*}{ecoli} & CoHiRF-SC-SRGF & 0.723 $\pm$ 0.011 & 0.668 $\pm$ 0.015 & 99.576 $\pm$ 12.660 & 0.347 $\pm$ 0.021 & \underline{1.096 $\pm$ 0.080} & 4.823 $\pm$ 2.437 & 299.834 $\pm$ 37.448 \\
#  & CoHiRF-SC-SRGF-1R & \underline{0.724 $\pm$ 0.003} & \underline{0.682 $\pm$ 0.013} & \bfseries 129.588 $\pm$ 10.047 & \underline{0.488 $\pm$ 0.121} & 9.193 $\pm$ 1.835 & 7.849 $\pm$ 4.695 & 673.788 $\pm$ 112.311 \\
#  & CoHiRF-SC-SRGF-2R & \bfseries 0.730 $\pm$ 0.011 & \bfseries 0.695 $\pm$ 0.014 & \underline{129.008 $\pm$ 7.999} & \bfseries 0.578 $\pm$ 0.048 & 8.176 $\pm$ 0.699 & 6.286 $\pm$ 4.053 & 629.632 $\pm$ 93.897 \\
#  & SC-SRGF & 0.713 $\pm$ 0.008 & 0.676 $\pm$ 0.008 & 128.087 $\pm$ 10.908 & 0.482 $\pm$ 0.126 & \bfseries 1.048 $\pm$ 0.168 & 1.712 $\pm$ 0.621 & 107.123 $\pm$ 15.567 \\
# \cline{1-9}
# \multirow[c]{4}{*}{garber-2001} & CoHiRF-SC-SRGF & \underline{0.437 $\pm$ 0.054} & \underline{0.323 $\pm$ 0.016} & 3.922 $\pm$ 0.107 & 0.054 $\pm$ 0.019 & \underline{1.909 $\pm$ 0.118} & 1.613 $\pm$ 1.551 & 462.721 $\pm$ 15.303 \\
#  & CoHiRF-SC-SRGF-1R & 0.235 $\pm$ 0.013 & 0.265 $\pm$ 0.015 & \underline{4.994 $\pm$ 0.030} & \underline{0.060 $\pm$ 0.002} & 3.883 $\pm$ 0.019 & 1.044 $\pm$ 0.719 & 757.734 $\pm$ 22.021 \\
#  & CoHiRF-SC-SRGF-2R & \bfseries 0.454 $\pm$ 0.034 & \bfseries 0.333 $\pm$ 0.009 & \bfseries 4.995 $\pm$ 0.055 & \bfseries 0.229 $\pm$ 0.097 & 5.633 $\pm$ 0.331 & 1.951 $\pm$ 1.524 & 781.041 $\pm$ 29.082 \\
#  & SC-SRGF & 0.204 $\pm$ 0.035 & 0.251 $\pm$ 0.023 & 4.966 $\pm$ 0.066 & 0.059 $\pm$ 0.003 & \bfseries 1.130 $\pm$ 0.016 & 0.156 $\pm$ 0.066 & 339.447 $\pm$ 12.270 \\
# \cline{1-9}
# \multirow[c]{4}{*}{golub-1999-v2} & CoHiRF-SC-SRGF & 0.352 $\pm$ 0.043 & 0.451 $\pm$ 0.035 & 3.163 $\pm$ 0.071 & 0.046 $\pm$ 0.010 & \underline{2.577 $\pm$ 0.146} & 2.415 $\pm$ 1.679 & 257.774 $\pm$ 12.362 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.378 $\pm$ 0.054 & \bfseries 0.466 $\pm$ 0.023 & \bfseries 4.444 $\pm$ 0.000 & \bfseries 0.091 $\pm$ 0.000 & 4.359 $\pm$ 0.016 & 1.360 $\pm$ 0.868 & 458.189 $\pm$ 17.176 \\
#  & CoHiRF-SC-SRGF-2R & \underline{0.367 $\pm$ 0.055} & 0.453 $\pm$ 0.058 & 4.395 $\pm$ 0.108 & 0.085 $\pm$ 0.008 & 4.357 $\pm$ 0.020 & 1.836 $\pm$ 1.074 & 480.858 $\pm$ 20.513 \\
#  & SC-SRGF & 0.298 $\pm$ 0.030 & \underline{0.455 $\pm$ 0.022} & \underline{4.402 $\pm$ 0.113} & \underline{0.087 $\pm$ 0.009} & \bfseries 1.346 $\pm$ 0.010 & 0.154 $\pm$ 0.060 & 139.056 $\pm$ 4.958 \\
# \cline{1-9}
# \multirow[c]{4}{*}{iris} & CoHiRF-SC-SRGF & 0.726 $\pm$ 0.032 & 0.718 $\pm$ 0.030 & \underline{160.846 $\pm$ 14.294} & \underline{0.344 $\pm$ 0.028} & \underline{0.666 $\pm$ 0.047} & 2.022 $\pm$ 1.544 & 176.195 $\pm$ 26.379 \\
#  & CoHiRF-SC-SRGF-1R & \bfseries 0.886 $\pm$ 0.008 & \bfseries 0.860 $\pm$ 0.000 & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & 5.786 $\pm$ 2.522 & 2.559 $\pm$ 1.658 & 348.786 $\pm$ 25.574 \\
#  & CoHiRF-SC-SRGF-2R & \underline{0.827 $\pm$ 0.036} & 0.803 $\pm$ 0.037 & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & 3.508 $\pm$ 0.802 & 2.967 $\pm$ 1.468 & 371.337 $\pm$ 26.004 \\
#  & SC-SRGF & 0.777 $\pm$ 0.078 & \underline{0.850 $\pm$ 0.025} & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & \bfseries 0.594 $\pm$ 0.001 & 0.507 $\pm$ 0.202 & 38.979 $\pm$ 4.577 \\
# \cline{1-9}
# \multirow[c]{4}{*}{khan-2001} & CoHiRF-SC-SRGF & 0.404 $\pm$ 0.017 & 0.552 $\pm$ 0.034 & 9.081 $\pm$ 0.000 & 0.123 $\pm$ 0.000 & \underline{1.496 $\pm$ 0.001} & 1.721 $\pm$ 1.493 & 200.455 $\pm$ 9.113 \\
#  & CoHiRF-SC-SRGF-1R & \underline{0.406 $\pm$ 0.000} & \underline{0.555 $\pm$ 0.000} & \underline{11.001 $\pm$ 0.986} & \underline{0.129 $\pm$ 0.012} & 3.077 $\pm$ 0.155 & 1.784 $\pm$ 1.222 & 389.500 $\pm$ 17.669 \\
#  & CoHiRF-SC-SRGF-2R & \bfseries 0.424 $\pm$ 0.007 & \bfseries 0.574 $\pm$ 0.005 & \bfseries 11.379 $\pm$ 1.168 & \bfseries 0.136 $\pm$ 0.016 & 3.138 $\pm$ 0.148 & 1.465 $\pm$ 0.861 & 387.904 $\pm$ 22.471 \\
#  & SC-SRGF & 0.364 $\pm$ 0.039 & 0.523 $\pm$ 0.007 & 10.359 $\pm$ 0.482 & \underline{0.129 $\pm$ 0.003} & \bfseries 1.068 $\pm$ 0.015 & 0.182 $\pm$ 0.078 & 94.799 $\pm$ 3.027 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # KMeans

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = [
    "garber-2001",
    "alizadeh-2000-v2",
    "golub-1999-v2",
    "armstrong-2002-v1",
    "nursery",
    "segment",
]
models_to_keep = [
    "K-Means",
    "CoHiRF",
	"CoHiRF-1000",
    "Batch CoHiRF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{3}{*}{alizadeh-2000-v2} & Batch CoHiRF & 0.360 $\pm$ 0.014 & 0.507 $\pm$ 0.021 & 4.274 $\pm$ 0.238 & 0.049 $\pm$ 0.010 & \bfseries 0.411 $\pm$ 0.084 & 0.143 $\pm$ 0.069 & 154.717 $\pm$ 4.251 \\
#  & CoHiRF & \bfseries 0.866 $\pm$ 0.007 & \bfseries 0.771 $\pm$ 0.030 & \underline{15.094 $\pm$ 0.126} & \underline{0.196 $\pm$ 0.015} & \underline{0.896 $\pm$ 0.083} & 0.054 $\pm$ 0.033 & 142.623 $\pm$ 4.180 \\
#  & K-Means & \underline{0.838 $\pm$ 0.014} & \underline{0.767 $\pm$ 0.037} & \bfseries 15.151 $\pm$ 0.000 & \bfseries 0.204 $\pm$ 0.036 & 0.934 $\pm$ 0.021 & 0.012 $\pm$ 0.003 & 137.865 $\pm$ 3.673 \\
# \cline{1-9}
# \multirow[c]{3}{*}{armstrong-2002-v1} & Batch CoHiRF & 0.225 $\pm$ 0.071 & 0.267 $\pm$ 0.061 & 2.933 $\pm$ 0.333 & 0.003 $\pm$ 0.007 & \bfseries 0.401 $\pm$ 0.025 & 0.125 $\pm$ 0.039 & 90.402 $\pm$ 3.605 \\
#  & CoHiRF & \underline{0.664 $\pm$ 0.111} & \underline{0.594 $\pm$ 0.088} & \underline{6.153 $\pm$ 0.705} & \underline{0.212 $\pm$ 0.072} & \underline{0.862 $\pm$ 0.176} & 0.055 $\pm$ 0.020 & 83.250 $\pm$ 3.069 \\
#  & K-Means & \bfseries 0.787 $\pm$ 0.167 & \bfseries 0.799 $\pm$ 0.030 & \bfseries 6.477 $\pm$ 0.032 & \bfseries 0.244 $\pm$ 0.062 & 0.903 $\pm$ 0.046 & 0.007 $\pm$ 0.002 & 74.288 $\pm$ 1.689 \\
# \cline{1-9}
# \multirow[c]{3}{*}{garber-2001} & Batch CoHiRF & 0.167 $\pm$ 0.050 & 0.164 $\pm$ 0.031 & 3.287 $\pm$ 0.090 & 0.113 $\pm$ 0.008 & \bfseries 0.431 $\pm$ 0.050 & 0.832 $\pm$ 0.494 & 393.396 $\pm$ 15.517 \\
#  & CoHiRF & \bfseries 0.292 $\pm$ 0.022 & \underline{0.220 $\pm$ 0.025} & \bfseries 6.108 $\pm$ 0.097 & \underline{0.326 $\pm$ 0.005} & \underline{0.687 $\pm$ 0.205} & 0.200 $\pm$ 0.090 & 344.136 $\pm$ 6.666 \\
#  & K-Means & \underline{0.248 $\pm$ 0.044} & \bfseries 0.241 $\pm$ 0.027 & \underline{5.606 $\pm$ 1.264} & \bfseries 0.333 $\pm$ 0.000 & 0.825 $\pm$ 0.022 & 0.025 $\pm$ 0.006 & 329.200 $\pm$ 6.094 \\
# \cline{1-9}
# \multirow[c]{3}{*}{golub-1999-v2} & Batch CoHiRF & 0.172 $\pm$ 0.052 & 0.209 $\pm$ 0.023 & 2.525 $\pm$ 0.102 & 0.029 $\pm$ 0.028 & \bfseries 0.415 $\pm$ 0.024 & 0.339 $\pm$ 0.298 & 155.459 $\pm$ 5.299 \\
#  & CoHiRF & \bfseries 0.389 $\pm$ 0.089 & \underline{0.405 $\pm$ 0.051} & \underline{4.423 $\pm$ 0.125} & \underline{0.257 $\pm$ 0.048} & \underline{0.756 $\pm$ 0.165} & 0.156 $\pm$ 0.027 & 144.442 $\pm$ 2.735 \\
#  & K-Means & \underline{0.344 $\pm$ 0.096} & \bfseries 0.455 $\pm$ 0.074 & \bfseries 4.453 $\pm$ 0.058 & \bfseries 0.277 $\pm$ 0.000 & 0.979 $\pm$ 0.048 & 0.011 $\pm$ 0.003 & 131.550 $\pm$ 4.848 \\
# \cline{1-9}
# \multirow[c]{4}{*}{nursery} & Batch CoHiRF & 0.057 $\pm$ 0.012 & 0.144 $\pm$ 0.014 & 147.465 $\pm$ 46.081 & -0.002 $\pm$ 0.004 & \underline{1.779 $\pm$ 0.026} & 0.857 $\pm$ 1.117 & 99.038 $\pm$ 46.900 \\
#  & CoHiRF & 0.268 $\pm$ 0.052 & \underline{0.381 $\pm$ 0.082} & 930.024 $\pm$ 14.734 & \bfseries 0.101 $\pm$ 0.008 & \bfseries 1.430 $\pm$ 0.095 & 0.290 $\pm$ 0.068 & 69.145 $\pm$ 38.992 \\
#  & CoHiRF-1000 & \underline{0.270 $\pm$ 0.123} & 0.351 $\pm$ 0.102 & \underline{959.279 $\pm$ 102.840} & \underline{0.075 $\pm$ 0.002} & 2.588 $\pm$ 0.083 & 0.482 $\pm$ 0.746 & 73.060 $\pm$ 40.993 \\
#  & K-Means & \bfseries 0.415 $\pm$ 0.062 & \bfseries 0.403 $\pm$ 0.126 & \bfseries 1023.966 $\pm$ 0.000 & \underline{0.075 $\pm$ 0.002} & 2.279 $\pm$ 0.018 & 0.037 $\pm$ 0.041 & 45.344 $\pm$ 39.548 \\
# \cline{1-9}
# \multirow[c]{4}{*}{segment} & Batch CoHiRF & 0.488 $\pm$ 0.027 & 0.581 $\pm$ 0.015 & 524.240 $\pm$ 46.064 & 0.259 $\pm$ 0.029 & 1.237 $\pm$ 0.053 & 0.066 $\pm$ 0.041 & 25.752 $\pm$ 2.447 \\
#  & CoHiRF & \underline{0.510 $\pm$ 0.050} & 0.635 $\pm$ 0.015 & 901.901 $\pm$ 67.357 & \underline{0.774 $\pm$ 0.099} & \underline{0.663 $\pm$ 0.360} & 0.108 $\pm$ 0.108 & 24.406 $\pm$ 2.336 \\
#  & CoHiRF-1000 & 0.479 $\pm$ 0.013 & \underline{0.652 $\pm$ 0.025} & \underline{981.423 $\pm$ 65.649} & \bfseries 0.789 $\pm$ 0.049 & \bfseries 0.513 $\pm$ 0.375 & 0.065 $\pm$ 0.028 & 27.624 $\pm$ 2.701 \\
#  & K-Means & \bfseries 0.569 $\pm$ 0.011 & \bfseries 0.694 $\pm$ 0.008 & \bfseries 1067.878 $\pm$ 0.000 & 0.449 $\pm$ 0.003 & 0.833 $\pm$ 0.013 & 0.007 $\pm$ 0.002 & 15.112 $\pm$ 1.414 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Kernel KMeans

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = [
    "khan-2001",
    "bittner-2000",
    "iris",
    "satimage",
]
models_to_keep = [
    "Kernel RBF K-Means",
    "CoHiRF-KernelRBF",
    "Batch CoHiRF-KernelRBF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{3}{*}{bittner-2000} & Batch CoHiRF-KernelRBF & 0.088 $\pm$ 0.015 & 0.098 $\pm$ 0.011 & \bfseries 1.918 $\pm$ 0.217 & 0.041 $\pm$ 0.020 & \bfseries 0.499 $\pm$ 0.083 & 0.224 $\pm$ 0.180 & 171.649 $\pm$ 4.442 \\
#  & CoHiRF-KernelRBF & \bfseries 0.104 $\pm$ 0.049 & \underline{0.136 $\pm$ 0.043} & \underline{1.569 $\pm$ 0.146} & \bfseries 0.054 $\pm$ 0.066 & \underline{0.530 $\pm$ 0.053} & 0.191 $\pm$ 0.118 & 158.762 $\pm$ 4.244 \\
#  & Kernel RBF K-Means & \underline{0.090 $\pm$ 0.038} & \bfseries 0.137 $\pm$ 0.034 & 1.334 $\pm$ 0.128 & \underline{0.043 $\pm$ 0.021} & 0.905 $\pm$ 0.014 & 0.062 $\pm$ 0.017 & 148.491 $\pm$ 2.636 \\
# \cline{1-9}
# \multirow[c]{3}{*}{iris} & Batch CoHiRF-KernelRBF & \underline{0.687 $\pm$ 0.090} & 0.704 $\pm$ 0.073 & 121.522 $\pm$ 26.880 & 0.396 $\pm$ 0.162 & 0.889 $\pm$ 0.169 & 0.351 $\pm$ 1.119 & 28.475 $\pm$ 4.454 \\
#  & CoHiRF-KernelRBF & \bfseries 0.813 $\pm$ 0.084 & \bfseries 0.829 $\pm$ 0.048 & \underline{216.155 $\pm$ 48.782} & \underline{0.575 $\pm$ 0.009} & \bfseries 0.529 $\pm$ 0.066 & 0.082 $\pm$ 0.108 & 20.849 $\pm$ 2.699 \\
#  & Kernel RBF K-Means & 0.641 $\pm$ 0.022 & \underline{0.728 $\pm$ 0.000} & \bfseries 228.040 $\pm$ 29.064 & \bfseries 0.578 $\pm$ 0.002 & \underline{0.741 $\pm$ 0.110} & 0.007 $\pm$ 0.001 & 9.549 $\pm$ 0.214 \\
# \cline{1-9}
# \multirow[c]{3}{*}{khan-2001} & Batch CoHiRF-KernelRBF & \bfseries 0.045 $\pm$ 0.019 & \underline{0.066 $\pm$ 0.024} & \underline{1494.967 $\pm$ 2044.448} & \bfseries 0.048 $\pm$ 0.037 & \bfseries 0.316 $\pm$ 0.288 & 0.510 $\pm$ 0.912 & 112.465 $\pm$ 7.089 \\
#  & CoHiRF-KernelRBF & \underline{0.039 $\pm$ 0.007} & \bfseries 0.078 $\pm$ 0.022 & \bfseries 2241.324 $\pm$ 2044.680 & \underline{0.020 $\pm$ 0.006} & \underline{0.331 $\pm$ 0.298} & 0.218 $\pm$ 0.217 & 103.259 $\pm$ 6.709 \\
#  & Kernel RBF K-Means & 0.034 $\pm$ 0.009 & 0.062 $\pm$ 0.011 & 1.581 $\pm$ 0.222 & \underline{0.020 $\pm$ 0.006} & 2.219 $\pm$ 0.049 & 0.044 $\pm$ 0.031 & 86.936 $\pm$ 3.957 \\
# \cline{1-9}
# \multirow[c]{3}{*}{satimage} & Batch CoHiRF-KernelRBF & \underline{0.461 $\pm$ 0.030} & 0.507 $\pm$ 0.026 & \underline{2139.014 $\pm$ 467.968} & 0.020 $\pm$ 0.028 & 1.581 $\pm$ 0.200 & 0.639 $\pm$ 0.801 & 340.167 $\pm$ 111.432 \\
#  & CoHiRF-KernelRBF & \bfseries 0.493 $\pm$ 0.023 & \underline{0.531 $\pm$ 0.020} & \bfseries 2965.727 $\pm$ 1172.597 & \bfseries 0.187 $\pm$ 0.164 & \underline{1.097 $\pm$ 0.078} & 0.799 $\pm$ 0.315 & 563.554 $\pm$ 218.587 \\
#  & Kernel RBF K-Means & 0.249 $\pm$ 0.058 & \bfseries 0.536 $\pm$ 0.023 & 1743.924 $\pm$ 318.347 & \underline{0.135 $\pm$ 0.132} & \bfseries 1.077 $\pm$ 0.089 & 0.268 $\pm$ 0.090 & 47.511 $\pm$ 11.334 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # DBSCAN

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = ["ecoli", "binary-alpha-digits", "segment", "chowdary-2006", "shuttle"]
models_to_keep = [
    "DBSCAN",
    "CoHiRF-DBSCAN",
    "Batch CoHiRF-DBSCAN",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{3}{*}{binary-alpha-digits} & Batch CoHiRF-DBSCAN & \underline{0.006 $\pm$ 0.008} & \underline{0.032 $\pm$ 0.033} & \underline{1.473 $\pm$ 0.131} & \bfseries 0.080 $\pm$ 0.025 & \bfseries 0.837 $\pm$ 0.037 & 0.284 $\pm$ 0.238 & 58.526 $\pm$ 3.098 \\
#  & CoHiRF-DBSCAN & \bfseries 0.009 $\pm$ 0.005 & \bfseries 0.035 $\pm$ 0.026 & 1.353 $\pm$ 0.109 & \underline{0.011 $\pm$ 0.035} & \underline{0.862 $\pm$ 0.035} & 0.189 $\pm$ 0.041 & 57.093 $\pm$ 1.612 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.002 $\pm$ 0.003 & \bfseries 1.574 $\pm$ 3.525 & -0.561 $\pm$ 0.602 & 600.462 $\pm$ 547.090 & 0.053 $\pm$ 0.036 & 44.413 $\pm$ 2.076 \\
# \cline{1-9}
# \multirow[c]{3}{*}{chowdary-2006} & Batch CoHiRF-DBSCAN & \underline{0.068 $\pm$ 0.053} & \underline{0.099 $\pm$ 0.047} & \underline{37.353 $\pm$ 0.000} & 0.398 $\pm$ 0.366 & \underline{0.369 $\pm$ 0.157} & 0.073 $\pm$ 0.036 & 26.751 $\pm$ 1.500 \\
#  & CoHiRF-DBSCAN & 0.063 $\pm$ 0.007 & 0.067 $\pm$ 0.055 & \bfseries 47.579 $\pm$ 22.864 & \bfseries 0.675 $\pm$ 0.021 & \bfseries 0.168 $\pm$ 0.000 & 0.024 $\pm$ 0.003 & 23.143 $\pm$ 0.995 \\
#  & DBSCAN & \bfseries 0.375 $\pm$ 0.011 & \bfseries 0.327 $\pm$ 0.013 & 27.190 $\pm$ 2.510 & \underline{0.598 $\pm$ 0.022} & 0.946 $\pm$ 0.000 & 0.003 $\pm$ 0.000 & 18.056 $\pm$ 0.666 \\
# \cline{1-9}
# \multirow[c]{3}{*}{ecoli} & Batch CoHiRF-DBSCAN & 0.404 $\pm$ 0.088 & 0.336 $\pm$ 0.051 & \underline{67.693 $\pm$ 2.754} & \bfseries \underline{0.836 $\pm$ 0.000} & \bfseries \underline{0.116 $\pm$ 0.000} & 0.262 $\pm$ 0.964 & 18.254 $\pm$ 1.188 \\
#  & CoHiRF-DBSCAN & \bfseries 0.568 $\pm$ 0.046 & \underline{0.374 $\pm$ 0.145} & \bfseries 68.924 $\pm$ 0.000 & \bfseries \underline{0.836 $\pm$ 0.000} & \bfseries \underline{0.116 $\pm$ 0.000} & 0.056 $\pm$ 0.056 & 14.713 $\pm$ 0.533 \\
#  & DBSCAN & \underline{0.540 $\pm$ 0.040} & \bfseries 0.451 $\pm$ 0.037 & \bfseries 68.924 $\pm$ 0.000 & \bfseries \underline{0.836 $\pm$ 0.000} & \bfseries \underline{0.116 $\pm$ 0.000} & 0.014 $\pm$ 0.000 & 10.643 $\pm$ 0.597 \\
# \cline{1-9}
# \multirow[c]{3}{*}{segment} & Batch CoHiRF-DBSCAN & 0.283 $\pm$ 0.025 & 0.476 $\pm$ 0.009 & \underline{174.150 $\pm$ 78.855} & 0.827 $\pm$ 0.028 & \underline{0.109 $\pm$ 0.003} & 0.161 $\pm$ 0.149 & 26.993 $\pm$ 2.293 \\
#  & CoHiRF-DBSCAN & \bfseries 0.385 $\pm$ 0.066 & \underline{0.512 $\pm$ 0.045} & 88.494 $\pm$ 21.974 & \bfseries 0.849 $\pm$ 0.000 & \bfseries 0.107 $\pm$ 0.002 & 0.150 $\pm$ 0.069 & 30.599 $\pm$ 2.389 \\
#  & DBSCAN & \underline{0.353 $\pm$ 0.024} & \bfseries 0.560 $\pm$ 0.019 & \bfseries 374.389 $\pm$ 69.620 & \underline{0.846 $\pm$ 0.000} & 0.335 $\pm$ 0.000 & 0.033 $\pm$ 0.021 & 17.483 $\pm$ 1.937 \\
# \cline{1-9}
# \multirow[c]{3}{*}{shuttle} & Batch CoHiRF-DBSCAN & \underline{0.700 $\pm$ 0.025} & \underline{0.626 $\pm$ 0.012} & 1590.540 $\pm$ 568.306 & 0.881 $\pm$ 0.030 & \underline{0.057 $\pm$ 0.006} & 10.985 $\pm$ 5.967 & 1299.520 $\pm$ 863.328 \\
#  & CoHiRF-DBSCAN & 0.692 $\pm$ 0.008 & 0.604 $\pm$ 0.072 & \underline{1661.915 $\pm$ 938.851} & \underline{0.947 $\pm$ 0.013} & \bfseries 0.044 $\pm$ 0.004 & 146.101 $\pm$ 136.032 & 12001.592 $\pm$ 7286.836 \\
#  & DBSCAN & \bfseries 0.709 $\pm$ 0.013 & \bfseries 0.643 $\pm$ 0.002 & \bfseries 7504.082 $\pm$ 12.888 & \bfseries 0.948 $\pm$ 0.001 & 1.738 $\pm$ 0.306 & 31.611 $\pm$ 13.034 & 3234.575 $\pm$ 1047.160 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # SC-SRGF

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = ["alizadeh-2000-v3", "alizadeh-2000-v2", "har", "satimage", "chowdary-2006"]
models_to_keep = [
    "SC-SRGF",
	"CoHiRF-SC-SRGF",
    "Batch CoHiRF-SC-SRGF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{2}{*}{alizadeh-2000-v2} & CoHiRF-SC-SRGF & \underline{0.633 $\pm$ 0.042} & \underline{0.758 $\pm$ 0.031} & \underline{7.422 $\pm$ 0.041} & \underline{0.094 $\pm$ 0.001} & \underline{1.550 $\pm$ 0.019} & 1.503 $\pm$ 1.527 & 254.264 $\pm$ 14.525 \\
#  & SC-SRGF & \bfseries 0.891 $\pm$ 0.125 & \bfseries 0.854 $\pm$ 0.093 & \bfseries 12.338 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & \bfseries 0.936 $\pm$ 0.014 & 0.132 $\pm$ 0.061 & 142.764 $\pm$ 4.481 \\
# \cline{1-9}
# \multirow[c]{2}{*}{alizadeh-2000-v3} & CoHiRF-SC-SRGF & \underline{0.443 $\pm$ 0.013} & \underline{0.628 $\pm$ 0.019} & \underline{7.411 $\pm$ 0.060} & \underline{0.093 $\pm$ 0.002} & \underline{1.562 $\pm$ 0.047} & 0.928 $\pm$ 1.146 & 245.332 $\pm$ 13.850 \\
#  & SC-SRGF & \bfseries 0.519 $\pm$ 0.000 & \bfseries 0.702 $\pm$ 0.048 & \bfseries 12.341 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & \bfseries 0.931 $\pm$ 0.011 & 0.124 $\pm$ 0.055 & 144.219 $\pm$ 6.544 \\
# \cline{1-9}
# \multirow[c]{2}{*}{chowdary-2006} & CoHiRF-SC-SRGF & \underline{0.702 $\pm$ 0.042} & \underline{0.647 $\pm$ 0.058} & \bfseries 30.348 $\pm$ 5.508 & \underline{0.174 $\pm$ 0.006} & \underline{1.450 $\pm$ 0.044} & 1.713 $\pm$ 1.668 & 130.320 $\pm$ 11.670 \\
#  & SC-SRGF & \bfseries 0.924 $\pm$ 0.000 & \bfseries 0.859 $\pm$ 0.000 & \underline{23.009 $\pm$ 4.973} & \bfseries 0.222 $\pm$ 0.007 & \bfseries 1.101 $\pm$ 0.022 & 0.179 $\pm$ 0.093 & 29.310 $\pm$ 2.845 \\
# \cline{1-9}
# \multirow[c]{2}{*}{satimage} & CoHiRF-SC-SRGF & \underline{0.299 $\pm$ No Run} & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & 265.883 $\pm$ No Run & 4263.133 $\pm$ No Run \\
#  & SC-SRGF & \bfseries 0.615 $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & 1709.322 $\pm$ No Run & 83482.103 $\pm$ No Run \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # COIL 20

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = ["coil-20", "mnist"]
models_to_keep = [
    "K-Means",
    "CoHiRF",
	"CoHiRF-1000",
    "Batch CoHiRF",
    "Kernel RBF K-Means",
    "CoHiRF-KernelRBF",
    "Batch CoHiRF-KernelRBF",
    "DBSCAN",
    "CoHiRF-DBSCAN",
    "Batch CoHiRF-DBSCAN",
    "SC-SRGF",
    "Batch CoHiRF-SC-SRGF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{11}{*}{coil-20} & Batch CoHiRF & 0.381 $\pm$ 0.008 & 0.632 $\pm$ 0.010 & 62.639 $\pm$ 4.789 & 0.107 $\pm$ 0.018 & 1.532 $\pm$ 0.065 & 0.541 $\pm$ 0.153 & 172.626 $\pm$ 7.695 \\
#  & Batch CoHiRF-DBSCAN & 0.335 $\pm$ 0.055 & 0.588 $\pm$ 0.051 & \bfseries 291.162 $\pm$ 71.197 & -0.001 $\pm$ 0.008 & \bfseries 0.077 $\pm$ 0.041 & 1.305 $\pm$ 1.005 & 175.064 $\pm$ 19.429 \\
#  & Batch CoHiRF-KernelRBF & 0.004 $\pm$ 0.006 & 0.023 $\pm$ 0.020 & 1.804 $\pm$ 0.276 & 0.005 $\pm$ 0.002 & 2.404 $\pm$ 0.100 & 10.855 $\pm$ 17.100 & 510.956 $\pm$ 280.500 \\
#  & CoHiRF & 0.355 $\pm$ 0.041 & 0.627 $\pm$ 0.017 & 287.989 $\pm$ 0.164 & \underline{0.220 $\pm$ 0.095} & 1.597 $\pm$ 0.166 & 0.290 $\pm$ 0.087 & 151.293 $\pm$ 4.393 \\
#  & CoHiRF-1000 & 0.338 $\pm$ 0.009 & 0.632 $\pm$ 0.006 & 288.053 $\pm$ 0.078 & 0.180 $\pm$ 0.004 & 1.725 $\pm$ 0.039 & 0.264 $\pm$ 0.053 & 142.514 $\pm$ 3.021 \\
#  & CoHiRF-DBSCAN & \underline{0.684 $\pm$ 0.040} & 0.756 $\pm$ 0.052 & 45.358 $\pm$ 69.153 & 0.148 $\pm$ 0.030 & \underline{0.429 $\pm$ 0.223} & 0.321 $\pm$ 0.042 & 151.694 $\pm$ 4.712 \\
#  & CoHiRF-KernelRBF & 0.007 $\pm$ 0.009 & 0.020 $\pm$ 0.020 & 7.272 $\pm$ 10.222 & 0.003 $\pm$ 0.002 & 2.548 $\pm$ 0.084 & 7.423 $\pm$ 12.185 & 563.079 $\pm$ 301.382 \\
#  & DBSCAN & 0.143 $\pm$ 0.000 & 0.563 $\pm$ 0.000 & 56.906 $\pm$ 0.000 & -0.005 $\pm$ 0.000 & 1.175 $\pm$ 0.019 & 0.049 $\pm$ 0.006 & 132.351 $\pm$ 3.358 \\
#  & K-Means & 0.664 $\pm$ 0.005 & \underline{0.803 $\pm$ 0.003} & \underline{288.095 $\pm$ 0.000} & \bfseries 0.225 $\pm$ 0.002 & 1.737 $\pm$ 0.018 & 0.085 $\pm$ 0.032 & 135.341 $\pm$ 4.313 \\
#  & Kernel RBF K-Means & 0.004 $\pm$ 0.003 & 0.019 $\pm$ 0.012 & 1.795 $\pm$ 0.427 & 0.001 $\pm$ 0.000 & 12.297 $\pm$ 0.107 & 0.094 $\pm$ 0.011 & 135.192 $\pm$ 5.138 \\
#  & SC-SRGF & \bfseries 0.779 $\pm$ 0.006 & \bfseries 0.928 $\pm$ 0.003 & 84.948 $\pm$ 0.314 & 0.160 $\pm$ 0.001 & 1.581 $\pm$ 0.414 & 39.291 $\pm$ 16.565 & 2507.799 $\pm$ 517.402 \\
# \cline{1-9}
# \multirow[c]{10}{*}{mnist} & Batch CoHiRF & \underline{0.262 $\pm$ 0.011} & \underline{0.351 $\pm$ 0.005} & 425.387 $\pm$ 24.292 & -0.007 $\pm$ 0.011 & 2.600 $\pm$ 0.045 & 6.672 $\pm$ 4.041 & 3677.351 $\pm$ 1600.152 \\
#  & Batch CoHiRF-DBSCAN & 0.036 $\pm$ 0.022 & 0.111 $\pm$ 0.047 & 16.883 $\pm$ 4.071 & -0.065 $\pm$ 0.031 & \bfseries 0.490 $\pm$ 0.054 & 85.266 $\pm$ 105.172 & 8452.126 $\pm$ 2096.038 \\
#  & Batch CoHiRF-KernelRBF & 0.003 $\pm$ 0.006 & 0.005 $\pm$ 0.010 & 20.538 $\pm$ 40.929 & 0.001 $\pm$ 0.000 & 3.017 $\pm$ 0.658 & 265.027 $\pm$ 434.564 & 17360.414 $\pm$ 9820.961 \\
#  & CoHiRF & 0.163 $\pm$ 0.022 & 0.280 $\pm$ 0.020 & 2117.601 $\pm$ 430.072 & \underline{0.790 $\pm$ 0.242} & 1.659 $\pm$ 1.481 & 11.759 $\pm$ 5.550 & 3269.537 $\pm$ 1552.664 \\
#  & CoHiRF-1000 & 0.146 $\pm$ 0.013 & 0.280 $\pm$ 0.028 & \underline{2741.517 $\pm$ 62.372} & \bfseries 0.843 $\pm$ 0.101 & 2.711 $\pm$ 0.546 & 9.301 $\pm$ 7.070 & 2984.199 $\pm$ 1522.985 \\
#  & CoHiRF-DBSCAN & 0.076 $\pm$ 0.041 & 0.172 $\pm$ 0.050 & 17.457 $\pm$ 5.217 & 0.013 $\pm$ 0.121 & \underline{0.671 $\pm$ 0.080} & 219.335 $\pm$ 274.504 & 15588.519 $\pm$ 4905.455 \\
#  & CoHiRF-KernelRBF & 0.004 $\pm$ 0.008 & 0.046 $\pm$ 0.089 & 2.201 $\pm$ 2.298 & 0.001 $\pm$ 0.001 & 2.998 $\pm$ 0.008 & 658.262 $\pm$ 1075.461 & 33262.015 $\pm$ 28464.266 \\
#  & DBSCAN & 0.063 $\pm$ 0.000 & 0.238 $\pm$ 0.004 & 1287.036 $\pm$ 10.985 & -0.113 $\pm$ 0.001 & 1.611 $\pm$ 0.003 & 27.578 $\pm$ 1.758 & 4861.954 $\pm$ 1500.047 \\
#  & K-Means & \bfseries 0.344 $\pm$ 0.005 & \bfseries 0.505 $\pm$ 0.001 & \bfseries 2795.031 $\pm$ 0.001 & 0.431 $\pm$ 0.416 & 2.544 $\pm$ 0.072 & 4.226 $\pm$ 3.049 & 3388.629 $\pm$ 1703.331 \\
#  & Kernel RBF K-Means & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & 1.234 $\pm$ 0.131 & 0.000 $\pm$ 0.000 & 66.822 $\pm$ 0.397 & 5.652 $\pm$ 2.138 & 3452.337 $\pm$ 1659.642 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Debug and explore

# %%
df = df_runs_raw_2.copy()

# %%
df = df.loc[df["status"].isin(["FAILED", "RUNNING"])]
df
# Out:
# key                                status              start_time  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f   FAILED 2025-07-16 14:26:07.607
# 0002f564f6e3405d859abc0abd6c448e   FAILED 2025-07-15 15:39:34.468
# 000303ea6e564058a7def8cddeeda1b0   FAILED 2025-07-15 13:18:50.524
# 00065738f4ba45a9b05cf8d62618e24b   FAILED 2025-07-15 12:30:22.107
# 0012a8230edf41cca17eb741cbc86867   FAILED 2025-07-16 14:24:32.448
# ...                                   ...                     ...
# fffc589efa744f54b3378fcda6ccbcfe   FAILED 2025-11-06 11:50:01.603
# fffca7628fd3470d98a993a367c8aa3d  RUNNING 2025-08-12 18:54:10.939
# fffe9e46b22949c48aa2eaffc64b7028   FAILED 2025-07-16 18:04:27.271
# ffff2ab265274063bd33d808a0f27dfe   FAILED 2025-07-16 09:24:41.361
# ffffb0e8e9074c5bad3225e8a1a08ade   FAILED 2025-07-15 13:37:22.259
#
# key                                   end_time best/base_model_kwargs/eps  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f  1.752676e+12                        NaN
# 0002f564f6e3405d859abc0abd6c448e  1.752594e+12                        NaN
# 000303ea6e564058a7def8cddeeda1b0  1.752586e+12                        NaN
# 00065738f4ba45a9b05cf8d62618e24b  1.752583e+12                        NaN
# 0012a8230edf41cca17eb741cbc86867  1.752676e+12                        NaN
# ...                                        ...                        ...
# fffc589efa744f54b3378fcda6ccbcfe  1.762430e+12                        NaN
# fffca7628fd3470d98a993a367c8aa3d           NaN                        NaN
# fffe9e46b22949c48aa2eaffc64b7028  1.752689e+12                        NaN
# ffff2ab265274063bd33d808a0f27dfe  1.752658e+12                        NaN
# ffffb0e8e9074c5bad3225e8a1a08ade  1.752587e+12                        NaN
#
# key                              best/base_model_kwargs/min_samples  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                NaN
# 0002f564f6e3405d859abc0abd6c448e                                NaN
# 000303ea6e564058a7def8cddeeda1b0                                NaN
# 00065738f4ba45a9b05cf8d62618e24b                                NaN
# 0012a8230edf41cca17eb741cbc86867                                NaN
# ...                                                             ...
# fffc589efa744f54b3378fcda6ccbcfe                                NaN
# fffca7628fd3470d98a993a367c8aa3d                                NaN
# fffe9e46b22949c48aa2eaffc64b7028                                NaN
# ffff2ab265274063bd33d808a0f27dfe                                NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                NaN
#
# key                              best/base_model_kwargs/n_clusters  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f                               NaN
# 0002f564f6e3405d859abc0abd6c448e                               NaN
# 000303ea6e564058a7def8cddeeda1b0                               NaN
# 00065738f4ba45a9b05cf8d62618e24b                               NaN
# 0012a8230edf41cca17eb741cbc86867                               NaN
# ...                                                            ...
# fffc589efa744f54b3378fcda6ccbcfe                               NaN
# fffca7628fd3470d98a993a367c8aa3d                               NaN
# fffe9e46b22949c48aa2eaffc64b7028                               NaN
# ffff2ab265274063bd33d808a0f27dfe                               NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                               NaN
#
# key                              best/base_model_kwargs/n_similarities  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                   NaN
# 0002f564f6e3405d859abc0abd6c448e                                   NaN
# 000303ea6e564058a7def8cddeeda1b0                                   NaN
# 00065738f4ba45a9b05cf8d62618e24b                                   NaN
# 0012a8230edf41cca17eb741cbc86867                                   NaN
# ...                                                                ...
# fffc589efa744f54b3378fcda6ccbcfe                                   NaN
# fffca7628fd3470d98a993a367c8aa3d                                   NaN
# fffe9e46b22949c48aa2eaffc64b7028                                   NaN
# ffff2ab265274063bd33d808a0f27dfe                                   NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                   NaN
#
# key                              best/base_model_kwargs/sampling_ratio  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                   NaN
# 0002f564f6e3405d859abc0abd6c448e                                   NaN
# 000303ea6e564058a7def8cddeeda1b0                                   NaN
# 00065738f4ba45a9b05cf8d62618e24b                                   NaN
# 0012a8230edf41cca17eb741cbc86867                                   NaN
# ...                                                                ...
# fffc589efa744f54b3378fcda6ccbcfe                                   NaN
# fffca7628fd3470d98a993a367c8aa3d                                   NaN
# fffe9e46b22949c48aa2eaffc64b7028                                   NaN
# ffff2ab265274063bd33d808a0f27dfe                                   NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                   NaN
#
# key                              best/base_model_kwargs/sc_n_clusters  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f                                  NaN
# 0002f564f6e3405d859abc0abd6c448e                                  NaN
# 000303ea6e564058a7def8cddeeda1b0                                  NaN
# 00065738f4ba45a9b05cf8d62618e24b                                  NaN
# 0012a8230edf41cca17eb741cbc86867                                  NaN
# ...                                                               ...
# fffc589efa744f54b3378fcda6ccbcfe                                  NaN
# fffca7628fd3470d98a993a367c8aa3d                                  NaN
# fffe9e46b22949c48aa2eaffc64b7028                                  NaN
# ffff2ab265274063bd33d808a0f27dfe                                  NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                                  NaN
#
# key                              best/child_run_id  ... best/rand_score  \
# run_uuid                                            ...
# 0002f1471a6f4a639bcfd8a3d7c90f1f               NaN  ...             NaN
# 0002f564f6e3405d859abc0abd6c448e               NaN  ...             NaN
# 000303ea6e564058a7def8cddeeda1b0               NaN  ...             NaN
# 00065738f4ba45a9b05cf8d62618e24b               NaN  ...             NaN
# 0012a8230edf41cca17eb741cbc86867               NaN  ...             NaN
# ...                                            ...  ...             ...
# fffc589efa744f54b3378fcda6ccbcfe               NaN  ...             NaN
# fffca7628fd3470d98a993a367c8aa3d               NaN  ...             NaN
# fffe9e46b22949c48aa2eaffc64b7028               NaN  ...             NaN
# ffff2ab265274063bd33d808a0f27dfe               NaN  ...             NaN
# ffffb0e8e9074c5bad3225e8a1a08ade               NaN  ...             NaN
#
# key                              best/silhouette best/v_measure  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f             NaN            NaN
# 0002f564f6e3405d859abc0abd6c448e             NaN            NaN
# 000303ea6e564058a7def8cddeeda1b0             NaN            NaN
# 00065738f4ba45a9b05cf8d62618e24b             NaN            NaN
# 0012a8230edf41cca17eb741cbc86867             NaN            NaN
# ...                                          ...            ...
# fffc589efa744f54b3378fcda6ccbcfe             NaN            NaN
# fffca7628fd3470d98a993a367c8aa3d             NaN            NaN
# fffe9e46b22949c48aa2eaffc64b7028             NaN            NaN
# ffff2ab265274063bd33d808a0f27dfe             NaN            NaN
# ffffb0e8e9074c5bad3225e8a1a08ade             NaN            NaN
#
# key                              fit_model_return_elapsed_time  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f                     21.065334
# 0002f564f6e3405d859abc0abd6c448e                      0.013465
# 000303ea6e564058a7def8cddeeda1b0                      0.025954
# 00065738f4ba45a9b05cf8d62618e24b                      0.029382
# 0012a8230edf41cca17eb741cbc86867                      0.015206
# ...                                                        ...
# fffc589efa744f54b3378fcda6ccbcfe                           NaN
# fffca7628fd3470d98a993a367c8aa3d                           NaN
# fffe9e46b22949c48aa2eaffc64b7028                      0.067094
# ffff2ab265274063bd33d808a0f27dfe                      0.343937
# ffffb0e8e9074c5bad3225e8a1a08ade                      0.014669
#
# key                              max_memory_used max_memory_used_after_fit  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f        1492.632                  1492.632
# 0002f564f6e3405d859abc0abd6c448e         455.484                   455.484
# 000303ea6e564058a7def8cddeeda1b0         595.816                   595.816
# 00065738f4ba45a9b05cf8d62618e24b         591.684                   591.684
# 0012a8230edf41cca17eb741cbc86867         493.316                   493.316
# ...                                          ...                       ...
# fffc589efa744f54b3378fcda6ccbcfe         359.500                       NaN
# fffca7628fd3470d98a993a367c8aa3d             NaN                       NaN
# fffe9e46b22949c48aa2eaffc64b7028         485.088                   485.088
# ffff2ab265274063bd33d808a0f27dfe         404.880                   404.760
# ffffb0e8e9074c5bad3225e8a1a08ade         377.132                   377.132
#
# key                                                                       EXCEPTION  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f  Expected a 2-dimensional container but got <cl...
# 0002f564f6e3405d859abc0abd6c448e            could not convert string to float: 'OG'
# 000303ea6e564058a7def8cddeeda1b0         could not convert string to float: '"SCC"'
# 00065738f4ba45a9b05cf8d62618e24b         could not convert string to float: '"SCC"'
# 0012a8230edf41cca17eb741cbc86867        could not convert string to float: 'DLBCL2'
# ...                                                                             ...
# fffc589efa744f54b3378fcda6ccbcfe                          kth(=3) out of bounds (3)
# fffca7628fd3470d98a993a367c8aa3d                                                NaN
# fffe9e46b22949c48aa2eaffc64b7028         could not convert string to float: '"ML2"'
# ffff2ab265274063bd33d808a0f27dfe             could not convert string to float: 'A'
# ffffb0e8e9074c5bad3225e8a1a08ade  Expected a 2-dimensional container but got <cl...
#
# key                              Last step finished  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f                NaN
# 0002f564f6e3405d859abc0abd6c448e                NaN
# 000303ea6e564058a7def8cddeeda1b0                NaN
# 00065738f4ba45a9b05cf8d62618e24b                NaN
# 0012a8230edf41cca17eb741cbc86867                NaN
# ...                                             ...
# fffc589efa744f54b3378fcda6ccbcfe  _before_fit_model
# fffca7628fd3470d98a993a367c8aa3d                NaN
# fffe9e46b22949c48aa2eaffc64b7028                NaN
# ffff2ab265274063bd33d808a0f27dfe                NaN
# ffffb0e8e9074c5bad3225e8a1a08ade                NaN
#
# key                                             mlflow.parentRunId  \
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f  4b3d5799ec4448719f0a0c5c291eda0c
# 0002f564f6e3405d859abc0abd6c448e  742cb3f363ef47a79da84cc6e4086844
# 000303ea6e564058a7def8cddeeda1b0  67862e364b9e4bf9a3a723cf9fae0873
# 00065738f4ba45a9b05cf8d62618e24b  53b4533a3e62427d90f539c1e9ac0337
# 0012a8230edf41cca17eb741cbc86867  181c0696d3b643758607c7dec14dfe0c
# ...                                                            ...
# fffc589efa744f54b3378fcda6ccbcfe  bff12221a1684a2f88776ab5859934c6
# fffca7628fd3470d98a993a367c8aa3d  236c3ffdfb1b441da0c1db9ca53994b3
# fffe9e46b22949c48aa2eaffc64b7028  8c5ee25a49bc4dd4a8c0f5960653aba4
# ffff2ab265274063bd33d808a0f27dfe  09a7b833676745ce8fd47a6c5048db70
# ffffb0e8e9074c5bad3225e8a1a08ade  7d3074b2b45142f38aaf137e18a3e6f9
#
# key                              raised_exception
# run_uuid
# 0002f1471a6f4a639bcfd8a3d7c90f1f             True
# 0002f564f6e3405d859abc0abd6c448e             True
# 000303ea6e564058a7def8cddeeda1b0             True
# 00065738f4ba45a9b05cf8d62618e24b             True
# 0012a8230edf41cca17eb741cbc86867             True
# ...                                           ...
# fffc589efa744f54b3378fcda6ccbcfe             True
# fffca7628fd3470d98a993a367c8aa3d              NaN
# fffe9e46b22949c48aa2eaffc64b7028             True
# ffff2ab265274063bd33d808a0f27dfe             True
# ffffb0e8e9074c5bad3225e8a1a08ade             True
#
# [31578 rows x 58 columns]

# %%
runs_to_delete_parents = list(df.index)
df = df_runs_raw_2.copy()
df = df.loc[df["mlflow.parentRunId"].isin(runs_to_delete_parents)]
runs_to_delete_children = list(df.index)
runs_to_delete = runs_to_delete_children + runs_to_delete_parents
run_uuid_query = [f"'{run_id}'" for run_id in runs_to_delete]
run_uuid_query = ", ".join(run_uuid_query)

# %%
query = f"""
UPDATE runs
SET lifecycle_stage = 'deleted'
WHERE run_uuid IN ({run_uuid_query}) 
"""
with engine.begin() as conn:
    conn.execute(text(query))

# %%
query = f"""
DELETE
FROM
	experiment_tags
WHERE
	experiment_id = ANY(
	SELECT
		experiment_id
	FROM
		experiments
	WHERE
		lifecycle_stage = 'deleted');

DELETE
FROM
	latest_metrics
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE
FROM
	metrics
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE
FROM
	params
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');

DELETE
FROM
	tags
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE 
FROM 
	runs
WHERE 
	lifecycle_stage = 'deleted';

DELETE 
FROM 
	experiments
WHERE 
	lifecycle_stage = 'deleted';
"""
with engine.begin() as conn:
    conn.execute(text(query))
