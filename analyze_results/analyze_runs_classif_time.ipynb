# %%
from sqlalchemy import create_engine, text
import pandas as pd
from ml_experiments.analyze import get_df_runs_from_mlflow_sql, get_missing_entries, get_common_combinations, get_df_with_combinations
import plotly.express as px
from itertools import product
import time
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %% [markdown]
# # Save Results

# %% [markdown]
# ## Load mlflow runs

# %%
db_port = 5001
db_name = 'recursive_clustering'
w = 'clust9'
# url = f'postgresql://{w}.ceremade.dauphine.lan:{db_port}/{db_name}'
url = f'postgresql://belucci@localhost:{db_port}/{db_name}'
engine = create_engine(url)
query = 'SELECT experiments.name from experiments'
experiment_names = pd.read_sql(query, engine)['name'].tolist()
results_dir = Path('/home/bbelucci/code/recursive_clustering/results/processed_results')
os.makedirs(results_dir, exist_ok=True)

# %%
experiment_names
# Out:
# ['Default',
#  'blob_experiment',
#  'hpo_classif_experiment',
#  'hpo_openml_experiment',
#  'hpo_gaussian_experiment',
#  'hpo_openml_final',
#  'outlier_hc',
#  'time_hc',
#  'hpo_n_clusters',
#  'hpo_classif_huge',
#  'test',
#  'gaussian_random_KMeans_calinski_harabasz_score',
#  'gaussian_random_RecursiveClustering_calinski_harabasz_score',
#  'gaussian_random_RecursiveClustering_silhouette',
#  'gaussian_random_KMeans_silhouette']

# %%
experiments_names = [
    'time_hc',
]

# %%
params_columns = [
    'model_nickname',
    'n_samples',
    'n_features',
    'pct_random',
    'seed_unified',
    'class_sep',
    'n_random',
    'n_informative',
    'n_classes',
    'model_params/representative_method',
    'model_params/n_samples_representative',
    'model_params/use_dask',
    'model_params/scalable_strategy',
    'model_params/n_samples_threshold',
    'model_params/batch_size',
]

# %%
latest_metrics_columns = [
    'fit_model_return_elapsed_time',
    'max_memory_used',
    'n_clusters_',
    'rand_score',
    'adjusted_rand',
    'mutual_info',
    'adjusted_mutual_info',
    'normalized_mutual_info',
    'homogeneity_completeness_v_measure',
    'silhouette',
    # 'best_n_clusters_',
    # 'best_rand_score',
    # 'best_adjusted_rand',
    # 'best_mutual_info',
    # 'best_adjusted_mutual_info',
    # 'best_normalized_mutual_info',
    # 'best_homogeneity_completeness_v_measure',
    # 'best_silhouette',
]

# %%
tags_columns = [
    'raised_exception',
    'EXCEPTION',
    # 'parent_run_id',
    # 'best_child_run_id',
]

# %%
# parameters of each model, they are saved as tags for the parent run
parameters = {
    'RecursiveClustering': ['components_size', 'repetitions', 'kmeans_n_clusters'],
    'KMeans': ['n_clusters'],
    'HDBSCAN': ['min_cluster_size'],
    'DBSCAN': ['eps', 'min_samples'],
    'AffinityPropagation': ['damping'],
    'OPTICS': ['min_samples'],
    'SpectralSubspaceRandomization': ['n_similarities', 'sampling_ratio', 'sc_n_clusters'],
    'WardAgglomerativeClustering': ['n_clusters'],
}
all_model_parameters = [p for model, params in parameters.items() for p in params]
all_model_parameters = list(set(all_model_parameters))
for param in all_model_parameters:
    tags_columns.append(param)

# %%
runs_columns = ['run_uuid', 'status', 'start_time', 'end_time']
experiments_columns = []
other_table = 'params'
other_table_keys = params_columns
df_params = get_df_runs_from_mlflow_sql(engine, runs_columns=runs_columns, experiments_columns=experiments_columns, experiments_names=experiments_names, other_table=other_table, other_table_keys=other_table_keys)
df_latest_metrics = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='latest_metrics', other_table_keys=latest_metrics_columns)
df_tags = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='tags', other_table_keys=tags_columns)

# %%
df_runs_raw = df_params.join(df_latest_metrics)
df_runs_raw = df_runs_raw.join(df_tags)
# fill with default values
df_runs_raw['model_params/representative_method'] = df_runs_raw['model_params/representative_method'].fillna('closest_overall')
df_runs_raw['model_params/n_samples_representative'] = df_runs_raw['model_params/n_samples_representative'].fillna('None')

# fix closest_overall_1000 with new params
df_runs_raw.loc[(df_runs_raw['model_nickname']=='RecursiveClustering') & (df_runs_raw['model_params/representative_method']=='closest_overall_1000'), 'n_samples_representative'] = '1000'
df_runs_raw.loc[(df_runs_raw['model_nickname']=='RecursiveClustering') & (df_runs_raw['model_params/representative_method']=='closest_overall_1000'), 'model_params/representative_method'] = 'closest_overall'

df_runs_raw.loc[df_runs_raw['model_nickname']=='RecursiveClustering', 'model_nickname'] = df_runs_raw.loc[df_runs_raw['model_nickname']=='RecursiveClustering', 'model_nickname'] + '_' + df_runs_raw.loc[df_runs_raw['model_nickname']=='RecursiveClustering', 'model_params/representative_method'] + '_' + df_runs_raw.loc[df_runs_raw['model_nickname']=='RecursiveClustering', 'model_params/n_samples_representative']

df_runs_raw.loc[(df_runs_raw['model_params/use_dask']=='1') & (df_runs_raw['model_params/scalable_strategy']=='sampling'), 'model_nickname'] = df_runs_raw.loc[(df_runs_raw['model_params/use_dask']=='1') & (df_runs_raw['model_params/scalable_strategy']=='sampling'), 'model_nickname'] + '_' + 'sampling' + '_' + df_runs_raw.loc[(df_runs_raw['model_params/use_dask']=='1') & (df_runs_raw['model_params/scalable_strategy']=='sampling'), 'model_params/batch_size']

# %% [markdown]
# ## Delete duplicate runs (if any) and complete some models that cannot run with some datasets

# %%
non_duplicate_columns = [
    'model_nickname',
    'n_samples',
    'n_features',
    'pct_random',
    'seed_unified',
    'class_sep',
    'n_random',
    'n_informative',
    'n_classes',
    'model_params/representative_method',
    'model_params/n_samples_representative',
    'model_params/use_dask',
    'model_params/scalable_strategy',
    'model_params/n_samples_threshold',
    'model_params/batch_size',
]
df_runs = df_runs_raw.dropna(axis=0, how='all', subset=['adjusted_rand']).copy()
df_runs = df_runs.loc[(~df_runs.duplicated(non_duplicate_columns))]

# %%
no_run_time = np.inf
df_runs_timed_out = df_runs_raw.copy()
df_runs_timed_out = df_runs_timed_out.loc[df_runs_timed_out.EXCEPTION == 'FunctionTimedOut']
df_runs_timed_out = df_runs_timed_out.loc[(~df_runs_timed_out.duplicated(non_duplicate_columns))]
df_runs_timed_out['fit_model_return_elapsed_time'] = no_run_time
df_runs = pd.concat([df_runs, df_runs_timed_out])

# %%
status = 'FAILED'
no_run_memory = np.inf
raised_exception = True
EXCEPTION = 'NoRun'
start_time = time.time() * 1000
end_time = time.time() * 1000
no_run_time = np.inf

# %%
# HDBSCAN do not run with (14427,14427), (14427,50000), and n_samples = 50000 n_features > 347
model_nickname = 'HDBSCAN'
n_samples = ['50000']
n_features = ['347', '1202', '4163', '14427', '50000']
seed_unified = [f'{i}' for i in range(10)]
pct_random = ['0.0']
class_sep = ['50.0']
combinations = list(product(n_samples, n_features, seed_unified, pct_random, class_sep))
combinations_samples_features = [('14427', '14427'), ('14427', '50000')]
for samples, features in combinations_samples_features:
    combinations += list(product([samples], [features], seed_unified, pct_random, class_sep))
df_cat = []
indexes = []
for n_sample, n_feature, seed, pct, sep in combinations:
    df = {}
    index = f'{model_nickname}_{n_sample}_{n_feature}'
    df['status'] = status
    df['start_time'] = start_time
    df['end_time'] = end_time
    df['model_nickname'] = model_nickname
    df['n_features'] = n_feature
    df['n_samples'] = n_sample
    df['pct_random'] = pct
    df['seed_unified'] = seed
    df['class_sep'] = sep
    df['fit_model_return_elapsed_time'] = no_run_time
    df['max_memory_used'] = no_run_memory
    df['EXCEPTION'] = EXCEPTION
    df['raised_exception'] = raised_exception
    df_cat.append(df)
    indexes.append(index)
df_no_run = pd.DataFrame(df_cat, index=indexes)
df_runs = pd.concat([df_runs, df_no_run])

# %%
# SpectralSubspaceRandomization do not run with n_samples > 50000
model_nickname = 'SpectralSubspaceRandomization'
n_samples = ['50000']
n_features = ['100', '347', '1202', '4163', '14427', '50000']
seed_unified = [f'{i}' for i in range(10)]
pct_random = ['0.0']
class_sep = ['50.0']
combinations = list(product(n_samples, n_features, seed_unified, pct_random, class_sep))
df_cat = []
indexes = []
for n_sample, n_feature, seed, pct, sep in combinations:
    df = {}
    index = f'{model_nickname}_{n_sample}_{n_feature}'
    df['status'] = status
    df['start_time'] = start_time
    df['end_time'] = end_time
    df['model_nickname'] = model_nickname
    df['n_features'] = n_feature
    df['n_samples'] = n_sample
    df['pct_random'] = pct
    df['seed_unified'] = seed
    df['class_sep'] = sep
    df['fit_model_return_elapsed_time'] = no_run_time
    df['max_memory_used'] = no_run_memory
    df['EXCEPTION'] = EXCEPTION
    df['raised_exception'] = raised_exception
    df_cat.append(df)
    indexes.append(index)
df_no_run = pd.DataFrame(df_cat, index=indexes)
df_runs = pd.concat([df_runs, df_no_run])

# %%
# IRFLLRR do not run with n_samples > 14427
model_nickname = 'IRFLLRR'
n_samples = ['14427', '50000']
n_features = ['100', '347', '1202', '4163', '14427', '50000']
seed_unified = [f'{i}' for i in range(10)]
pct_random = ['0.0']
class_sep = ['50.0']
combinations = list(product(n_samples, n_features, seed_unified, pct_random, class_sep))
df_cat = []
indexes = []
for n_sample, n_feature, seed, pct, sep in combinations:
    df = {}
    index = f'{model_nickname}_{n_sample}_{n_feature}'
    df['status'] = status
    df['start_time'] = start_time
    df['end_time'] = end_time
    df['model_nickname'] = model_nickname
    df['n_features'] = n_feature
    df['n_samples'] = n_sample
    df['pct_random'] = pct
    df['seed_unified'] = seed
    df['class_sep'] = sep
    df['fit_model_return_elapsed_time'] = no_run_time
    df['max_memory_used'] = no_run_memory
    df['EXCEPTION'] = EXCEPTION
    df['raised_exception'] = raised_exception
    df_cat.append(df)
    indexes.append(index)
df_no_run = pd.DataFrame(df_cat, index=indexes)
df_runs = pd.concat([df_runs, df_no_run])

# %%
# KMeansProj do not run with (14427,14427), (14427,50000), (50000,14427), (50000,50000)
model_nickname = 'KMeansProj'
n_samples = ['14427', '50000']
n_features = ['14427', '50000']
seed_unified = [f'{i}' for i in range(10)]
pct_random = ['0.0']
class_sep = ['50.0']
combinations = list(product(n_samples, n_features, seed_unified, pct_random, class_sep))
df_cat = []
indexes = []
for n_sample, n_feature, seed, pct, sep in combinations:
    df = {}
    index = f'{model_nickname}_{n_sample}_{n_feature}'
    df['status'] = status
    df['start_time'] = start_time
    df['end_time'] = end_time
    df['model_nickname'] = model_nickname
    df['n_features'] = n_feature
    df['n_samples'] = n_sample
    df['pct_random'] = pct
    df['seed_unified'] = seed
    df['class_sep'] = sep
    df['fit_model_return_elapsed_time'] = no_run_time
    df['max_memory_used'] = no_run_memory
    df['EXCEPTION'] = EXCEPTION
    df['raised_exception'] = raised_exception
    df_cat.append(df)
    indexes.append(index)
df_no_run = pd.DataFrame(df_cat, index=indexes)
df_runs = pd.concat([df_runs, df_no_run])

# %%
# SingleAgglomerativeClustering do not run with (14427,14427), (14427,50000), (50000,14427), (50000,50000)
model_nickname = 'SingleAgglomerativeClustering'
n_samples = ['14427', '50000']
n_features = ['14427', '50000']
seed_unified = [f'{i}' for i in range(10)]
pct_random = ['0.0']
class_sep = ['50.0']
combinations = list(product(n_samples, n_features, seed_unified, pct_random, class_sep))
df_cat = []
indexes = []
for n_sample, n_feature, seed, pct, sep in combinations:
    df = {}
    index = f'{model_nickname}_{n_sample}_{n_feature}'
    df['status'] = status
    df['start_time'] = start_time
    df['end_time'] = end_time
    df['model_nickname'] = model_nickname
    df['n_features'] = n_feature
    df['n_samples'] = n_sample
    df['pct_random'] = pct
    df['seed_unified'] = seed
    df['class_sep'] = sep
    df['fit_model_return_elapsed_time'] = no_run_time
    df['max_memory_used'] = no_run_memory
    df['EXCEPTION'] = EXCEPTION
    df['raised_exception'] = raised_exception
    df_cat.append(df)
    indexes.append(index)
df_no_run = pd.DataFrame(df_cat, index=indexes)
df_runs = pd.concat([df_runs, df_no_run])

# %% [markdown]
# # Missing

# %%
model_nickname = df_runs['model_nickname'].unique().tolist()
model_nickname.sort()
model_nickname
# Out:
# ['AffinityPropagation',
#  'AverageAgglomerativeClustering',
#  'Clique',
#  'CompleteAgglomerativeClustering',
#  'DBSCAN',
#  'HDBSCAN',
#  'IRFLLRR',
#  'KMeans',
#  'KMeansProj',
#  'OPTICS',
#  'Proclus',
#  'RecursiveClusteringHDBSCAN_sampling_1024',
#  'RecursiveClusteringSCSRGF_sampling_1024',
#  'RecursiveClustering_closest_overall_1000',
#  'RecursiveClustering_closest_overall_None',
#  'RecursiveClustering_closest_overall_None_sampling_1024',
#  'SingleAgglomerativeClustering',
#  'SpectralClustering',
#  'SpectralSubspaceRandomization',
#  'WardAgglomerativeClustering']

# %%
non_duplicate_columns = [
    'model_nickname',
    'n_samples',
    'n_features',
    'pct_random',
    'seed_unified',
    'class_sep',
]

# %%
# n_samples = ['100', '1000', '10000']
# n_features = ['100', '1000', '10000']
# pct_random = ['0.0', '0.2', '0.5', '0.7']
# seed_unified = [f'{i}' for i in range(10)]
# class_sep = ['10.0', '50.0', '100.0']
n_samples = ['100', '347', '1202', '4163', '14427', '50000']
n_features = ['14427']
pct_random = ['0.0']
seed_unified = [f'{i}' for i in range(5)]
class_sep = ['50.0']
model_nickname = [
    'AffinityPropagation',
    'AverageAgglomerativeClustering',
    'Clique',
    'CompleteAgglomerativeClustering',
    'DBSCAN',
    'HDBSCAN',
    'IRFLLRR',
    'KMeans',
    'KMeansProj',
    'OPTICS',
    'Proclus',
    'RecursiveClusteringHDBSCAN_sampling_1024',
    'RecursiveClusteringSCSRGF_sampling_1024',
    'RecursiveClustering_closest_overall_1000',
    'RecursiveClustering_closest_overall_None',
    'RecursiveClustering_closest_overall_None_sampling_1024',
    'SingleAgglomerativeClustering',
    'SpectralClustering',
    'SpectralSubspaceRandomization',
    'WardAgglomerativeClustering'
]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, n_samples, n_features, pct_random, seed_unified, class_sep]
df_missing = get_missing_entries(df_runs, columns_names, should_contain_values)

# %%
df_missing.sort_values(['model_nickname', 'n_samples', 'n_features', 'seed_unified'])
# Out:
#         model_nickname n_samples n_features pct_random seed_unified class_sep
# 0  AffinityPropagation     50000      14427        0.0            3      50.0
# 1  AffinityPropagation     50000      14427        0.0            4      50.0
# 2              Proclus     50000      14427        0.0            4      50.0

# %%
# n_samples = ['100', '1000', '10000']
# n_features = ['100', '1000', '10000']
# pct_random = ['0.0', '0.2', '0.5', '0.7']
# seed_unified = [f'{i}' for i in range(10)]
# class_sep = ['10.0', '50.0', '100.0']
n_samples = ['14427']
n_features = ['100', '347', '1202', '4163', '14427', '50000']
pct_random = ['0.0']
seed_unified = [f'{i}' for i in range(5)]
class_sep = ['50.0']
model_nickname = [
    'AffinityPropagation',
    'AverageAgglomerativeClustering',
    'Clique',
    'CompleteAgglomerativeClustering',
    'DBSCAN',
    'HDBSCAN',
    'IRFLLRR',
    'KMeans',
    'KMeansProj',
    'OPTICS',
    'Proclus',
    'RecursiveClusteringHDBSCAN_sampling_1024',
    'RecursiveClusteringSCSRGF_sampling_1024',
    'RecursiveClustering_closest_overall_1000',
    'RecursiveClustering_closest_overall_None',
    'RecursiveClustering_closest_overall_None_sampling_1024',
    'SingleAgglomerativeClustering',
    'SpectralClustering',
    'SpectralSubspaceRandomization',
    'WardAgglomerativeClustering'
]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, n_samples, n_features, pct_random, seed_unified, class_sep]
df_missing2 = get_missing_entries(df_runs, columns_names, should_contain_values)

# %%
df_missing2
# Out:
#                   model_nickname n_samples n_features pct_random seed_unified  \
# 0                        HDBSCAN     14427       4163        0.0            3
# 1                        HDBSCAN     14427       4163        0.0            4
# 2                        Proclus     14427      50000        0.0            4
# 3  SingleAgglomerativeClustering     14427       4163        0.0            4
# 4  SpectralSubspaceRandomization     14427       1202        0.0            3
# 5  SpectralSubspaceRandomization     14427       1202        0.0            4
# 6  SpectralSubspaceRandomization     14427       4163        0.0            3
# 7  SpectralSubspaceRandomization     14427       4163        0.0            4
# 8  SpectralSubspaceRandomization     14427      50000        0.0            3
# 9  SpectralSubspaceRandomization     14427      50000        0.0            4
#
#   class_sep
# 0      50.0
# 1      50.0
# 2      50.0
# 3      50.0
# 4      50.0
# 5      50.0
# 6      50.0
# 7      50.0
# 8      50.0
# 9      50.0

# %% [markdown]
# # Plots

# %% [markdown]
# # Time

# %%
model_nickname = [
    'AffinityPropagation',
    'AverageAgglomerativeClustering',
    'Clique',
    'CompleteAgglomerativeClustering',
    'DBSCAN',
    'HDBSCAN',
    'IRFLLRR',
    'KMeans',
    'KMeansProj',
    'OPTICS',
    'Proclus',
    'RecursiveClusteringHDBSCAN_sampling_1024',
    'RecursiveClusteringSCSRGF_sampling_1024',
    'RecursiveClustering_closest_overall_1000',
    'RecursiveClustering_closest_overall_None',
    'RecursiveClustering_closest_overall_None_sampling_1024',
    'SingleAgglomerativeClustering',
    'SpectralClustering',
    'SpectralSubspaceRandomization',
    'WardAgglomerativeClustering'
]

# %%
# Time x Number of samples some models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    # 'AffinityPropagation': 'Affinity Propagation',
    # 'AverageAgglomerativeClustering': 'Average Agglomerative',
    # 'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    # 'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    # 'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    # 'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    # 'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    # 'SingleAgglomerativeClustering': 'Single Agglomerative',
    # 'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (10, 8),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    # df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of samples (n)', y='Time (s)', hue='Model', style='Model', markers=True, errorbar='ci')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.0), ncols=2)
    plt.savefig(results_dir / f'time_n-samples_n-features{n_features}_better.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %%
# Time x Number of samples all models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    'AffinityPropagation': 'Affinity Propagation',
    'AverageAgglomerativeClustering': 'Average Agglomerative',
    'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    # 'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    # 'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    'SingleAgglomerativeClustering': 'Single Agglomerative',
    'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    # 'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (16, 8),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    # df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of samples (n)', y='Time (s)', hue='Model', style='Model', markers=True, errorbar='ci')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.3), ncols=4)
    plt.savefig(results_dir / f'time_n-samples_n-features{n_features}_full.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %%
# Time x Number of features some models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    # 'AffinityPropagation': 'Affinity Propagation',
    # 'AverageAgglomerativeClustering': 'Average Agglomerative',
    # 'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    # 'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    # 'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    # 'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    # 'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    # 'SingleAgglomerativeClustering': 'Single Agglomerative',
    # 'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (10, 10),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    # df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of features (p)', y='Time (s)', hue='Model', style='Model', markers=True, errorbar='ci')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.0), ncols=3)
    plt.savefig(results_dir / f'time_n-features_n-samples{n_samples}_better.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %%
# Time x Number of features all models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    'AffinityPropagation': 'Affinity Propagation',
    'AverageAgglomerativeClustering': 'Average Agglomerative',
    'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    # 'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    # 'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    'SingleAgglomerativeClustering': 'Single Agglomerative',
    'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    # 'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (16, 8),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    # df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of features (p)', y='Time (s)', hue='Model', style='Model', markers=True, errorbar='ci')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.3), ncols=4)
    plt.savefig(results_dir / f'time_n-features_n-samples{n_samples}_full.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %%
# Mem x Number of samples all models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    'AffinityPropagation': 'Affinity Propagation',
    'AverageAgglomerativeClustering': 'Average Agglomerative',
    'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    'SingleAgglomerativeClustering': 'Single Agglomerative',
    'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    # 'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (16, 8),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    # df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of samples (n)', y='Memory (MB)', hue='Model', style='Model', markers=True, errorbar='ci')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.3), ncols=4)
    plt.savefig(results_dir / f'mem_n-samples_n-features{n_features}_full.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %%
# Mem x Number of features all models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    'AffinityPropagation': 'Affinity Propagation',
    'AverageAgglomerativeClustering': 'Average Agglomerative',
    'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    'SingleAgglomerativeClustering': 'Single Agglomerative',
    'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    # 'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (16, 8),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    # df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of features (p)', y='Memory (MB)', hue='Model', style='Model', markers=True, errorbar='ci')
    ax.set_xscale('log')
    ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.3), ncols=4)
    plt.savefig(results_dir / f'mem_n-features_n-samples{n_samples}_full.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %%
# ARI x Number of samples all models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    'AffinityPropagation': 'Affinity Propagation',
    'AverageAgglomerativeClustering': 'Average Agglomerative',
    'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    'SingleAgglomerativeClustering': 'Single Agglomerative',
    'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'adjusted_rand':'ARI', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    # 'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (16, 8),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    # df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of samples (n)', y='ARI', hue='Model', style='Model', markers=True, errorbar='ci')
    # ax.set_xscale('log')
    # ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.3), ncols=4)
    # plt.savefig(results_dir / f'time_n-samples_n-features{n_features}_full.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %%
# ARI x Number of features all models
df = df_runs.copy()
df['n_samples'] = df['n_samples'].astype(int)
df['n_features'] = df['n_features'].astype(int)
df['class_sep'] = df['class_sep'].astype(float)
n_features = 14427
n_samples = 14427
class_sep = 50.0
models_names = {
    'AffinityPropagation': 'Affinity Propagation',
    'AverageAgglomerativeClustering': 'Average Agglomerative',
    'Clique': 'Clique',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'DBSCAN': 'DBSCAN',
    'HDBSCAN': 'HDBSCAN',
    'IRFLLRR': 'IRFLLRR',
    'KMeans': 'K-Means',
    'KMeansProj': 'Projective K-Means',
    'OPTICS': 'OPTICS',
    'Proclus': 'Proclus',
    'RecursiveClusteringHDBSCAN_sampling_1024': 'CoHiRF-HDBSCAN',
    'RecursiveClusteringSCSRGF_sampling_1024': 'CoHiRF-SC-SRGF',
    'RecursiveClustering_closest_overall_1000': 'CoHiRF-1000',
    'RecursiveClustering_closest_overall_None': 'CoHiRF',
    'RecursiveClustering_closest_overall_None_sampling_1024': 'CoHiRF-Sampled',
    'SingleAgglomerativeClustering': 'Single Agglomerative',
    'SpectralClustering': 'Spectral Clustering',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.loc[df['model_nickname'].isin(models_names.keys())]
df = df.replace({'model_nickname': models_names})
df = df.sort_values(by='model_nickname')
df = df.rename(columns={'fit_model_return_elapsed_time': 'Time (s)', 'max_memory_used': 'Memory (MB)', 'n_samples': 'Number of samples (n)', 'n_features': 'Number of features (p)', 'model_nickname': 'Model', 'adjusted_rand':'ARI', 'class_sep': 'Class Separation'})
plt.style.use('default')
# plt.style.use('seaborn-v0_8-paper')
with mpl.rc_context(rc={
    # 'figure.constrained_layout.use': True,
    'savefig.bbox': 'tight',
    'figure.figsize': (16, 8),
    'legend.loc': 'upper left',
    'legend.frameon': False,
    'font.size': 15,
    # 'font.family': 'serif',
    # 'font.serif': 'Times',
    'text.color': 'black',
    'grid.color': 'black',
    'grid.alpha': 0.5,
}):
    # fig, axs = plt.subplots(1, 1)
    # axs = axs.flatten()
    df_plot = df.copy()
    df_plot = df_plot.loc[df_plot['Class Separation']==class_sep]
    # df_plot = df_plot.loc[df_plot['Number of features (p)']==n_features]
    df_plot = df_plot.loc[df_plot['Number of samples (n)']==n_samples]
    ax = sns.lineplot(data=df_plot, x='Number of features (p)', y='ARI', hue='Model', style='Model', markers=True, errorbar='ci')
    # ax.set_xscale('log')
    # ax.set_yscale('log')
    # set grid
    ax.grid(True, which='both', color='gray', alpha=0.2)
    plt.legend(title=None, bbox_to_anchor=(0.0, 1.3), ncols=4)
    # plt.savefig(results_dir / f'time_n-features_n-samples{n_samples}_full.pdf')
        # plt.legend(title=None, bbox_to_anchor=(0.6, 0.3))
        # plt.savefig(f'hypercube_n-samples{n_samples}_n-features{n_features}_pct-random{pct_random}.pdf')
        # plt.show()
    plt.show()

# %% [markdown]
# # Debug and explore

# %%
df = df_runs_raw.copy()
df = df.loc[df['status'] == 'FAILED']

# %%
df['EXCEPTION'].unique()
# Out:
# array(['Input X contains NaN.\nSpectralClustering does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values',
#        'Empty cluster', 'FunctionTimedOut',
#        'index 16 is out of bounds for axis 0 with size 16',
#        'index 18 is out of bounds for axis 0 with size 18', nan,
#        'SVD did not converge'], dtype=object)

# %%
df = df_runs_raw_parents.copy()
df = df.loc[df['status'] == 'FAILED']

# %%
df
# Out:
# key                               status     start_time      end_time  \
# run_uuid
# 01f490e163954c9b914d9f9f7765e075  FAILED  1737242580909  1.737260e+12
# 1185ab831bbc44d1966d666a207215c4  FAILED  1737242168108  1.737260e+12
# 12c09c8e4f834d15983dc3bdfcbc5959  FAILED  1737241068913  1.737242e+12
# 183f2361e71047adae98f3a64c4174fd  FAILED  1736863645016  1.736865e+12
# 27f9e72213b44c04bdb67ef7d2a0e693  FAILED  1737069296874  1.737070e+12
# 2ce22bf1a8c0477b8313a2c021926f17  FAILED  1737242600585  1.737260e+12
# 3457a0fa91564368ac3ae4164b12c70d  FAILED  1736863640977  1.736865e+12
# 38e1e3deb33b46608f6a5b5b8f99da93  FAILED  1737113267664  1.737181e+12
# 3a54a04f81d0422ca859a7bab8881c8d  FAILED  1736863838482  1.736889e+12
# 4bb729150a4047e3936c0d62898d819f  FAILED  1736931891947  1.736934e+12
# 4bdc0a18868e4e9f998bf130711d2b23  FAILED  1736513816913  1.736518e+12
# 509a5f91adc24a559c551a67d3176b19  FAILED  1736513896012  1.736518e+12
# 56dfbd80504d4894b7f9346d94379352  FAILED  1737115073250  1.737137e+12
# 584d5567482a47a38b2365e42daaf666  FAILED  1737069001459  1.737077e+12
# 5bfa2e15da68491f91ef0e52658ded1a  FAILED  1736882030195  1.736920e+12
# 63f3db0d9768455891db79bf4f25cb9a  FAILED  1737242191866  1.737260e+12
# 6cb72b4cb1a7484fb07ccb762e2afa60  FAILED  1737115075914  1.737137e+12
# 728eeba9325144af81fcb3e61779f67c  FAILED  1737113259564  1.737181e+12
# 734c393283594d0580c681ee480ea77f  FAILED  1737242600408  1.737260e+12
# 83386e96e53347d6b0a94a650638ebe0  FAILED  1737115073545  1.737137e+12
# 87afb3a0102f478b9e93789ceb9c765b  FAILED  1736863774405  1.736889e+12
# 8f7ca2c7f3824f80895636f6e4ffc224  FAILED  1736882019619  1.736926e+12
# 91aef0d462cf41e98c8158b9a2cf3d60  FAILED  1736688735541  1.736708e+12
# a509fded18e34b2db012ad900a8ea33d  FAILED  1736513968008  1.736518e+12
# aa7a22cb6c2544a99f93fef9ad998812  FAILED  1737113265325  1.737181e+12
# ac5535d9dab64e0984f05e4781878211  FAILED  1737069213120  1.737070e+12
# ae9e3db12a3841b4a6b7d7cc99a8175e  FAILED  1736875742592  1.736882e+12
# b160a087813c4754b2d7f6848b979830  FAILED  1736875742720  1.736880e+12
# c28f551421f344a3838ec7b067729497  FAILED  1737069299438  1.737070e+12
# c2d295c773904f42a96d3d44991acbb2  FAILED  1736513963303  1.736518e+12
# c37b31a388684d6b8b11be8299ecba3f  FAILED  1737069004859  1.737071e+12
# c5a8576261d245b380c5609e94b17c5f  FAILED  1737069002454  1.737075e+12
# c895c90728b6411cbf900a66685a7100  FAILED  1737069004130  1.737072e+12
# d660695629974f0a83f55e7dff508447  FAILED  1737242191382  1.737260e+12
# ded81217caea48f990cc5eaf9a7a59fa  FAILED  1736926299363  1.736979e+12
# e110b77c865b4a1eb191b66d2b14605d  FAILED  1736932067386  1.736934e+12
# e2a487840e414ae8a41f8ab37cd5e4b5  FAILED  1737242575932  1.737260e+12
# e980ba0ee8ac4fb7935e0241a71aacae  FAILED  1736932170300  1.736934e+12
# ea489364461445c59223afb8fc6b5893  FAILED  1736688776164  1.736708e+12
# f2d7dcad9adc4da99a24f64dc107d5e5  FAILED  1736875737628  1.736882e+12
#
# key                              class_sep                 model_nickname  \
# run_uuid
# 01f490e163954c9b914d9f9f7765e075     100.0            RecursiveClustering
# 1185ab831bbc44d1966d666a207215c4      10.0            RecursiveClustering
# 12c09c8e4f834d15983dc3bdfcbc5959      50.0                         OPTICS
# 183f2361e71047adae98f3a64c4174fd     100.0                        HDBSCAN
# 27f9e72213b44c04bdb67ef7d2a0e693      50.0  SpectralSubspaceRandomization
# 2ce22bf1a8c0477b8313a2c021926f17     100.0            RecursiveClustering
# 3457a0fa91564368ac3ae4164b12c70d      10.0                        HDBSCAN
# 38e1e3deb33b46608f6a5b5b8f99da93      50.0  SpectralSubspaceRandomization
# 3a54a04f81d0422ca859a7bab8881c8d      10.0  SingleAgglomerativeClustering
# 4bb729150a4047e3936c0d62898d819f     100.0  SpectralSubspaceRandomization
# 4bdc0a18868e4e9f998bf130711d2b23     100.0                         Clique
# 509a5f91adc24a559c551a67d3176b19     100.0                         Clique
# 56dfbd80504d4894b7f9346d94379352      50.0                        HDBSCAN
# 584d5567482a47a38b2365e42daaf666      50.0                        HDBSCAN
# 5bfa2e15da68491f91ef0e52658ded1a      50.0                        IRFLLRR
# 63f3db0d9768455891db79bf4f25cb9a      10.0            RecursiveClustering
# 6cb72b4cb1a7484fb07ccb762e2afa60      50.0                        HDBSCAN
# 728eeba9325144af81fcb3e61779f67c      50.0  SpectralSubspaceRandomization
# 734c393283594d0580c681ee480ea77f     100.0            RecursiveClustering
# 83386e96e53347d6b0a94a650638ebe0      50.0                        HDBSCAN
# 87afb3a0102f478b9e93789ceb9c765b     100.0  SingleAgglomerativeClustering
# 8f7ca2c7f3824f80895636f6e4ffc224      50.0                        IRFLLRR
# 91aef0d462cf41e98c8158b9a2cf3d60      10.0                        HDBSCAN
# a509fded18e34b2db012ad900a8ea33d      10.0                         Clique
# aa7a22cb6c2544a99f93fef9ad998812      50.0  SpectralSubspaceRandomization
# ac5535d9dab64e0984f05e4781878211      50.0  SpectralSubspaceRandomization
# ae9e3db12a3841b4a6b7d7cc99a8175e      50.0                        HDBSCAN
# b160a087813c4754b2d7f6848b979830      50.0                        HDBSCAN
# c28f551421f344a3838ec7b067729497      50.0  SpectralSubspaceRandomization
# c2d295c773904f42a96d3d44991acbb2      10.0                         Clique
# c37b31a388684d6b8b11be8299ecba3f      50.0                        HDBSCAN
# c5a8576261d245b380c5609e94b17c5f      50.0                        HDBSCAN
# c895c90728b6411cbf900a66685a7100      50.0                        HDBSCAN
# d660695629974f0a83f55e7dff508447      10.0            RecursiveClustering
# ded81217caea48f990cc5eaf9a7a59fa      50.0  SingleAgglomerativeClustering
# e110b77c865b4a1eb191b66d2b14605d      10.0  SingleAgglomerativeClustering
# e2a487840e414ae8a41f8ab37cd5e4b5     100.0            RecursiveClustering
# e980ba0ee8ac4fb7935e0241a71aacae     100.0  SingleAgglomerativeClustering
# ea489364461445c59223afb8fc6b5893      10.0                        HDBSCAN
# f2d7dcad9adc4da99a24f64dc107d5e5      50.0                        HDBSCAN
#
# key                              n_classes n_features n_informative n_random  \
# run_uuid
# 01f490e163954c9b914d9f9f7765e075         5      10000             2       16
# 1185ab831bbc44d1966d666a207215c4         5      10000             2       16
# 12c09c8e4f834d15983dc3bdfcbc5959         5        100             2       16
# 183f2361e71047adae98f3a64c4174fd         5      10000             2       16
# 27f9e72213b44c04bdb67ef7d2a0e693         5        100             2       16
# 2ce22bf1a8c0477b8313a2c021926f17         5      10000             2       16
# 3457a0fa91564368ac3ae4164b12c70d         5      10000             2       16
# 38e1e3deb33b46608f6a5b5b8f99da93         5      10000             2       16
# 3a54a04f81d0422ca859a7bab8881c8d         5      10000             2       16
# 4bb729150a4047e3936c0d62898d819f         5        100             2       16
# 4bdc0a18868e4e9f998bf130711d2b23         5      10000             2       16
# 509a5f91adc24a559c551a67d3176b19         5      10000             2       16
# 56dfbd80504d4894b7f9346d94379352         5      10000             2       16
# 584d5567482a47a38b2365e42daaf666         5      10000             2       16
# 5bfa2e15da68491f91ef0e52658ded1a         5      10000             2       16
# 63f3db0d9768455891db79bf4f25cb9a         5      10000             2       16
# 6cb72b4cb1a7484fb07ccb762e2afa60         5      10000             2       16
# 728eeba9325144af81fcb3e61779f67c         5      10000             2       16
# 734c393283594d0580c681ee480ea77f         5      10000             2       16
# 83386e96e53347d6b0a94a650638ebe0         5      10000             2       16
# 87afb3a0102f478b9e93789ceb9c765b         5      10000             2       16
# 8f7ca2c7f3824f80895636f6e4ffc224         5      10000             2       16
# 91aef0d462cf41e98c8158b9a2cf3d60         5      10000             2       16
# a509fded18e34b2db012ad900a8ea33d         5      10000             2       16
# aa7a22cb6c2544a99f93fef9ad998812         5      10000             2       16
# ac5535d9dab64e0984f05e4781878211         5       1000             2       16
# ae9e3db12a3841b4a6b7d7cc99a8175e         5      10000             2       16
# b160a087813c4754b2d7f6848b979830         5      10000             2       16
# c28f551421f344a3838ec7b067729497         5      10000             2       16
# c2d295c773904f42a96d3d44991acbb2         5      10000             2       16
# c37b31a388684d6b8b11be8299ecba3f         5      10000             2       16
# c5a8576261d245b380c5609e94b17c5f         5      10000             2       16
# c895c90728b6411cbf900a66685a7100         5      10000             2       16
# d660695629974f0a83f55e7dff508447         5      10000             2       16
# ded81217caea48f990cc5eaf9a7a59fa         5      10000             2       16
# e110b77c865b4a1eb191b66d2b14605d         5      10000             2       16
# e2a487840e414ae8a41f8ab37cd5e4b5         5      10000             2       16
# e980ba0ee8ac4fb7935e0241a71aacae         5      10000             2       16
# ea489364461445c59223afb8fc6b5893         5      10000             2       16
# f2d7dcad9adc4da99a24f64dc107d5e5         5      10000             2       16
#
# key                              n_samples  ... max_memory_used mutual_info  \
# run_uuid                                    ...
# 01f490e163954c9b914d9f9f7765e075     10000  ...        3631.760    1.609438
# 1185ab831bbc44d1966d666a207215c4     10000  ...        3345.972    0.793675
# 12c09c8e4f834d15983dc3bdfcbc5959     10000  ...         426.124         NaN
# 183f2361e71047adae98f3a64c4174fd     10000  ...        1037.448         NaN
# 27f9e72213b44c04bdb67ef7d2a0e693     10000  ...        1042.800         NaN
# 2ce22bf1a8c0477b8313a2c021926f17     10000  ...        3637.124    1.609438
# 3457a0fa91564368ac3ae4164b12c70d     10000  ...        1038.472         NaN
# 38e1e3deb33b46608f6a5b5b8f99da93      1000  ...        2070.728    1.609438
# 3a54a04f81d0422ca859a7bab8881c8d     10000  ...        1935.216    0.001932
# 4bb729150a4047e3936c0d62898d819f     10000  ...         269.848         NaN
# 4bdc0a18868e4e9f998bf130711d2b23       100  ...             NaN    0.000000
# 509a5f91adc24a559c551a67d3176b19       100  ...             NaN    0.005221
# 56dfbd80504d4894b7f9346d94379352     10000  ...        1035.016         NaN
# 584d5567482a47a38b2365e42daaf666     10000  ...        1037.572    1.609438
# 5bfa2e15da68491f91ef0e52658ded1a     10000  ...        5278.060         NaN
# 63f3db0d9768455891db79bf4f25cb9a     10000  ...        3632.620    0.092525
# 6cb72b4cb1a7484fb07ccb762e2afa60     10000  ...        1087.680         NaN
# 728eeba9325144af81fcb3e61779f67c      1000  ...        2080.616    1.054920
# 734c393283594d0580c681ee480ea77f     10000  ...        3509.676    1.609438
# 83386e96e53347d6b0a94a650638ebe0     10000  ...        1035.676         NaN
# 87afb3a0102f478b9e93789ceb9c765b     10000  ...        1850.444    1.609438
# 8f7ca2c7f3824f80895636f6e4ffc224     10000  ...        3457.536         NaN
# 91aef0d462cf41e98c8158b9a2cf3d60     10000  ...        3566.280         NaN
# a509fded18e34b2db012ad900a8ea33d       100  ...        2096.676    0.005221
# aa7a22cb6c2544a99f93fef9ad998812      1000  ...        2078.428    1.609438
# ac5535d9dab64e0984f05e4781878211     10000  ...         333.948         NaN
# ae9e3db12a3841b4a6b7d7cc99a8175e     10000  ...        1037.960         NaN
# b160a087813c4754b2d7f6848b979830     10000  ...        2811.316         NaN
# c28f551421f344a3838ec7b067729497      1000  ...         964.988    1.609438
# c2d295c773904f42a96d3d44991acbb2       100  ...         309.588    0.201144
# c37b31a388684d6b8b11be8299ecba3f     10000  ...        1073.516         NaN
# c5a8576261d245b380c5609e94b17c5f     10000  ...        1081.000         NaN
# c895c90728b6411cbf900a66685a7100     10000  ...        1076.420         NaN
# d660695629974f0a83f55e7dff508447     10000  ...        3637.492    0.573621
# ded81217caea48f990cc5eaf9a7a59fa     10000  ...        1065.028    1.609438
# e110b77c865b4a1eb191b66d2b14605d     10000  ...             NaN    0.004207
# e2a487840e414ae8a41f8ab37cd5e4b5     10000  ...        3362.208         NaN
# e980ba0ee8ac4fb7935e0241a71aacae     10000  ...             NaN         NaN
# ea489364461445c59223afb8fc6b5893     10000  ...        3565.436         NaN
# f2d7dcad9adc4da99a24f64dc107d5e5     10000  ...        1039.084         NaN
#
# key                               n_clusters_  normalized_mutual_info  \
# run_uuid
# 01f490e163954c9b914d9f9f7765e075          7.0                0.920715
# 1185ab831bbc44d1966d666a207215c4       2202.0                0.177624
# 12c09c8e4f834d15983dc3bdfcbc5959          NaN                     NaN
# 183f2361e71047adae98f3a64c4174fd          NaN                     NaN
# 27f9e72213b44c04bdb67ef7d2a0e693          NaN                     NaN
# 2ce22bf1a8c0477b8313a2c021926f17          5.0                1.000000
# 3457a0fa91564368ac3ae4164b12c70d          NaN                     NaN
# 38e1e3deb33b46608f6a5b5b8f99da93          5.0                1.000000
# 3a54a04f81d0422ca859a7bab8881c8d         13.0                0.002382
# 4bb729150a4047e3936c0d62898d819f          NaN                     NaN
# 4bdc0a18868e4e9f998bf130711d2b23          1.0                0.000000
# 509a5f91adc24a559c551a67d3176b19          2.0                0.005018
# 56dfbd80504d4894b7f9346d94379352          NaN                     NaN
# 584d5567482a47a38b2365e42daaf666          5.0                1.000000
# 5bfa2e15da68491f91ef0e52658ded1a          NaN                     NaN
# 63f3db0d9768455891db79bf4f25cb9a         20.0                0.043510
# 6cb72b4cb1a7484fb07ccb762e2afa60          NaN                     NaN
# 728eeba9325144af81fcb3e61779f67c          3.0                0.791876
# 734c393283594d0580c681ee480ea77f          5.0                1.000000
# 83386e96e53347d6b0a94a650638ebe0          NaN                     NaN
# 87afb3a0102f478b9e93789ceb9c765b         28.0                0.993450
# 8f7ca2c7f3824f80895636f6e4ffc224          NaN                     NaN
# 91aef0d462cf41e98c8158b9a2cf3d60          NaN                     NaN
# a509fded18e34b2db012ad900a8ea33d          2.0                0.005018
# aa7a22cb6c2544a99f93fef9ad998812         27.0                0.670133
# ac5535d9dab64e0984f05e4781878211          NaN                     NaN
# ae9e3db12a3841b4a6b7d7cc99a8175e          NaN                     NaN
# b160a087813c4754b2d7f6848b979830          NaN                     NaN
# c28f551421f344a3838ec7b067729497          7.0                0.930755
# c2d295c773904f42a96d3d44991acbb2         13.0                0.102083
# c37b31a388684d6b8b11be8299ecba3f          NaN                     NaN
# c5a8576261d245b380c5609e94b17c5f          NaN                     NaN
# c895c90728b6411cbf900a66685a7100          NaN                     NaN
# d660695629974f0a83f55e7dff508447       1699.0                0.132188
# ded81217caea48f990cc5eaf9a7a59fa          5.0                1.000000
# e110b77c865b4a1eb191b66d2b14605d         27.0                0.005141
# e2a487840e414ae8a41f8ab37cd5e4b5          NaN                     NaN
# e980ba0ee8ac4fb7935e0241a71aacae          NaN                     NaN
# ea489364461445c59223afb8fc6b5893          NaN                     NaN
# f2d7dcad9adc4da99a24f64dc107d5e5          NaN                     NaN
#
# key                               rand_score  silhouette  \
# run_uuid
# 01f490e163954c9b914d9f9f7765e075    0.960011    0.336783
# 1185ab831bbc44d1966d666a207215c4    0.799918   -0.216621
# 12c09c8e4f834d15983dc3bdfcbc5959         NaN         NaN
# 183f2361e71047adae98f3a64c4174fd         NaN         NaN
# 27f9e72213b44c04bdb67ef7d2a0e693         NaN         NaN
# 2ce22bf1a8c0477b8313a2c021926f17    1.000000    0.555884
# 3457a0fa91564368ac3ae4164b12c70d         NaN         NaN
# 38e1e3deb33b46608f6a5b5b8f99da93    1.000000    0.401385
# 3a54a04f81d0422ca859a7bab8881c8d    0.201360    0.078242
# 4bb729150a4047e3936c0d62898d819f         NaN         NaN
# 4bdc0a18868e4e9f998bf130711d2b23    0.191919   -1.000000
# 509a5f91adc24a559c551a67d3176b19    0.372121   -0.015482
# 56dfbd80504d4894b7f9346d94379352         NaN         NaN
# 584d5567482a47a38b2365e42daaf666    1.000000    0.172137
# 5bfa2e15da68491f91ef0e52658ded1a         NaN         NaN
# 63f3db0d9768455891db79bf4f25cb9a    0.753343   -0.031437
# 6cb72b4cb1a7484fb07ccb762e2afa60         NaN         NaN
# 728eeba9325144af81fcb3e61779f67c    0.839840    0.213125
# 734c393283594d0580c681ee480ea77f    1.000000    0.577506
# 83386e96e53347d6b0a94a650638ebe0         NaN         NaN
# 87afb3a0102f478b9e93789ceb9c765b    0.999002    0.150586
# 8f7ca2c7f3824f80895636f6e4ffc224         NaN         NaN
# 91aef0d462cf41e98c8158b9a2cf3d60         NaN         NaN
# a509fded18e34b2db012ad900a8ea33d    0.372121   -0.016055
# aa7a22cb6c2544a99f93fef9ad998812    0.844224    0.066024
# ac5535d9dab64e0984f05e4781878211         NaN         NaN
# ae9e3db12a3841b4a6b7d7cc99a8175e         NaN         NaN
# b160a087813c4754b2d7f6848b979830         NaN         NaN
# c28f551421f344a3838ec7b067729497    0.967113    0.263185
# c2d295c773904f42a96d3d44991acbb2    0.732727   -0.111018
# c37b31a388684d6b8b11be8299ecba3f         NaN         NaN
# c5a8576261d245b380c5609e94b17c5f         NaN         NaN
# c895c90728b6411cbf900a66685a7100         NaN         NaN
# d660695629974f0a83f55e7dff508447    0.799663   -0.212134
# ded81217caea48f990cc5eaf9a7a59fa    1.000000    0.184139
# e110b77c865b4a1eb191b66d2b14605d    0.203157   -0.023862
# e2a487840e414ae8a41f8ab37cd5e4b5         NaN         NaN
# e980ba0ee8ac4fb7935e0241a71aacae         NaN         NaN
# ea489364461445c59223afb8fc6b5893         NaN         NaN
# f2d7dcad9adc4da99a24f64dc107d5e5         NaN         NaN
#
# key                                                                       EXCEPTION  \
# run_uuid
# 01f490e163954c9b914d9f9f7765e075  [Errno 28] No space left on device: '/tmp/ea30...
# 1185ab831bbc44d1966d666a207215c4  RecursiveClustering_0_10000_16_2_10000_0.5_10....
# 12c09c8e4f834d15983dc3bdfcbc5959        Every trial failed, no best model was found
# 183f2361e71047adae98f3a64c4174fd  HDBSCAN_0_10000_16_2_10000_0.7_100.0_0-19785e2...
# 27f9e72213b44c04bdb67ef7d2a0e693  SpectralSubspaceRandomization_0_10000_16_2_100...
# 2ce22bf1a8c0477b8313a2c021926f17  RecursiveClustering_0_10000_16_2_10000_0.5_100...
# 3457a0fa91564368ac3ae4164b12c70d  HDBSCAN_0_10000_16_2_10000_0.2_10.0_0-b2773806...
# 38e1e3deb33b46608f6a5b5b8f99da93  SpectralSubspaceRandomization_0_1000_16_2_1000...
# 3a54a04f81d0422ca859a7bab8881c8d  SingleAgglomerativeClustering_0_10000_16_2_100...
# 4bb729150a4047e3936c0d62898d819f  Attempted to run task 'SpectralSubspaceRandomi...
# 4bdc0a18868e4e9f998bf130711d2b23                                                NaN
# 509a5f91adc24a559c551a67d3176b19                                                NaN
# 56dfbd80504d4894b7f9346d94379352  HDBSCAN_0_10000_16_2_10000_0.0_50.0_3-d45ed9a7...
# 584d5567482a47a38b2365e42daaf666  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# 5bfa2e15da68491f91ef0e52658ded1a  Attempted to run task 'IRFLLRR_0_10000_16_2_10...
# 63f3db0d9768455891db79bf4f25cb9a  RecursiveClustering_0_10000_16_2_10000_0.5_10....
# 6cb72b4cb1a7484fb07ccb762e2afa60  HDBSCAN_0_10000_16_2_10000_0.0_50.0_4-1fb46a0d...
# 728eeba9325144af81fcb3e61779f67c  SpectralSubspaceRandomization_0_1000_16_2_1000...
# 734c393283594d0580c681ee480ea77f  RecursiveClustering_0_10000_16_2_10000_0.5_100...
# 83386e96e53347d6b0a94a650638ebe0  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# 87afb3a0102f478b9e93789ceb9c765b  SingleAgglomerativeClustering_0_10000_16_2_100...
# 8f7ca2c7f3824f80895636f6e4ffc224  IRFLLRR_0_10000_16_2_10000_0.2_50.0_0-99d9265e...
# 91aef0d462cf41e98c8158b9a2cf3d60  HDBSCAN_0_10000_16_2_10000_0.0_10.0_7-2c45257c...
# a509fded18e34b2db012ad900a8ea33d  INVALID_PARAMETER_VALUE: Changing param values...
# aa7a22cb6c2544a99f93fef9ad998812  SpectralSubspaceRandomization_0_1000_16_2_1000...
# ac5535d9dab64e0984f05e4781878211  SpectralSubspaceRandomization_0_10000_16_2_100...
# ae9e3db12a3841b4a6b7d7cc99a8175e  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# b160a087813c4754b2d7f6848b979830  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# c28f551421f344a3838ec7b067729497  SpectralSubspaceRandomization_0_1000_16_2_1000...
# c2d295c773904f42a96d3d44991acbb2  INVALID_PARAMETER_VALUE: Changing param values...
# c37b31a388684d6b8b11be8299ecba3f  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# c5a8576261d245b380c5609e94b17c5f  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# c895c90728b6411cbf900a66685a7100  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# d660695629974f0a83f55e7dff508447  RecursiveClustering_0_10000_16_2_10000_0.5_10....
# ded81217caea48f990cc5eaf9a7a59fa  SingleAgglomerativeClustering_0_10000_16_2_100...
# e110b77c865b4a1eb191b66d2b14605d                                                NaN
# e2a487840e414ae8a41f8ab37cd5e4b5     Not enough free space to write 800160000 bytes
# e980ba0ee8ac4fb7935e0241a71aacae                                                NaN
# ea489364461445c59223afb8fc6b5893  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
# f2d7dcad9adc4da99a24f64dc107d5e5  Attempted to run task 'HDBSCAN_0_10000_16_2_10...
#
# key                               best_child_run_id  parent_run_id  \
# run_uuid
# 01f490e163954c9b914d9f9f7765e075                NaN            NaN
# 1185ab831bbc44d1966d666a207215c4                NaN            NaN
# 12c09c8e4f834d15983dc3bdfcbc5959                NaN            NaN
# 183f2361e71047adae98f3a64c4174fd                NaN            NaN
# 27f9e72213b44c04bdb67ef7d2a0e693                NaN            NaN
# 2ce22bf1a8c0477b8313a2c021926f17                NaN            NaN
# 3457a0fa91564368ac3ae4164b12c70d                NaN            NaN
# 38e1e3deb33b46608f6a5b5b8f99da93                NaN            NaN
# 3a54a04f81d0422ca859a7bab8881c8d                NaN            NaN
# 4bb729150a4047e3936c0d62898d819f                NaN            NaN
# 4bdc0a18868e4e9f998bf130711d2b23                NaN            NaN
# 509a5f91adc24a559c551a67d3176b19                NaN            NaN
# 56dfbd80504d4894b7f9346d94379352                NaN            NaN
# 584d5567482a47a38b2365e42daaf666                NaN            NaN
# 5bfa2e15da68491f91ef0e52658ded1a                NaN            NaN
# 63f3db0d9768455891db79bf4f25cb9a                NaN            NaN
# 6cb72b4cb1a7484fb07ccb762e2afa60                NaN            NaN
# 728eeba9325144af81fcb3e61779f67c                NaN            NaN
# 734c393283594d0580c681ee480ea77f                NaN            NaN
# 83386e96e53347d6b0a94a650638ebe0                NaN            NaN
# 87afb3a0102f478b9e93789ceb9c765b                NaN            NaN
# 8f7ca2c7f3824f80895636f6e4ffc224                NaN            NaN
# 91aef0d462cf41e98c8158b9a2cf3d60                NaN            NaN
# a509fded18e34b2db012ad900a8ea33d                NaN            NaN
# aa7a22cb6c2544a99f93fef9ad998812                NaN            NaN
# ac5535d9dab64e0984f05e4781878211                NaN            NaN
# ae9e3db12a3841b4a6b7d7cc99a8175e                NaN            NaN
# b160a087813c4754b2d7f6848b979830                NaN            NaN
# c28f551421f344a3838ec7b067729497                NaN            NaN
# c2d295c773904f42a96d3d44991acbb2                NaN            NaN
# c37b31a388684d6b8b11be8299ecba3f                NaN            NaN
# c5a8576261d245b380c5609e94b17c5f                NaN            NaN
# c895c90728b6411cbf900a66685a7100                NaN            NaN
# d660695629974f0a83f55e7dff508447                NaN            NaN
# ded81217caea48f990cc5eaf9a7a59fa                NaN            NaN
# e110b77c865b4a1eb191b66d2b14605d                NaN            NaN
# e2a487840e414ae8a41f8ab37cd5e4b5                NaN            NaN
# e980ba0ee8ac4fb7935e0241a71aacae                NaN            NaN
# ea489364461445c59223afb8fc6b5893                NaN            NaN
# f2d7dcad9adc4da99a24f64dc107d5e5                NaN            NaN
#
# key                               raised_exception
# run_uuid
# 01f490e163954c9b914d9f9f7765e075              True
# 1185ab831bbc44d1966d666a207215c4              True
# 12c09c8e4f834d15983dc3bdfcbc5959              True
# 183f2361e71047adae98f3a64c4174fd              True
# 27f9e72213b44c04bdb67ef7d2a0e693              True
# 2ce22bf1a8c0477b8313a2c021926f17              True
# 3457a0fa91564368ac3ae4164b12c70d              True
# 38e1e3deb33b46608f6a5b5b8f99da93              True
# 3a54a04f81d0422ca859a7bab8881c8d              True
# 4bb729150a4047e3936c0d62898d819f              True
# 4bdc0a18868e4e9f998bf130711d2b23               NaN
# 509a5f91adc24a559c551a67d3176b19               NaN
# 56dfbd80504d4894b7f9346d94379352              True
# 584d5567482a47a38b2365e42daaf666              True
# 5bfa2e15da68491f91ef0e52658ded1a              True
# 63f3db0d9768455891db79bf4f25cb9a              True
# 6cb72b4cb1a7484fb07ccb762e2afa60              True
# 728eeba9325144af81fcb3e61779f67c              True
# 734c393283594d0580c681ee480ea77f              True
# 83386e96e53347d6b0a94a650638ebe0              True
# 87afb3a0102f478b9e93789ceb9c765b              True
# 8f7ca2c7f3824f80895636f6e4ffc224              True
# 91aef0d462cf41e98c8158b9a2cf3d60              True
# a509fded18e34b2db012ad900a8ea33d              True
# aa7a22cb6c2544a99f93fef9ad998812              True
# ac5535d9dab64e0984f05e4781878211              True
# ae9e3db12a3841b4a6b7d7cc99a8175e              True
# b160a087813c4754b2d7f6848b979830              True
# c28f551421f344a3838ec7b067729497              True
# c2d295c773904f42a96d3d44991acbb2              True
# c37b31a388684d6b8b11be8299ecba3f              True
# c5a8576261d245b380c5609e94b17c5f              True
# c895c90728b6411cbf900a66685a7100              True
# d660695629974f0a83f55e7dff508447              True
# ded81217caea48f990cc5eaf9a7a59fa              True
# e110b77c865b4a1eb191b66d2b14605d               NaN
# e2a487840e414ae8a41f8ab37cd5e4b5              True
# e980ba0ee8ac4fb7935e0241a71aacae               NaN
# ea489364461445c59223afb8fc6b5893              True
# f2d7dcad9adc4da99a24f64dc107d5e5              True
#
# [40 rows x 32 columns]

# %%
parent_run_ids = list(df.index)

# %%
parent_run_ids
# Out:
# ['01f490e163954c9b914d9f9f7765e075',
#  '1185ab831bbc44d1966d666a207215c4',
#  '12c09c8e4f834d15983dc3bdfcbc5959',
#  '183f2361e71047adae98f3a64c4174fd',
#  '27f9e72213b44c04bdb67ef7d2a0e693',
#  '2ce22bf1a8c0477b8313a2c021926f17',
#  '3457a0fa91564368ac3ae4164b12c70d',
#  '38e1e3deb33b46608f6a5b5b8f99da93',
#  '3a54a04f81d0422ca859a7bab8881c8d',
#  '4bb729150a4047e3936c0d62898d819f',
#  '4bdc0a18868e4e9f998bf130711d2b23',
#  '509a5f91adc24a559c551a67d3176b19',
#  '56dfbd80504d4894b7f9346d94379352',
#  '584d5567482a47a38b2365e42daaf666',
#  '5bfa2e15da68491f91ef0e52658ded1a',
#  '63f3db0d9768455891db79bf4f25cb9a',
#  '6cb72b4cb1a7484fb07ccb762e2afa60',
#  '728eeba9325144af81fcb3e61779f67c',
#  '734c393283594d0580c681ee480ea77f',
#  '83386e96e53347d6b0a94a650638ebe0',
#  '87afb3a0102f478b9e93789ceb9c765b',
#  '8f7ca2c7f3824f80895636f6e4ffc224',
#  '91aef0d462cf41e98c8158b9a2cf3d60',
#  'a509fded18e34b2db012ad900a8ea33d',
#  'aa7a22cb6c2544a99f93fef9ad998812',
#  'ac5535d9dab64e0984f05e4781878211',
#  'ae9e3db12a3841b4a6b7d7cc99a8175e',
#  'b160a087813c4754b2d7f6848b979830',
#  'c28f551421f344a3838ec7b067729497',
#  'c2d295c773904f42a96d3d44991acbb2',
#  'c37b31a388684d6b8b11be8299ecba3f',
#  'c5a8576261d245b380c5609e94b17c5f',
#  'c895c90728b6411cbf900a66685a7100',
#  'd660695629974f0a83f55e7dff508447',
#  'ded81217caea48f990cc5eaf9a7a59fa',
#  'e110b77c865b4a1eb191b66d2b14605d',
#  'e2a487840e414ae8a41f8ab37cd5e4b5',
#  'e980ba0ee8ac4fb7935e0241a71aacae',
#  'ea489364461445c59223afb8fc6b5893',
#  'f2d7dcad9adc4da99a24f64dc107d5e5']

# %%
df = df_runs_raw.copy()
df = df.loc[df['parent_run_id'].isin(parent_run_ids)]

# %%
child_run_ids = list(df.index)

# %%
runs_to_delete = child_run_ids

# %%
print(runs_to_delete, len(runs_to_delete))
# Out:
# ['0000c6d69e0f4e85b8d1650b58da14f2', '0000da5f9fc24a569b9ffb8b8432f437', '000206dcb44b4b91a3e4b9e14c6ca91d', '000235a40393424b9eec5ae38d3c5df9', '00027203bf6240759b5c94c2a71df7e2', '00049fb232ea4abcacd62d7fd1b9a984', '000b9da051974b9f9a629569bf067175', '000f3ca3f9ba4d0a9b0a2337d3acefb9', '0010a7237b3b4aa08ed0a5108b3aeac3', '0012082c59754f679754ad74e8770c03', '00139e746ec040a58d7b18bc45ec5b9b', '00199a61ac8049719568c2d2d3f3ef76', '001ded53b30142399200ae03e96dc164', '001f9f0c3804485ea40ddf7c648e1656', '002058b02b3a431fac0e2479a4819986', '0022adbe04484660af3908bfa5356221', '0024617690814b169201c319c7cc4b8f', '002599d25ba64c83a75d96fb6f8ef4ba', '002679b28ce4407ebaa5f4dd4d320feb', '0026de99ef744795b7debe8634055f65', '00289663864d47bd89a0f30684d3d0cf', '0030f0faf01943a6bb82d7739f1f0043', '00318479d22d425f9e63eef277a28167', '003646d80ffd4949bf7bf814f8ad6b6f', '00367ceaee50474b831ddf75a38ebf01', '003fab528dc64ac8ba585942a4fdb421', '00407135dda44c76ad763fa046180e05', '0041650e45e54ef8a33c302d1ef1c10c', '00417437f1634d27a737a467fa92de99', '0042a94fe4604a6f98384df3a929a1a4', '0042ec6e8fd54f4a995c3c05609f37ae', '0044e26cb26d4981965da3cc760d15a3', '004bd280a7ac4daebd38c8f9fe1afdea', '004bec7b9be2474695e1ae817f23cd5f', '004c955b64414374a622d5cf18121bae', '004cc4dca8c04023a83d00008bf3f92e', '004dd2bd7e0b403cadb4374ef7cb9eae', '004fb9818805411bb219f9bd60f6ab51', '0050181c56e0445da703bd1327e1ce8e', '0050a9a221a24cc6b2a882d77d17c080', '0053521d713348108030d9ddc6e17299', '0056dc775e894aa6a07c439c5e12d03f', '00585f5a486a42b2a988cc91bf44dd05', '005899740f4c45588f17352588bdda55', '005c618848dc48a6a621bf971dd08e9b', '005da937b9bf42739dbb3babe414430f', '0060de9755e54b089d1e8220ec8ad6e2', '0060fe2349ea4ed7bb9f0d91cc970623', '006331929373446bb981b321eefc13d3', '006559141b5c4a668bbbf6ae9b0e5213', '0065fc02c5ce454f985eec714ad0a083', '0067ad13701f46dfbae3687ee64947c0', '006856ec234a4a578e60fc3184946733', '006b0c22a572452cbdd7c5aaaee61056', '006c119e82a34405809b0cae6c0485c6', '0075da7978e04cd49c444a60e7c54db2', '0078507c0c014bccb85b7dd1a79dd008', '00785186b3d045e3b5ac2b1215ed9b16', '007a07af848a42248f0defef72666010', '007b5b2c9cbc4c4bb2a3d2be83de20cd', '007de09c3d394f74b8252bc6defe31a1', '00800da2188e4ee7967be4a50ce946d0', '008044b667024b8c92c59d6e6679fb8f', '00845327e70e421f87d4f896430e22fc', '0084ef37a1824b63b99d7ef609ab7d6b', '008a3af85f564152aa700e293e842175', '008b56d473804deeb5f8fa08529cbecf', '008dcf82c6d347c890b40eac3a8c9889', '008e6b35bc184c7597fad7ed6f877aa9', '008feb400a314e418e2d5ab000eabf66', '0094b5f66b0e496d9a430062de0b87b4', '00977d3b6d1748e4889729d261f0200e', '009995f585a64d58b2744317a1f52e26', '009a9768c41144d8bc357028371f0232', '009b88e69d95486492509c43ac4e793c', '009f83c549fe4744a8369b0070eea88b', '00a097fcc2984bdab2e097fc12bade38', '00a2ed7978524580a4b2b17fdd660b9d', '00a4e124f8bf4da99355d9708b093836', '00a617ee63cc4928a35e98b162ad2f15', '00a7860a347744049d2c65626023a062', '00a856631d604d348906f7b57dc40a74', '00a92f38f18f4b6ca361dffe89ed8192', '00a9aa7df09645858c2519bcedefacc6', '00ad181bf44c413f8e7aa812d099847f', '00bb9ef0917e485d8488b715dcd34ea1', '00bc96244ee247ce9dfb7ad064dfdc33', '00bfa0bbc99c40abaca348b47e899918', '00c448666c834f6b8c3296db3d93558b', '00c655732c97465499864e93eb709c05', '00c671390cd9450a9791da839f9ba6b7', '00c8035f9854412581664253be3b4037', '00caa62ba76f49cd94cc8733ef2e8793', '00ce93dea9d54969ab55a4202a27fcaa', '00cea0d81fd04ca08c9a857340ea50fb', '00d23084ca8d4e609a734c91ee21ca1a', '00d4398c7e524cf2b5842a89effd12f0', '00d473ab3e01412196bc3b9ea30bb8f4', '00d5ff3300c346179e95aaf18bc08664', '00d7ef61cf44451f96169a8d36214caf', '00dd0f741c1d4e8e93e27332e903c3fb', '00ded2344c334d539a26842d11b25688', '00df6299450648b1a9bbe03547737592', '00e09ad479724c59b24bd87695ad6b0c', '00e4f12aa6d845248f50fd3327519e2a', '00e835eb740745bfbf14cbccc162b0ea', '00e8f4370346486b9c4fa8bf1761a054', '00e928ff0ec24cfaa9dafa617331cd4b', '00e99ef8d69240b786f1c69a751ace43', '00ec5c00d151496c97cb681709d214ed', '00ed149fd31341dcadb0fe939c645413', '00 ...

# %%
run_uuid_query = [f"'{run_id}'" for run_id in runs_to_delete]
run_uuid_query = ', '.join(run_uuid_query)

# %%
query = f"""
UPDATE runs
SET lifecycle_stage = 'deleted'
WHERE run_uuid IN ({run_uuid_query}) 
"""
with engine.begin() as conn:
    conn.execute(text(query))

# %% [markdown]
# for i, row in df_runs_raw.iterrows():
#     run_id = row.run_id
#     model_name = row['params.model_name']
#     with mlflow.start_run(run_id) as run:
#         mlflow.log_param('model_nickname', model_name)
