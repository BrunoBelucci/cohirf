# %%
from sqlalchemy import create_engine, text
import pandas as pd
from ml_experiments.analyze import get_df_runs_from_mlflow_sql, get_missing_entries
from functools import partial

# %% [markdown]
# # Save Results

# %% [markdown]
# ## Load mlflow runs

# %%
db_port = 5101
db_name = 'cohirf'
w = 'clust9'
# url = f'postgresql://{w}.ceremade.dauphine.lan:{db_port}/{db_name}'
url = f'postgresql://beluccib@localhost:{db_port}/{db_name}'
engine = create_engine(url)
query = 'SELECT experiments.name from experiments'
experiment_names = pd.read_sql(query, engine)['name'].tolist()
# results_dir = Path('~/tab_benchmark/results')
# os.makedirs(results_dir, exist_ok=True)

# %%
experiment_names
# Out:
# ['Default',
#  'classif_huge_cohirf',
#  'classif_huge_kmeans',
#  'classif_clusters_kmeans',
#  'classif_clusters_cohirf',
#  'classif_huge_cohirf_sampling',
#  'classif_huge_cohirf_minibatch',
#  'time_hc_CompleteAgglomerativeClustering_samples',
#  'time_hc_WardAgglomerativeClustering_samples',
#  'time_hc_OPTICS_samples',
#  'time_hc_CompleteAgglomerativeClustering_features',
#  'time_hc_Proclus_features',
#  'time_hc_WardAgglomerativeClustering_features',
#  'time_hc_KMeans_features',
#  'time_hc_KMeansProj_samples',
#  'time_hc_Clique_samples',
#  'time_hc_DBSCAN_features',
#  'time_hc_KMeans_samples',
#  'time_hc_DBSCAN_samples',
#  'time_hc_AffinityPropagation_samples',
#  'time_hc_RecursiveClustering_features',
#  'time_hc_SpectralSubspaceRandomization_samples',
#  'time_hc_KMeansProj_features',
#  'time_hc_MeanShift_features',
#  'time_hc_HDBSCAN_features',
#  'time_hc_OPTICS_features',
#  'time_hc_Clique_features',
#  'time_hc_IRFLLRR_features',
#  'time_hc_RecursiveClustering_samples',
#  'time_hc_MeanShift_samples',
#  'time_hc_SpectralSubspaceRandomization_features',
#  'time_hc_SingleAgglomerativeClustering_features',
#  'time_hc_SpectralClustering_samples',
#  'time_hc_AverageAgglomerativeClustering_samples',
#  'time_hc_Proclus_samples',
#  'time_hc_SpectralClustering_features',
#  'time_hc_IRFLLRR_samples',
#  'time_hc_AffinityPropagation_features',
#  'time_hc_SingleAgglomerativeClustering_samples',
#  'time_hc_AverageAgglomerativeClustering_features',
#  'time_hc_HDBSCAN_samples',
#  'gaussian_CompleteAgglomerativeClustering_features_10000.sbatch',
#  'gaussian_MeanShift_features_10000.sbatch',
#  'gaussian_OPTICS_features_1000.sbatch',
#  'gaussian_HDBSCAN_features_10000.sbatch',
#  'gaussian_RecursiveClustering_features_1000.sbatch',
#  'gaussian_SingleAgglomerativeClustering_features_10000.sbatch',
#  'gaussian_AffinityPropagation_features_100.sbatch',
#  'gaussian_Proclus_features_100.sbatch',
#  'gaussian_IRFLLRR_features_100.sbatch',
#  'gaussian_SpectralClustering_features_10000.sbatch',
#  'gaussian_WardAgglomerativeClustering_features_10000.sbatch',
#  'gaussian_KMeans_features_100.sbatch',
#  'gaussian_AffinityPropagation_features_1000.sbatch',
#  'gaussian_KMeansProj_features_10000.sbatch',
#  'gaussian_Clique_features_10000.sbatch',
#  'gaussian_AffinityPropagation_features_10000.sbatch',
#  'gaussian_AverageAgglomerativeClustering_features_100.sbatch',
#  'gaussian_IRFLLRR_features_1000.sbatch',
#  'gaussian_RecursiveClustering_features_10000.sbatch',
#  'gaussian_RecursiveClustering_features_100.sbatch',
#  'gaussian_SpectralSubspaceRandomization_features_1000.sbatch',
#  'gaussian_IRFLLRR_features_10000.sbatch',
#  'gaussian_WardAgglomerativeClustering_features_1000.sbatch',
#  'gaussian_CompleteAgglomerativeClustering_features_100.sbatch',
#  'gaussian_AverageAgglomerativeClustering_features_1000.sbatch',
#  'gaussian_KMeansProj_features_1000.sbatch',
#  'gaussian_Proclus_features_10000.sbatch',
#  'gaussian_OPTICS_features_100.sbatch',
#  'gaussian_HDBSCAN_features_1000.sbatch',
#  'gaussian_OPTICS_features_10000.sbatch',
#  'gaussian_Proclus_features_1000.sbatch',
#  'gaussian_DBSCAN_features_1000.sbatch',
#  'gaussian_SingleAgglomerativeClustering_features_1000.sbatch',
#  'gaussian_KMeans_features_10000.sbatch',
#  'gaussian_HDBSCAN_features_100.sbatch',
#  'gaussian_SpectralSubspaceRandomization_features_10000.sbatch',
#  'gaussian_SpectralClustering_features_1000.sbatch',
#  'gaussian_SingleAgglomerativeClustering_features_100.sbatch',
#  'gaussian_KMeans_features_1000.sbatch',
#  'gaussian_WardAgglomerativeClustering_features_100.sbatch',
#  'gaussian_KMeansProj_features_100.sbatch',
#  'gaussian_Clique_features_1000.sbatch',
#  'gaussian_Clique_features_100.sbatch',
#  'gaussian_CompleteAgglomerativeClustering_features_1000.sbatch',
#  'gaussian_AverageAgglomerativeClustering_features_10000.sbatch',
#  'gaussian_MeanShift_features_1000.sbatch',
#  'gaussian_DBSCAN_features_10000.sbatch',
#  'gaussian_SpectralClustering_features_100.sbatch',
#  'gaussian_SpectralSubspaceRandomization_features_100.sbatch',
#  'gaussian_DBSCAN_features_100.sbatch',
#  'gaussian_MeanShift_features_100.sbatch',
#  'openml_RecursiveClustering_adjusted_rand',
#  'openml_Proclus_adjusted_rand',
#  'openml_HDBSCAN_adjusted_rand',
#  'openml_OPTICS_adjusted_rand',
#  'openml_AffinityPropagation_adjusted_rand',
#  'openml_MeanShift_adjusted_rand',
#  'openml_SingleAgglomerativeClustering_adjusted_rand',
#  'openml_KMeansProj_adjusted_rand',
#  'openml_AverageAgglomerativeClustering_adjusted_rand',
#  'openml_SpectralSubspaceRandomization_adjusted_rand',
#  'openml_SpectralClustering_adjusted_rand',
#  'openml_CompleteAgglomerativeClustering_adjusted_rand',
#  'openml_WardAgglomerativeClustering_adjusted_rand',
#  'openml_KMeans_adjusted_rand',
#  'openml_DBSCAN_adjusted_rand',
#  'openml_Clique_adjusted_rand',
#  'openml_IRFLLRR_adjusted_rand',
#  'time_hc_RecursiveClustering_full_features',
#  'time_hc_RecursiveClustering_full_samples',
#  'gaussian_random_RecursiveClustering_calinski_harabasz_score',
#  'gaussian_random_RecursiveClustering_silhouette',
#  'gaussian_random_KMeans_silhouette',
#  'gaussian_random_Proclus_silhouette',
#  'gaussian_random_AffinityPropagation_silhouette',
#  'gaussian_random_MeanShift_silhouette',
#  'gaussian_random_RecursiveClustering_full_silhouette',
#  'gaussian_random_SpectralClustering_silhouette',
#  'gaussian_random_AverageAgglomerativeClustering_silhouette',
#  'gaussian_random_IRFLLRR_silhouette',
#  'gaussian_random_KMeansProj_silhouette',
#  'gaussian_random_OPTICS_silhouette',
#  'gaussian_random_Clique_silhouette',
#  'gaussian_random_WardAgglomerativeClustering_silhouette',
#  'gaussian_random_CompleteAgglomerativeClustering_silhouette',
#  'gaussian_random_SpectralSubspaceRandomization_silhouette',
#  'gaussian_MeanShift_features_10000',
#  'gaussian_random_SingleAgglomerativeClustering_silhouette',
#  'gaussian_random_DBSCAN_silhouette',
#  'gaussian_random_HDBSCAN_silhouette',
#  'openml_task_WardAgglomerativeClustering_adjusted_rand',
#  'openml_task_Proclus_adjusted_rand',
#  'openml_task_OPTICS_adjusted_rand',
#  'openml_task_CompleteAgglomerativeClustering_adjusted_rand',
#  'openml_task_RecursiveClustering_adjusted_rand',
#  'openml_task_DBSCAN_adjusted_rand',
#  'openml_task_IRFLLRR_adjusted_rand',
#  'openml_task_RecursiveClustering_full_adjusted_rand',
#  'openml_task_SingleAgglomerativeClustering_adjusted_rand',
#  'openml_task_KMeansProj_adjusted_rand',
#  'openml_task_KMeans_adjusted_rand',
#  'openml_task_MeanShift_adjusted_rand',
#  'openml_task_AverageAgglomerativeClustering_adjusted_rand',
#  'openml_task_HDBSCAN_adjusted_rand',
#  'openml_task_Clique_adjusted_rand',
#  'openml_task_SpectralClustering_adjusted_rand',
#  'openml_task_AffinityPropagation_adjusted_rand',
#  'openml_task_SpectralSubspaceRandomization_adjusted_rand',
#  'gaussian_HDBSCAN_features_100',
#  'gaussian_SpectralClustering_features_1000',
#  'gaussian_SpectralSubspaceRandomization_features_100',
#  'gaussian_KMeans_features_1000',
#  'gaussian_CompleteAgglomerativeClustering_features_1000',
#  'gaussian_SingleAgglomerativeClustering_features_10000',
#  'gaussian_OPTICS_features_100',
#  'gaussian_RecursiveClustering_features_1000',
#  'gaussian_Clique_features_100',
#  'gaussian_SpectralClustering_features_10000',
#  'gaussian_WardAgglomerativeClustering_features_100',
#  'gaussian_CompleteAgglomerativeClustering_features_100',
#  'gaussian_RecursiveClustering_features_100',
#  'gaussian_AverageAgglomerativeClustering_features_1000',
#  'gaussian_IRFLLRR_features_10000',
#  'gaussian_KMeans_features_100',
#  'gaussian_WardAgglomerativeClustering_features_1000',
#  'gaussian_SpectralSubspaceRandomization_features_10000',
#  'gaussian_DBSCAN_features_10000',
#  'gaussian_AverageAgglomerativeClustering_features_10000',
#  'gaussian_SpectralSubspaceRandomization_features_1000',
#  'gaussian_MeanShift_features_100',
#  'gaussian_AffinityPropagation_features_10000',
#  'gaussian_Proclus_features_10000',
#  'gaussian_MeanShift_features_1000',
#  'gaussian_Proclus_features_1000',
#  'gaussian_OPTICS_features_1000',
#  'gaussian_RecursiveClustering_features_10000',
#  'gaussian_HDBSCAN_features_10000',
#  'gaussian_KMeansProj_features_100',
#  'gaussian_SingleAgglomerativeClustering_features_1000',
#  'gaussian_IRFLLRR_features_1000',
#  'gaussian_IRFLLRR_features_100',
#  'gaussian_DBSCAN_features_100',
#  'gaussian_AffinityPropagation_features_100',
#  'gaussian_KMeans_features_10000',
#  'gaussian_CompleteAgglomerativeClustering_features_10000',
#  'gaussian_SpectralClustering_features_100',
#  'gaussian_Proclus_features_100',
#  'gaussian_OPTICS_features_10000',
#  'gaussian_SingleAgglomerativeClustering_features_100',
#  'gaussian_Clique_features_10000',
#  'gaussian_KMeansProj_features_1000',
#  'gaussian_Clique_features_1000',
#  'gaussian_AverageAgglomerativeClustering_features_100',
#  'gaussian_HDBSCAN_features_1000',
#  'gaussian_AffinityPropagation_features_1000',
#  'gaussian_WardAgglomerativeClustering_features_10000',
#  'gaussian_DBSCAN_features_1000',
#  'gaussian_KMeansProj_features_10000',
#  'gaussian_random_KMeans_calinski_harabasz_score',
#  'gaussian_RecursiveClustering_full_features_10000',
#  'openml_RecursiveClustering_full_adjusted_rand',
#  'openml_task_SpectralClustering_adjusted_rand2',
#  'openml_task_IRFLLRR_adjusted_rand2',
#  'gaussian_RecursiveClusteringHDBSCAN_features_10000',
#  'gaussian_RecursiveClusteringSCSRGF_features_10000']

# %%
experiments_names = [exp for exp in experiment_names if exp.find('openml')!= -1 and exp.find('openml_task')==-1]

# %%
params_columns = [
    'model_nickname',
    'n_samples',
    'n_features',
    'n_classes',
    'seed_model',
    'dataset_id',
    'dataset_name',
    'model_params/representative_method',
    'model_params/n_samples_representative',
    'model_params/kernel_kmeans',
    'direction',
    'hpo_metric',
    'standardize'
]

# %%
latest_metrics_columns = [
    'fit_model_return_elapsed_time',
    'max_memory_used',
    'n_clusters_',
    'rand_score',
    'adjusted_rand',
    'mutual_info',
    'adjusted_mutual_info',
    'normalized_mutual_info',
    'homogeneity',
    'completeness',
    'v_measure',
    'silhouette',
    'calinski_harabasz_score',
    'davies_bouldin_score',
    'inertia_score',
    'best_n_clusters_',
    'best_rand_score',
    'best_adjusted_rand',
    'best_mutual_info',
    'best_adjusted_mutual_info',
    'best_normalized_mutual_info',
    'best_homogeneity_completeness_v_measure',
    'best_silhouette',
    'best_calinski_harabasz_score',
    'best_davies_bouldin_score',
    'best_inertia_score',
    'best_homogeneity',
    'best_completeness',
    'best_v_measure',
]

# %%
tags_columns = [
    'raised_exception',
    'EXCEPTION',
    'parent_run_id',
    'best_child_run_id',
]

# %%
# parameters of each model, they are saved as tags for the parent run
parameters = {
    'RecursiveClustering': ['components_size', 'repetitions', 'kmeans_n_clusters'],
    'KMeans': ['n_clusters'],
    'HDBSCAN': ['min_cluster_size'],
    'DBSCAN': ['eps', 'min_samples'],
    'AffinityPropagation': ['damping'],
    'OPTICS': ['min_samples'],
    'SpectralSubspaceRandomization': ['n_similarities', 'sampling_ratio', 'sc_n_clusters'],
    'WardAgglomerativeClustering': ['n_clusters'],
    'Clique': ['n_partitions', 'density_threshold'],
    'IRFLLRR': ['sc_n_clusters', 'p', 'c', 'lambda_', 'alpha'],
    'KMeansProj': ['n_clusters'],
    'Proclus': ['n_clusters', 'avg_dims'],
    'SpectralClustering': ['n_clusters'],
    'SingleAgglomerativeClustering': ['n_clusters'],
    'CompleteAgglomerativeClustering': ['n_clusters'],
    'AverageAgglomerativeClustering': ['n_clusters'],
    'MeanShift': ['min_bin_freq'],
}
all_model_parameters = [p for model, params in parameters.items() for p in params]
all_model_parameters = list(set(all_model_parameters))
for param in all_model_parameters:
    tags_columns.append(param)

# %%
runs_columns = ['run_uuid', 'status', 'start_time', 'end_time']
experiments_columns = []
other_table = 'params'
other_table_keys = params_columns
df_params = get_df_runs_from_mlflow_sql(engine, runs_columns=runs_columns, experiments_columns=experiments_columns, experiments_names=experiments_names, other_table=other_table, other_table_keys=other_table_keys)
df_latest_metrics = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='latest_metrics', other_table_keys=latest_metrics_columns)
df_tags = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='tags', other_table_keys=tags_columns)

# %%
df_runs_raw = df_params.join(df_latest_metrics)
df_runs_raw = df_runs_raw.join(df_tags)

# %%
df_runs_raw_parents = df_runs_raw.copy()
df_runs_raw_parents = df_runs_raw_parents.loc[df_runs_raw_parents['parent_run_id'].isna()]

# %%
# get all metrics beside best or last
metrics_columns = [
    'adjusted_rand',
    'silhouette',
    'calinski_harabasz_score',
    'davies_bouldin_score',
    'inertia_score',
]
metrics_columns_query = [f"'{m}'" for m in metrics_columns]
metrics_columns_query = ', '.join(metrics_columns_query)
experiments_names_query = [f"'{name}'" for name in experiments_names]
experiments_names_query = ', '.join(experiments_names_query)
query = f"""
SELECT
	runs.run_uuid,
	metrics."key",
	metrics.value,
	metrics.step 
FROM
	runs
LEFT JOIN metrics ON
	metrics.run_uuid = runs.run_uuid
LEFT JOIN experiments ON 
	experiments.experiment_id = runs.experiment_id  
WHERE 
	metrics."key" IN ({metrics_columns_query})
	AND experiments."name" IN ({experiments_names_query})
"""
df_metrics = pd.read_sql(query, engine)
df_metrics = df_metrics.pivot_table(index=['run_uuid', 'step'], columns='key', values='value')
df_metrics
# Out:
# key                                    adjusted_rand  calinski_harabasz_score  \
# run_uuid                         step
# 000bd31bf02444d592585bc542d4df5b 0         -0.042740                 2.347953
# 002720a0dd1e499893174c161e95410f 0          0.095148                 2.432060
# 002b40f8feac40b68e0b8045bd4d1597 0          0.000000                -1.000000
# 002c80864618429395e88192cef8533a 0          0.142890                 2.301928
# 00314537240c486a98dbf78117a3c41c 0          0.300603                 3.330224
# ...                                              ...                      ...
# ffa26d4096a74842a45417159f50f00a 0          0.016404                 2.893411
# ffaedace4f804208b4e621dd0c827210 0          0.159510                 3.898134
# ffc4640be38d4423a01514a3bdad668e 0          0.084148                 2.373405
# ffcdc82b5ae0400588958a87661539cc 0         -0.015867                 2.147544
# ffe988d1a19142bb9e071abb3b0f10c3 0          0.053274                40.095383
#
# key                                    davies_bouldin_score  inertia_score  \
# run_uuid                         step
# 000bd31bf02444d592585bc542d4df5b 0                 0.665062   1.182605e+05
# 002720a0dd1e499893174c161e95410f 0                 1.074172   2.854436e+04
# 002b40f8feac40b68e0b8045bd4d1597 0              1000.000000   3.605180e+03
# 002c80864618429395e88192cef8533a 0                 0.915314   9.033444e+04
# 00314537240c486a98dbf78117a3c41c 0                 2.160309   7.000641e+04
# ...                                                     ...            ...
# ffa26d4096a74842a45417159f50f00a 0                 0.575626   1.584268e+05
# ffaedace4f804208b4e621dd0c827210 0                 1.224359   2.901377e+04
# ffc4640be38d4423a01514a3bdad668e 0                 1.420516   4.814853e+04
# ffcdc82b5ae0400588958a87661539cc 0                 2.938432   6.461672e+04
# ffe988d1a19142bb9e071abb3b0f10c3 0                 2.781520   1.359646e+06
#
# key                                    silhouette
# run_uuid                         step
# 000bd31bf02444d592585bc542d4df5b 0       0.161783
# 002720a0dd1e499893174c161e95410f 0       0.048543
# 002b40f8feac40b68e0b8045bd4d1597 0      -1.000000
# 002c80864618429395e88192cef8533a 0       0.077393
# 00314537240c486a98dbf78117a3c41c 0       0.055164
# ...                                           ...
# ffa26d4096a74842a45417159f50f00a 0       0.142035
# ffaedace4f804208b4e621dd0c827210 0       0.097607
# ffc4640be38d4423a01514a3bdad668e 0       0.031826
# ffcdc82b5ae0400588958a87661539cc 0      -0.006516
# ffe988d1a19142bb9e071abb3b0f10c3 0      -0.035470
#
# [10906 rows x 5 columns]

# %%
df_runs_raw_parents
# Out:
# key                                 status     start_time      end_time  \
# run_uuid
# 000977a3bdd6401599eae1684ec59d0d    FAILED  1742922415890  1.742930e+12
# 0152dc997af245d4baf79d0192b306ae    FAILED  1742922366888  1.742930e+12
# 017f4aad072141019af28721a3408745    FAILED  1742922369405  1.742930e+12
# 01adf00b439041338d8fc130fb8ebbba  FINISHED  1743266411846  1.743285e+12
# 01b919d95d4c4aedada499d3cd3cc53f    FAILED  1742922368297  1.742930e+12
# ...                                    ...            ...           ...
# fd7ce3adee7345ddb805b04404918f09  FINISHED  1742938538892  1.742939e+12
# fdd8f9917a814c44998f5aba77f1c49e   RUNNING  1742997251963           NaN
# fe990c4d8d9b484998e72e992aab22ee  FINISHED  1742938550295  1.742939e+12
# ff025f2b9e1e445cb9b3ed581c561187  FINISHED  1742938453913  1.742939e+12
# ff7beb5847294ab392e20b8e1fad8fd0    FAILED  1742922366508  1.742930e+12
#
# key                              dataset_id         dataset_name direction  \
# run_uuid
# 000977a3bdd6401599eae1684ec59d0d      46782  binary_alpha_digits  maximize
# 0152dc997af245d4baf79d0192b306ae      46775    armstrong-2002-v1  maximize
# 017f4aad072141019af28721a3408745      46783              coil-20  maximize
# 01adf00b439041338d8fc130fb8ebbba        554            mnist_784  maximize
# 01b919d95d4c4aedada499d3cd3cc53f      46774     alizadeh-2000-v3  maximize
# ...                                     ...                  ...       ...
# fd7ce3adee7345ddb805b04404918f09      46778        chowdary-2006  maximize
# fdd8f9917a814c44998f5aba77f1c49e      46781                  NaN  maximize
# fe990c4d8d9b484998e72e992aab22ee      46782  binary_alpha_digits  maximize
# ff025f2b9e1e445cb9b3ed581c561187      46781            khan-2001  maximize
# ff7beb5847294ab392e20b8e1fad8fd0      46776         bittner-2000  maximize
#
# key                                  hpo_metric  \
# run_uuid
# 000977a3bdd6401599eae1684ec59d0d  adjusted_rand
# 0152dc997af245d4baf79d0192b306ae  adjusted_rand
# 017f4aad072141019af28721a3408745  adjusted_rand
# 01adf00b439041338d8fc130fb8ebbba  adjusted_rand
# 01b919d95d4c4aedada499d3cd3cc53f  adjusted_rand
# ...                                         ...
# fd7ce3adee7345ddb805b04404918f09  adjusted_rand
# fdd8f9917a814c44998f5aba77f1c49e  adjusted_rand
# fe990c4d8d9b484998e72e992aab22ee  adjusted_rand
# ff025f2b9e1e445cb9b3ed581c561187  adjusted_rand
# ff7beb5847294ab392e20b8e1fad8fd0  adjusted_rand
#
# key                                                model_nickname n_classes  \
# run_uuid
# 000977a3bdd6401599eae1684ec59d0d                           DBSCAN       NaN
# 0152dc997af245d4baf79d0192b306ae                       KMeansProj       NaN
# 017f4aad072141019af28721a3408745               SpectralClustering       NaN
# 01adf00b439041338d8fc130fb8ebbba  CompleteAgglomerativeClustering       NaN
# 01b919d95d4c4aedada499d3cd3cc53f  CompleteAgglomerativeClustering       NaN
# ...                                                           ...       ...
# fd7ce3adee7345ddb805b04404918f09                        MeanShift       NaN
# fdd8f9917a814c44998f5aba77f1c49e                           Clique       NaN
# fe990c4d8d9b484998e72e992aab22ee                           KMeans       NaN
# ff025f2b9e1e445cb9b3ed581c561187              AffinityPropagation       NaN
# ff7beb5847294ab392e20b8e1fad8fd0               SpectralClustering       NaN
#
# key                              n_features  ... min_samples n_clusters  \
# run_uuid                                     ...
# 000977a3bdd6401599eae1684ec59d0d        NaN  ...         NaN        NaN
# 0152dc997af245d4baf79d0192b306ae        NaN  ...         NaN        NaN
# 017f4aad072141019af28721a3408745        NaN  ...         NaN        NaN
# 01adf00b439041338d8fc130fb8ebbba        NaN  ...         NaN         13
# 01b919d95d4c4aedada499d3cd3cc53f        NaN  ...         NaN        NaN
# ...                                     ...  ...         ...        ...
# fd7ce3adee7345ddb805b04404918f09        NaN  ...         NaN        NaN
# fdd8f9917a814c44998f5aba77f1c49e        NaN  ...         NaN        NaN
# fe990c4d8d9b484998e72e992aab22ee        NaN  ...         NaN         26
# ff025f2b9e1e445cb9b3ed581c561187        NaN  ...         NaN        NaN
# ff7beb5847294ab392e20b8e1fad8fd0        NaN  ...         NaN        NaN
#
# key                              n_partitions  n_similarities    p  \
# run_uuid
# 000977a3bdd6401599eae1684ec59d0d          NaN             NaN  NaN
# 0152dc997af245d4baf79d0192b306ae          NaN             NaN  NaN
# 017f4aad072141019af28721a3408745          NaN             NaN  NaN
# 01adf00b439041338d8fc130fb8ebbba          NaN             NaN  NaN
# 01b919d95d4c4aedada499d3cd3cc53f          NaN             NaN  NaN
# ...                                       ...             ...  ...
# fd7ce3adee7345ddb805b04404918f09          NaN             NaN  NaN
# fdd8f9917a814c44998f5aba77f1c49e          NaN             NaN  NaN
# fe990c4d8d9b484998e72e992aab22ee          NaN             NaN  NaN
# ff025f2b9e1e445cb9b3ed581c561187          NaN             NaN  NaN
# ff7beb5847294ab392e20b8e1fad8fd0          NaN             NaN  NaN
#
# key                               parent_run_id  raised_exception  \
# run_uuid
# 000977a3bdd6401599eae1684ec59d0d            NaN              True
# 0152dc997af245d4baf79d0192b306ae            NaN              True
# 017f4aad072141019af28721a3408745            NaN              True
# 01adf00b439041338d8fc130fb8ebbba            NaN             False
# 01b919d95d4c4aedada499d3cd3cc53f            NaN              True
# ...                                         ...               ...
# fd7ce3adee7345ddb805b04404918f09            NaN             False
# fdd8f9917a814c44998f5aba77f1c49e            NaN               NaN
# fe990c4d8d9b484998e72e992aab22ee            NaN             False
# ff025f2b9e1e445cb9b3ed581c561187            NaN             False
# ff7beb5847294ab392e20b8e1fad8fd0            NaN              True
#
# key                               repetitions  sampling_ratio  sc_n_clusters
# run_uuid
# 000977a3bdd6401599eae1684ec59d0d          NaN             NaN            NaN
# 0152dc997af245d4baf79d0192b306ae          NaN             NaN            NaN
# 017f4aad072141019af28721a3408745          NaN             NaN            NaN
# 01adf00b439041338d8fc130fb8ebbba          NaN             NaN            NaN
# 01b919d95d4c4aedada499d3cd3cc53f          NaN             NaN            NaN
# ...                                       ...             ...            ...
# fd7ce3adee7345ddb805b04404918f09          NaN             NaN            NaN
# fdd8f9917a814c44998f5aba77f1c49e          NaN             NaN            NaN
# fe990c4d8d9b484998e72e992aab22ee          NaN             NaN            NaN
# ff025f2b9e1e445cb9b3ed581c561187          NaN             NaN            NaN
# ff7beb5847294ab392e20b8e1fad8fd0          NaN             NaN            NaN
#
# [508 rows x 63 columns]

# %% [markdown]
# # Separate our method with two types of representative_method

# %%
df_runs_parents = df_runs_raw_parents.copy()

# # fill with default values
# df_runs_parents['model_params/representative_method'] = df_runs_parents['model_params/representative_method'].fillna('closest_overall')
# df_runs_parents['model_params/n_samples_representative'] = 'None' #df_runs_parents['model_params/n_samples_representative'].fillna('None')
# df_runs_parents['model_params/kernel_kmeans'] = df_runs_parents['model_params/kernel_kmeans'].fillna('False')
#
# # fix closest_overall_1000 with new params
# df_runs_parents.loc[(df_runs_parents['model_nickname']=='RecursiveClustering') & (df_runs_parents['model_params/representative_method']=='closest_overall_1000'), 'model_params/n_samples_representative'] = '1000'
# df_runs_parents.loc[(df_runs_parents['model_nickname']=='RecursiveClustering') & (df_runs_parents['model_params/representative_method']=='closest_overall_1000'), 'model_params/representative_method'] = 'closest_overall'
#
# df_runs_parents.loc[df_runs_parents['model_nickname']=='RecursiveClustering', 'model_nickname'] = df_runs_parents.loc[df_runs_parents['model_nickname']=='RecursiveClustering', 'model_nickname'] + '_' + df_runs_parents.loc[df_runs_parents['model_nickname']=='RecursiveClustering', 'model_params/representative_method'] + '_' + df_runs_parents.loc[df_runs_parents['model_nickname']=='RecursiveClustering', 'model_params/n_samples_representative'] + '_' + df_runs_parents.loc[df_runs_parents['model_nickname']=='RecursiveClustering', 'model_params/kernel_kmeans']

# df_runs_parents.loc[(df_runs_parents['model_nickname'] == 'RecursiveClustering') & (df_runs_parents['model_params/representative_method'].isna()), 'model_params/representative_method'] = 'closest_overall'
# df_runs_parents.loc[(df_runs_parents['model_nickname'] == 'RecursiveClustering') & (df_runs_parents['model_params/representative_method'] == 'rbf'), 'model_nickname'] = df_runs_parents.loc[(df_runs_parents['model_nickname'] == 'RecursiveClustering') & (df_runs_parents['model_params/representative_method'] == 'rbf'), 'model_nickname'] + '_rbf'
# df_runs_parents.loc[(df_runs_parents['model_nickname'] == 'RecursiveClustering') & (df_runs_parents['model_params/representative_method'] == 'closest_overall_1000'), 'model_nickname'] = df_runs_parents.loc[(df_runs_parents['model_nickname'] == 'RecursiveClustering') & (df_runs_parents['model_params/representative_method'] == 'closest_overall_1000'), 'model_nickname'] + '_aproximated'

# %% [markdown]
# ## Delete duplicate runs (if any) and complete some models that cannot run with some datasets

# %%
non_duplicate_columns = [
    'model_nickname',
    'dataset_id',
    # 'model_params/normalization',
    'direction',
    'hpo_metric',
    'standardize',
]
df_runs_parents = df_runs_parents.dropna(axis=0, how='all', subset=['best_adjusted_rand']).copy()
df_runs_parents = df_runs_parents.loc[(~df_runs_parents.duplicated(non_duplicate_columns))]

# %% [markdown]
#  # Missing

# %%
model_nickname = df_runs_parents['model_nickname'].unique().tolist()
model_nickname.sort()
model_nickname
# Out:
# ['AffinityPropagation',
#  'AverageAgglomerativeClustering',
#  'Clique',
#  'CompleteAgglomerativeClustering',
#  'DBSCAN',
#  'HDBSCAN',
#  'IRFLLRR',
#  'KMeans',
#  'KMeansProj',
#  'MeanShift',
#  'OPTICS',
#  'Proclus',
#  'RecursiveClustering',
#  'RecursiveClustering_full',
#  'SingleAgglomerativeClustering',
#  'SpectralClustering',
#  'SpectralSubspaceRandomization',
#  'WardAgglomerativeClustering']

# %%
non_duplicate_columns = [
    'model_nickname',
    'dataset_id',
    'direction',
    'hpo_metric',
    'standardize',
]

# %%
model_nickname = df_runs_parents['model_nickname'].unique().tolist()
model_nickname.sort()
model_nickname
# Out:
# ['AffinityPropagation',
#  'AverageAgglomerativeClustering',
#  'Clique',
#  'CompleteAgglomerativeClustering',
#  'DBSCAN',
#  'HDBSCAN',
#  'IRFLLRR',
#  'KMeans',
#  'KMeansProj',
#  'MeanShift',
#  'OPTICS',
#  'Proclus',
#  'RecursiveClustering',
#  'RecursiveClustering_full',
#  'SingleAgglomerativeClustering',
#  'SpectralClustering',
#  'SpectralSubspaceRandomization',
#  'WardAgglomerativeClustering']

# %%
# dataset_id = datasets['dataset_id'].tolist()
dataset_id = [46773,46774,46775,46776,46777,46778,46779,46780,46781,46782,46783,]
# dataset_id = [554,40996]
dataset_id = [str(d) for d in dataset_id]
direction = ['maximize']
metric = ['adjusted_rand']
standardize = ['True']
model_nickname = [
    'AffinityPropagation',
    'AverageAgglomerativeClustering',
    'Clique',
    'CompleteAgglomerativeClustering',
    'DBSCAN',
    'HDBSCAN',
    'IRFLLRR',
    'KMeans',
    'KMeansProj',
    'MeanShift',
    'OPTICS',
    'Proclus',
    'RecursiveClustering',
    'SingleAgglomerativeClustering',
    'SpectralClustering',
    'SpectralSubspaceRandomization',
    'WardAgglomerativeClustering'
]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, direction, metric, standardize]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)

# %%
df = df_runs_raw_parents.copy()
df = df.set_index(['model_nickname', 'dataset_id', 'direction', 'hpo_metric', 'standardize'])[['raised_exception', 'EXCEPTION']]
df_missing = df_missing.join(df, on=non_duplicate_columns)

# %%
df_missing
# Out:
#        model_nickname dataset_id direction     hpo_metric standardize  \
# 0              Clique      46778  maximize  adjusted_rand        True
# 1              Clique      46780  maximize  adjusted_rand        True
# 2              Clique      46781  maximize  adjusted_rand        True
# 3              Clique      46782  maximize  adjusted_rand        True
# 4              Clique      46783  maximize  adjusted_rand        True
# 5             IRFLLRR      46783  maximize  adjusted_rand        True
# 5             IRFLLRR      46783  maximize  adjusted_rand        True
# 5             IRFLLRR      46783  maximize  adjusted_rand        True
# 5             IRFLLRR      46783  maximize  adjusted_rand        True
# 6  SpectralClustering      46782  maximize  adjusted_rand        True
# 6  SpectralClustering      46782  maximize  adjusted_rand        True
# 6  SpectralClustering      46782  maximize  adjusted_rand        True
# 6  SpectralClustering      46782  maximize  adjusted_rand        True
# 7  SpectralClustering      46783  maximize  adjusted_rand        True
# 7  SpectralClustering      46783  maximize  adjusted_rand        True
# 7  SpectralClustering      46783  maximize  adjusted_rand        True
# 7  SpectralClustering      46783  maximize  adjusted_rand        True
#
#   raised_exception                                    EXCEPTION
# 0              NaN                                          NaN
# 1              NaN                                          NaN
# 2              NaN                                          NaN
# 3              NaN                                          NaN
# 4              NaN                                          NaN
# 5             True  Every trial failed, no best model was found
# 5              NaN                                          NaN
# 5              NaN                                          NaN
# 5              NaN                                          NaN
# 6              NaN                                          NaN
# 6              NaN                                          NaN
# 6              NaN                                          NaN
# 6             True  Every trial failed, no best model was found
# 7             True  Every trial failed, no best model was found
# 7              NaN                                          NaN
# 7              NaN                                          NaN
# 7              NaN                                          NaN

# %%
df_missing['model_nickname'].unique().tolist()
# Out:
# ['Clique', 'IRFLLRR', 'SpectralClustering']

# %% [markdown]
# # Plots

# %%
all_model_parameters
# Out:
# ['damping',
#  'sc_n_clusters',
#  'lambda_',
#  'sampling_ratio',
#  'alpha',
#  'eps',
#  'avg_dims',
#  'kmeans_n_clusters',
#  'n_similarities',
#  'components_size',
#  'min_samples',
#  'density_threshold',
#  'n_partitions',
#  'n_clusters',
#  'min_cluster_size',
#  'c',
#  'repetitions',
#  'p']

# %%
def get_parameters_string(row):
    parameter_names = {
        'components_size': 'q',
        'repetitions': 'R',
        'kmeans_n_clusters': 'C',
        'n_clusters': 'C',
        'min_cluster_size': 'C_{\\text{min}}',
        'eps': '\epsilon',
        'min_samples': 'n_{\\text{min}}',
        'damping': '\lambda',
        'n_similarities': 'm',
        'sampling_ratio': 'r',
        'sc_n_clusters': 'C',
        'density_threshold': '\\tau',
        'n_partitions': 'P',
        'avg_dims': 'd',
        'lambda_': '\lambda',
        'alpha': '\\alpha',
        'c': 'c',
        'p': 'p',
    }
    first = True
    str = ''
    for p in all_model_parameters:
        if not pd.isna(row[p]):
            if not first:
                str += '; '
            else:
                first = False
            value = float(row[p])
            if value.is_integer():
                value = int(value)
                str += f'${parameter_names[p]}={value}$'
            else:
                str += f'${parameter_names[p]}={value:0.2f}$'
    return str

# %%
def highlight_max(df, column_name, level=0):
    df_column = df[column_name]
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_highlighted] = 'font-weight: bold'
    return df_css

# %%
def highlight_max_index(series_index, df_column, level=0):
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css[:] = ''
    series_css[is_highlighted.values] = 'font-weight: bold'
    return series_css

# %%
def underline_2nd_max(df, column_name, level=0):
    df_column = df[column_name]
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_underlined] = 'underline: --latex--rwrap'
    return df_css

# %%
def underline_2nd_max_index(series_index, df_column, level=0):
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css.loc[:] = ''
    series_css[is_underlined.values] = 'underline: --latex--rwrap'
    return series_css

# %% [markdown]
# ## Some Models

# %% [markdown]
# The following will provide the latex code for a clean table, we only need to make a little adjustement in the first line to delete the "key" and have only one header. For the longtable environment (full data) we need to add the "\*" at the end of lines we dont want to have a page break. We also should replace the entire begin{table} ... end{table} by begin{longtable} ... end{longtable} in the latex file.

# %%
datasets_ids = [40685, 39, 61, 182, 40984, 1478, 1568]
datasets_ids = [str(d) for d in datasets_ids]
models_nicknames = ['RecursiveClustering', 'RecursiveClustering_rbf', 'RecursiveClustering_aproximated', 'KMeans', 'HDBSCAN', 'DBSCAN', 'AffinityPropagation', 'OPTICS', 'SpectralSubspaceRandomization', 'WardAgglomerativeClustering']
df = df_runs_parents.copy()
# get time of the child run
df_child = df_runs_raw.copy()
df_child = df_child[['parent_run_id', 'fit_model_return_elapsed_time']]
df_child = df_child.rename(columns={'fit_model_return_elapsed_time': 'Time (s)'})
df = df.join(df_child.set_index('parent_run_id'), on='run_uuid', rsuffix='_child')
df = df.loc[df['dataset_id'].isin(datasets_ids)]
df = df.loc[df['model_nickname'].isin(models_nicknames)]
df = df.loc[df['hpo_metric'] == 'adjusted_rand']
df = df.loc[df['standardize'] == 'True']
df['Parameters'] = df.apply(get_parameters_string, axis=1)
df = df[['model_nickname', 'dataset_name', 'best_adjusted_rand', 'Parameters', 'Time (s)']]
df = df.loc[~((df['model_nickname'] == 'RecursiveClustering_aproximated') & (df['dataset_name'].isin(['iris', 'ecoli'])))]
models_names = {
    'RecursiveClustering_closest_overall_None_False': 'CoHiRF',
    'RecursiveClustering_rbf': 'CoHiRF-RBF',
    'RecursiveClustering_aproximated': 'CoHiRF-1000',
    'KMeans': 'K-Means',
    'HDBSCAN': 'HDBSCAN',
    'DBSCAN': 'DBSCAN',
    'AffinityPropagation': 'Affinity Propagation',
    'OPTICS': 'OPTICS',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
}
df = df.replace({'model_nickname': models_names})
df = df.rename(columns={'best_adjusted_rand': 'ARI', 'model_nickname': 'Model', 'dataset_name': 'Dataset'})
df = df.groupby(['Dataset', 'Model']).agg({'ARI': 'mean', 'Time (s)': 'first', 'Parameters': 'first'})

# %%
# with time, appendix
df_latex = df.copy()
highlight_max_ari = partial(highlight_max, column_name='ARI')
highlight_max_ari_index = partial(highlight_max_index, df_column=df_latex['ARI'])
underline_2nd_max_ari = partial(underline_2nd_max, column_name='ARI')
underline_2nd_max_ari_index = partial(underline_2nd_max_index, df_column=df_latex['ARI'])
print(df_latex.style.apply(highlight_max_ari, subset='ARI', axis=None).apply_index(highlight_max_ari_index,'index', level=1).apply(underline_2nd_max_ari, subset='ARI', axis=None).apply_index(underline_2nd_max_ari_index, 'index', level=1).format(precision=3, na_rep='No Run', subset='ARI').format(formatter='{:4.3f}',subset='Time (s)').to_latex(hrules=True, clines='skip-last;data', convert_css=True, column_format='llrrl'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 7
#       5 underline_2nd_max_ari = partial(underline_2nd_max, column_name='ARI')
#       6 underline_2nd_max_ari_index = partial(underline_2nd_max_index, df_column=df_latex['ARI'])
# ----> 7 print(df_latex.style.apply(highlight_max_ari, subset='ARI', axis=None).apply_index(highlight_max_ari_index,'index', level=1).apply(underline_2nd_max_ari, subset='ARI', axis=None).apply_index(underline_2nd_max_ari_index, 'index', level=1).format(precision=3, na_rep='No Run', subset='ARI').format(formatter='{:4.3f}',subset='Time (s)').to_latex(hrules=True, clines='skip-last;data', convert_css=True, column_format='llrrl'))
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/io/formats/style.py:1156, in Styler.to_latex(self, buf, column_format, position, position_float, hrules, clines, label, caption, sparse_index, sparse_columns, multirow_align, multicol_align, siunitx, environment, encoding, convert_css)
#    1154 multicol_align = multicol_align or get_option("styler.latex.multicol_align")
#    1155 multirow_align = multirow_align or get_option("styler.latex.multirow_align")
# -> 1156 latex = obj._render_latex(
#    1157     sparse_index=sparse_index,
#    1158     sparse_columns=sparse_columns,
#    1159     multirow_align=multirow_align,
#    1160     multicol_align=multicol_align,
#    1161     environment=environment,
#    1162     convert_css=convert_css,
#    1163     siunitx=siunitx,
#    1164     clines=clines,
#    1165 )
#    1167 encoding = (
#    1168     (encoding or get_option("styler.render.encoding"))
#    1169     if isinstance(buf, str)  # i.e. a filepath
#    1170     else encoding
#    1171 )
#    1172 return save_to_buffer(latex, buf=buf, encoding=encoding)
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/io/formats/style_render.py:218, in StylerRenderer._render_latex(self, sparse_index, sparse_columns, clines, **kwargs)
#     212 def _render_latex(
#     213     self, sparse_index: bool, sparse_columns: bool, clines: str | None, **kwargs
#     214 ) -> str:
#     215     """
#     216     Render a Styler in latex format
#     217     """
# --> 218     d = self._render(sparse_index, sparse_columns, None, None)
#     219     self._translate_latex(d, clines=clines)
#     220     self.template_latex.globals["parse_wrap"] = _parse_latex_table_wrapping
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/io/formats/style_render.py:161, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     147 def _render(
#     148     self,
#     149     sparse_index: bool,
#    (...)    153     blank: str = "",
#     154 ):
#     155     """
#     156     Computes and applies styles and then generates the general render dicts.
#     157
#     158     Also extends the `ctx` and `ctx_index` attributes with those of concatenated
#     159     stylers for use within `_translate_latex`
#     160     """
# --> 161     self._compute()
#     162     dxs = []
#     163     ctx_len = len(self.index)
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/io/formats/style_render.py:256, in StylerRenderer._compute(self)
#     254 r = self
#     255 for func, args, kwargs in self._todo:
# --> 256     r = func(self)(*args, **kwargs)
#     257 return r
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/io/formats/style.py:1860, in Styler._apply_index(self, func, axis, level, method, **kwargs)
#    1857 obj = self.index if axis == 0 else self.columns
#    1859 levels_ = refactor_levels(level, obj)
# -> 1860 data = DataFrame(obj.to_list()).loc[:, levels_]
#    1862 if method == "apply":
#    1863     result = data.apply(func, axis=0, **kwargs)
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1017 if com.is_null_slice(key):
#    1018     continue
# -> 1020 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1021 # We should never have retval.ndim < self.ndim, as that should
#    1022 #  be handled by the _getitem_lowerdim call above.
#    1023 assert retval.ndim == self.ndim
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexing.py:1360, in _LocIndexer._getitem_iterable(self, key, axis)
#    1357 self._validate_key(key, axis)
#    1359 # A collection of keys
# -> 1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/cohirf/lib/python3.11/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([1], dtype='int64')] are in the [columns]"

# %%
# no time, main text
df_latex = df.copy()[['ARI', 'Parameters']]
highlight_max_ari = partial(highlight_max, column_name='ARI')
highlight_max_ari_index = partial(highlight_max_index, df_column=df_latex['ARI'])
underline_2nd_max_ari = partial(underline_2nd_max, column_name='ARI')
underline_2nd_max_ari_index = partial(underline_2nd_max_index, df_column=df_latex['ARI'])
print(df_latex.style.apply(highlight_max_ari, subset='ARI', axis=None).apply_index(highlight_max_ari_index,'index', level=1).apply(underline_2nd_max_ari, subset='ARI', axis=None).apply_index(underline_2nd_max_ari_index, 'index', level=1).format(precision=3, na_rep='No Run', subset='ARI').to_latex(hrules=True, clines='skip-last;data', convert_css=True, column_format='p{0.95cm}lp{0.5cm}l'))
# Out:
# \begin{tabular}{p{0.95cm}lp{0.5cm}l}
# \toprule
#  & key & ARI & Parameters \\
# Dataset & Model &  &  \\
# \midrule
# \multirow[c]{7}{*}{ecoli} & Affinity Propagation & 0.248 & $\lambda=0.58$ \\
#  & DBSCAN & 0.345 & $n_{\text{min}}=7$; $\epsilon=0.78$ \\
#  & HDBSCAN & 0.398 & $C_{\text{min}}=10$ \\
#  & K-Means & 0.719 & $C=6$ \\
#  & OPTICS & 0.314 & $n_{\text{min}}=10$ \\
#  & \underline{SC-SRGF} & \underline{0.723} & $C=4$; $m=15$; $r=0.80$ \\
#  & \bfseries Ward's Method & \bfseries 0.735 & $C=7$ \\
# \cline{1-4}
# \multirow[c]{7}{*}{har} & Affinity Propagation & 0.313 & $\lambda=1.00$ \\
#  & DBSCAN & 0.302 & $n_{\text{min}}=3$; $\epsilon=13.91$ \\
#  & HDBSCAN & 0.287 & $C_{\text{min}}=6$ \\
#  & K-Means & 0.438 & $C=9$ \\
#  & OPTICS & 0.001 & $n_{\text{min}}=4$ \\
#  & \bfseries SC-SRGF & \bfseries 0.546 & $C=20$; $m=21$; $r=0.45$ \\
#  & \underline{Ward's Method} & \underline{0.511} & $C=4$ \\
# \cline{1-4}
# \multirow[c]{7}{*}{iris} & Affinity Propagation & 0.477 & $\lambda=0.98$ \\
#  & DBSCAN & 0.558 & $n_{\text{min}}=5$; $\epsilon=1.37$ \\
#  & HDBSCAN & 0.564 & $C_{\text{min}}=9$ \\
#  & K-Means & 0.592 & $C=3$ \\
#  & OPTICS & 0.396 & $n_{\text{min}}=10$ \\
#  & \bfseries SC-SRGF & \bfseries 0.865 & $C=3$; $m=26$; $r=0.79$ \\
#  & \underline{Ward's Method} & \underline{0.615} & $C=3$ \\
# \cline{1-4}
# \multirow[c]{6}{*}{nursery} & Affinity Propagation & 0.016 & $\lambda=0.95$ \\
#  & DBSCAN & 0.000 & $n_{\text{min}}=5$; $\epsilon=0.50$ \\
#  & HDBSCAN & 0.014 & $C_{\text{min}}=9$ \\
#  & \underline{K-Means} & \underline{0.150} & $C=2$ \\
#  & OPTICS & 0.000 & $n_{\text{min}}=9$ \\
#  & \bfseries Ward's Method & \bfseries 0.254 & $C=3$ \\
# \cline{1-4}
# \multirow[c]{7}{*}{satimage} & Affinity Propagation & 0.190 & $\lambda=0.99$ \\
#  & DBSCAN & 0.297 & $n_{\text{min}}=7$; $\epsilon=1.54$ \\
#  & HDBSCAN & 0.308 & $C_{\text{min}}=6$ \\
#  & \underline{K-Means} & \underline{0.566} & $C=7$ \\
#  & OPTICS & 0.023 & $n_{\text{min}}=2$ \\
#  & \bfseries SC-SRGF & \bfseries 0.618 & $C=4$; $m=21$; $r=0.76$ \\
#  & Ward's Method & 0.485 & $C=5$ \\
# \cline{1-4}
# \multirow[c]{7}{*}{segment} & Affinity Propagation & 0.280 & $\lambda=0.93$ \\
#  & DBSCAN & 0.251 & $n_{\text{min}}=7$; $\epsilon=0.54$ \\
#  & HDBSCAN & 0.390 & $C_{\text{min}}=5$ \\
#  & \bfseries K-Means & \bfseries 0.512 & $C=10$ \\
#  & OPTICS & 0.097 & $n_{\text{min}}=10$ \\
#  & \underline{SC-SRGF} & \underline{0.481} & $C=14$; $m=23$; $r=0.65$ \\
#  & Ward's Method & 0.446 & $C=8$ \\
# \cline{1-4}
# \multirow[c]{5}{*}{shuttle} & \bfseries DBSCAN & \bfseries 0.686 & $n_{\text{min}}=10$; $\epsilon=0.27$ \\
#  & HDBSCAN & 0.001 & $C_{\text{min}}=2$ \\
#  & \underline{K-Means} & \underline{0.608} & $C=2$ \\
#  & OPTICS & 0.017 & $n_{\text{min}}=5$ \\
#  & Ward's Method & 0.478 & $C=2$ \\
# \cline{1-4}
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## All models

# %%
# for some reason the css conversion dont work with longtable, so we slightly modify the css for latex
def highlight_max(df, column_name, level=0):
    df_column = df[column_name]
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_highlighted] = 'bfseries: '
    return df_css


def highlight_max_index(series_index, df_column, level=0):
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css[:] = ''
    series_css[is_highlighted.values] = 'bfseries: '
    return series_css


def underline_2nd_max(df, column_name, level=0):
    df_column = df[column_name]
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_underlined] = 'underline: --rwrap'
    return df_css


def underline_2nd_max_index(series_index, df_column, level=0):
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css.loc[:] = ''
    series_css[is_underlined.values] = 'underline: --rwrap'
    return series_css

# %%
model_nickname
# Out:
# ['AffinityPropagation',
#  'AverageAgglomerativeClustering',
#  'Clique',
#  'CompleteAgglomerativeClustering',
#  'DBSCAN',
#  'HDBSCAN',
#  'IRFLLRR',
#  'KMeans',
#  'KMeansProj',
#  'MeanShift',
#  'OPTICS',
#  'Proclus',
#  'RecursiveClustering',
#  'SingleAgglomerativeClustering',
#  'SpectralClustering',
#  'SpectralSubspaceRandomization',
#  'WardAgglomerativeClustering']

# %%
# datasets_ids = [40685, 39, 61, 182, 40984, 1478, 1568]
# datasets_ids = [46773,46774,46775,46776,46777,46778,46779,46780,46781,46782,46783,]
datasets_ids = [46773, 46779, 46783]
datasets_ids = [str(d) for d in datasets_ids]
df = df_runs_parents.copy()
# get time of the child run
df_child = df_runs_raw.copy()
df_child = df_child[['parent_run_id', 'fit_model_return_elapsed_time']]
df_child = df_child.rename(columns={'fit_model_return_elapsed_time': 'Time (s)'})
df = df.join(df_child, on='best_child_run_id', rsuffix='_child')
df = df.loc[df['dataset_id'].isin(datasets_ids)]
df = df.loc[df['hpo_metric'] == 'adjusted_rand']
df = df.loc[df['standardize'] == 'True']
df['Parameters'] = df.apply(get_parameters_string, axis=1)
df = df[['model_nickname', 'dataset_name', 'best_adjusted_rand', 'Parameters', 'Time (s)', 'best_normalized_mutual_info', 'best_silhouette', 'best_davies_bouldin_score']]
df = df.loc[~((df['model_nickname'] == 'RecursiveClustering_aproximated') & (df['dataset_name'].isin(['iris', 'ecoli'])))]
models_names = {
    'RecursiveClustering': 'CoHiRF',
    # 'RecursiveClustering_rbf_None_False': 'CoHiRF-RBF(old)',
    # 'RecursiveClustering_rbf_None_1': 'CoHiRF-RBF',
    # 'RecursiveClustering_closest_overall_1000_False': 'CoHiRF-1000',
    'KMeans': 'K-Means',
    'HDBSCAN': 'HDBSCAN',
    'DBSCAN': 'DBSCAN',
    'AffinityPropagation': 'Affinity Propagation',
    'OPTICS': 'OPTICS',
    'SpectralSubspaceRandomization': 'SC-SRGF',
    'WardAgglomerativeClustering': "Ward's Method",
    'AverageAgglomerativeClustering': 'Average Agglomerative',
    'CompleteAgglomerativeClustering': 'Complete Agglomerative',
    'SingleAgglomerativeClustering': 'Single Agglomerative',
    'IRFLLRR': 'IRFLLRR',
    'Proclus': 'Proclus',
    'Clique': 'Clique',
    'KMeansProj': 'Projective K-Means',
}
df = df.replace({'model_nickname': models_names})
df = df.rename(columns={'best_adjusted_rand': 'ARI', 'model_nickname': 'Model', 'dataset_name': 'Dataset', 'best_normalized_mutual_info': 'NMI', 'best_silhouette': 'Silhouette', 'best_davies_bouldin_score': 'DBI'})
df.to_csv('df_openml_tgcc.csv')
df = df.groupby(['Dataset', 'Model']).agg({'ARI': 'mean', 'Time (s)': 'first', 'Parameters': 'first'})

# %%
df
# Out:
# key                                           ARI    Time (s)  \
# Dataset          Model
# alizadeh-2000-v2 Affinity Propagation    0.362816    0.011788
#                  Average Agglomerative   0.809591    0.019119
#                  Clique                  0.000000    0.130828
#                  CoHiRF                  0.830673    0.016346
#                  Complete Agglomerative  0.539059    0.009286
#                  DBSCAN                  0.250189    0.009145
#                  HDBSCAN                 0.165928    0.025262
#                  IRFLLRR                 0.079580    2.837931
#                  K-Means                 0.814706    0.010609
#                  MeanShift              -0.042740    2.352131
#                  OPTICS                  0.394998    0.049546
#                  Proclus                 0.446010    0.033395
#                  Projective K-Means      0.117385    0.235270
#                  SC-SRGF                 0.599132    0.141913
#                  Single Agglomerative   -0.021908    0.011437
#                  SpectralClustering      0.088318    0.048353
#                  Ward's Method           0.947128    0.011248
# coil-20          Affinity Propagation    0.407319    3.614988
#                  Average Agglomerative   0.080605    0.364514
#                  CoHiRF                  0.464201    0.513552
#                  Complete Agglomerative  0.177666    0.355324
#                  DBSCAN                  0.491158    0.054560
#                  HDBSCAN                 0.677216    2.172935
#                  K-Means                 0.655482    0.072838
#                  MeanShift               0.000077   30.971588
#                  OPTICS                  0.092457    5.224758
#                  Proclus                 0.166905    3.331996
#                  Projective K-Means      0.371780  553.074881
#                  SC-SRGF                 0.775928   22.408264
#                  Single Agglomerative    0.000154    0.981307
#                  Ward's Method           0.719345    0.353966
# garber-2001      Affinity Propagation    0.075380    0.021625
#                  Average Agglomerative   0.146050    0.019162
#                  Clique                  0.061669    0.255860
#                  CoHiRF                  0.298085    0.128058
#                  Complete Agglomerative  0.283306    0.018732
#                  DBSCAN                  0.043459    0.019955
#                  HDBSCAN                 0.026032    0.050493
#                  IRFLLRR                -0.015036    6.606880
#                  K-Means                 0.188167    0.021952
#                  MeanShift               0.016404    2.838703
#                  OPTICS                  0.067677    0.119647
#                  Proclus                 0.046262    0.152017
#                  Projective K-Means      0.114652   21.086727
#                  SC-SRGF                 0.175286    0.162107
#                  Single Agglomerative    0.144825    0.024719
#                  SpectralClustering      0.092858    0.052024
#                  Ward's Method           0.199979    0.020972
#
# key                                                                             Parameters
# Dataset          Model
# alizadeh-2000-v2 Affinity Propagation                                       $\lambda=0.86$
#                  Average Agglomerative                                               $C=4$
#                  Clique                                               $P=100$; $\tau=0.50$
#                  CoHiRF                                               $R=3$; $C=2$; $q=30$
#                  Complete Agglomerative                                              $C=6$
#                  DBSCAN                               $\epsilon=39.56$; $n_{\text{min}}=2$
#                  HDBSCAN                                                $C_{\text{min}}=2$
#                  IRFLLRR                 $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alph...
#                  K-Means                                                             $C=2$
#                  MeanShift
#                  OPTICS                                                 $n_{\text{min}}=2$
#                  Proclus                                                     $d=21$; $C=2$
#                  Projective K-Means                                                  $C=2$
#                  SC-SRGF                                           $r=0.76$; $C=4$; $m=21$
#                  Single Agglomerative                                                $C=2$
#                  SpectralClustering                                                 $C=30$
#                  Ward's Method                                                       $C=3$
# coil-20          Affinity Propagation                                       $\lambda=0.51$
#                  Average Agglomerative                                              $C=30$
#                  CoHiRF                                               $R=7$; $C=10$; $q=8$
#                  Complete Agglomerative                                             $C=30$
#                  DBSCAN                               $\epsilon=22.78$; $n_{\text{min}}=5$
#                  HDBSCAN                                                $C_{\text{min}}=4$
#                  K-Means                                                            $C=30$
#                  MeanShift
#                  OPTICS                                                 $n_{\text{min}}=8$
#                  Proclus                                                    $d=28$; $C=18$
#                  Projective K-Means                                                 $C=10$
#                  SC-SRGF                                          $r=0.23$; $C=18$; $m=24$
#                  Single Agglomerative                                               $C=30$
#                  Ward's Method                                                      $C=24$
# garber-2001      Affinity Propagation                                       $\lambda=0.80$
#                  Average Agglomerative                                              $C=26$
#                  Clique                                                $P=23$; $\tau=0.41$
#                  CoHiRF                                              $R=10$; $C=2$; $q=18$
#                  Complete Agglomerative                                             $C=14$
#                  DBSCAN                               $\epsilon=77.80$; $n_{\text{min}}=5$
#                  HDBSCAN                                                $C_{\text{min}}=2$
#                  IRFLLRR                 $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alph...
#                  K-Means                                                             $C=3$
#                  MeanShift
#                  OPTICS                                                 $n_{\text{min}}=9$
#                  Proclus                                                    $d=13$; $C=15$
#                  Projective K-Means                                                  $C=7$
#                  SC-SRGF                                           $r=0.76$; $C=4$; $m=21$
#                  Single Agglomerative                                               $C=25$
#                  SpectralClustering                                                 $C=26$
#                  Ward's Method                                                      $C=13$

# %%
# with time, appendix
df_latex = df.copy()
highlight_max_ari = partial(highlight_max, column_name='ARI')
highlight_max_ari_index = partial(highlight_max_index, df_column=df_latex['ARI'])
underline_2nd_max_ari = partial(underline_2nd_max, column_name='ARI')
underline_2nd_max_ari_index = partial(underline_2nd_max_index, df_column=df_latex['ARI'])
print(df_latex.style.apply(highlight_max_ari, subset='ARI', axis=None).apply_index(highlight_max_ari_index,'index', level=1).apply(underline_2nd_max_ari, subset='ARI', axis=None).apply_index(underline_2nd_max_ari_index, 'index', level=1).format(precision=3, na_rep='No Run', subset='ARI').format(formatter='{:4.3f}',subset='Time (s)').to_latex(hrules=True, clines='skip-last;data', convert_css=False, column_format='llrrl', environment='longtable'))
# Out:
# \begin{longtable}{llrrl}
# \toprule
#  & key & ARI & Time (s) & Parameters \\
# Dataset & Model &  &  &  \\
# \midrule
# \endfirsthead
# \toprule
#  & key & ARI & Time (s) & Parameters \\
# Dataset & Model &  &  &  \\
# \midrule
# \endhead
# \midrule
# \multicolumn{5}{r}{Continued on next page} \\
# \midrule
# \endfoot
# \bottomrule
# \endlastfoot
# \multirow[c]{17}{*}{alizadeh-2000-v2} & Affinity Propagation & 0.363 & 0.012 & $\lambda=0.86$ \\
#  & Average Agglomerative & 0.810 & 0.019 & $C=4$ \\
#  & Clique & 0.000 & 0.131 & $P=100$; $\tau=0.50$ \\
#  & Complete Agglomerative & 0.539 & 0.009 & $C=6$ \\
#  & DBSCAN & 0.250 & 0.009 & $\epsilon=39.56$; $n_{\text{min}}=2$ \\
#  & HDBSCAN & 0.166 & 0.025 & $C_{\text{min}}=2$ \\
#  & IRFLLRR & 0.080 & 2.838 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & K-Means & 0.815 & 0.011 & $C=2$ \\
#  & MeanShift & -0.043 & 2.352 &  \\
#  & OPTICS & 0.395 & 0.050 & $n_{\text{min}}=2$ \\
#  & Proclus & 0.446 & 0.033 & $d=21$; $C=2$ \\
#  & Projective K-Means & 0.117 & 0.235 & $C=2$ \\
#  & \underline{RecursiveClustering} & \underline{0.831} & 0.016 & $R=3$; $C=2$; $q=30$ \\
#  & SC-SRGF & 0.599 & 0.142 & $r=0.76$; $C=4$; $m=21$ \\
#  & Single Agglomerative & -0.022 & 0.011 & $C=2$ \\
#  & SpectralClustering & 0.088 & 0.048 & $C=30$ \\
#  & \bfseries Ward's Method & \bfseries 0.947 & 0.011 & $C=3$ \\
# \cline{1-5}
# \multirow[c]{17}{*}{alizadeh-2000-v3} & Affinity Propagation & 0.425 & 0.012 & $\lambda=0.86$ \\
#  & \underline{Average Agglomerative} & \underline{0.480} & 0.009 & $C=9$ \\
#  & Clique & 0.000 & 0.147 & $P=100$; $\tau=0.50$ \\
#  & Complete Agglomerative & 0.412 & 0.009 & $C=13$ \\
#  & DBSCAN & 0.135 & 0.009 & $\epsilon=39.56$; $n_{\text{min}}=2$ \\
#  & HDBSCAN & 0.138 & 0.025 & $C_{\text{min}}=2$ \\
#  & IRFLLRR & 0.041 & 2.570 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & K-Means & 0.439 & 0.012 & $C=8$ \\
#  & MeanShift & -0.010 & 2.245 &  \\
#  & OPTICS & 0.156 & 0.051 & $n_{\text{min}}=2$ \\
#  & Proclus & 0.234 & 0.068 & $d=17$; $C=4$ \\
#  & Projective K-Means & 0.087 & 0.230 & $C=2$ \\
#  & RecursiveClustering & 0.455 & 0.048 & $R=6$; $C=2$; $q=20$ \\
#  & SC-SRGF & 0.464 & 0.077 & $r=0.23$; $C=4$; $m=16$ \\
#  & Single Agglomerative & -0.005 & 0.012 & $C=2$ \\
#  & SpectralClustering & 0.068 & 0.043 & $C=26$ \\
#  & \bfseries Ward's Method & \bfseries 0.519 & 0.011 & $C=3$ \\
# \cline{1-5}
# \multirow[c]{17}{*}{armstrong-2002-v1} & Affinity Propagation & 0.405 & 0.007 & $\lambda=0.98$ \\
#  & Average Agglomerative & 0.076 & 0.006 & $C=30$ \\
#  & Clique & 0.298 & 1.047 & $P=150$; $\tau=0.76$ \\
#  & \bfseries Complete Agglomerative & \bfseries 0.704 & 0.006 & $C=3$ \\
#  & DBSCAN & 0.055 & 0.006 & $\epsilon=33.47$; $n_{\text{min}}=2$ \\
#  & HDBSCAN & 0.055 & 0.020 & $C_{\text{min}}=2$ \\
#  & IRFLLRR & 0.063 & 2.191 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & K-Means & 0.341 & 0.009 & $C=14$ \\
#  & MeanShift & -0.026 & 2.138 &  \\
#  & OPTICS & 0.146 & 0.046 & $n_{\text{min}}=2$ \\
#  & \underline{Proclus} & \underline{0.659} & 0.031 & $d=10$; $C=4$ \\
#  & Projective K-Means & 0.102 & 6.958 & $C=7$ \\
#  & RecursiveClustering & 0.197 & 0.044 & $R=9$; $C=2$; $q=22$ \\
#  & SC-SRGF & 0.255 & 0.066 & $r=0.70$; $C=2$; $m=13$ \\
#  & Single Agglomerative & -0.014 & 0.007 & $C=2$ \\
#  & SpectralClustering & 0.000 & 0.087 & $C=4$ \\
#  & Ward's Method & 0.521 & 0.006 & $C=3$ \\
# \cline{1-5}
# \multirow[c]{15}{*}{binary_alpha_digits} & Affinity Propagation & 0.214 & 4.041 & $\lambda=0.99$ \\
#  & Average Agglomerative & 0.211 & 0.129 & $C=29$ \\
#  & Complete Agglomerative & 0.205 & 0.128 & $C=30$ \\
#  & DBSCAN & 0.003 & 0.019 & $\epsilon=0.16$; $n_{\text{min}}=2$ \\
#  & HDBSCAN & 0.029 & 0.826 & $C_{\text{min}}=2$ \\
#  & IRFLLRR & 0.001 & 116.036 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & K-Means & 0.276 & 0.028 & $C=26$ \\
#  & MeanShift & 0.000 & 8.832 &  \\
#  & OPTICS & 0.006 & 1.638 & $n_{\text{min}}=2$ \\
#  & Proclus & 0.086 & 3.030 & $d=30$; $C=13$ \\
#  & Projective K-Means & 0.100 & 266.908 & $C=10$ \\
#  & RecursiveClustering & 0.151 & 2.474 & $R=7$; $C=10$; $q=28$ \\
#  & \underline{SC-SRGF} & \underline{0.299} & 5.516 & $r=0.76$; $C=30$; $m=10$ \\
#  & Single Agglomerative & 0.000 & 0.286 & $C=26$ \\
#  & \bfseries Ward's Method & \bfseries 0.312 & 0.133 & $C=30$ \\
# \cline{1-5}
# \multirow[c]{17}{*}{bittner-2000} & Affinity Propagation & 0.043 & 0.010 & $\lambda=0.99$ \\
#  & Average Agglomerative & 0.039 & 0.009 & $C=12$ \\
#  & Clique & 0.001 & 0.093 & $P=17$; $\tau=0.45$ \\
#  & \underline{Complete Agglomerative} & \underline{0.176} & 0.008 & $C=10$ \\
#  & DBSCAN & 0.000 & 0.062 & $\epsilon=0.50$; $n_{\text{min}}=5$ \\
#  & HDBSCAN & 0.021 & 0.023 & $C_{\text{min}}=2$ \\
#  & IRFLLRR & 0.004 & 1.710 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & \bfseries K-Means & \bfseries 0.183 & 0.011 & $C=6$ \\
#  & MeanShift & -0.003 & 2.160 &  \\
#  & OPTICS & 0.034 & 0.032 & $n_{\text{min}}=3$ \\
#  & Proclus & 0.089 & 0.033 & $d=30$; $C=3$ \\
#  & Projective K-Means & 0.096 & 3.006 & $C=5$ \\
#  & RecursiveClustering & 0.028 & 0.090 & $R=7$; $C=4$; $q=16$ \\
#  & SC-SRGF & 0.141 & 0.069 & $r=0.40$; $C=3$; $m=16$ \\
#  & Single Agglomerative & 0.009 & 0.009 & $C=21$ \\
#  & SpectralClustering & 0.042 & 0.026 & $C=11$ \\
#  & Ward's Method & 0.100 & 0.009 & $C=10$ \\
# \cline{1-5}
# \multirow[c]{17}{*}{bredel-2005} & Affinity Propagation & 0.420 & 0.009 & $\lambda=0.95$ \\
#  & Average Agglomerative & 0.187 & 0.008 & $C=24$ \\
#  & Clique & 0.000 & 0.085 & $P=100$; $\tau=0.50$ \\
#  & Complete Agglomerative & 0.301 & 0.015 & $C=4$ \\
#  & DBSCAN & 0.000 & 0.056 & $\epsilon=0.50$; $n_{\text{min}}=5$ \\
#  & HDBSCAN & 0.209 & 0.022 & $C_{\text{min}}=3$ \\
#  & IRFLLRR & 0.023 & 1.779 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & \underline{K-Means} & \underline{0.516} & 0.009 & $C=3$ \\
#  & MeanShift & 0.060 & 2.152 &  \\
#  & OPTICS & 0.000 & 0.080 & $n_{\text{min}}=9$ \\
#  & Proclus & 0.168 & 0.133 & $d=16$; $C=7$ \\
#  & Projective K-Means & 0.125 & 11.486 & $C=9$ \\
#  & RecursiveClustering & 0.269 & 0.029 & $R=6$; $C=2$; $q=20$ \\
#  & \bfseries SC-SRGF & \bfseries 0.615 & 0.083 & $r=0.28$; $C=2$; $m=17$ \\
#  & Single Agglomerative & 0.085 & 0.009 & $C=3$ \\
#  & SpectralClustering & 0.069 & 0.014 & $C=2$ \\
#  & Ward's Method & 0.470 & 0.009 & $C=2$ \\
# \cline{1-5}
# \multirow[c]{16}{*}{chowdary-2006} & Affinity Propagation & 0.334 & 0.012 & $\lambda=0.86$ \\
#  & Average Agglomerative & 0.360 & 0.002 & $C=25$ \\
#  & Complete Agglomerative & 0.347 & 0.002 & $C=17$ \\
#  & DBSCAN & 0.298 & 0.003 & $\epsilon=4.43$; $n_{\text{min}}=8$ \\
#  & HDBSCAN & 0.217 & 0.016 & $C_{\text{min}}=5$ \\
#  & IRFLLRR & -0.037 & 2.416 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & \underline{K-Means} & \underline{0.856} & 0.003 & $C=5$ \\
#  & MeanShift & 0.023 & 2.075 &  \\
#  & OPTICS & 0.344 & 0.050 & $n_{\text{min}}=10$ \\
#  & Proclus & 0.571 & 0.092 & $d=8$; $C=22$ \\
#  & Projective K-Means & 0.777 & 0.313 & $C=3$ \\
#  & RecursiveClustering & 0.505 & 0.041 & $R=4$; $C=8$; $q=21$ \\
#  & \bfseries SC-SRGF & \bfseries 0.887 & 0.079 & $r=0.70$; $C=2$; $m=13$ \\
#  & Single Agglomerative & 0.060 & 0.003 & $C=7$ \\
#  & SpectralClustering & 0.218 & 0.042 & $C=25$ \\
#  & Ward's Method & 0.843 & 0.002 & $C=6$ \\
# \cline{1-5}
# \multirow[c]{14}{*}{coil-20} & Affinity Propagation & 0.407 & 3.615 & $\lambda=0.51$ \\
#  & Average Agglomerative & 0.081 & 0.365 & $C=30$ \\
#  & Complete Agglomerative & 0.178 & 0.355 & $C=30$ \\
#  & DBSCAN & 0.491 & 0.055 & $\epsilon=22.78$; $n_{\text{min}}=5$ \\
#  & HDBSCAN & 0.677 & 2.173 & $C_{\text{min}}=4$ \\
#  & K-Means & 0.655 & 0.073 & $C=30$ \\
#  & MeanShift & 0.000 & 30.972 &  \\
#  & OPTICS & 0.092 & 5.225 & $n_{\text{min}}=8$ \\
#  & Proclus & 0.167 & 3.332 & $d=28$; $C=18$ \\
#  & Projective K-Means & 0.372 & 553.075 & $C=10$ \\
#  & RecursiveClustering & 0.464 & 0.514 & $R=7$; $C=10$; $q=8$ \\
#  & \bfseries SC-SRGF & \bfseries 0.776 & 22.408 & $r=0.23$; $C=18$; $m=24$ \\
#  & Single Agglomerative & 0.000 & 0.981 & $C=30$ \\
#  & \underline{Ward's Method} & \underline{0.719} & 0.354 & $C=24$ \\
# \cline{1-5}
# \multirow[c]{17}{*}{garber-2001} & Affinity Propagation & 0.075 & 0.022 & $\lambda=0.80$ \\
#  & Average Agglomerative & 0.146 & 0.019 & $C=26$ \\
#  & Clique & 0.062 & 0.256 & $P=23$; $\tau=0.41$ \\
#  & \underline{Complete Agglomerative} & \underline{0.283} & 0.019 & $C=14$ \\
#  & DBSCAN & 0.043 & 0.020 & $\epsilon=77.80$; $n_{\text{min}}=5$ \\
#  & HDBSCAN & 0.026 & 0.050 & $C_{\text{min}}=2$ \\
#  & IRFLLRR & -0.015 & 6.607 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & K-Means & 0.188 & 0.022 & $C=3$ \\
#  & MeanShift & 0.016 & 2.839 &  \\
#  & OPTICS & 0.068 & 0.120 & $n_{\text{min}}=9$ \\
#  & Proclus & 0.046 & 0.152 & $d=13$; $C=15$ \\
#  & Projective K-Means & 0.115 & 21.087 & $C=7$ \\
#  & \bfseries RecursiveClustering & \bfseries 0.298 & 0.128 & $R=10$; $C=2$; $q=18$ \\
#  & SC-SRGF & 0.175 & 0.162 & $r=0.76$; $C=4$; $m=21$ \\
#  & Single Agglomerative & 0.145 & 0.025 & $C=25$ \\
#  & SpectralClustering & 0.093 & 0.052 & $C=26$ \\
#  & Ward's Method & 0.200 & 0.021 & $C=13$ \\
# \cline{1-5}
# \multirow[c]{16}{*}{golub-1999-v2} & Affinity Propagation & 0.050 & 0.010 & $\lambda=0.98$ \\
#  & Average Agglomerative & 0.143 & 0.009 & $C=13$ \\
#  & Complete Agglomerative & 0.190 & 0.009 & $C=9$ \\
#  & DBSCAN & 0.000 & 0.061 & $\epsilon=0.50$; $n_{\text{min}}=5$ \\
#  & HDBSCAN & 0.029 & 0.027 & $C_{\text{min}}=2$ \\
#  & IRFLLRR & -0.005 & 3.435 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & K-Means & 0.197 & 0.011 & $C=5$ \\
#  & MeanShift & -0.002 & 2.314 &  \\
#  & OPTICS & 0.000 & 0.100 & $n_{\text{min}}=9$ \\
#  & \bfseries Proclus & \bfseries 0.371 & 0.068 & $d=2$; $C=21$ \\
#  & Projective K-Means & 0.082 & 8.012 & $C=6$ \\
#  & RecursiveClustering & 0.243 & 0.070 & $R=8$; $C=2$; $q=21$ \\
#  & \underline{SC-SRGF} & \underline{0.302} & 0.102 & $r=0.46$; $C=5$; $m=16$ \\
#  & Single Agglomerative & 0.065 & 0.012 & $C=25$ \\
#  & SpectralClustering & 0.050 & 0.028 & $C=14$ \\
#  & Ward's Method & 0.137 & 0.009 & $C=20$ \\
# \cline{1-5}
# \multirow[c]{16}{*}{khan-2001} & Affinity Propagation & 0.228 & 0.012 & $\lambda=0.50$ \\
#  & Average Agglomerative & 0.107 & 0.006 & $C=26$ \\
#  & Complete Agglomerative & 0.124 & 0.006 & $C=19$ \\
#  & DBSCAN & 0.073 & 0.006 & $\epsilon=23.72$; $n_{\text{min}}=6$ \\
#  & HDBSCAN & 0.160 & 0.023 & $C_{\text{min}}=3$ \\
#  & IRFLLRR & 0.078 & 3.110 & $C=8$; $p=0.95$; $c=0.10$; $\lambda=1$; $\alpha=4$ \\
#  & K-Means & 0.257 & 0.008 & $C=10$ \\
#  & MeanShift & -0.009 & 2.263 &  \\
#  & OPTICS & 0.211 & 0.054 & $n_{\text{min}}=4$ \\
#  & \underline{Proclus} & \underline{0.285} & 0.040 & $d=26$; $C=2$ \\
#  & Projective K-Means & 0.173 & 0.994 & $C=4$ \\
#  & RecursiveClustering & 0.114 & 0.186 & $R=10$; $C=3$; $q=10$ \\
#  & \bfseries SC-SRGF & \bfseries 0.342 & 0.253 & $r=0.64$; $C=5$; $m=30$ \\
#  & Single Agglomerative & -0.002 & 0.008 & $C=2$ \\
#  & SpectralClustering & 0.020 & 0.025 & $C=13$ \\
#  & Ward's Method & 0.189 & 0.006 & $C=16$ \\
# \cline{1-5}
# \end{longtable}

# %% [markdown]
# # Debug and explore

# %%
df = df_runs_raw_parents.copy()

# %%
df
# Out:
# key                                 status     start_time      end_time  \
# run_uuid
# 0018714386f44f95ab7141d480ce09f0  FINISHED  1737557036103  1.737557e+12
# 00502ff54da4466191d5fadd2ab0f945  FINISHED  1737556950053  1.737557e+12
# 00b6f8e09ce1419e84214bb9734a9bff  FINISHED  1737589285408  1.737590e+12
# 00b7b74b49c2418e8cd9108326d76f54  FINISHED  1737504019181  1.737512e+12
# 0200fd7653474a6ab77e2fa4085e294f  FINISHED  1737617015722  1.737619e+12
# ...                                    ...            ...           ...
# fb946510558746d29d122b87ee9869da  FINISHED  1737617084498  1.737620e+12
# fd61b8a547c54e11b898653ebc8769db  FINISHED  1737557019786  1.737557e+12
# fdc6bb9a534743c7be6ce026fd67252a  FINISHED  1737556999587  1.737557e+12
# feca472c0d2149368332abf98bab6bd7  FINISHED  1737516203798  1.737519e+12
# ff4106e59afd4d4e9a8db9723068c40e  FINISHED  1737556981411  1.737557e+12
#
# key                              dataset_id         dataset_name direction  \
# run_uuid
# 0018714386f44f95ab7141d480ce09f0       1044        eye_movements  maximize
# 00502ff54da4466191d5fadd2ab0f945          7            audiology  maximize
# 00b6f8e09ce1419e84214bb9734a9bff      23380                  cjs  maximize
# 00b7b74b49c2418e8cd9108326d76f54      46335  primary-tumor_clean  maximize
# 0200fd7653474a6ab77e2fa4085e294f         16       mfeat-karhunen  maximize
# ...                                     ...                  ...       ...
# fb946510558746d29d122b87ee9869da         30          page-blocks  maximize
# fd61b8a547c54e11b898653ebc8769db      40984              segment  maximize
# fdc6bb9a534743c7be6ce026fd67252a         61                 iris  maximize
# feca472c0d2149368332abf98bab6bd7         42              soybean  maximize
# ff4106e59afd4d4e9a8db9723068c40e         10                lymph  maximize
#
# key                                  hpo_metric  \
# run_uuid
# 0018714386f44f95ab7141d480ce09f0  adjusted_rand
# 00502ff54da4466191d5fadd2ab0f945  adjusted_rand
# 00b6f8e09ce1419e84214bb9734a9bff  adjusted_rand
# 00b7b74b49c2418e8cd9108326d76f54  adjusted_rand
# 0200fd7653474a6ab77e2fa4085e294f  adjusted_rand
# ...                                         ...
# fb946510558746d29d122b87ee9869da  adjusted_rand
# fd61b8a547c54e11b898653ebc8769db  adjusted_rand
# fdc6bb9a534743c7be6ce026fd67252a  adjusted_rand
# feca472c0d2149368332abf98bab6bd7  adjusted_rand
# ff4106e59afd4d4e9a8db9723068c40e  adjusted_rand
#
# key                                              model_nickname n_classes  \
# run_uuid
# 0018714386f44f95ab7141d480ce09f0                        HDBSCAN       NaN
# 00502ff54da4466191d5fadd2ab0f945                        HDBSCAN       NaN
# 00b6f8e09ce1419e84214bb9734a9bff                        HDBSCAN       NaN
# 00b7b74b49c2418e8cd9108326d76f54            RecursiveClustering       NaN
# 0200fd7653474a6ab77e2fa4085e294f                         OPTICS       NaN
# ...                                                         ...       ...
# fb946510558746d29d122b87ee9869da                         OPTICS       NaN
# fd61b8a547c54e11b898653ebc8769db                        HDBSCAN       NaN
# fdc6bb9a534743c7be6ce026fd67252a                         DBSCAN       NaN
# feca472c0d2149368332abf98bab6bd7            AffinityPropagation       NaN
# ff4106e59afd4d4e9a8db9723068c40e  SpectralSubspaceRandomization       NaN
#
# key                              n_features  ... max_memory_used mutual_info  \
# run_uuid                                     ...
# 0018714386f44f95ab7141d480ce09f0        NaN  ...         422.740    0.003246
# 00502ff54da4466191d5fadd2ab0f945        NaN  ...         361.448    0.078387
# 00b6f8e09ce1419e84214bb9734a9bff        NaN  ...         491.640    0.271687
# 00b7b74b49c2418e8cd9108326d76f54        NaN  ...         541.000    2.169609
# 0200fd7653474a6ab77e2fa4085e294f        NaN  ...        1005.424    0.028445
# ...                                     ...  ...             ...         ...
# fb946510558746d29d122b87ee9869da        NaN  ...        1005.424    0.081613
# fd61b8a547c54e11b898653ebc8769db        NaN  ...         410.420    1.356621
# fdc6bb9a534743c7be6ce026fd67252a        NaN  ...        7826.080    0.638874
# feca472c0d2149368332abf98bab6bd7        NaN  ...         308.308    2.379024
# ff4106e59afd4d4e9a8db9723068c40e        NaN  ...        1085.472    0.190064
#
# key                              n_clusters_  normalized_mutual_info  \
# run_uuid
# 0018714386f44f95ab7141d480ce09f0         6.0                0.005303
# 00502ff54da4466191d5fadd2ab0f945         3.0                0.058583
# 00b6f8e09ce1419e84214bb9734a9bff        51.0                0.125215
# 00b7b74b49c2418e8cd9108326d76f54       216.0                0.563600
# 0200fd7653474a6ab77e2fa4085e294f         4.0                0.023843
# ...                                      ...                     ...
# fb946510558746d29d122b87ee9869da        80.0                0.099852
# fd61b8a547c54e11b898653ebc8769db        33.0                0.598839
# fdc6bb9a534743c7be6ce026fd67252a         3.0                0.685822
# feca472c0d2149368332abf98bab6bd7        76.0                0.691180
# ff4106e59afd4d4e9a8db9723068c40e         2.0                0.255025
#
# key                               rand_score  silhouette  EXCEPTION  \
# run_uuid
# 0018714386f44f95ab7141d480ce09f0    0.358073    0.527841        NaN
# 00502ff54da4466191d5fadd2ab0f945    0.213176   -0.124492        NaN
# 00b6f8e09ce1419e84214bb9734a9bff    0.739143    0.441531        NaN
# 00b7b74b49c2418e8cd9108326d76f54    0.891047    0.359055        NaN
# 0200fd7653474a6ab77e2fa4085e294f    0.120347   -0.058768        NaN
# ...                                      ...         ...        ...
# fb946510558746d29d122b87ee9869da    0.634365   -0.584304        NaN
# fd61b8a547c54e11b898653ebc8769db    0.856482    0.196516        NaN
# fdc6bb9a534743c7be6ce026fd67252a    0.772975    0.507009        NaN
# feca472c0d2149368332abf98bab6bd7    0.921723    0.160309        NaN
# ff4106e59afd4d4e9a8db9723068c40e    0.649108    0.168587        NaN
#
# key                                              best_child_run_id  \
# run_uuid
# 0018714386f44f95ab7141d480ce09f0  756cc869acc94fed89376ae563e075a2
# 00502ff54da4466191d5fadd2ab0f945  3d80243180a847ceb7542ac29e31edd8
# 00b6f8e09ce1419e84214bb9734a9bff  f7b70e6394ce4793bd5d1924df8d7cf0
# 00b7b74b49c2418e8cd9108326d76f54  f2af19c022474cc587b3a26c1c1518b7
# 0200fd7653474a6ab77e2fa4085e294f  e1c3ab245a3e47d0813cd19cb56802d0
# ...                                                            ...
# fb946510558746d29d122b87ee9869da  6578c7710d3d445eb88dd432d6c88b91
# fd61b8a547c54e11b898653ebc8769db  d81f797b53d142e68e400b8143cb2586
# fdc6bb9a534743c7be6ce026fd67252a  abfd2a33adaf48689df0ef0a86e211b6
# feca472c0d2149368332abf98bab6bd7  9ab6f55ea3df48e589d4358bbc15688b
# ff4106e59afd4d4e9a8db9723068c40e  93f3ae5b1ed74965a7537f859786c54e
#
# key                               parent_run_id  raised_exception
# run_uuid
# 0018714386f44f95ab7141d480ce09f0            NaN             False
# 00502ff54da4466191d5fadd2ab0f945            NaN             False
# 00b6f8e09ce1419e84214bb9734a9bff            NaN             False
# 00b7b74b49c2418e8cd9108326d76f54            NaN             False
# 0200fd7653474a6ab77e2fa4085e294f            NaN             False
# ...                                         ...               ...
# fb946510558746d29d122b87ee9869da            NaN             False
# fd61b8a547c54e11b898653ebc8769db            NaN             False
# fdc6bb9a534743c7be6ce026fd67252a            NaN             False
# feca472c0d2149368332abf98bab6bd7            NaN             False
# ff4106e59afd4d4e9a8db9723068c40e            NaN             False
#
# [517 rows x 39 columns]

# %%
df = df.loc[df['status'] == 'RUNNING']

# %%
df
# Out:
# key                                status     start_time  end_time dataset_id  \
# run_uuid
# 0289c581d4a74c6998008fd8c6a23a8b  RUNNING  1737633122174       NaN      41168
# 0417c1059c264cdf8399c22c311b9876  RUNNING  1737514361699       NaN      41168
# 043d0cbd906747819040f8979d7f40d1  RUNNING  1737626372810       NaN      40996
# 08ca8fb95ff84adcb2b8c6567a29cc34  RUNNING  1737626671949       NaN      41168
# 16a5d69973d3475eae567d57d9241d3d  RUNNING  1737516197385       NaN      41027
# 1798d892c9b54192ac736b8013d9229e  RUNNING  1737617191351       NaN       1596
# 1e3053ee2da046f8aaf7a0e0c70ba9dc  RUNNING  1737589047902       NaN        184
# 230e310a3ff640f6865d1bda85845caf  RUNNING  1737504059995       NaN       1501
# 2490402188d94a7ca9f499eee32a52d3  RUNNING  1737590230603       NaN       1501
# 2545cfaa4ce44d4ba25a4c57945f8f4a  RUNNING  1737591088527       NaN      40927
# 26ab3cc84c4a420b8857b1a95ed6f767  RUNNING  1737504060452       NaN       1483
# 2ec4852314ed431f96d3841991fdc743  RUNNING  1737589153110       NaN       1483
# 338ba54bce1345a2a924b657bd5993bf  RUNNING  1737557008721       NaN       1567
# 3692c78f34fd4c3c885c21c7a9071eaa  RUNNING  1737624993138       NaN      40927
# 3eb48652d7dd4c87ac58ddd07b3c5175  RUNNING  1737590230592       NaN      40685
# 4ea354c749a844fea7fa84bbb49cb447  RUNNING  1737624970103       NaN       1567
# 54433df700ed4a78801c8425094c326f  RUNNING  1737514362850       NaN      40685
# 571eb50796254ba09de64dc30acdebc1  RUNNING  1737556999069       NaN      41027
# 6a48f613362447c78e3359b5c9dcc2f3  RUNNING  1737557089813       NaN       1568
# 6cc3d2d840764cbea8c488d14e14b443  RUNNING  1737591718849       NaN      40927
# 6e847cd448bd4b8184b831772de744bd  RUNNING  1737633160085       NaN      41168
# 71d0891f6ac041e38d423fe3328f130e  RUNNING  1737591479107       NaN      40927
# 7239cc6680ec46a880e51cd9e02c3b62  RUNNING  1737591719276       NaN      40927
# 72528d7e02ad4ba1b51ba2ca3335ae83  RUNNING  1737590231050       NaN       1567
# 72cbb804b0d44f4e83b8d6e723bde1d2  RUNNING  1737589278460       NaN       1596
# 7354437c98ce4de9af3822771725e288  RUNNING  1737591728560       NaN       1596
# 7e33df0102fb40968e05fb8ce3e3c909  RUNNING  1737589047392       NaN      41027
# 7e7f30738e20404c93980ec8ff08f88c  RUNNING  1737591719499       NaN          6
# 80f876784fe243c7a1ef0c0d60402523  RUNNING  1737591755252       NaN       1567
# 88b601c9c6a34035931335425bb9800f  RUNNING  1737591732950       NaN      41168
# 96e64dc9e8634e7ab6e9927181c2e3d1  RUNNING  1737625862499       NaN      40927
# 978ae34447454a2f9d3ff95b044484a7  RUNNING  1737589278346       NaN      40668
# 9ae1a2be20cc4774a5a075a55c18f35e  RUNNING  1737591300354       NaN      40927
# 9e125b89e1cf4a709312eb4083352c6a  RUNNING  1737516203805       NaN        554
# a962016fad28492fad410f3862bf921f  RUNNING  1737633347979       NaN       1478
# add2a102856643cba33e4680923f4551  RUNNING  1737591241100       NaN      40927
# b18b8eb8d5434537ac7bc0a0b6481f07  RUNNING  1737504059994       NaN       1509
# b521a23517834c1a9d210a40cada29f9  RUNNING  1737557117426       NaN       1044
# b5c4ba847ed54a8795d50e77d9ee7115  RUNNING  1737504465062       NaN       1596
# b74bbac1474845eab29023e234fd5f5a  RUNNING  1737589293877       NaN      40996
# b8aedc9c167143b49c4ecaadd583f34d  RUNNING  1737588968231       NaN      40927
# b9f9f1fef542404d85ae933ed9dd4d0c  RUNNING  1737568987357       NaN      41168
# baeb090275454b4098242e7879644c55  RUNNING  1737589156618       NaN      41168
# bdfaeb40d8214d9b95da3222038aa333  RUNNING  1737568989967       NaN      41166
# c61f793a969e4409bbffae0ce98fb6da  RUNNING  1737589289168       NaN      40927
# c905708c43cc4baf8b47beb01178f01a  RUNNING  1737557172264       NaN      41168
# c99abf79e67c4a4d94d498e88a630fe0  RUNNING  1737557171448       NaN      41166
# d7e82004d67d44c88b593d6c1446b3da  RUNNING  1737557171927       NaN      41165
# da79d6c7ccf54fc1af6b3ca3b9811f6a  RUNNING  1737514380285       NaN       1483
#
# key                              dataset_name direction     hpo_metric  \
# run_uuid
# 0289c581d4a74c6998008fd8c6a23a8b          NaN  maximize  adjusted_rand
# 0417c1059c264cdf8399c22c311b9876          NaN  maximize  adjusted_rand
# 043d0cbd906747819040f8979d7f40d1          NaN  maximize  adjusted_rand
# 08ca8fb95ff84adcb2b8c6567a29cc34          NaN  maximize  adjusted_rand
# 16a5d69973d3475eae567d57d9241d3d          NaN  maximize  adjusted_rand
# 1798d892c9b54192ac736b8013d9229e          NaN  maximize  adjusted_rand
# 1e3053ee2da046f8aaf7a0e0c70ba9dc          NaN  maximize  adjusted_rand
# 230e310a3ff640f6865d1bda85845caf          NaN  maximize  adjusted_rand
# 2490402188d94a7ca9f499eee32a52d3          NaN  maximize  adjusted_rand
# 2545cfaa4ce44d4ba25a4c57945f8f4a          NaN  maximize  adjusted_rand
# 26ab3cc84c4a420b8857b1a95ed6f767          NaN  maximize  adjusted_rand
# 2ec4852314ed431f96d3841991fdc743          NaN  maximize  adjusted_rand
# 338ba54bce1345a2a924b657bd5993bf          NaN  maximize  adjusted_rand
# 3692c78f34fd4c3c885c21c7a9071eaa          NaN  maximize  adjusted_rand
# 3eb48652d7dd4c87ac58ddd07b3c5175          NaN  maximize  adjusted_rand
# 4ea354c749a844fea7fa84bbb49cb447          NaN  maximize  adjusted_rand
# 54433df700ed4a78801c8425094c326f          NaN  maximize  adjusted_rand
# 571eb50796254ba09de64dc30acdebc1          NaN  maximize  adjusted_rand
# 6a48f613362447c78e3359b5c9dcc2f3          NaN  maximize  adjusted_rand
# 6cc3d2d840764cbea8c488d14e14b443          NaN  maximize  adjusted_rand
# 6e847cd448bd4b8184b831772de744bd          NaN  maximize  adjusted_rand
# 71d0891f6ac041e38d423fe3328f130e          NaN  maximize  adjusted_rand
# 7239cc6680ec46a880e51cd9e02c3b62          NaN  maximize  adjusted_rand
# 72528d7e02ad4ba1b51ba2ca3335ae83          NaN  maximize  adjusted_rand
# 72cbb804b0d44f4e83b8d6e723bde1d2          NaN  maximize  adjusted_rand
# 7354437c98ce4de9af3822771725e288          NaN  maximize  adjusted_rand
# 7e33df0102fb40968e05fb8ce3e3c909          NaN  maximize  adjusted_rand
# 7e7f30738e20404c93980ec8ff08f88c          NaN  maximize  adjusted_rand
# 80f876784fe243c7a1ef0c0d60402523          NaN  maximize  adjusted_rand
# 88b601c9c6a34035931335425bb9800f          NaN  maximize  adjusted_rand
# 96e64dc9e8634e7ab6e9927181c2e3d1          NaN  maximize  adjusted_rand
# 978ae34447454a2f9d3ff95b044484a7          NaN  maximize  adjusted_rand
# 9ae1a2be20cc4774a5a075a55c18f35e          NaN  maximize  adjusted_rand
# 9e125b89e1cf4a709312eb4083352c6a          NaN  maximize  adjusted_rand
# a962016fad28492fad410f3862bf921f          NaN  maximize  adjusted_rand
# add2a102856643cba33e4680923f4551          NaN  maximize  adjusted_rand
# b18b8eb8d5434537ac7bc0a0b6481f07          NaN  maximize  adjusted_rand
# b521a23517834c1a9d210a40cada29f9          NaN  maximize  adjusted_rand
# b5c4ba847ed54a8795d50e77d9ee7115          NaN  maximize  adjusted_rand
# b74bbac1474845eab29023e234fd5f5a          NaN  maximize  adjusted_rand
# b8aedc9c167143b49c4ecaadd583f34d          NaN  maximize  adjusted_rand
# b9f9f1fef542404d85ae933ed9dd4d0c          NaN  maximize  adjusted_rand
# baeb090275454b4098242e7879644c55          NaN  maximize  adjusted_rand
# bdfaeb40d8214d9b95da3222038aa333          NaN  maximize  adjusted_rand
# c61f793a969e4409bbffae0ce98fb6da          NaN  maximize  adjusted_rand
# c905708c43cc4baf8b47beb01178f01a          NaN  maximize  adjusted_rand
# c99abf79e67c4a4d94d498e88a630fe0          NaN  maximize  adjusted_rand
# d7e82004d67d44c88b593d6c1446b3da          NaN  maximize  adjusted_rand
# da79d6c7ccf54fc1af6b3ca3b9811f6a          NaN  maximize  adjusted_rand
#
# key                                              model_nickname n_classes  \
# run_uuid
# 0289c581d4a74c6998008fd8c6a23a8b    WardAgglomerativeClustering       NaN
# 0417c1059c264cdf8399c22c311b9876    WardAgglomerativeClustering       NaN
# 043d0cbd906747819040f8979d7f40d1                        HDBSCAN       NaN
# 08ca8fb95ff84adcb2b8c6567a29cc34    WardAgglomerativeClustering       NaN
# 16a5d69973d3475eae567d57d9241d3d            AffinityPropagation       NaN
# 1798d892c9b54192ac736b8013d9229e                         OPTICS       NaN
# 1e3053ee2da046f8aaf7a0e0c70ba9dc                         DBSCAN       NaN
# 230e310a3ff640f6865d1bda85845caf            RecursiveClustering       NaN
# 2490402188d94a7ca9f499eee32a52d3            RecursiveClustering       NaN
# 2545cfaa4ce44d4ba25a4c57945f8f4a                        HDBSCAN       NaN
# 26ab3cc84c4a420b8857b1a95ed6f767            RecursiveClustering       NaN
# 2ec4852314ed431f96d3841991fdc743    WardAgglomerativeClustering       NaN
# 338ba54bce1345a2a924b657bd5993bf                         DBSCAN       NaN
# 3692c78f34fd4c3c885c21c7a9071eaa                        HDBSCAN       NaN
# 3eb48652d7dd4c87ac58ddd07b3c5175            RecursiveClustering       NaN
# 4ea354c749a844fea7fa84bbb49cb447            RecursiveClustering       NaN
# 54433df700ed4a78801c8425094c326f    WardAgglomerativeClustering       NaN
# 571eb50796254ba09de64dc30acdebc1                         DBSCAN       NaN
# 6a48f613362447c78e3359b5c9dcc2f3  SpectralSubspaceRandomization       NaN
# 6cc3d2d840764cbea8c488d14e14b443            AffinityPropagation       NaN
# 6e847cd448bd4b8184b831772de744bd                        HDBSCAN       NaN
# 71d0891f6ac041e38d423fe3328f130e            AffinityPropagation       NaN
# 7239cc6680ec46a880e51cd9e02c3b62                        HDBSCAN       NaN
# 72528d7e02ad4ba1b51ba2ca3335ae83            RecursiveClustering       NaN
# 72cbb804b0d44f4e83b8d6e723bde1d2                        HDBSCAN       NaN
# 7354437c98ce4de9af3822771725e288                         DBSCAN       NaN
# 7e33df0102fb40968e05fb8ce3e3c909                         DBSCAN       NaN
# 7e7f30738e20404c93980ec8ff08f88c  SpectralSubspaceRandomization       NaN
# 80f876784fe243c7a1ef0c0d60402523            RecursiveClustering       NaN
# 88b601c9c6a34035931335425bb9800f    WardAgglomerativeClustering       NaN
# 96e64dc9e8634e7ab6e9927181c2e3d1                        HDBSCAN       NaN
# 978ae34447454a2f9d3ff95b044484a7                        HDBSCAN       NaN
# 9ae1a2be20cc4774a5a075a55c18f35e                         DBSCAN       NaN
# 9e125b89e1cf4a709312eb4083352c6a            AffinityPropagation       NaN
# a962016fad28492fad410f3862bf921f                         OPTICS       NaN
# add2a102856643cba33e4680923f4551    WardAgglomerativeClustering       NaN
# b18b8eb8d5434537ac7bc0a0b6481f07            RecursiveClustering       NaN
# b521a23517834c1a9d210a40cada29f9  SpectralSubspaceRandomization       NaN
# b5c4ba847ed54a8795d50e77d9ee7115                        HDBSCAN       NaN
# b74bbac1474845eab29023e234fd5f5a            AffinityPropagation       NaN
# b8aedc9c167143b49c4ecaadd583f34d            RecursiveClustering       NaN
# b9f9f1fef542404d85ae933ed9dd4d0c    WardAgglomerativeClustering       NaN
# baeb090275454b4098242e7879644c55    WardAgglomerativeClustering       NaN
# bdfaeb40d8214d9b95da3222038aa333    WardAgglomerativeClustering       NaN
# c61f793a969e4409bbffae0ce98fb6da            AffinityPropagation       NaN
# c905708c43cc4baf8b47beb01178f01a                        HDBSCAN       NaN
# c99abf79e67c4a4d94d498e88a630fe0                        HDBSCAN       NaN
# d7e82004d67d44c88b593d6c1446b3da                        HDBSCAN       NaN
# da79d6c7ccf54fc1af6b3ca3b9811f6a    WardAgglomerativeClustering       NaN
#
# key                              n_features  ... max_memory_used mutual_info  \
# run_uuid                                     ...
# 0289c581d4a74c6998008fd8c6a23a8b        NaN  ...             NaN    0.145176
# 0417c1059c264cdf8399c22c311b9876        NaN  ...             NaN         NaN
# 043d0cbd906747819040f8979d7f40d1        NaN  ...             NaN         NaN
# 08ca8fb95ff84adcb2b8c6567a29cc34        NaN  ...             NaN    0.145176
# 16a5d69973d3475eae567d57d9241d3d        NaN  ...             NaN         NaN
# 1798d892c9b54192ac736b8013d9229e        NaN  ...             NaN         NaN
# 1e3053ee2da046f8aaf7a0e0c70ba9dc        NaN  ...             NaN    0.000000
# 230e310a3ff640f6865d1bda85845caf        NaN  ...             NaN    0.949910
# 2490402188d94a7ca9f499eee32a52d3        NaN  ...             NaN    0.272477
# 2545cfaa4ce44d4ba25a4c57945f8f4a        NaN  ...             NaN         NaN
# 26ab3cc84c4a420b8857b1a95ed6f767        NaN  ...             NaN    0.199976
# 2ec4852314ed431f96d3841991fdc743        NaN  ...             NaN         NaN
# 338ba54bce1345a2a924b657bd5993bf        NaN  ...             NaN    0.000531
# 3692c78f34fd4c3c885c21c7a9071eaa        NaN  ...             NaN         NaN
# 3eb48652d7dd4c87ac58ddd07b3c5175        NaN  ...             NaN    0.001285
# 4ea354c749a844fea7fa84bbb49cb447        NaN  ...             NaN    0.003018
# 54433df700ed4a78801c8425094c326f        NaN  ...             NaN         NaN
# 571eb50796254ba09de64dc30acdebc1        NaN  ...             NaN    0.030472
# 6a48f613362447c78e3359b5c9dcc2f3        NaN  ...             NaN         NaN
# 6cc3d2d840764cbea8c488d14e14b443        NaN  ...             NaN         NaN
# 6e847cd448bd4b8184b831772de744bd        NaN  ...             NaN    0.001953
# 71d0891f6ac041e38d423fe3328f130e        NaN  ...             NaN         NaN
# 7239cc6680ec46a880e51cd9e02c3b62        NaN  ...             NaN         NaN
# 72528d7e02ad4ba1b51ba2ca3335ae83        NaN  ...             NaN    0.000819
# 72cbb804b0d44f4e83b8d6e723bde1d2        NaN  ...             NaN         NaN
# 7354437c98ce4de9af3822771725e288        NaN  ...             NaN    0.511244
# 7e33df0102fb40968e05fb8ce3e3c909        NaN  ...             NaN         NaN
# 7e7f30738e20404c93980ec8ff08f88c        NaN  ...             NaN         NaN
# 80f876784fe243c7a1ef0c0d60402523        NaN  ...             NaN    0.002407
# 88b601c9c6a34035931335425bb9800f        NaN  ...             NaN    0.145176
# 96e64dc9e8634e7ab6e9927181c2e3d1        NaN  ...             NaN         NaN
# 978ae34447454a2f9d3ff95b044484a7        NaN  ...             NaN         NaN
# 9ae1a2be20cc4774a5a075a55c18f35e        NaN  ...             NaN    0.000000
# 9e125b89e1cf4a709312eb4083352c6a        NaN  ...             NaN         NaN
# a962016fad28492fad410f3862bf921f        NaN  ...             NaN    0.006524
# add2a102856643cba33e4680923f4551        NaN  ...             NaN         NaN
# b18b8eb8d5434537ac7bc0a0b6481f07        NaN  ...             NaN         NaN
# b521a23517834c1a9d210a40cada29f9        NaN  ...             NaN         NaN
# b5c4ba847ed54a8795d50e77d9ee7115        NaN  ...             NaN         NaN
# b74bbac1474845eab29023e234fd5f5a        NaN  ...             NaN         NaN
# b8aedc9c167143b49c4ecaadd583f34d        NaN  ...             NaN         NaN
# b9f9f1fef542404d85ae933ed9dd4d0c        NaN  ...             NaN         NaN
# baeb090275454b4098242e7879644c55        NaN  ...             NaN         NaN
# bdfaeb40d8214d9b95da3222038aa333        NaN  ...             NaN         NaN
# c61f793a969e4409bbffae0ce98fb6da        NaN  ...             NaN         NaN
# c905708c43cc4baf8b47beb01178f01a        NaN  ...             NaN    0.001967
# c99abf79e67c4a4d94d498e88a630fe0        NaN  ...             NaN    0.000490
# d7e82004d67d44c88b593d6c1446b3da        NaN  ...             NaN         NaN
# da79d6c7ccf54fc1af6b3ca3b9811f6a        NaN  ...             NaN         NaN
#
# key                              n_clusters_  normalized_mutual_info  \
# run_uuid
# 0289c581d4a74c6998008fd8c6a23a8b        25.0                0.073103
# 0417c1059c264cdf8399c22c311b9876         NaN                     NaN
# 043d0cbd906747819040f8979d7f40d1         NaN                     NaN
# 08ca8fb95ff84adcb2b8c6567a29cc34        25.0                0.073103
# 16a5d69973d3475eae567d57d9241d3d         NaN                     NaN
# 1798d892c9b54192ac736b8013d9229e         NaN                     NaN
# 1e3053ee2da046f8aaf7a0e0c70ba9dc         1.0                0.000000
# 230e310a3ff640f6865d1bda85845caf        64.0                0.335039
# 2490402188d94a7ca9f499eee32a52d3         7.0                0.140823
# 2545cfaa4ce44d4ba25a4c57945f8f4a         NaN                     NaN
# 26ab3cc84c4a420b8857b1a95ed6f767        31.0                0.094997
# 2ec4852314ed431f96d3841991fdc743         NaN                     NaN
# 338ba54bce1345a2a924b657bd5993bf       275.0                0.001061
# 3692c78f34fd4c3c885c21c7a9071eaa         NaN                     NaN
# 3eb48652d7dd4c87ac58ddd07b3c5175         4.0                0.003838
# 4ea354c749a844fea7fa84bbb49cb447        25.0                0.001829
# 54433df700ed4a78801c8425094c326f         NaN                     NaN
# 571eb50796254ba09de64dc30acdebc1         6.0                0.025732
# 6a48f613362447c78e3359b5c9dcc2f3         NaN                     NaN
# 6cc3d2d840764cbea8c488d14e14b443         NaN                     NaN
# 6e847cd448bd4b8184b831772de744bd         4.0                0.003443
# 71d0891f6ac041e38d423fe3328f130e         NaN                     NaN
# 7239cc6680ec46a880e51cd9e02c3b62         NaN                     NaN
# 72528d7e02ad4ba1b51ba2ca3335ae83        30.0                0.000439
# 72cbb804b0d44f4e83b8d6e723bde1d2         NaN                     NaN
# 7354437c98ce4de9af3822771725e288      4055.0                0.183088
# 7e33df0102fb40968e05fb8ce3e3c909         NaN                     NaN
# 7e7f30738e20404c93980ec8ff08f88c         NaN                     NaN
# 80f876784fe243c7a1ef0c0d60402523        29.0                0.001272
# 88b601c9c6a34035931335425bb9800f        25.0                0.073103
# 96e64dc9e8634e7ab6e9927181c2e3d1         NaN                     NaN
# 978ae34447454a2f9d3ff95b044484a7         NaN                     NaN
# 9ae1a2be20cc4774a5a075a55c18f35e         1.0                0.000000
# 9e125b89e1cf4a709312eb4083352c6a         NaN                     NaN
# a962016fad28492fad410f3862bf921f         4.0                0.007193
# add2a102856643cba33e4680923f4551         NaN                     NaN
# b18b8eb8d5434537ac7bc0a0b6481f07         NaN                     NaN
# b521a23517834c1a9d210a40cada29f9         NaN                     NaN
# b5c4ba847ed54a8795d50e77d9ee7115         NaN                     NaN
# b74bbac1474845eab29023e234fd5f5a         NaN                     NaN
# b8aedc9c167143b49c4ecaadd583f34d         NaN                     NaN
# b9f9f1fef542404d85ae933ed9dd4d0c         NaN                     NaN
# baeb090275454b4098242e7879644c55         NaN                     NaN
# bdfaeb40d8214d9b95da3222038aa333         NaN                     NaN
# c61f793a969e4409bbffae0ce98fb6da         NaN                     NaN
# c905708c43cc4baf8b47beb01178f01a         4.0                0.003468
# c99abf79e67c4a4d94d498e88a630fe0         5.0                0.000477
# d7e82004d67d44c88b593d6c1446b3da         NaN                     NaN
# da79d6c7ccf54fc1af6b3ca3b9811f6a         NaN                     NaN
#
# key                               rand_score  silhouette  EXCEPTION  \
# run_uuid
# 0289c581d4a74c6998008fd8c6a23a8b    0.630174   -0.003434        NaN
# 0417c1059c264cdf8399c22c311b9876         NaN         NaN        NaN
# 043d0cbd906747819040f8979d7f40d1         NaN         NaN        NaN
# 08ca8fb95ff84adcb2b8c6567a29cc34    0.630174   -0.003434        NaN
# 16a5d69973d3475eae567d57d9241d3d         NaN         NaN        NaN
# 1798d892c9b54192ac736b8013d9229e         NaN         NaN        NaN
# 1e3053ee2da046f8aaf7a0e0c70ba9dc    0.104322   -1.000000        NaN
# 230e310a3ff640f6865d1bda85845caf    0.880739   -0.074361        NaN
# 2490402188d94a7ca9f499eee32a52d3    0.686752   -0.005928        NaN
# 2545cfaa4ce44d4ba25a4c57945f8f4a         NaN         NaN        NaN
# 26ab3cc84c4a420b8857b1a95ed6f767    0.742969   -0.032500        NaN
# 2ec4852314ed431f96d3841991fdc743         NaN         NaN        NaN
# 338ba54bce1345a2a924b657bd5993bf    0.432825   -1.000000        NaN
# 3692c78f34fd4c3c885c21c7a9071eaa         NaN         NaN        NaN
# 3eb48652d7dd4c87ac58ddd07b3c5175    0.645203   -1.000000        NaN
# 4ea354c749a844fea7fa84bbb49cb447    0.551096   -0.096389        NaN
# 54433df700ed4a78801c8425094c326f         NaN         NaN        NaN
# 571eb50796254ba09de64dc30acdebc1    0.535702    0.106244        NaN
# 6a48f613362447c78e3359b5c9dcc2f3         NaN         NaN        NaN
# 6cc3d2d840764cbea8c488d14e14b443         NaN         NaN        NaN
# 6e847cd448bd4b8184b831772de744bd    0.362948   -0.172245        NaN
# 71d0891f6ac041e38d423fe3328f130e         NaN         NaN        NaN
# 7239cc6680ec46a880e51cd9e02c3b62         NaN         NaN        NaN
# 72528d7e02ad4ba1b51ba2ca3335ae83    0.556214   -0.163491        NaN
# 72cbb804b0d44f4e83b8d6e723bde1d2         NaN         NaN        NaN
# 7354437c98ce4de9af3822771725e288    0.621667   -0.253641        NaN
# 7e33df0102fb40968e05fb8ce3e3c909         NaN         NaN        NaN
# 7e7f30738e20404c93980ec8ff08f88c         NaN         NaN        NaN
# 80f876784fe243c7a1ef0c0d60402523    0.557876   -0.060675        NaN
# 88b601c9c6a34035931335425bb9800f    0.630174   -0.003434        NaN
# 96e64dc9e8634e7ab6e9927181c2e3d1         NaN         NaN        NaN
# 978ae34447454a2f9d3ff95b044484a7         NaN         NaN        NaN
# 9ae1a2be20cc4774a5a075a55c18f35e    0.099985   -1.000000        NaN
# 9e125b89e1cf4a709312eb4083352c6a         NaN         NaN        NaN
# a962016fad28492fad410f3862bf921f    0.173483   -0.335586        NaN
# add2a102856643cba33e4680923f4551         NaN         NaN        NaN
# b18b8eb8d5434537ac7bc0a0b6481f07         NaN         NaN        NaN
# b521a23517834c1a9d210a40cada29f9         NaN         NaN        NaN
# b5c4ba847ed54a8795d50e77d9ee7115         NaN         NaN        NaN
# b74bbac1474845eab29023e234fd5f5a         NaN         NaN        NaN
# b8aedc9c167143b49c4ecaadd583f34d         NaN         NaN        NaN
# b9f9f1fef542404d85ae933ed9dd4d0c         NaN         NaN        NaN
# baeb090275454b4098242e7879644c55         NaN         NaN        NaN
# bdfaeb40d8214d9b95da3222038aa333         NaN         NaN        NaN
# c61f793a969e4409bbffae0ce98fb6da         NaN         NaN        NaN
# c905708c43cc4baf8b47beb01178f01a    0.362767   -0.182040        NaN
# c99abf79e67c4a4d94d498e88a630fe0    0.149086   -1.000000        NaN
# d7e82004d67d44c88b593d6c1446b3da         NaN         NaN        NaN
# da79d6c7ccf54fc1af6b3ca3b9811f6a         NaN         NaN        NaN
#
# key                               best_child_run_id  parent_run_id  \
# run_uuid
# 0289c581d4a74c6998008fd8c6a23a8b                NaN            NaN
# 0417c1059c264cdf8399c22c311b9876                NaN            NaN
# 043d0cbd906747819040f8979d7f40d1                NaN            NaN
# 08ca8fb95ff84adcb2b8c6567a29cc34                NaN            NaN
# 16a5d69973d3475eae567d57d9241d3d                NaN            NaN
# 1798d892c9b54192ac736b8013d9229e                NaN            NaN
# 1e3053ee2da046f8aaf7a0e0c70ba9dc                NaN            NaN
# 230e310a3ff640f6865d1bda85845caf                NaN            NaN
# 2490402188d94a7ca9f499eee32a52d3                NaN            NaN
# 2545cfaa4ce44d4ba25a4c57945f8f4a                NaN            NaN
# 26ab3cc84c4a420b8857b1a95ed6f767                NaN            NaN
# 2ec4852314ed431f96d3841991fdc743                NaN            NaN
# 338ba54bce1345a2a924b657bd5993bf                NaN            NaN
# 3692c78f34fd4c3c885c21c7a9071eaa                NaN            NaN
# 3eb48652d7dd4c87ac58ddd07b3c5175                NaN            NaN
# 4ea354c749a844fea7fa84bbb49cb447                NaN            NaN
# 54433df700ed4a78801c8425094c326f                NaN            NaN
# 571eb50796254ba09de64dc30acdebc1                NaN            NaN
# 6a48f613362447c78e3359b5c9dcc2f3                NaN            NaN
# 6cc3d2d840764cbea8c488d14e14b443                NaN            NaN
# 6e847cd448bd4b8184b831772de744bd                NaN            NaN
# 71d0891f6ac041e38d423fe3328f130e                NaN            NaN
# 7239cc6680ec46a880e51cd9e02c3b62                NaN            NaN
# 72528d7e02ad4ba1b51ba2ca3335ae83                NaN            NaN
# 72cbb804b0d44f4e83b8d6e723bde1d2                NaN            NaN
# 7354437c98ce4de9af3822771725e288                NaN            NaN
# 7e33df0102fb40968e05fb8ce3e3c909                NaN            NaN
# 7e7f30738e20404c93980ec8ff08f88c                NaN            NaN
# 80f876784fe243c7a1ef0c0d60402523                NaN            NaN
# 88b601c9c6a34035931335425bb9800f                NaN            NaN
# 96e64dc9e8634e7ab6e9927181c2e3d1                NaN            NaN
# 978ae34447454a2f9d3ff95b044484a7                NaN            NaN
# 9ae1a2be20cc4774a5a075a55c18f35e                NaN            NaN
# 9e125b89e1cf4a709312eb4083352c6a                NaN            NaN
# a962016fad28492fad410f3862bf921f                NaN            NaN
# add2a102856643cba33e4680923f4551                NaN            NaN
# b18b8eb8d5434537ac7bc0a0b6481f07                NaN            NaN
# b521a23517834c1a9d210a40cada29f9                NaN            NaN
# b5c4ba847ed54a8795d50e77d9ee7115                NaN            NaN
# b74bbac1474845eab29023e234fd5f5a                NaN            NaN
# b8aedc9c167143b49c4ecaadd583f34d                NaN            NaN
# b9f9f1fef542404d85ae933ed9dd4d0c                NaN            NaN
# baeb090275454b4098242e7879644c55                NaN            NaN
# bdfaeb40d8214d9b95da3222038aa333                NaN            NaN
# c61f793a969e4409bbffae0ce98fb6da                NaN            NaN
# c905708c43cc4baf8b47beb01178f01a                NaN            NaN
# c99abf79e67c4a4d94d498e88a630fe0                NaN            NaN
# d7e82004d67d44c88b593d6c1446b3da                NaN            NaN
# da79d6c7ccf54fc1af6b3ca3b9811f6a                NaN            NaN
#
# key                               raised_exception
# run_uuid
# 0289c581d4a74c6998008fd8c6a23a8b               NaN
# 0417c1059c264cdf8399c22c311b9876               NaN
# 043d0cbd906747819040f8979d7f40d1               NaN
# 08ca8fb95ff84adcb2b8c6567a29cc34               NaN
# 16a5d69973d3475eae567d57d9241d3d               NaN
# 1798d892c9b54192ac736b8013d9229e               NaN
# 1e3053ee2da046f8aaf7a0e0c70ba9dc               NaN
# 230e310a3ff640f6865d1bda85845caf               NaN
# 2490402188d94a7ca9f499eee32a52d3               NaN
# 2545cfaa4ce44d4ba25a4c57945f8f4a               NaN
# 26ab3cc84c4a420b8857b1a95ed6f767               NaN
# 2ec4852314ed431f96d3841991fdc743               NaN
# 338ba54bce1345a2a924b657bd5993bf               NaN
# 3692c78f34fd4c3c885c21c7a9071eaa               NaN
# 3eb48652d7dd4c87ac58ddd07b3c5175               NaN
# 4ea354c749a844fea7fa84bbb49cb447               NaN
# 54433df700ed4a78801c8425094c326f               NaN
# 571eb50796254ba09de64dc30acdebc1               NaN
# 6a48f613362447c78e3359b5c9dcc2f3               NaN
# 6cc3d2d840764cbea8c488d14e14b443               NaN
# 6e847cd448bd4b8184b831772de744bd               NaN
# 71d0891f6ac041e38d423fe3328f130e               NaN
# 7239cc6680ec46a880e51cd9e02c3b62               NaN
# 72528d7e02ad4ba1b51ba2ca3335ae83               NaN
# 72cbb804b0d44f4e83b8d6e723bde1d2               NaN
# 7354437c98ce4de9af3822771725e288               NaN
# 7e33df0102fb40968e05fb8ce3e3c909               NaN
# 7e7f30738e20404c93980ec8ff08f88c               NaN
# 80f876784fe243c7a1ef0c0d60402523               NaN
# 88b601c9c6a34035931335425bb9800f               NaN
# 96e64dc9e8634e7ab6e9927181c2e3d1               NaN
# 978ae34447454a2f9d3ff95b044484a7               NaN
# 9ae1a2be20cc4774a5a075a55c18f35e               NaN
# 9e125b89e1cf4a709312eb4083352c6a               NaN
# a962016fad28492fad410f3862bf921f               NaN
# add2a102856643cba33e4680923f4551               NaN
# b18b8eb8d5434537ac7bc0a0b6481f07               NaN
# b521a23517834c1a9d210a40cada29f9               NaN
# b5c4ba847ed54a8795d50e77d9ee7115               NaN
# b74bbac1474845eab29023e234fd5f5a               NaN
# b8aedc9c167143b49c4ecaadd583f34d               NaN
# b9f9f1fef542404d85ae933ed9dd4d0c               NaN
# baeb090275454b4098242e7879644c55               NaN
# bdfaeb40d8214d9b95da3222038aa333               NaN
# c61f793a969e4409bbffae0ce98fb6da               NaN
# c905708c43cc4baf8b47beb01178f01a               NaN
# c99abf79e67c4a4d94d498e88a630fe0               NaN
# d7e82004d67d44c88b593d6c1446b3da               NaN
# da79d6c7ccf54fc1af6b3ca3b9811f6a               NaN
#
# [49 rows x 39 columns]

# %%
parent_run_ids = list(df.index)

# %%
parent_run_ids
# Out:
# ['0289c581d4a74c6998008fd8c6a23a8b',
#  '0417c1059c264cdf8399c22c311b9876',
#  '043d0cbd906747819040f8979d7f40d1',
#  '08ca8fb95ff84adcb2b8c6567a29cc34',
#  '16a5d69973d3475eae567d57d9241d3d',
#  '1798d892c9b54192ac736b8013d9229e',
#  '1e3053ee2da046f8aaf7a0e0c70ba9dc',
#  '230e310a3ff640f6865d1bda85845caf',
#  '2490402188d94a7ca9f499eee32a52d3',
#  '2545cfaa4ce44d4ba25a4c57945f8f4a',
#  '26ab3cc84c4a420b8857b1a95ed6f767',
#  '2ec4852314ed431f96d3841991fdc743',
#  '338ba54bce1345a2a924b657bd5993bf',
#  '3692c78f34fd4c3c885c21c7a9071eaa',
#  '3eb48652d7dd4c87ac58ddd07b3c5175',
#  '4ea354c749a844fea7fa84bbb49cb447',
#  '54433df700ed4a78801c8425094c326f',
#  '571eb50796254ba09de64dc30acdebc1',
#  '6a48f613362447c78e3359b5c9dcc2f3',
#  '6cc3d2d840764cbea8c488d14e14b443',
#  '6e847cd448bd4b8184b831772de744bd',
#  '71d0891f6ac041e38d423fe3328f130e',
#  '7239cc6680ec46a880e51cd9e02c3b62',
#  '72528d7e02ad4ba1b51ba2ca3335ae83',
#  '72cbb804b0d44f4e83b8d6e723bde1d2',
#  '7354437c98ce4de9af3822771725e288',
#  '7e33df0102fb40968e05fb8ce3e3c909',
#  '7e7f30738e20404c93980ec8ff08f88c',
#  '80f876784fe243c7a1ef0c0d60402523',
#  '88b601c9c6a34035931335425bb9800f',
#  '96e64dc9e8634e7ab6e9927181c2e3d1',
#  '978ae34447454a2f9d3ff95b044484a7',
#  '9ae1a2be20cc4774a5a075a55c18f35e',
#  '9e125b89e1cf4a709312eb4083352c6a',
#  'a962016fad28492fad410f3862bf921f',
#  'add2a102856643cba33e4680923f4551',
#  'b18b8eb8d5434537ac7bc0a0b6481f07',
#  'b521a23517834c1a9d210a40cada29f9',
#  'b5c4ba847ed54a8795d50e77d9ee7115',
#  'b74bbac1474845eab29023e234fd5f5a',
#  'b8aedc9c167143b49c4ecaadd583f34d',
#  'b9f9f1fef542404d85ae933ed9dd4d0c',
#  'baeb090275454b4098242e7879644c55',
#  'bdfaeb40d8214d9b95da3222038aa333',
#  'c61f793a969e4409bbffae0ce98fb6da',
#  'c905708c43cc4baf8b47beb01178f01a',
#  'c99abf79e67c4a4d94d498e88a630fe0',
#  'd7e82004d67d44c88b593d6c1446b3da',
#  'da79d6c7ccf54fc1af6b3ca3b9811f6a']

# %%
df = df_runs_raw.copy()
df = df.loc[df['parent_run_id'].isin(parent_run_ids)]

# %%
child_run_ids = list(df.index)

# %%
runs_to_delete = parent_run_ids + child_run_ids

# %%
runs_to_delete
# Out:
# ['0289c581d4a74c6998008fd8c6a23a8b',
#  '0417c1059c264cdf8399c22c311b9876',
#  '043d0cbd906747819040f8979d7f40d1',
#  '08ca8fb95ff84adcb2b8c6567a29cc34',
#  '16a5d69973d3475eae567d57d9241d3d',
#  '1798d892c9b54192ac736b8013d9229e',
#  '1e3053ee2da046f8aaf7a0e0c70ba9dc',
#  '230e310a3ff640f6865d1bda85845caf',
#  '2490402188d94a7ca9f499eee32a52d3',
#  '2545cfaa4ce44d4ba25a4c57945f8f4a',
#  '26ab3cc84c4a420b8857b1a95ed6f767',
#  '2ec4852314ed431f96d3841991fdc743',
#  '338ba54bce1345a2a924b657bd5993bf',
#  '3692c78f34fd4c3c885c21c7a9071eaa',
#  '3eb48652d7dd4c87ac58ddd07b3c5175',
#  '4ea354c749a844fea7fa84bbb49cb447',
#  '54433df700ed4a78801c8425094c326f',
#  '571eb50796254ba09de64dc30acdebc1',
#  '6a48f613362447c78e3359b5c9dcc2f3',
#  '6cc3d2d840764cbea8c488d14e14b443',
#  '6e847cd448bd4b8184b831772de744bd',
#  '71d0891f6ac041e38d423fe3328f130e',
#  '7239cc6680ec46a880e51cd9e02c3b62',
#  '72528d7e02ad4ba1b51ba2ca3335ae83',
#  '72cbb804b0d44f4e83b8d6e723bde1d2',
#  '7354437c98ce4de9af3822771725e288',
#  '7e33df0102fb40968e05fb8ce3e3c909',
#  '7e7f30738e20404c93980ec8ff08f88c',
#  '80f876784fe243c7a1ef0c0d60402523',
#  '88b601c9c6a34035931335425bb9800f',
#  '96e64dc9e8634e7ab6e9927181c2e3d1',
#  '978ae34447454a2f9d3ff95b044484a7',
#  '9ae1a2be20cc4774a5a075a55c18f35e',
#  '9e125b89e1cf4a709312eb4083352c6a',
#  'a962016fad28492fad410f3862bf921f',
#  'add2a102856643cba33e4680923f4551',
#  'b18b8eb8d5434537ac7bc0a0b6481f07',
#  'b521a23517834c1a9d210a40cada29f9',
#  'b5c4ba847ed54a8795d50e77d9ee7115',
#  'b74bbac1474845eab29023e234fd5f5a',
#  'b8aedc9c167143b49c4ecaadd583f34d',
#  'b9f9f1fef542404d85ae933ed9dd4d0c',
#  'baeb090275454b4098242e7879644c55',
#  'bdfaeb40d8214d9b95da3222038aa333',
#  'c61f793a969e4409bbffae0ce98fb6da',
#  'c905708c43cc4baf8b47beb01178f01a',
#  'c99abf79e67c4a4d94d498e88a630fe0',
#  'd7e82004d67d44c88b593d6c1446b3da',
#  'da79d6c7ccf54fc1af6b3ca3b9811f6a',
#  '000cfb9715d547d08928eba20b8bfe7f',
#  '0087ff305be940bfb67db54f36f3d5e2',
#  '01e19e6d2d804497958ed3af450c7e5b',
#  '02926adf2f0c49db839d49dbad153daa',
#  '02d0bc75b867400d8dfad1b53d95d4ea',
#  '032d827197b24ba3ad6f4254b880a3bd',
#  '035725f8f471403f967511fc39aba18b',
#  '05858b80138541dcb08ee2c1d34e6314',
#  '06f7d20a2cc84b3e8a6b980d7870684f',
#  '0729ddb274f14f45b0a2ac4db13de568',
#  '0960f45f9cd54fa39fcc6e3afecbe26b',
#  '09e04444fae04ef9b92707bee05111ed',
#  '0a1efe2a4e2b4a09995d414c1b62d357',
#  '0e24a2f889294d0ab18350d6f1320b59',
#  '0e4d6c39892a45918ee792ba979a53dd',
#  '10407f6b37ad4009aebb7e226edf93ba',
#  '1162bcaea38b46c3a6aa4f98434ebcc4',
#  '14587c99ba2441b989b106768d2a9f36',
#  '1504026bec344134af0ed20b7f128647',
#  '15e45c6dec2d4ff0a95b3a2cfc8e71bf',
#  '15ff5fcd0d0e412a882d1f43708ff2c1',
#  '1780a964e40949629ce4b82ba8ee2488',
#  '17e919324afd4545bf1cc8c5a867fc9c',
#  '17ee3e0e19494d0f8744fe0573bc86c6',
#  '1967ae8201bc4be68715e22e48fd8ed0',
#  '1ac73f891deb4915a249d1e00d89db5c',
#  '1b4f61b34aaa42ee8cc6a6880228c5f3',
#  '1b6de71af27d4457ac6a6f2218d811de',
#  '1f4e102a416742ff85b9e3e912587f87',
#  '1f5d8b1b7f5e4d1b96517acd116e8f3c',
#  '1f6c2b3dd68946a8a8d553055824b1ac',
#  '1f74fe408f1f4cd0b12c19b2496274e9',
#  '1f9f5b11fe394e2e84abc530f3474a3f',
#  '22e7bb77c944429baf774c2ff9d980e7',
#  '23c58813b5f1408b829820937c138fe4',
#  '273c98b322034f999724b938968dda69',
#  '273e6955fa974a508401de5be73f77a1',
#  '280652047d72446cbf3b3c6abf7069ac',
#  '2b4418f7ab364f04b0cf132771034cae',
#  '2c34fbe289344db7aad85ca0b5e7234d',
#  '2ca5ad5a8c9d400c9f7815a61eba710b',
#  '2cc6aa0f7a144ee28c8252bce32de925',
#  '2fb18e6a51d6481dbdfbbcab1bcdb4f2',
#  '30c6c15854c54a75b1afd89bf8c6607e',
#  '3296c15dbcc94799a22a560843e1847c',
#  '335349032dca4ddd90928a00f4243914',
#  '3471e3ddf3b94a18948f54bb4d4cb9b8',
#  '391c775dea7b475ea986f17282b1fcda',
#  '3b02c62a9f63468a99eeaa129da0eeef',
#  '3b951b3c3fb94ceaaadec1b5af0335de',
#  '3d9ff4d71a7043de94c945ebb7441641',
#  '3e2fdf802ada44309f667b6442bb2422',
#  '3f3b63b9f29247938e722160ec7d8142',
#  '3f9b7dc9af27425c8eabe94bc0adb8b5',
#  '3fa894a722dc4686b7685b2195cf520f',
#  '3fc796880cc54364829be623824b8421',
#  '423da8c6c2c74ff5a9ed5b35e82055c6',
#  '42b2783eca3649d09806c91751f979f6',
#  '46e14a566dc44483b36308cf23483603',
#  '46fee798e44745f2aca16441b125c9ce',
#  '48ae688a23f24ca2aaf04a66c17f91d1',
#  '4919c5137acb4a51b3c83939a1bb7ecd',
#  '4943c249ac5b4e12b35e543af99bd5e0',
#  '4a270856be174329a07545f79e8c67c8',
#  '4aa361c3139b496f9451ae657868f95c',
#  '4c8a2f66a9224182ba5b34415c7c07ef',
#  '4db43f333b3f48d7838af5a8a15b85df',
#  '4fb6aca03eda4e17bcf74220cb331f31',
#  '507209b2bef547f6b1e126018b9e4852',
#  '5364cf4fc48146ec94708e0f32bb694b',
#  '546d616378f8455dab1b682ea3ea0eab',
#  '55a1aa1f448a4ae4ab2dcecea67177ac',
#  '57271d4c73e540bfa08e398091ebf570',
#  '598e63a36832447dadf0908d04186d29',
#  '5a8703b2626a4f2eb98fe26f40039796',
#  '5afa2cdfc6f546718f14c40ac087b3d5',
#  '5e7779375c964849a5cf31a94fbdc654',
#  '609b7c7adbc74e0bb41d8a0545c9002b',
#  '60b730058c194fa09bc0cc475da4e111',
#  '615c5189660b4884b49b11e144d5d295',
#  '61868e04be3c48c5a6088cefb3d935fe',
#  '618a7125c60e4e408d1db41afcadf536',
#  '61ca365137c44286b58823b6d1127a14',
#  '62c01aa1cea74a2b80de3f52edc8dda5',
#  '63430f455d414d5ebb63a6be9a3d5de8',
#  '63a3e1d567ac4f9fa6cd5dc33738d0e5',
#  '64229d85d484404997d90d8882d46ef7',
#  '64b29d1365a84144b68b028586adf76a',
#  '6579e8c3fa6a4d0baefd2065808e89f0',
#  '667ec5963c2a4490910bef08c9c7bebb',
#  '6937524f3974497586b9f00a26472f9f',
#  '69e4c471ac9d47079da5f4ad08682e83',
#  '6a71473a55504e8a9e4ac961546fce83',
#  '6b12ae3e1cd749e2b5d1a889a193322e',
#  '6b15a65038374e998681e01597dc186a',
#  '6c085d79707744f98ea63e83e21a0194',
#  '6ecc32ff7c0d449193d30a49dbec9933',
#  '6f6b1a4c12e648519e4aac47d6a5a2c7',
#  '7106c39dd55447d5aed413ea89233bf2',
#  '7162833dc2154af59e9e91306619832a',
#  '72db26adf3944cb68593ca3f7adfbfc0',
#  '73863662f522434b993dd6337f0560b7',
#  '7409db29352f4755b02d22185a81d3eb',
#  '74b2064f894740dfb4f00a305f3df77a',
#  '768e2ba6900c49aa867dc40f5d7d658c',
#  '774695ebe07847c292745ee4e5a21307',
#  '77cb1b99d1d140929edd9bc98c388be2',
#  '7871d709ffd44c52a9e7e8231ff9210c',
#  '7a018fcbf65149f096a81bf2c25f3439',
#  '7a1e4f1f05b2466fa39d48bccf30303d',
#  '7b835962d25345d3931925cb5e4e50f4',
#  '7d3450152b6c4623a632105e591bcd59',
#  '7f05dcc830104dd4b88eb42793c88a18',
#  '8011be4d01d94e5d9b25448a8bd764ea',
#  '80b1f0304beb4ceba922c614f91658bb',
#  '8178e8a35e6f4e5d999b0d0ad1c5ba6c',
#  '825fe25b575d46eb8ff7c2f730dc2baf',
#  '832fbd23149247bda2341c855dd33531',
#  '848fa17b901242d4960d0bd6714f44c7',
#  '8945b3fccc904b6297a2e0387fb27efe',
#  '8b90eb7d0f3e4e45924381d60bb530cd',
#  '8bb6f099bd9848569e2656f7d3efe426',
#  '8d93a08115b64a55b905740acbaf0397',
#  '8e13a9cd55f14ce2a7f467470496a7e8',
#  '8fb4e5d1ba624fe684736f679d3a668a',
#  '901a45ac0f07404bae3d3ae1dcf6f679',
#  '91fd18593591426ba19cec9ff74b0d1a',
#  '920975c4ee954ccd979741cd8c16bc3b',
#  '9232eace52ae42eb85d8256cb7ccd74d',
#  '92b89b84a64e4a07bc904fb26f64dba0',
#  '9336d9f096264e9fafad05f4a22112fa',
#  '93e1ee5aa54542d4b3db99ef625c7dc3',
#  '9921f37bcffc4ae08b59ea84eae4890b',
#  '994c94a070b2434c9480f4fe02b42ad8',
#  '9a261bbb48e04498ae5c1962a8aad275',
#  '9a73d025a4aa40399255904ff96c8249',
#  '9c45df30c29c4e1d800e2d80bc044f0d',
#  '9c9063b42bd64389b89536214db92f03',
#  '9d05fc566c2847328f0fdc18ef1b16de',
#  '9e20a7338894496a9caf692534e376c8',
#  'a1e58b12ca1b4742a4fa13e66e0afdf0',
#  'a2a7cc6fa4b14de0a554c6b59950608a',
#  'a778e197aab8414aace429e0b323bda2',
#  'a909bbe1b5e04fa0963e14d46e60fea3',
#  'ab72bc36e6524452b0fffef1829c67cd',
#  'ac154c37c9f341d684c5580bd069d4ea',
#  'ac340d1fd2624cf091e7452a90a8dbc0',
#  'ad0b0ecc673747efaf3a5fa463eb95c3',
#  'ad77ad2ca9d34e43b9173afdff96487e',
#  'ae28776908b04ac083844dd33eaa88fc',
#  'ae380eb41dc241fd957d58f556ed338a',
#  'afefae1a87c642e7bbb205c39579d5a3',
#  'b07f0f1d8e3e445b9730e8eff733ec86',
#  'b186d651a6ba4978ace40e1e8adc6780',
#  'b21cc29f551c427383168b291f2da158',
#  'b2dda2abcff04a568ab3c908d1535afe',
#  'b349e85c694c4f51bb5b73a88e1d3bb7',
#  'b3548a5f5d3148a98f202abb73bf9ddf',
#  'b40f2e84890940ceb274650c85889b7e',
#  'b5584a048d7e440bb689de3d97a20444',
#  'b778d3614d7345a89b0c3fd81b3603a3',
#  'b7b767fb2b5c4b95a10e47ceaa6824c2',
#  'b9dca613a1cb4f558a33982f27b48b82',
#  'ba435f7776f843ffa69bf8da074e9417',
#  'bb5e085f421246d595a3a8a87d4fb30b',
#  'bb78a00a9e3d407db83c1e8247c815a1',
#  'bc881677ac184b7bb61a1f750c40d9b2',
#  'bdfa588a13a44689be556e8303778145',
#  'bf157a2954e54cc1ab11b497d02a101a',
#  'bf331bbf8dcd4c0da01f805842bcdfe4',
#  'c0157509e95042c5a3c441b322f7e6ec',
#  'c1060a57a5b9489eabc37e2df8109900',
#  'c121240c197b4c6e922d14bb94727184',
#  'c3970a639b034228a4ae64f0d9e18872',
#  'c3a43b66cc964e9c915af4e914c64c9f',
#  'c66a637d5433416eb599ba4a7ba88b76',
#  'c69cb4641caf403083cf64fcc56673a2',
#  'c74261b19ccc4d5d86fc0e157488fc5f',
#  'c8fe7734e80045f1ba5558f4403981bb',
#  'ca2680dfeabe4f3ba57b45eeca423464',
#  'ca3557d98c6b41a0bb49aef467f36c68',
#  'ca6a65748a3c4d668d674f9b063d00fd',
#  'cb7d7634819246dca9ba31f52b6c810c',
#  'cbfdc81338864ce3b6ecbe1967c66a01',
#  'cd54bfa17a9f4b7bac2889ae954e8886',
#  'cda5163c610f43a7b6b8dea3cd09fccb',
#  'ce73da49aa404d27930b6fe215dd3aef',
#  'cfacf2a62b63407b999b74a3db575376',
#  'd064f98e9a2d4bd88cf4b0e3f05a1100',
#  'd072e3cb75b94152b070b71ec22896e6',
#  'd14a5ceb36b64c769a2352c67329599c',
#  'd206d6db4a5c4730a647f12a5e416268',
#  'd68ba3604763482098a17e9c1af91ef6',
#  'd7be48b9a3f9409ba80d836339969797',
#  'd84954a66b5540248ce205fbe4ce9cac',
#  'd90bf70aab674c5ea4069872bb6c9250',
#  'd96cc1468c9a4091a0241748adcb64fd',
#  'de57f12db61d4359a0eb44f668fefad4',
#  'de755fb1664f440cbf80b2683462fe17',
#  'deacdb9346ba4d599f9e23892017bd92',
#  'dee1c766ba5444d498ca02d6569a3800',
#  'e0d2d8339bf9464a9af466f9399162b0',
#  'e160efdc9b944ef9a0494c4224232876',
#  'e18ff1b5a79d466fae2eaa457adfdf23',
#  'e1c383cf5b3544d6b054cac80bbcb68f',
#  'e2d9aa6854a44882866e42119edf272f',
#  'e3c3d7414c9b40678682b2d29a7ef927',
#  'e4b08cf2ade94170b7dec75b1c611c0d',
#  'e5027c8315284504aff15cdbc6253fb1',
#  'e6520a581bb44eb880926ac21cc3133e',
#  'e66052ea2e1f4163bdeebbcbf01808ea',
#  'e69597409f2e48d48ba7636d697266b1',
#  'e7e7894445ba4964880c850f44516e34',
#  'e92043a47ddd4c0fb600e000e8b539ba',
#  'eac8a869957e4db1a01dc8e5745e5188',
#  'eb1f550a3cb54c9794eeb8cee538eb4a',
#  'ee4ad817c2db4ca98fd978d36cd3c02e',
#  'f0070b77e1914439942774defaa94ff3',
#  'f13feec34d3844c9bc1529e915d00006',
#  'f24f2c2c8bd9465fa840eda1daf89c05',
#  'f409aa62e40046dfa1db09b4ea4799ce',
#  'f461cc6389144f9fb09df39ad72cf333',
#  'f499a28fbf6e4e83a84c8779d157a4b9',
#  'f5416ad3d79c4317a77520099e26770a',
#  'f65e129e44cb4b939b35d85a86611137',
#  'f959a8c69f3740b09b9f459dca841132',
#  'f9729139459649dc9ad66ef6a891d061',
#  'fa0cb8a9d42249c2a30d712d010f8428',
#  'fe6465bbd7e245398054c51d1e09f728',
#  'fea1ba753119454cb621baee257021da']

# %%
run_uuid_query = [f"'{run_id}'" for run_id in runs_to_delete]
run_uuid_query = ', '.join(run_uuid_query)

# %%
query = f"""
UPDATE runs
SET lifecycle_stage = 'deleted'
WHERE run_uuid IN ({run_uuid_query}) 
"""
with engine.begin() as conn:
    conn.execute(text(query))

# %% [markdown]
# for i, row in df_runs_raw.iterrows():
#     run_id = row.run_id
#     model_name = row['params.model_name']
#     with mlflow.start_run(run_id) as run:
#         mlflow.log_param('model_nickname', model_name)
