# %%
from sqlalchemy import create_engine, text
import pandas as pd
from ml_experiments.analyze import get_df_runs_from_mlflow_sql, get_missing_entries
from pathlib import Path
import os
import pickle
from functools import partial

# %% [markdown]
# # Save Results

# %% [markdown]
# ## Load mlflow runs

# %%
results_dir = Path.cwd().parent / "results" / "real"
os.makedirs(results_dir, exist_ok=True)

# %%
db_port = 5101
db_name = "cohirf"
url = f"postgresql://beluccib@localhost:{db_port}/{db_name}"
# url = f"postgresql://beluccib@clust5:{db_port}/{db_name}"
engine = create_engine(url)
query = "SELECT experiments.name from experiments"
experiment_names = pd.read_sql(query, engine)["name"].tolist()

# %%
experiment_names
# Out:
# ['Default',
#  'real-adjusted_rand-KernelRBFKMeans',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_rand-KMeans',
#  'real-adjusted_rand-DBSCAN',
#  'real-adjusted_rand-CoHiRF-DBSCAN',
#  'real-adjusted_rand-BatchCoHiRF',
#  'real-adjusted_rand-CoHiRF',
#  'real-adjusted_rand-CoHiRF-KernelRBF',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-1iter',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter',
#  'real-silhouette-BatchCoHiRF-1iter',
#  'real-silhouette-DBSCAN',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter',
#  'real-davies_bouldin_score-KernelRBFKMeans',
#  'real-silhouette-KMeans',
#  'real-davies_bouldin_score-KMeans',
#  'real-calinski_harabasz_score-CoHiRF',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_mutual_info-CoHiRF',
#  'real-adjusted_mutual_info-CoHiRF-KernelRBF',
#  'real-davies_bouldin_score-CoHiRF-DBSCAN',
#  'real-adjusted_mutual_info-CoHiRF-DBSCAN',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_rand-BatchCoHiRF-1iter',
#  'real-davies_bouldin_score-DBSCAN',
#  'real-silhouette-CoHiRF-KernelRBF',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter',
#  'real-calinski_harabasz_score-CoHiRF-DBSCAN',
#  'real-adjusted_mutual_info-KMeans',
#  'real-calinski_harabasz_score-CoHiRF-KernelRBF',
#  'real-davies_bouldin_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-adjusted_mutual_info-DBSCAN',
#  'real-silhouette-CoHiRF',
#  'real-adjusted_mutual_info-KernelRBFKMeans',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-calinski_harabasz_score-KMeans',
#  'real-davies_bouldin_score-CoHiRF',
#  'real-silhouette-KernelRBFKMeans',
#  'real-silhouette-CoHiRF-DBSCAN',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter',
#  'real-davies_bouldin_score-CoHiRF-KernelRBF',
#  'real-calinski_harabasz_score-KernelRBFKMeans',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter',
#  'real-calinski_harabasz_score-DBSCAN',
#  'real-silhouette-CoHiRF-SC-SRGF',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF',
#  'real-silhouette-SpectralSubspaceRandomization',
#  'real-calinski_harabasz_score-SpectralSubspaceRandomization',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF',
#  'real-davies_bouldin_score-SpectralSubspaceRandomization',
#  'real-adjusted_rand-SpectralSubspaceRandomization',
#  'real-adjusted_mutual_info-SpectralSubspaceRandomization',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_rand-CoHiRF-SC-SRGF',
#  'real-silhouette-BatchCoHiRF-SC-SRGF',
#  'adjusted_rand_mean-DistributedKMeans',
#  'adjusted_rand_mean-VPC',
#  'davies_bouldin_score-DistributedKMeansLocal',
#  'calinski_harabasz_score-CoresetKMeans',
#  'adjusted_mutual_info-VeCoHiRF',
#  'calinski_harabasz_score-VeCoHiRF',
#  'davies_bouldin_score-VeCoHiRF',
#  'davies_bouldin_score-VPC',
#  'silhouette-VPC',
#  'adjusted_rand_mean-VeCoHiRF',
#  'adjusted_mutual_info-DistributedKMeans',
#  'adjusted_rand_mean-CoresetKMeans',
#  'silhouette-CoresetKMeans',
#  'silhouette-VeCoHiRF',
#  'davies_bouldin_score-CoresetKMeans',
#  'calinski_harabasz_score-VPC',
#  'adjusted_rand_mean-DistributedKMeansLocal',
#  'adjusted_mutual_info-VPC',
#  'davies_bouldin_score-DistributedKMeans',
#  'adjusted_mutual_info-DistributedKMeansLocal',
#  'adjusted_mutual_info-V2way',
#  'adjusted_mutual_info-CoresetKMeans',
#  'calinski_harabasz_score-DistributedKMeans',
#  'silhouette-DistributedKMeans',
#  'calinski_harabasz_score-DistributedKMeansLocal',
#  'adjusted_rand_mean-V2way',
#  'silhouette-DistributedKMeansLocal',
#  'calinski_harabasz_score-V2way',
#  'real-silhouette-BatchCoHiRF-SC-SRGF-2',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF-2',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF-2',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-2',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF-2',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter-stratified',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter-stratified',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-1iter-stratified',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter-stratified',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-stratified',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-1iter',
#  'real-silhouette-CoHiRF-1000',
#  'real-adjusted_rand-CoHiRF-1000',
#  'real-davies_bouldin_score-CoHiRF-1000',
#  'real-calinski_harabasz_score-CoHiRF-1000',
#  'real-adjusted_mutual_info-CoHiRF-1000',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF-1iter',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF-1iter',
#  'real-silhouette-BatchCoHiRF-SC-SRGF-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF-1iter',
#  'gnoise-CoHiRF-1000',
#  'gnoise-CoHiRF',
#  'gnoise-KMeans',
#  'gnoise-CoHiRF-top-down-inv',
#  'gnoise-CoHiRF-top-down',
#  'real-davies_bouldin_score-CoHiRF-top-down',
#  'real-adjusted_mutual_info-CoHiRF-top-down',
#  'real-adjusted_rand-CoHiRF-top-down',
#  'real-adjusted_rand-CoHiRF-top-down-inv',
#  'real-calinski_harabasz_score-CoHiRF-top-down',
#  'real-davies_bouldin_score-CoHiRF-top-down-inv',
#  'real-calinski_harabasz_score-CoHiRF-top-down-inv',
#  'real-adjusted_mutual_info-CoHiRF-top-down-inv',
#  'real-silhouette-CoHiRF-top-down-inv',
#  'real-silhouette-CoHiRF-top-down']

# %%
experiments_names = [exp for exp in experiment_names if exp.startswith("real-")]

# %%
query = "SELECT DISTINCT(key) FROM params WHERE key LIKE 'best/%%'"
best_params = pd.read_sql(query, engine)["key"].tolist()

# %%
params_columns = [
    "model",
    "dataset_id",
	"n_trials",
	"dataset_name",
	"standardize",
	"hpo_metric",
	"direction",
	"hpo_seed",
] + best_params

# %%
latest_metrics_columns = [
    "fit_model_return_elapsed_time",
    "max_memory_used_after_fit",
    "max_memory_used",
	"best/n_clusters_",
    "best/rand_score",
    "best/adjusted_rand",
    "best/mutual_info",
    "best/adjusted_mutual_info",
    "best/normalized_mutual_info",
    "best/homogeneity_completeness_v_measure",
    "best/silhouette",
    "best/calinski_harabasz_score",
    "best/davies_bouldin_score",
    "best/inertia_score",
    "best/homogeneity",
    "best/completeness",
    "best/v_measure",
    "best/elapsed_time",
]

# %%
tags_columns = ["raised_exception", "EXCEPTION", "mlflow.parentRunId", "Last step finished"]

# %%
runs_columns = ['run_uuid', 'status', 'start_time', 'end_time']
experiments_columns = []
other_table = 'params'
other_table_keys = params_columns
df_params = get_df_runs_from_mlflow_sql(engine, runs_columns=runs_columns, experiments_columns=experiments_columns, experiments_names=experiments_names, other_table=other_table, other_table_keys=other_table_keys)
df_latest_metrics = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='latest_metrics', other_table_keys=latest_metrics_columns)
df_tags = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='tags', other_table_keys=tags_columns)

# %%
dataset_characteristics = pd.read_csv(results_dir / "datasets_characteristics.csv", index_col=0)
dataset_characteristics.index = dataset_characteristics["openml_id"].astype(str)

# %%
df_runs_raw = df_params.join(df_latest_metrics)
df_runs_raw = df_runs_raw.join(df_tags)
df_runs_raw = df_runs_raw.join(dataset_characteristics, on='dataset_id', rsuffix='_dataset')
df_runs_raw.to_csv(results_dir / 'df_runs_raw_tgcc2.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_runs_raw = df_params.join(df_latest_metrics)
#       2 df_runs_raw = df_runs_raw.join(df_tags)
#       3 df_runs_raw = df_runs_raw.join(dataset_characteristics, on='dataset_id', rsuffix='_dataset')
#
# NameError: name 'df_params' is not defined

# %%
df_runs_raw = pd.read_csv(results_dir / "df_runs_raw_tgcc2.csv", index_col=0)
df_runs_raw["model"] = df_runs_raw["model"] + "-" + df_runs_raw["n_trials"].astype(str)
# mask = df_runs_raw["model"].str.contains("CoHiRF")
# df_runs_raw.loc[mask, "model"] = df_runs_raw.loc[mask].apply(lambda row: f"{row['model']}-{row['n_trials']}", axis=1)
df_runs_raw_parents = df_runs_raw.copy()
df_runs_raw_parents = df_runs_raw_parents.loc[df_runs_raw_parents["mlflow.parentRunId"].isna()]

# %%
df_runs_raw_parents.head(5)
# Out:
#                                     status     start_time      end_time  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea  FINISHED  1757511120768  1.757511e+12
# 00027aa26863479689cb9159eb05d27d  FINISHED  1759251752094  1.759254e+12
# 000ed0a4c2254d48a2ea293ecf9480b9  FINISHED  1761159995601  1.761160e+12
# 0016b21b09e44c7595b26130cbf448f9  FINISHED  1757524956961  1.757525e+12
# 001b3f77c3e44c12b14761e15c808ec9  FINISHED  1757510889568  1.757511e+12
#
#                                   best/base_model_kwargs/eps  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                         NaN
# 00027aa26863479689cb9159eb05d27d                         NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                         NaN
# 0016b21b09e44c7595b26130cbf448f9                         NaN
# 001b3f77c3e44c12b14761e15c808ec9                         NaN
#
#                                   best/base_model_kwargs/min_samples  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                 NaN
# 00027aa26863479689cb9159eb05d27d                                 NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                 NaN
# 0016b21b09e44c7595b26130cbf448f9                                 NaN
# 001b3f77c3e44c12b14761e15c808ec9                                 NaN
#
#                                   best/base_model_kwargs/n_clusters  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                NaN
# 00027aa26863479689cb9159eb05d27d                               21.0
# 000ed0a4c2254d48a2ea293ecf9480b9                                NaN
# 0016b21b09e44c7595b26130cbf448f9                                3.0
# 001b3f77c3e44c12b14761e15c808ec9                                NaN
#
#                                   best/base_model_kwargs/n_similarities  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                    NaN
# 00027aa26863479689cb9159eb05d27d                                    NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                    NaN
# 0016b21b09e44c7595b26130cbf448f9                                    NaN
# 001b3f77c3e44c12b14761e15c808ec9                                    NaN
#
#                                   best/base_model_kwargs/sampling_ratio  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                    NaN
# 00027aa26863479689cb9159eb05d27d                                    NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                    NaN
# 0016b21b09e44c7595b26130cbf448f9                                    NaN
# 001b3f77c3e44c12b14761e15c808ec9                                    NaN
#
#                                   best/base_model_kwargs/sc_n_clusters  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                                   NaN
# 00027aa26863479689cb9159eb05d27d                                   NaN
# 000ed0a4c2254d48a2ea293ecf9480b9                                   NaN
# 0016b21b09e44c7595b26130cbf448f9                                   NaN
# 001b3f77c3e44c12b14761e15c808ec9                                   NaN
#
#                                                  best/child_run_id  ...  \
# run_uuid                                                            ...
# 0001f124c40c40b6b902fcabc76e7eea  c854172d93d945b5b98d1d2e7f8b8244  ...
# 00027aa26863479689cb9159eb05d27d  c968bd4c602b4cc1b80ea7ebf3ef514a  ...
# 000ed0a4c2254d48a2ea293ecf9480b9  775080a847654e7885ed3003bbb9d622  ...
# 0016b21b09e44c7595b26130cbf448f9  318c5fee63ac48ee93c0f8897a15e567  ...
# 001b3f77c3e44c12b14761e15c808ec9  c3df07fdb54f487a922cb765d3b9c0a7  ...
#
#                                   EXCEPTION  Last step finished  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea        NaN                 NaN
# 00027aa26863479689cb9159eb05d27d        NaN                 NaN
# 000ed0a4c2254d48a2ea293ecf9480b9        NaN       _on_train_end
# 0016b21b09e44c7595b26130cbf448f9        NaN                 NaN
# 001b3f77c3e44c12b14761e15c808ec9        NaN                 NaN
#
#                                   mlflow.parentRunId  raised_exception  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea                 NaN             False
# 00027aa26863479689cb9159eb05d27d                 NaN             False
# 000ed0a4c2254d48a2ea293ecf9480b9                 NaN             False
# 0016b21b09e44c7595b26130cbf448f9                 NaN             False
# 001b3f77c3e44c12b14761e15c808ec9                 NaN             False
#
#                                         dataset  openml_id  n_instances  \
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea           iris         61          150
# 00027aa26863479689cb9159eb05d27d      mnist_784        554        70000
# 000ed0a4c2254d48a2ea293ecf9480b9        nursery       1568        12958
# 0016b21b09e44c7595b26130cbf448f9  golub-1999-v2      46780           72
# 001b3f77c3e44c12b14761e15c808ec9          ecoli         39          336
#
#                                   n_features  n_classes  n_categorical
# run_uuid
# 0001f124c40c40b6b902fcabc76e7eea           5          3              1
# 00027aa26863479689cb9159eb05d27d         785         10              1
# 000ed0a4c2254d48a2ea293ecf9480b9           9          4              9
# 0016b21b09e44c7595b26130cbf448f9        1869          3              0
# 001b3f77c3e44c12b14761e15c808ec9           8          8              1
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Delete duplicate runs (if any) and complete some models that cannot run with some datasets

# %%
non_duplicate_columns = [
    "model",
    "dataset_id",
	"standardize",
	"hpo_metric",
	"hpo_seed",
]
# df_runs_parents.loc[df_runs_parents["best/n_clusters_"]*0.5 > df_runs_parents["n_instances"], "best/adjusted_rand"] = 
df_runs_parents = df_runs_raw_parents.dropna(axis=0, how="all", subset=["best/adjusted_rand"]).copy()
# add back runs that were not evaluated because we judged too many clusters (but they run anyway)
# df_valid_runs = df_runs_raw_parents.loc[df_runs_raw_parents["best/n_clusters_"] > df_runs_raw_parents["n_instances"]*0.5].copy()
# df_runs_parents = pd.concat([df_runs_parents, df_valid_runs], axis=0)
df_runs_parents = df_runs_parents.loc[(~df_runs_parents.duplicated(non_duplicate_columns))]
# fill missing values with "None"
df_runs_parents = df_runs_parents.fillna("None")

# %%
# get number of children runs that raised exception for each parent run
children_exceptions = df_runs_raw.groupby("mlflow.parentRunId")["raised_exception"].sum()
df_runs_parents["n_children_raised_exception"] = df_runs_parents.index.map(children_exceptions).fillna(0)

# %%
df_runs_parents.loc[(df_runs_parents["n_children_raised_exception"] > 0) & (df_runs_parents["raised_exception"] == False) & (df_runs_parents["model"].str.find("SC-SRGF") == -1), ["dataset_id", "model", "hpo_metric", "n_children_raised_exception"]]
# Out:
#                                   dataset_id                 model  \
# run_uuid
# 0523d99695664a3294fa128a1eae79af         554      CoHiRF-DBSCAN-60
# 075cbb1e8b9f41a0b1b1cb54ff6673af          39    CoHiRF-top-down-60
# 08433992474241cdbe44aca2692cd7df         554      CoHiRF-DBSCAN-60
# 086989a27cdb467b85ed2248ce8b32d3         554      CoHiRF-DBSCAN-60
# 0abf67098276481cabbcb002ae6bdf84        1568    CoHiRF-top-down-60
# ...                                      ...                   ...
# f7504ad3ccad429e82fb12541282747b       40685    CoHiRF-top-down-60
# f84f03dfb6964911a05142a3072c699f        1568    CoHiRF-top-down-60
# fa554932b2f842d6833bc8331388e3f7       47039  BatchCoHiRF-1iter-60
# fe81e6a0ceac403db992df84e6e5d682          39    CoHiRF-top-down-60
# fe849da24195456587a6ea02aab9a0f3        1568    CoHiRF-top-down-60
#
#                                                hpo_metric  \
# run_uuid
# 0523d99695664a3294fa128a1eae79af  calinski_harabasz_score
# 075cbb1e8b9f41a0b1b1cb54ff6673af     davies_bouldin_score
# 08433992474241cdbe44aca2692cd7df     davies_bouldin_score
# 086989a27cdb467b85ed2248ce8b32d3  calinski_harabasz_score
# 0abf67098276481cabbcb002ae6bdf84  calinski_harabasz_score
# ...                                                   ...
# f7504ad3ccad429e82fb12541282747b  calinski_harabasz_score
# f84f03dfb6964911a05142a3072c699f     adjusted_mutual_info
# fa554932b2f842d6833bc8331388e3f7            adjusted_rand
# fe81e6a0ceac403db992df84e6e5d682     davies_bouldin_score
# fe849da24195456587a6ea02aab9a0f3               silhouette
#
#                                   n_children_raised_exception
# run_uuid
# 0523d99695664a3294fa128a1eae79af                            9
# 075cbb1e8b9f41a0b1b1cb54ff6673af                            4
# 08433992474241cdbe44aca2692cd7df                            2
# 086989a27cdb467b85ed2248ce8b32d3                            8
# 0abf67098276481cabbcb002ae6bdf84                            2
# ...                                                       ...
# f7504ad3ccad429e82fb12541282747b                            1
# f84f03dfb6964911a05142a3072c699f                            3
# fa554932b2f842d6833bc8331388e3f7                            7
# fe81e6a0ceac403db992df84e6e5d682                            4
# fe849da24195456587a6ea02aab9a0f3                            1
#
# [164 rows x 4 columns]

# %%
df_to_cat = []
hpo_metrics = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    "silhouette",
    "davies_bouldin_score",
    "normalized_mutual_info",
]
standardize = [True]
hpo_seed = [i for i in range(5)]
fill_value = pd.NA
fill_columns = ["best/adjusted_rand", "best/adjusted_mutual_info", "best/calinski_harabasz_score", "best/silhouette", "best/davies_bouldin_score", "best/normalized_mutual_info"]

# %%
# Too memory intensive
dataset_ids_to_complete = [182, 554, 1478, 1568, 40685]
model_names = ["CoHiRF-SC-SRGF-60", "SpectralSubspaceRandomization-60"]
for dataset_id in dataset_ids_to_complete:
	for model_name in model_names:
		for hpo_metric in hpo_metrics:
			for std in standardize:
				for seed in hpo_seed:
					new_row = {
						"dataset_id": dataset_id,
						"model": model_name,
						"hpo_metric": hpo_metric,
						"standardize": std,
						"hpo_seed": seed
					}
					for col in fill_columns:
						new_row[col] = fill_value
					df_to_cat.append(new_row)

# %%
# # Too few examples (<100) to run in batch
# dataset_ids_to_complete = [46773, 46774, 46775, 46776, 46777, 46779, 46780, 46781]
# model_names = [
#     "BatchCoHiRF-1iter-30",
#     "BatchCoHiRF-DBSCAN-1iter-30",
#     "BatchCoHiRF-SC-SRGF-30",
#     "BatchCoHiRF-KernelRBF-1iter-30",
#     "BatchCoHiRF-1iter-60",
# 	"BatchCoHiRF-DBSCAN-1iter-60",
# 	# "BatchCoHiRF-SC-SRGF-60",
# 	# "BatchCoHiRF-KernelRBF-1iter-60",
# ]
# for dataset_id in dataset_ids_to_complete:
# 	for model_name in model_names:
# 		for hpo_metric in hpo_metrics:
# 			for std in standardize:
# 				mask = (df_runs_parents["dataset_id"] == dataset_id) & (df_runs_parents["model"] == model_name) & (df_runs_parents["hpo_metric"] == hpo_metric) & (df_runs_parents["standardize"] == std)
# 				if not mask.any():
# 					new_row = {
# 						"dataset_id": dataset_id,
# 						"model": model_name,
# 						"hpo_metric": hpo_metric,
# 						"standardize": std,
# 					}
# 					for col in fill_columns:
# 						new_row[col] = fill_value
# 					df_to_cat.append(new_row)

# %%
# # Too many examples for IRFLLRR
# dataset_ids_to_complete = [40685]
# model_names = [
#     "IRFLLRR-30",
#     "IRFLLRR-60",
# ]
# hpo_metrics = ["adjusted_rand", "adjusted_mutual_info", "calinski_harabasz_score", "silhouette", "davies_bouldin_score", "normalized_mutual_info"]
# standardize = [True]
# fill_value = pd.NA
# fill_columns = ["best/adjusted_rand", "best/adjusted_mutual_info", "best/calinski_harabasz_score", "best/silhouette", "best/davies_bouldin_score", "best/normalized_mutual_info"]
# for dataset_id in dataset_ids_to_complete:
#     for model_name in model_names:
#         for hpo_metric in hpo_metrics:
#             for std in standardize:
#                 mask = (
#                     (df_runs_parents["dataset_id"] == dataset_id)
#                     & (df_runs_parents["model"] == model_name)
#                     & (df_runs_parents["hpo_metric"] == hpo_metric)
#                     & (df_runs_parents["standardize"] == std)
#                 )
#                 if not mask.any():
#                     new_row = {
#                         "dataset_id": dataset_id,
#                         "model": model_name,
#                         "hpo_metric": hpo_metric,
#                         "standardize": std,
#                     }
#                     for col in fill_columns:
#                         new_row[col] = fill_value
#                     df_to_cat.append(new_row)

# %%
df_runs_parents = pd.concat([df_runs_parents, pd.DataFrame(df_to_cat)], axis=0)

# %% [markdown]
# # Slow / Memory intensive datasets/models

# %%
df = df_runs_parents.copy()
df = df[["model", "dataset_id", "max_memory_used", "max_memory_used_after_fit"]]
df = df.sort_values(by="max_memory_used", ascending=False)
high_mem_tuples = df.loc[df["max_memory_used"] > 10000].copy()
high_mem_tuples = high_mem_tuples[["model", "dataset_id"]]

# %%
df
# Out:
#                                                              model  \
# 8002d12704c142ff99021098b82ac3a7                  CoHiRF-DBSCAN-60
# 569719f398044e5d8b5056c702355584                  CoHiRF-DBSCAN-60
# 640e3f59ca4144e68cc3a497d7787280                  CoHiRF-DBSCAN-60
# a5f9c8d0d9ca497ca067be35b8cb5b3e                  CoHiRF-DBSCAN-60
# 02ec0fef9d864abd8da2ac7adeb7d505                  CoHiRF-DBSCAN-60
# ...                                                            ...
# 295                               SpectralSubspaceRandomization-60
# 296                               SpectralSubspaceRandomization-60
# 297                               SpectralSubspaceRandomization-60
# 298                               SpectralSubspaceRandomization-60
# 299                               SpectralSubspaceRandomization-60
#
#                                   dataset_id  max_memory_used  \
# 8002d12704c142ff99021098b82ac3a7       40685        52893.696
# 569719f398044e5d8b5056c702355584       40685        52854.720
# 640e3f59ca4144e68cc3a497d7787280       40685        52814.868
# a5f9c8d0d9ca497ca067be35b8cb5b3e       40685        52742.684
# 02ec0fef9d864abd8da2ac7adeb7d505       40685        51440.404
# ...                                      ...              ...
# 295                                    40685              NaN
# 296                                    40685              NaN
# 297                                    40685              NaN
# 298                                    40685              NaN
# 299                                    40685              NaN
#
#                                   max_memory_used_after_fit
# 8002d12704c142ff99021098b82ac3a7                  52893.696
# 569719f398044e5d8b5056c702355584                  52854.720
# 640e3f59ca4144e68cc3a497d7787280                  52814.868
# a5f9c8d0d9ca497ca067be35b8cb5b3e                  52742.684
# 02ec0fef9d864abd8da2ac7adeb7d505                  51440.404
# ...                                                     ...
# 295                                                     NaN
# 296                                                     NaN
# 297                                                     NaN
# 298                                                     NaN
# 299                                                     NaN
#
# [7090 rows x 4 columns]

# %%
model_nickname = [
    # "AffinityPropagation",
    # "AverageAgglomerativeClustering",
    # "BatchCoHiRF",
    "BatchCoHiRF-1iter",
    # "BatchCoHiRF-DBSCAN",
    "BatchCoHiRF-DBSCAN-1iter",
    "BatchCoHiRF-KernelRBF-1iter",
    "BatchCoHiRF-SC-SRGF",
    # "Clique",
    "CoHiRF",
    "CoHiRF-DBSCAN",
    "CoHiRF-KernelRBF",
    # "CompleteAgglomerativeClustering",
    "DBSCAN",
    # "HDBSCAN",
    # "IRFLLRR",
    "KMeans",
    # "KMeansProj",
    "KernelRBFKMeans",
    # "MeanShift",
    # "OPTICS",
    # "Proclus",
    # "SingleAgglomerativeClustering",
    # "SpectralClustering",
    "SpectralSubspaceRandomization",
    # "WardAgglomerativeClustering",
]

# %%
dataset_id = [
    39,
    61,
    182,
    1478,
    1568,
    40685,
    40984,
    46773,
    46774,
    46775,
    46776,
    46777,
    46778,
    46779,
    46780,
    46781,
    46782,
    46783,
    554,
]

# %%
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "normalized_mutual_info",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    "silhouette",
    "davies_bouldin_score",
]

# %%
# from itertools import product
# combinations_keys = ["model", "dataset_id", "hpo_metric", "standardize"]
# combinations = product(model_nickname, dataset_id, hpo_metric, standardize)
# combination_list = [dict(zip(combinations_keys, comb)) for comb in combinations]
# df_combination = pd.DataFrame(combination_list)
# # exclude slow/mem intensive runs
# # df_combination = df_combination.merge(
# # 	high_mem_tuples, on=["model", "dataset_id"], how="left", indicator=True
# # )
# # df_combination = df_combination.loc[df_combination["_merge"] == "left_only"].drop(columns=["_merge"])
# # get only slow/mem intensive runs
# df_combination = df_combination.merge(high_mem_tuples, on=["model", "dataset_id"], how="left", indicator=True)
# df_combination = df_combination.loc[df_combination["_merge"] == "both"].drop(columns=["_merge"])
# runs_dict = {}
# for model in df_combination["model"].unique():
#     sub = df_combination[df_combination["model"] == model].drop(columns=["model"])
#     # standardize = True
#     sub_standardized = sub.loc[sub["standardize"] == True].copy()
#     sub_standardized["standardize"] = ""
#     sub_standardized_dict = sub_standardized.to_dict(orient="records")
#     # standardize = False
#     sub_not_standardized = sub.loc[sub["standardize"] == False].copy()
#     sub_not_standardized.drop(columns=["standardize"], inplace=True)
#     sub_not_standardized_dict = sub_not_standardized.to_dict(orient="records")
#     # combine both dictionaries
#     runs_dict[model] = sub_standardized_dict + sub_not_standardized_dict
# if len(runs_dict) != 0:
#     with open(results_dir / "runs_dict.pkl", "wb") as f:
#         pickle.dump(runs_dict, f)

# %%
df_runs_raw.head(5)
# Out:
#                                     status     start_time      end_time  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef  FINISHED  1757711218952  1.757711e+12
# 0000219091d04b54b2deb488d80372cb  FINISHED  1757519633653  1.757520e+12
# 0000328e9d8c48a2b65b0b0068626eff  FINISHED  1757513591211  1.757514e+12
# 0000ed82407546de89923a2ae5c18f40  FINISHED  1757766655932  1.757767e+12
# 00018ba47c2c4d358096ab82decc67d1    FAILED  1757725820112  1.757730e+12
#
#                                   best/base_model_kwargs/eps  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                         NaN
# 0000219091d04b54b2deb488d80372cb                         NaN
# 0000328e9d8c48a2b65b0b0068626eff                         NaN
# 0000ed82407546de89923a2ae5c18f40                         NaN
# 00018ba47c2c4d358096ab82decc67d1                         NaN
#
#                                   best/base_model_kwargs/min_samples  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                                 NaN
# 0000219091d04b54b2deb488d80372cb                                 NaN
# 0000328e9d8c48a2b65b0b0068626eff                                 NaN
# 0000ed82407546de89923a2ae5c18f40                                 NaN
# 00018ba47c2c4d358096ab82decc67d1                                 NaN
#
#                                   best/base_model_kwargs/n_clusters  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                                NaN
# 0000219091d04b54b2deb488d80372cb                                NaN
# 0000328e9d8c48a2b65b0b0068626eff                                NaN
# 0000ed82407546de89923a2ae5c18f40                                NaN
# 00018ba47c2c4d358096ab82decc67d1                                NaN
#
#                                   best/base_model_kwargs/n_similarities  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                                    NaN
# 0000219091d04b54b2deb488d80372cb                                    NaN
# 0000328e9d8c48a2b65b0b0068626eff                                    NaN
# 0000ed82407546de89923a2ae5c18f40                                    NaN
# 00018ba47c2c4d358096ab82decc67d1                                    NaN
#
#                                   best/base_model_kwargs/sampling_ratio  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                                    NaN
# 0000219091d04b54b2deb488d80372cb                                    NaN
# 0000328e9d8c48a2b65b0b0068626eff                                    NaN
# 0000ed82407546de89923a2ae5c18f40                                    NaN
# 00018ba47c2c4d358096ab82decc67d1                                    NaN
#
#                                   best/base_model_kwargs/sc_n_clusters  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                                   NaN
# 0000219091d04b54b2deb488d80372cb                                   NaN
# 0000328e9d8c48a2b65b0b0068626eff                                   NaN
# 0000ed82407546de89923a2ae5c18f40                                   NaN
# 00018ba47c2c4d358096ab82decc67d1                                   NaN
#
#                                  best/child_run_id  ...  \
# run_uuid                                            ...
# 0000208c805246b99faffa1de27af1ef               NaN  ...
# 0000219091d04b54b2deb488d80372cb               NaN  ...
# 0000328e9d8c48a2b65b0b0068626eff               NaN  ...
# 0000ed82407546de89923a2ae5c18f40               NaN  ...
# 00018ba47c2c4d358096ab82decc67d1               NaN  ...
#
#                                                                           EXCEPTION  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                                                NaN
# 0000219091d04b54b2deb488d80372cb                                                NaN
# 0000328e9d8c48a2b65b0b0068626eff                                                NaN
# 0000ed82407546de89923a2ae5c18f40                                                NaN
# 00018ba47c2c4d358096ab82decc67d1  Expected n_neighbors <= n_samples_fit, but n_n...
#
#                                   Last step finished  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef                 NaN
# 0000219091d04b54b2deb488d80372cb                 NaN
# 0000328e9d8c48a2b65b0b0068626eff                 NaN
# 0000ed82407546de89923a2ae5c18f40                 NaN
# 00018ba47c2c4d358096ab82decc67d1                 NaN
#
#                                                 mlflow.parentRunId  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef  60d4079cf33149eea4faeb9dd9edcd76
# 0000219091d04b54b2deb488d80372cb  6a51f509c15c4027b51831a6932f1da1
# 0000328e9d8c48a2b65b0b0068626eff  5aa95abbcb3348e0bbb0c8f13ca888d6
# 0000ed82407546de89923a2ae5c18f40  147979577e7c40368773e106a98585b4
# 00018ba47c2c4d358096ab82decc67d1  895d17c603cf4e1e81430030acf2933b
#
#                                   raised_exception              dataset  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef             False            khan-2001
# 0000219091d04b54b2deb488d80372cb             False          bredel-2005
# 0000328e9d8c48a2b65b0b0068626eff             False             satimage
# 0000ed82407546de89923a2ae5c18f40             False                  har
# 00018ba47c2c4d358096ab82decc67d1              True  binary_alpha_digits
#
#                                   openml_id  n_instances  n_features  \
# run_uuid
# 0000208c805246b99faffa1de27af1ef      46781           83        1070
# 0000219091d04b54b2deb488d80372cb      46777           50        1740
# 0000328e9d8c48a2b65b0b0068626eff        182         6430          37
# 0000ed82407546de89923a2ae5c18f40       1478        10299         562
# 00018ba47c2c4d358096ab82decc67d1      46782         1404         321
#
#                                   n_classes  n_categorical
# run_uuid
# 0000208c805246b99faffa1de27af1ef          4              0
# 0000219091d04b54b2deb488d80372cb          3              0
# 0000328e9d8c48a2b65b0b0068626eff          6              1
# 0000ed82407546de89923a2ae5c18f40          6              1
# 00018ba47c2c4d358096ab82decc67d1         36              0
#
# [5 rows x 64 columns]

# %% [markdown]
# # Missing

# %%
df = df_runs_parents.copy()
df = df.loc[df["model"] == "BatchCoHiRF-SC-SRGF-1iter-60"]
df = df.loc[df["dataset_id"] == 40685]
df
# Out:
#                                     status    start_time      end_time  \
# 13d74a0a35a149258003a50224eaec8a  FINISHED  1.760610e+12  1.760637e+12
# 15718296e50c492fbc450ff2f1041b2b  FINISHED  1.760610e+12  1.760633e+12
# 188a09ec8f744c7e8b4f1dbc6528ba66  FINISHED  1.760610e+12  1.760638e+12
# 2747789790104448ae6876643a5fe49c  FINISHED  1.760610e+12  1.760645e+12
# 2dce548e975c4e2392d7662076dfaaaa  FINISHED  1.760610e+12  1.760639e+12
# 2e4a96562c1b4e2c995719c9fd074353  FINISHED  1.760521e+12  1.760545e+12
# 342dd1052eb5415db3081955d28ba35c  FINISHED  1.760610e+12  1.760637e+12
# 60c8265022f5421680ce4cde8ba54619  FINISHED  1.760610e+12  1.760637e+12
# 704f3aecfdbd451bab9c519bf6173b60  FINISHED  1.760610e+12  1.760635e+12
# 7aed72d246b2439b86981eac048bffcb  FINISHED  1.760610e+12  1.760648e+12
# 7ddb82eaf1094950a4a1fdba967c7b7c  FINISHED  1.760610e+12  1.760640e+12
# 848fb35cba004368b434c33ff5e122b0  FINISHED  1.760610e+12  1.760637e+12
# 864dbf1b7a5c457480f7f25a9e7e9d7b  FINISHED  1.760610e+12  1.760634e+12
# 8e45d75efc3b4552bd756dc55223123b  FINISHED  1.760610e+12  1.760646e+12
# 940c81d098c44970abd4bb3439bf86ff  FINISHED  1.760610e+12  1.760635e+12
# 9774e1575fab4bcc998ec5148231fded  FINISHED  1.760610e+12  1.760636e+12
# 9ce408d199634fd4b2b2d09702eb2814  FINISHED  1.760610e+12  1.760631e+12
# af8336d3176846168f06b5ab33fc9b2a  FINISHED  1.760610e+12  1.760634e+12
# b90fa16a20b74f56983f6fd05e36c864  FINISHED  1.760610e+12  1.760635e+12
# d87b50fd4dcd4d19934d638175118e9f  FINISHED  1.760610e+12  1.760636e+12
# e0ca054b55ee43028a2682402d521657  FINISHED  1.760610e+12  1.760636e+12
# ede9bb3f15ac4596b6b09dad20da209c  FINISHED  1.760610e+12  1.760648e+12
# ee6e90bb382a4fcb92d286c760da2a9c  FINISHED  1.760610e+12  1.760642e+12
# efadaf9b96da445e80ca557393cbf3ac  FINISHED  1.760610e+12  1.760633e+12
# f0fb1cab62e0497aac27be2e8d1f8a00  FINISHED  1.760610e+12  1.760636e+12
#
#                                  best/base_model_kwargs/eps  \
# 13d74a0a35a149258003a50224eaec8a                       None
# 15718296e50c492fbc450ff2f1041b2b                       None
# 188a09ec8f744c7e8b4f1dbc6528ba66                       None
# 2747789790104448ae6876643a5fe49c                       None
# 2dce548e975c4e2392d7662076dfaaaa                       None
# 2e4a96562c1b4e2c995719c9fd074353                       None
# 342dd1052eb5415db3081955d28ba35c                       None
# 60c8265022f5421680ce4cde8ba54619                       None
# 704f3aecfdbd451bab9c519bf6173b60                       None
# 7aed72d246b2439b86981eac048bffcb                       None
# 7ddb82eaf1094950a4a1fdba967c7b7c                       None
# 848fb35cba004368b434c33ff5e122b0                       None
# 864dbf1b7a5c457480f7f25a9e7e9d7b                       None
# 8e45d75efc3b4552bd756dc55223123b                       None
# 940c81d098c44970abd4bb3439bf86ff                       None
# 9774e1575fab4bcc998ec5148231fded                       None
# 9ce408d199634fd4b2b2d09702eb2814                       None
# af8336d3176846168f06b5ab33fc9b2a                       None
# b90fa16a20b74f56983f6fd05e36c864                       None
# d87b50fd4dcd4d19934d638175118e9f                       None
# e0ca054b55ee43028a2682402d521657                       None
# ede9bb3f15ac4596b6b09dad20da209c                       None
# ee6e90bb382a4fcb92d286c760da2a9c                       None
# efadaf9b96da445e80ca557393cbf3ac                       None
# f0fb1cab62e0497aac27be2e8d1f8a00                       None
#
#                                  best/base_model_kwargs/min_samples  \
# 13d74a0a35a149258003a50224eaec8a                               None
# 15718296e50c492fbc450ff2f1041b2b                               None
# 188a09ec8f744c7e8b4f1dbc6528ba66                               None
# 2747789790104448ae6876643a5fe49c                               None
# 2dce548e975c4e2392d7662076dfaaaa                               None
# 2e4a96562c1b4e2c995719c9fd074353                               None
# 342dd1052eb5415db3081955d28ba35c                               None
# 60c8265022f5421680ce4cde8ba54619                               None
# 704f3aecfdbd451bab9c519bf6173b60                               None
# 7aed72d246b2439b86981eac048bffcb                               None
# 7ddb82eaf1094950a4a1fdba967c7b7c                               None
# 848fb35cba004368b434c33ff5e122b0                               None
# 864dbf1b7a5c457480f7f25a9e7e9d7b                               None
# 8e45d75efc3b4552bd756dc55223123b                               None
# 940c81d098c44970abd4bb3439bf86ff                               None
# 9774e1575fab4bcc998ec5148231fded                               None
# 9ce408d199634fd4b2b2d09702eb2814                               None
# af8336d3176846168f06b5ab33fc9b2a                               None
# b90fa16a20b74f56983f6fd05e36c864                               None
# d87b50fd4dcd4d19934d638175118e9f                               None
# e0ca054b55ee43028a2682402d521657                               None
# ede9bb3f15ac4596b6b09dad20da209c                               None
# ee6e90bb382a4fcb92d286c760da2a9c                               None
# efadaf9b96da445e80ca557393cbf3ac                               None
# f0fb1cab62e0497aac27be2e8d1f8a00                               None
#
#                                  best/base_model_kwargs/n_clusters  \
# 13d74a0a35a149258003a50224eaec8a                              None
# 15718296e50c492fbc450ff2f1041b2b                              None
# 188a09ec8f744c7e8b4f1dbc6528ba66                              None
# 2747789790104448ae6876643a5fe49c                              None
# 2dce548e975c4e2392d7662076dfaaaa                              None
# 2e4a96562c1b4e2c995719c9fd074353                              None
# 342dd1052eb5415db3081955d28ba35c                              None
# 60c8265022f5421680ce4cde8ba54619                              None
# 704f3aecfdbd451bab9c519bf6173b60                              None
# 7aed72d246b2439b86981eac048bffcb                              None
# 7ddb82eaf1094950a4a1fdba967c7b7c                              None
# 848fb35cba004368b434c33ff5e122b0                              None
# 864dbf1b7a5c457480f7f25a9e7e9d7b                              None
# 8e45d75efc3b4552bd756dc55223123b                              None
# 940c81d098c44970abd4bb3439bf86ff                              None
# 9774e1575fab4bcc998ec5148231fded                              None
# 9ce408d199634fd4b2b2d09702eb2814                              None
# af8336d3176846168f06b5ab33fc9b2a                              None
# b90fa16a20b74f56983f6fd05e36c864                              None
# d87b50fd4dcd4d19934d638175118e9f                              None
# e0ca054b55ee43028a2682402d521657                              None
# ede9bb3f15ac4596b6b09dad20da209c                              None
# ee6e90bb382a4fcb92d286c760da2a9c                              None
# efadaf9b96da445e80ca557393cbf3ac                              None
# f0fb1cab62e0497aac27be2e8d1f8a00                              None
#
#                                  best/base_model_kwargs/n_similarities  \
# 13d74a0a35a149258003a50224eaec8a                                  None
# 15718296e50c492fbc450ff2f1041b2b                                  None
# 188a09ec8f744c7e8b4f1dbc6528ba66                                  None
# 2747789790104448ae6876643a5fe49c                                  None
# 2dce548e975c4e2392d7662076dfaaaa                                  None
# 2e4a96562c1b4e2c995719c9fd074353                                  None
# 342dd1052eb5415db3081955d28ba35c                                  None
# 60c8265022f5421680ce4cde8ba54619                                  None
# 704f3aecfdbd451bab9c519bf6173b60                                  None
# 7aed72d246b2439b86981eac048bffcb                                  None
# 7ddb82eaf1094950a4a1fdba967c7b7c                                  None
# 848fb35cba004368b434c33ff5e122b0                                  None
# 864dbf1b7a5c457480f7f25a9e7e9d7b                                  None
# 8e45d75efc3b4552bd756dc55223123b                                  None
# 940c81d098c44970abd4bb3439bf86ff                                  None
# 9774e1575fab4bcc998ec5148231fded                                  None
# 9ce408d199634fd4b2b2d09702eb2814                                  None
# af8336d3176846168f06b5ab33fc9b2a                                  None
# b90fa16a20b74f56983f6fd05e36c864                                  None
# d87b50fd4dcd4d19934d638175118e9f                                  None
# e0ca054b55ee43028a2682402d521657                                  None
# ede9bb3f15ac4596b6b09dad20da209c                                  None
# ee6e90bb382a4fcb92d286c760da2a9c                                  None
# efadaf9b96da445e80ca557393cbf3ac                                  None
# f0fb1cab62e0497aac27be2e8d1f8a00                                  None
#
#                                  best/base_model_kwargs/sampling_ratio  \
# 13d74a0a35a149258003a50224eaec8a                                  None
# 15718296e50c492fbc450ff2f1041b2b                                  None
# 188a09ec8f744c7e8b4f1dbc6528ba66                                  None
# 2747789790104448ae6876643a5fe49c                                  None
# 2dce548e975c4e2392d7662076dfaaaa                                  None
# 2e4a96562c1b4e2c995719c9fd074353                                  None
# 342dd1052eb5415db3081955d28ba35c                                  None
# 60c8265022f5421680ce4cde8ba54619                                  None
# 704f3aecfdbd451bab9c519bf6173b60                                  None
# 7aed72d246b2439b86981eac048bffcb                                  None
# 7ddb82eaf1094950a4a1fdba967c7b7c                                  None
# 848fb35cba004368b434c33ff5e122b0                                  None
# 864dbf1b7a5c457480f7f25a9e7e9d7b                                  None
# 8e45d75efc3b4552bd756dc55223123b                                  None
# 940c81d098c44970abd4bb3439bf86ff                                  None
# 9774e1575fab4bcc998ec5148231fded                                  None
# 9ce408d199634fd4b2b2d09702eb2814                                  None
# af8336d3176846168f06b5ab33fc9b2a                                  None
# b90fa16a20b74f56983f6fd05e36c864                                  None
# d87b50fd4dcd4d19934d638175118e9f                                  None
# e0ca054b55ee43028a2682402d521657                                  None
# ede9bb3f15ac4596b6b09dad20da209c                                  None
# ee6e90bb382a4fcb92d286c760da2a9c                                  None
# efadaf9b96da445e80ca557393cbf3ac                                  None
# f0fb1cab62e0497aac27be2e8d1f8a00                                  None
#
#                                  best/base_model_kwargs/sc_n_clusters  \
# 13d74a0a35a149258003a50224eaec8a                                 None
# 15718296e50c492fbc450ff2f1041b2b                                 None
# 188a09ec8f744c7e8b4f1dbc6528ba66                                 None
# 2747789790104448ae6876643a5fe49c                                 None
# 2dce548e975c4e2392d7662076dfaaaa                                 None
# 2e4a96562c1b4e2c995719c9fd074353                                 None
# 342dd1052eb5415db3081955d28ba35c                                 None
# 60c8265022f5421680ce4cde8ba54619                                 None
# 704f3aecfdbd451bab9c519bf6173b60                                 None
# 7aed72d246b2439b86981eac048bffcb                                 None
# 7ddb82eaf1094950a4a1fdba967c7b7c                                 None
# 848fb35cba004368b434c33ff5e122b0                                 None
# 864dbf1b7a5c457480f7f25a9e7e9d7b                                 None
# 8e45d75efc3b4552bd756dc55223123b                                 None
# 940c81d098c44970abd4bb3439bf86ff                                 None
# 9774e1575fab4bcc998ec5148231fded                                 None
# 9ce408d199634fd4b2b2d09702eb2814                                 None
# af8336d3176846168f06b5ab33fc9b2a                                 None
# b90fa16a20b74f56983f6fd05e36c864                                 None
# d87b50fd4dcd4d19934d638175118e9f                                 None
# e0ca054b55ee43028a2682402d521657                                 None
# ede9bb3f15ac4596b6b09dad20da209c                                 None
# ee6e90bb382a4fcb92d286c760da2a9c                                 None
# efadaf9b96da445e80ca557393cbf3ac                                 None
# f0fb1cab62e0497aac27be2e8d1f8a00                                 None
#
#                                                  best/child_run_id  ...  \
# 13d74a0a35a149258003a50224eaec8a  43b369e06e004816a7c7ccd116eda6ab  ...
# 15718296e50c492fbc450ff2f1041b2b  fca881bee1784d00a5a770528cfaa187  ...
# 188a09ec8f744c7e8b4f1dbc6528ba66  d7dda8649df94288bc168d898c14f096  ...
# 2747789790104448ae6876643a5fe49c  c028a35d6c4d46be8c5de564fd9aebce  ...
# 2dce548e975c4e2392d7662076dfaaaa  30ba366c81954233bbbc7af20bdeb164  ...
# 2e4a96562c1b4e2c995719c9fd074353  7ff74e173713447ba9d5c71022c7c2c6  ...
# 342dd1052eb5415db3081955d28ba35c  f0094f15cb4644139ff5901dd1af02e4  ...
# 60c8265022f5421680ce4cde8ba54619  2c632b3ee8e44f54aea6eb5eaff9cb56  ...
# 704f3aecfdbd451bab9c519bf6173b60  69000ffc0d96498fa6396ffdc9285e50  ...
# 7aed72d246b2439b86981eac048bffcb  5f08267fb45f4cabbc87cd90cec23e85  ...
# 7ddb82eaf1094950a4a1fdba967c7b7c  c8d0137ad248408da8b4ef2e115c38c2  ...
# 848fb35cba004368b434c33ff5e122b0  ecb4521778bc4770bce027233641b4a8  ...
# 864dbf1b7a5c457480f7f25a9e7e9d7b  fdb2a97e795b4763a7f02c5027c9e3ef  ...
# 8e45d75efc3b4552bd756dc55223123b  645c0a0e8a5d46d5b257d69cdc8c4824  ...
# 940c81d098c44970abd4bb3439bf86ff  1785e265555d4a2fa222f830333fd8c4  ...
# 9774e1575fab4bcc998ec5148231fded  c9390a877c0d4974b3d41b7852c16897  ...
# 9ce408d199634fd4b2b2d09702eb2814  5605b669b7a34e04b4cefcb42d936db7  ...
# af8336d3176846168f06b5ab33fc9b2a  a45fd5053f164fefbede9a3ee7f17000  ...
# b90fa16a20b74f56983f6fd05e36c864  50f22c67e9bd453fa6fa4404133b4dae  ...
# d87b50fd4dcd4d19934d638175118e9f  acbaaae9311f445bb5140bbd8d491cdc  ...
# e0ca054b55ee43028a2682402d521657  75c6c102fbdb40169ab4c05dc2bea136  ...
# ede9bb3f15ac4596b6b09dad20da209c  040e457459714298b3f0acda6606dca5  ...
# ee6e90bb382a4fcb92d286c760da2a9c  ff5052f62cc14473a8ad5845bdf1885e  ...
# efadaf9b96da445e80ca557393cbf3ac  52c67fecbc064e20b68e840cbddfe5d9  ...
# f0fb1cab62e0497aac27be2e8d1f8a00  5c474019cfbe4abcb9bdb55558093c91  ...
#
#                                  Last step finished mlflow.parentRunId  \
# 13d74a0a35a149258003a50224eaec8a      _on_train_end               None
# 15718296e50c492fbc450ff2f1041b2b      _on_train_end               None
# 188a09ec8f744c7e8b4f1dbc6528ba66      _on_train_end               None
# 2747789790104448ae6876643a5fe49c      _on_train_end               None
# 2dce548e975c4e2392d7662076dfaaaa      _on_train_end               None
# 2e4a96562c1b4e2c995719c9fd074353      _on_train_end               None
# 342dd1052eb5415db3081955d28ba35c      _on_train_end               None
# 60c8265022f5421680ce4cde8ba54619      _on_train_end               None
# 704f3aecfdbd451bab9c519bf6173b60      _on_train_end               None
# 7aed72d246b2439b86981eac048bffcb      _on_train_end               None
# 7ddb82eaf1094950a4a1fdba967c7b7c      _on_train_end               None
# 848fb35cba004368b434c33ff5e122b0      _on_train_end               None
# 864dbf1b7a5c457480f7f25a9e7e9d7b      _on_train_end               None
# 8e45d75efc3b4552bd756dc55223123b      _on_train_end               None
# 940c81d098c44970abd4bb3439bf86ff      _on_train_end               None
# 9774e1575fab4bcc998ec5148231fded      _on_train_end               None
# 9ce408d199634fd4b2b2d09702eb2814      _on_train_end               None
# af8336d3176846168f06b5ab33fc9b2a      _on_train_end               None
# b90fa16a20b74f56983f6fd05e36c864      _on_train_end               None
# d87b50fd4dcd4d19934d638175118e9f      _on_train_end               None
# e0ca054b55ee43028a2682402d521657      _on_train_end               None
# ede9bb3f15ac4596b6b09dad20da209c      _on_train_end               None
# ee6e90bb382a4fcb92d286c760da2a9c      _on_train_end               None
# efadaf9b96da445e80ca557393cbf3ac      _on_train_end               None
# f0fb1cab62e0497aac27be2e8d1f8a00      _on_train_end               None
#
#                                  raised_exception  dataset openml_id  \
# 13d74a0a35a149258003a50224eaec8a            False  shuttle   40685.0
# 15718296e50c492fbc450ff2f1041b2b            False  shuttle   40685.0
# 188a09ec8f744c7e8b4f1dbc6528ba66            False  shuttle   40685.0
# 2747789790104448ae6876643a5fe49c            False  shuttle   40685.0
# 2dce548e975c4e2392d7662076dfaaaa            False  shuttle   40685.0
# 2e4a96562c1b4e2c995719c9fd074353            False  shuttle   40685.0
# 342dd1052eb5415db3081955d28ba35c            False  shuttle   40685.0
# 60c8265022f5421680ce4cde8ba54619            False  shuttle   40685.0
# 704f3aecfdbd451bab9c519bf6173b60            False  shuttle   40685.0
# 7aed72d246b2439b86981eac048bffcb            False  shuttle   40685.0
# 7ddb82eaf1094950a4a1fdba967c7b7c            False  shuttle   40685.0
# 848fb35cba004368b434c33ff5e122b0            False  shuttle   40685.0
# 864dbf1b7a5c457480f7f25a9e7e9d7b            False  shuttle   40685.0
# 8e45d75efc3b4552bd756dc55223123b            False  shuttle   40685.0
# 940c81d098c44970abd4bb3439bf86ff            False  shuttle   40685.0
# 9774e1575fab4bcc998ec5148231fded            False  shuttle   40685.0
# 9ce408d199634fd4b2b2d09702eb2814            False  shuttle   40685.0
# af8336d3176846168f06b5ab33fc9b2a            False  shuttle   40685.0
# b90fa16a20b74f56983f6fd05e36c864            False  shuttle   40685.0
# d87b50fd4dcd4d19934d638175118e9f            False  shuttle   40685.0
# e0ca054b55ee43028a2682402d521657            False  shuttle   40685.0
# ede9bb3f15ac4596b6b09dad20da209c            False  shuttle   40685.0
# ee6e90bb382a4fcb92d286c760da2a9c            False  shuttle   40685.0
# efadaf9b96da445e80ca557393cbf3ac            False  shuttle   40685.0
# f0fb1cab62e0497aac27be2e8d1f8a00            False  shuttle   40685.0
#
#                                  n_instances n_features n_classes  \
# 13d74a0a35a149258003a50224eaec8a     58000.0       10.0       7.0
# 15718296e50c492fbc450ff2f1041b2b     58000.0       10.0       7.0
# 188a09ec8f744c7e8b4f1dbc6528ba66     58000.0       10.0       7.0
# 2747789790104448ae6876643a5fe49c     58000.0       10.0       7.0
# 2dce548e975c4e2392d7662076dfaaaa     58000.0       10.0       7.0
# 2e4a96562c1b4e2c995719c9fd074353     58000.0       10.0       7.0
# 342dd1052eb5415db3081955d28ba35c     58000.0       10.0       7.0
# 60c8265022f5421680ce4cde8ba54619     58000.0       10.0       7.0
# 704f3aecfdbd451bab9c519bf6173b60     58000.0       10.0       7.0
# 7aed72d246b2439b86981eac048bffcb     58000.0       10.0       7.0
# 7ddb82eaf1094950a4a1fdba967c7b7c     58000.0       10.0       7.0
# 848fb35cba004368b434c33ff5e122b0     58000.0       10.0       7.0
# 864dbf1b7a5c457480f7f25a9e7e9d7b     58000.0       10.0       7.0
# 8e45d75efc3b4552bd756dc55223123b     58000.0       10.0       7.0
# 940c81d098c44970abd4bb3439bf86ff     58000.0       10.0       7.0
# 9774e1575fab4bcc998ec5148231fded     58000.0       10.0       7.0
# 9ce408d199634fd4b2b2d09702eb2814     58000.0       10.0       7.0
# af8336d3176846168f06b5ab33fc9b2a     58000.0       10.0       7.0
# b90fa16a20b74f56983f6fd05e36c864     58000.0       10.0       7.0
# d87b50fd4dcd4d19934d638175118e9f     58000.0       10.0       7.0
# e0ca054b55ee43028a2682402d521657     58000.0       10.0       7.0
# ede9bb3f15ac4596b6b09dad20da209c     58000.0       10.0       7.0
# ee6e90bb382a4fcb92d286c760da2a9c     58000.0       10.0       7.0
# efadaf9b96da445e80ca557393cbf3ac     58000.0       10.0       7.0
# f0fb1cab62e0497aac27be2e8d1f8a00     58000.0       10.0       7.0
#
#                                  n_categorical n_children_raised_exception
# 13d74a0a35a149258003a50224eaec8a           1.0                         0.0
# 15718296e50c492fbc450ff2f1041b2b           1.0                         0.0
# 188a09ec8f744c7e8b4f1dbc6528ba66           1.0                         0.0
# 2747789790104448ae6876643a5fe49c           1.0                         0.0
# 2dce548e975c4e2392d7662076dfaaaa           1.0                         0.0
# 2e4a96562c1b4e2c995719c9fd074353           1.0                         0.0
# 342dd1052eb5415db3081955d28ba35c           1.0                         0.0
# 60c8265022f5421680ce4cde8ba54619           1.0                         0.0
# 704f3aecfdbd451bab9c519bf6173b60           1.0                         0.0
# 7aed72d246b2439b86981eac048bffcb           1.0                         0.0
# 7ddb82eaf1094950a4a1fdba967c7b7c           1.0                         0.0
# 848fb35cba004368b434c33ff5e122b0           1.0                         0.0
# 864dbf1b7a5c457480f7f25a9e7e9d7b           1.0                         0.0
# 8e45d75efc3b4552bd756dc55223123b           1.0                         0.0
# 940c81d098c44970abd4bb3439bf86ff           1.0                         0.0
# 9774e1575fab4bcc998ec5148231fded           1.0                         0.0
# 9ce408d199634fd4b2b2d09702eb2814           1.0                         0.0
# af8336d3176846168f06b5ab33fc9b2a           1.0                         0.0
# b90fa16a20b74f56983f6fd05e36c864           1.0                         0.0
# d87b50fd4dcd4d19934d638175118e9f           1.0                         0.0
# e0ca054b55ee43028a2682402d521657           1.0                         0.0
# ede9bb3f15ac4596b6b09dad20da209c           1.0                         0.0
# ee6e90bb382a4fcb92d286c760da2a9c           1.0                         0.0
# efadaf9b96da445e80ca557393cbf3ac           1.0                         0.0
# f0fb1cab62e0497aac27be2e8d1f8a00           1.0                         0.0
#
# [25 rows x 65 columns]

# %%
model_nickname = df_runs_parents['model'].unique().tolist()
model_nickname.sort()
model_nickname
# Out:
# ['BatchCoHiRF-1iter-60',
#  'BatchCoHiRF-1iter-random-60',
#  'BatchCoHiRF-1iter-stratified-60',
#  'BatchCoHiRF-60',
#  'BatchCoHiRF-DBSCAN-1iter-60',
#  'BatchCoHiRF-DBSCAN-1iter-random-60',
#  'BatchCoHiRF-DBSCAN-1iter-stratified-60',
#  'BatchCoHiRF-KernelRBF-1iter-60',
#  'BatchCoHiRF-KernelRBF-1iter-random-60',
#  'BatchCoHiRF-KernelRBF-1iter-stratified-60',
#  'BatchCoHiRF-SC-SRGF-1iter-60',
#  'BatchCoHiRF-SC-SRGF-2-60',
#  'CoHiRF-1000-60',
#  'CoHiRF-60',
#  'CoHiRF-DBSCAN-60',
#  'CoHiRF-KernelRBF-60',
#  'CoHiRF-SC-SRGF-60',
#  'CoHiRF-top-down-60',
#  'CoHiRF-top-down-inv-60',
#  'DBSCAN-60',
#  'KMeans-60',
#  'KernelRBFKMeans-60',
#  'SpectralSubspaceRandomization-60']

# %%
non_duplicate_columns = [
	"model",
	"dataset_id",
	"standardize",
	"hpo_metric",
	"hpo_seed",
]

# %%
model_nickname = [
    "BatchCoHiRF-1iter-60",
    # "BatchCoHiRF-1iter-random-60",
    # "BatchCoHiRF-1iter-stratified-60",
    "BatchCoHiRF-DBSCAN-1iter-60",
    # "BatchCoHiRF-DBSCAN-1iter-random-60",
    # "BatchCoHiRF-DBSCAN-1iter-stratified-60",
    "BatchCoHiRF-KernelRBF-1iter-60",
    # "BatchCoHiRF-KernelRBF-1iter-random-60",
    # "BatchCoHiRF-KernelRBF-1iter-stratified-60",
    "BatchCoHiRF-SC-SRGF-1iter-60",
    # "BatchCoHiRF-SC-SRGF-1iter-random-60",
    # "BatchCoHiRF-SC-SRGF-1iter-stratified-60",
    # "BatchCoHiRF-SC-SRGF-2-60",
    "CoHiRF-60",
    "CoHiRF-top-down-60",
    "CoHiRF-top-down-inv-60",
    # "CoHiRF-1000-60",
    "CoHiRF-DBSCAN-60",
    "CoHiRF-KernelRBF-60",
    "CoHiRF-SC-SRGF-60",
    "DBSCAN-60",
    "KMeans-60",
    "KernelRBFKMeans-60",
    "SpectralSubspaceRandomization-60",
]
dataset_id = [
    39,
    61,
    182,
    1478,
    1568,
    40685,
    40984,
    46773,
    46774,
    46775,
    46776,
    46777,
    46778,
    46779,
    46780,
    46781,
    46782,
    46783,
    554,
    # 1110,
    # 47039
]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    "davies_bouldin_score",
    "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
# Empty DataFrame
# Columns: [model, dataset_id, standardize, hpo_metric, hpo_seed]
# Index: []

# %%
model_nickname = [
    "CoHiRF-1000-60",
]
dataset_id = [
    182,
    1478,
    1568,
    40685,
    40984,
    46782,
    46783,
    554,
]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    "davies_bouldin_score",
    "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
# Empty DataFrame
# Columns: [model, dataset_id, standardize, hpo_metric, hpo_seed]
# Index: []

# %%
model_nickname = [
    "BatchCoHiRF-1iter-60",
    # "BatchCoHiRF-1iter-random-60",
    # "BatchCoHiRF-1iter-stratified-60",
    "BatchCoHiRF-DBSCAN-1iter-60",
    # "BatchCoHiRF-DBSCAN-1iter-random-60",
    # "BatchCoHiRF-DBSCAN-1iter-stratified-60",
    "BatchCoHiRF-KernelRBF-1iter-60",
    # "BatchCoHiRF-KernelRBF-1iter-random-60",
    # "BatchCoHiRF-KernelRBF-1iter-stratified-60",
    "BatchCoHiRF-SC-SRGF-1iter-60",
    # "BatchCoHiRF-SC-SRGF-1iter-random-60",
    # "BatchCoHiRF-SC-SRGF-1iter-stratified-60",
    # "BatchCoHiRF-SC-SRGF-2-60",
    # "CoHiRF-60",
    # "CoHiRF-1000-60",
    # "CoHiRF-DBSCAN-60",
    # "CoHiRF-KernelRBF-60",
    # "CoHiRF-SC-SRGF-60",
    # "DBSCAN-60",
    "KMeans-60",
    # "KernelRBFKMeans-60",
    # "SpectralSubspaceRandomization-60",
]
dataset_id = [
    47039
]
standardize = [True]
hpo_metric = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    # "normalized_mutual_info",
    # "davies_bouldin_score",
    # "silhouette",
]
hpo_seed = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, dataset_id, standardize, hpo_metric, hpo_seed]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)
df_missing
# Out:
#                            model  dataset_id  standardize  \
# 0   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 1   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 2   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 3   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 4   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 5   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 6   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 7   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 8   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 9   BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 10  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 11  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 12  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 13  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
# 14  BatchCoHiRF-SC-SRGF-1iter-60       47039         True
#
#                  hpo_metric  hpo_seed
# 0             adjusted_rand         0
# 1             adjusted_rand         1
# 2             adjusted_rand         2
# 3             adjusted_rand         3
# 4             adjusted_rand         4
# 5      adjusted_mutual_info         0
# 6      adjusted_mutual_info         1
# 7      adjusted_mutual_info         2
# 8      adjusted_mutual_info         3
# 9      adjusted_mutual_info         4
# 10  calinski_harabasz_score         0
# 11  calinski_harabasz_score         1
# 12  calinski_harabasz_score         2
# 13  calinski_harabasz_score         3
# 14  calinski_harabasz_score         4

# %%
# Join df_runs_raw_parents into df_missing using non_duplicate_columns to get the EXCEPTION column
df_missing_with_exception = df_missing.merge(
    df_runs_raw_parents[non_duplicate_columns + ["raised_exception", "EXCEPTION", "Last step finished"]],
    how="left",
    left_on=["model", "dataset_id", "standardize", "hpo_metric", "hpo_seed"],
    right_on=["model", "dataset_id", "standardize", "hpo_metric", "hpo_seed"],
)
df_missing_with_exception[
    [
        "model",
        "dataset_id",
        "standardize",
        "hpo_metric",
        "hpo_seed",
        "raised_exception",
        "EXCEPTION",
        "Last step finished",
    ]
]
# Out:
#                      model  dataset_id  standardize            hpo_metric  \
# 0       CoHiRF-top-down-60        1568         True  adjusted_mutual_info
# 1       CoHiRF-top-down-60        1568         True  adjusted_mutual_info
# 2       CoHiRF-top-down-60        1568         True  adjusted_mutual_info
# 3       CoHiRF-top-down-60        1568         True  adjusted_mutual_info
# 4       CoHiRF-top-down-60        1568         True  adjusted_mutual_info
# 5       CoHiRF-top-down-60        1568         True  adjusted_mutual_info
# 6   CoHiRF-top-down-inv-60        1568         True         adjusted_rand
# 7   CoHiRF-top-down-inv-60        1568         True         adjusted_rand
# 8   CoHiRF-top-down-inv-60        1568         True  adjusted_mutual_info
# 9   CoHiRF-top-down-inv-60        1568         True  adjusted_mutual_info
# 10  CoHiRF-top-down-inv-60        1568         True  adjusted_mutual_info
# 11  CoHiRF-top-down-inv-60        1568         True  adjusted_mutual_info
# 12  CoHiRF-top-down-inv-60        1568         True  davies_bouldin_score
# 13  CoHiRF-top-down-inv-60        1568         True  davies_bouldin_score
#
#     hpo_seed raised_exception EXCEPTION Last step finished
# 0          2              NaN       NaN  _before_fit_model
# 1          2              NaN       NaN  _before_fit_model
# 2          2              NaN       NaN  _before_fit_model
# 3          3              NaN       NaN  _before_fit_model
# 4          3              NaN       NaN  _before_fit_model
# 5          3              NaN       NaN  _before_fit_model
# 6          1              NaN       NaN  _before_fit_model
# 7          1              NaN       NaN  _before_fit_model
# 8          1              NaN       NaN  _before_fit_model
# 9          1              NaN       NaN  _before_fit_model
# 10         4              NaN       NaN  _before_fit_model
# 11         4              NaN       NaN  _before_fit_model
# 12         0              NaN       NaN  _before_fit_model
# 13         0              NaN       NaN  _before_fit_model

# %%
df_missing_dict = df_missing.copy()
# get only rows from high_mem_tuples
# df_missing_dict = df_missing_dict.merge(high_mem_tuples, on=["model", "dataset_id"], how="left", indicator=True)
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "both"].drop(columns="_merge")
# exclude rows that are in missing_ari_tuples
# df_missing_dict = df_missing_dict.merge(
# 	missing_ari_tuples, on=["model", "dataset_id"], how="left", indicator=True
# )|
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "left_only"].drop(columns="_merge")
# exclude rows that are in high_mem_tuples
# df_missing_dict = df_missing_dict.merge(
# 	high_mem_tuples, on=["model", "dataset_id"], how="left", indicator=True
# )
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "left_only"].drop(columns="_merge")
# to_drop = pd.concat([missing_ari_tuples, high_mem_tuples], ignore_index=True)
# df_missing_dict = df_missing_dict[df_missing_dict["_merge"] == "left_only"].drop(columns="_merge")

# %%
# get rid of -60
df_missing_dict["model"] = df_missing_dict["model"].str.replace("-60", "")
df_missing_dict["seed_dataset_order"] = df_missing_dict["hpo_seed"]

# %%
df_missing_dict
# Out:
#                   model  dataset_id  standardize               hpo_metric  \
# 0       CoHiRF-top-down         554         True            adjusted_rand
# 1       CoHiRF-top-down         554         True            adjusted_rand
# 2       CoHiRF-top-down         554         True            adjusted_rand
# 3       CoHiRF-top-down         554         True            adjusted_rand
# 4       CoHiRF-top-down         554         True            adjusted_rand
# 5       CoHiRF-top-down         554         True     adjusted_mutual_info
# 6       CoHiRF-top-down         554         True     adjusted_mutual_info
# 7       CoHiRF-top-down         554         True     adjusted_mutual_info
# 8       CoHiRF-top-down         554         True     adjusted_mutual_info
# 9       CoHiRF-top-down         554         True     adjusted_mutual_info
# 10      CoHiRF-top-down         554         True  calinski_harabasz_score
# 11      CoHiRF-top-down         554         True  calinski_harabasz_score
# 12      CoHiRF-top-down         554         True  calinski_harabasz_score
# 13      CoHiRF-top-down         554         True  calinski_harabasz_score
# 14      CoHiRF-top-down         554         True  calinski_harabasz_score
# 15      CoHiRF-top-down         554         True     davies_bouldin_score
# 16      CoHiRF-top-down         554         True     davies_bouldin_score
# 17      CoHiRF-top-down         554         True     davies_bouldin_score
# 18      CoHiRF-top-down         554         True     davies_bouldin_score
# 19      CoHiRF-top-down         554         True     davies_bouldin_score
# 20      CoHiRF-top-down         554         True               silhouette
# 21      CoHiRF-top-down         554         True               silhouette
# 22      CoHiRF-top-down         554         True               silhouette
# 23      CoHiRF-top-down         554         True               silhouette
# 24      CoHiRF-top-down         554         True               silhouette
# 25  CoHiRF-top-down-inv         554         True            adjusted_rand
# 26  CoHiRF-top-down-inv         554         True            adjusted_rand
# 27  CoHiRF-top-down-inv         554         True            adjusted_rand
# 28  CoHiRF-top-down-inv         554         True            adjusted_rand
# 29  CoHiRF-top-down-inv         554         True            adjusted_rand
# 30  CoHiRF-top-down-inv         554         True     adjusted_mutual_info
# 31  CoHiRF-top-down-inv         554         True     adjusted_mutual_info
# 32  CoHiRF-top-down-inv         554         True     adjusted_mutual_info
# 33  CoHiRF-top-down-inv         554         True     adjusted_mutual_info
# 34  CoHiRF-top-down-inv         554         True     adjusted_mutual_info
# 35  CoHiRF-top-down-inv         554         True  calinski_harabasz_score
# 36  CoHiRF-top-down-inv         554         True  calinski_harabasz_score
# 37  CoHiRF-top-down-inv         554         True  calinski_harabasz_score
# 38  CoHiRF-top-down-inv         554         True  calinski_harabasz_score
# 39  CoHiRF-top-down-inv         554         True  calinski_harabasz_score
# 40  CoHiRF-top-down-inv         554         True     davies_bouldin_score
# 41  CoHiRF-top-down-inv         554         True     davies_bouldin_score
# 42  CoHiRF-top-down-inv         554         True     davies_bouldin_score
# 43  CoHiRF-top-down-inv         554         True     davies_bouldin_score
# 44  CoHiRF-top-down-inv         554         True     davies_bouldin_score
# 45  CoHiRF-top-down-inv         554         True               silhouette
# 46  CoHiRF-top-down-inv         554         True               silhouette
# 47  CoHiRF-top-down-inv         554         True               silhouette
# 48  CoHiRF-top-down-inv         554         True               silhouette
# 49  CoHiRF-top-down-inv         554         True               silhouette
#
#     hpo_seed  seed_dataset_order
# 0          0                   0
# 1          1                   1
# 2          2                   2
# 3          3                   3
# 4          4                   4
# 5          0                   0
# 6          1                   1
# 7          2                   2
# 8          3                   3
# 9          4                   4
# 10         0                   0
# 11         1                   1
# 12         2                   2
# 13         3                   3
# 14         4                   4
# 15         0                   0
# 16         1                   1
# 17         2                   2
# 18         3                   3
# 19         4                   4
# 20         0                   0
# 21         1                   1
# 22         2                   2
# 23         3                   3
# 24         4                   4
# 25         0                   0
# 26         1                   1
# 27         2                   2
# 28         3                   3
# 29         4                   4
# 30         0                   0
# 31         1                   1
# 32         2                   2
# 33         3                   3
# 34         4                   4
# 35         0                   0
# 36         1                   1
# 37         2                   2
# 38         3                   3
# 39         4                   4
# 40         0                   0
# 41         1                   1
# 42         2                   2
# 43         3                   3
# 44         4                   4
# 45         0                   0
# 46         1                   1
# 47         2                   2
# 48         3                   3
# 49         4                   4

# %%
missing_dict = {}
for model in df_missing_dict["model"].unique():
    sub = df_missing_dict[df_missing_dict["model"] == model].drop(columns=["model"])
    # standardize = True
    sub_standardized = sub.loc[sub["standardize"] == True].copy()
    sub_standardized["standardize"] = ''
    sub_standardized_dict = sub_standardized.to_dict(orient="records")
    # standardize = False
    sub_not_standardized = sub.loc[sub["standardize"] == False].copy()
    sub_not_standardized.drop(columns=["standardize"], inplace=True)
    sub_not_standardized_dict = sub_not_standardized.to_dict(orient="records")
    # combine both dictionaries
    missing_dict[model] = sub_standardized_dict + sub_not_standardized_dict
if len(missing_dict) != 0:
    with open(results_dir / 'missing_dict.pkl', 'wb') as f:
        pickle.dump(missing_dict, f)

# %%
missing_dict
# Out:
# {'CoHiRF-top-down': [{'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4}],
#  'CoHiRF-top-down-inv': [{'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_rand',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'adjusted_mutual_info',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'calinski_harabasz_score',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'davies_bouldin_score',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 0,
#    'seed_dataset_order': 0},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 1,
#    'seed_dataset_order': 1},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 2,
#    'seed_dataset_order': 2},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 3,
#    'seed_dataset_order': 3},
#   {'dataset_id': 554,
#    'standardize': '',
#    'hpo_metric': 'silhouette',
#    'hpo_seed': 4,
#    'seed_dataset_order': 4}]}

# %% [markdown]
# # Tables

# %%
def get_parameters_string(row):
    parameter_names = {
		"best/alpha": "\\alpha",
		"best/avg_dims": "d",
		"best/base_model_kwargs/eps": "\\epsilon",
		"best/base_model_kwargs/min_samples": "n_{\\text{min}}",
		"best/base_model_kwargs/n_clusters": "C",
		"best/c": "c",
		"best/cohirf_kwargs/base_model_kwargs/eps": "\\epsilon",
		"best/cohirf_kwargs/base_model_kwargs/min_samples": "n_{\\text{min}}",
		"best/cohirf_kwargs/kmeans_n_clusters": "C",
		"best/cohirf_kwargs/n_features": "q",
		"best/cohirf_kwargs/repetitions": "R",
		"best/damping": "\\lambda",
		# "best/density_threshold": "\\tau",
		"best/eps": "\\epsilon",
		"best/kmeans_n_clusters": "C",
		"best/lambda_": "\\lambda",
		"best/min_bin_freq": "bin_{\\text{min}}",
		"best/min_cluster_size": "C_{\\text{min}}",
		"best/min_samples": "n_{\\text{min}}",
		"best/n_clusters": "C",
		"best/n_features": "q",
		# "best/n_partitions": "P",
		"best/n_similarities": "m",
		"best/p": "p",
		"best/repetitions": "R",
		"best/sampling_ratio": "r",
		"best/sc_n_clusters": "C",
		"best/transform_kwargs/gamma": "\\gamma",
	}
    first = True
    str = ""
    for p in parameter_names.keys():
        if not pd.isna(row[p]) and row[p] != "None":
            if not first:
                str += "; "
            else:
                first = False
            value = float(row[p])
            if value.is_integer():
                value = int(value)
                str += f"${parameter_names[p]}={value}$"
            else:
                str += f"${parameter_names[p]}={value:0.2f}$"
    return str

# %%
def highlight_max(df, column_name, level=0):
    df_column = df[column_name]
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_highlighted] = 'font-weight: bold'
    return df_css

# %%
def highlight_min(df, column_name, level=0):
    df_column = df[column_name]
    min_values = df_column.groupby(level=level).transform("min")
    is_highlighted = df_column.round(3) == min_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ""
    df_css[is_highlighted] = "font-weight: bold"
    return df_css

# %%
def highlight_max_index(series_index, df_column, level=0):
    max_values = df_column.groupby(level=level).transform('max')
    is_highlighted = df_column.round(3) == max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css[:] = ''
    series_css[is_highlighted.values] = 'font-weight: bold'
    return series_css

# %%
def underline_2nd_max(df, column_name, level=0):
    df_column = df[column_name]
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.round(3).drop_duplicates().nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ''
    df_css[is_underlined] = 'underline: --latex--rwrap'
    return df_css

# %%
def underline_2nd_min(df, column_name, level=0):
    df_column = df[column_name]
    # get the second min value
    second_min_values = df_column.groupby(level=level).transform(
        lambda x: x.round(3).drop_duplicates().nsmallest(2).iloc[-1]
    )
    is_underlined = df_column.round(3) == second_min_values.round(3)
    df_css = df.copy().astype(str)
    df_css.loc[:, :] = ""
    df_css[is_underlined] = "underline: --latex--rwrap"
    return df_css

# %%
def underline_2nd_max_index(series_index, df_column, level=0):
    # get the second max value
    second_max_values = df_column.groupby(level=level).transform(lambda x: x.nlargest(2).iloc[-1])
    is_underlined = df_column.round(3) == second_max_values.round(3)
    series_css = series_index.copy().astype(str)
    series_css.loc[:] = ''
    series_css[is_underlined.values] = 'underline: --latex--rwrap'
    return series_css

# %% [markdown]
# ## Some Models

# %%
print(*df_runs_parents['model'].unique(), sep="\n")
# Out:
# BatchCoHiRF-DBSCAN-1iter-60
# KernelRBFKMeans-60
# CoHiRF-top-down-inv-60
# CoHiRF-KernelRBF-60
# BatchCoHiRF-1iter-60
# CoHiRF-top-down-60
# CoHiRF-SC-SRGF-60
# CoHiRF-1000-60
# KMeans-60
# BatchCoHiRF-SC-SRGF-1iter-60
# SpectralSubspaceRandomization-60
# BatchCoHiRF-KernelRBF-1iter-60
# DBSCAN-60
# CoHiRF-DBSCAN-60
# BatchCoHiRF-DBSCAN-1iter-stratified-60
# CoHiRF-60
# BatchCoHiRF-DBSCAN-1iter-random-60
# BatchCoHiRF-KernelRBF-1iter-stratified-60
# BatchCoHiRF-60
# BatchCoHiRF-KernelRBF-1iter-random-60
# BatchCoHiRF-SC-SRGF-2-60
# BatchCoHiRF-1iter-random-60
# BatchCoHiRF-1iter-stratified-60

# %%
model_names = {
    "BatchCoHiRF-1iter-60": "Batch CoHiRF",
    "BatchCoHiRF-1iter-stratified-60": "Batch CoHiRF-Stratified",
    "BatchCoHiRF-1iter-random-60": "Batch CoHiRF-Random",
    "BatchCoHiRF-DBSCAN-1iter-60": "Batch CoHiRF-DBSCAN",
    "BatchCoHiRF-DBSCAN-1iter-stratified-60": "Batch CoHiRF-DBSCAN-Stratified",
    "BatchCoHiRF-DBSCAN-1iter-random-60": "Batch CoHiRF-DBSCAN-Random",
    "BatchCoHiRF-KernelRBF-1iter-60": "Batch CoHiRF-KernelRBF",
    "BatchCoHiRF-KernelRBF-1iter-stratified-60": "Batch CoHiRF-KernelRBF-Stratified",
    "BatchCoHiRF-KernelRBF-1iter-random-60": "Batch CoHiRF-KernelRBF-Random",
    "BatchCoHiRF-SC-SRGF-1iter-60": "Batch CoHiRF-SC-SRGF",
    "BatchCoHiRF-SC-SRGF-2-1iter-60": "Batch CoHiRF-SC-SRGF-2",
    "CoHiRF-60": "CoHiRF",
    "CoHiRF-top-down-60": "CoHiRF Top-Down",
    "CoHiRF-top-down-inv-60": "CoHiRF Top-Down Inv",
	"CoHiRF-1000-60": "CoHiRF-1000",
    "CoHiRF-DBSCAN-60": "CoHiRF-DBSCAN",
    "CoHiRF-KernelRBF-60": "CoHiRF-KernelRBF",
    "CoHiRF-SC-SRGF-60": "CoHiRF-SC-SRGF",
    "DBSCAN-60": "DBSCAN",
    "KMeans-60": "K-Means",
    "KernelRBFKMeans-60": "Kernel RBF K-Means",
    "SpectralSubspaceRandomization-60": "SC-SRGF",
}

dataset_names = {
    "binary_alpha_digits": "binary-alpha-digits",
	"mnist_784": "mnist",
}  # otherwise we get an error in latex

# Filter to only standardized runs
df = df_runs_parents.copy()
df = df.loc[df['standardize'] == True]
df = df.loc[df['model'].isin(model_names.keys())]
df = df.replace({"model": model_names})
df = df.replace({"dataset_name": dataset_names})

# Filter to only runs with hpo_seed in range(5)
df = df.loc[df['hpo_seed'].isin(range(5))]

# %%
hpo_metrics = [
    "adjusted_rand",
    "adjusted_mutual_info",
    "calinski_harabasz_score",
    "silhouette",
    "davies_bouldin_score",
    "normalized_mutual_info",
]

hpo_metrics_rename = [
    "ARI",
    "AMI",
    "Calinski",
    "Silhouette",
    "Davies-Bouldin",
    "NMI",
]

dfs_metrics = {}

for hpo_metric, hpo_metric_rename in zip(hpo_metrics, hpo_metrics_rename):
    df_metric = df.loc[df['hpo_metric'] == hpo_metric][
        ['dataset_name', 'model', 'hpo_seed', f'best/{hpo_metric}']
    ].rename(columns={f'best/{hpo_metric}': hpo_metric_rename})
    df_metric = df_metric.dropna(subset=[hpo_metric_rename])
    df_metric = df_metric.set_index(['dataset_name', 'model', 'hpo_seed'])
    df_metric = df_metric.astype({hpo_metric_rename: float})
    dfs_metrics[hpo_metric_rename] = df_metric

df_metrics = pd.concat(dfs_metrics.values(), axis=1, join="outer")
df_metrics = df_metrics.reset_index()

# calculate mean and std
df_metrics = df_metrics.groupby(['dataset_name', 'model']).agg(['mean', 'std'])
# flatten multiindex columns
df_metrics.columns = [' '.join(col).strip() for col in df_metrics.columns.values]
# drop hpo_seed level
df_metrics = df_metrics.drop(columns=['hpo_seed mean', 'hpo_seed std'])
# Rename index levels
df_metrics.index.names = ["Dataset", "Model"]
# df_metrics["Davies-Bouldin"] = df_metrics["Davies-Bouldin"].astype(float)
# create columns Metric (Mean ± Std)
# for metric in hpo_metrics_rename:
#     df_metrics[f"{metric}"] = df_metrics[f"{metric} mean"].round(3).astype(str) + " $\\pm$ " + df_metrics[f"{metric} std"].round(3).astype(str)

for metric in hpo_metrics_rename:
    df_metrics[f"{metric}"] = (
        df_metrics[f"{metric} mean"].apply(lambda x: f"{x:.3f}" if not pd.isna(x) else "No Run")
        + " $\\pm$ "
        + df_metrics[f"{metric} std"].apply(lambda x: f"{x:.3f}" if not pd.isna(x) else "No Run")
    )


# Reset Seed level
# df_metrics = df_metrics.reset_index(level="Seed")

# %%
df_metrics
# Out:
#                                          ARI mean   ARI std      AMI mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF            0.359896  0.014291  5.065753e-01
#                  Batch CoHiRF-DBSCAN     0.000000  0.000000 -1.355437e-14
#                  Batch CoHiRF-KernelRBF  0.078146  0.055388  8.028088e-02
#                  Batch CoHiRF-SC-SRGF    0.785098  0.075567  6.652103e-01
#                  CoHiRF                  0.865875  0.006962  7.713592e-01
# ...                                           ...       ...           ...
# shuttle          CoHiRF-DBSCAN           0.691670  0.007741  6.041114e-01
#                  CoHiRF-KernelRBF        0.460048  0.119175  4.577238e-01
#                  DBSCAN                  0.708522  0.012708  6.430448e-01
#                  K-Means                 0.608404  0.000000  4.727386e-01
#                  Kernel RBF K-Means      0.250069  0.083577  3.884542e-01
#
#                                           AMI std  Calinski mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF            0.021294       4.273626
#                  Batch CoHiRF-DBSCAN     0.000000      -1.000000
#                  Batch CoHiRF-KernelRBF  0.017931       1.575115
#                  Batch CoHiRF-SC-SRGF    0.097561      14.183740
#                  CoHiRF                  0.029894      15.094428
# ...                                           ...            ...
# shuttle          CoHiRF-DBSCAN           0.072497    1661.914919
#                  CoHiRF-KernelRBF        0.062942   10955.561513
#                  DBSCAN                  0.001591    7504.081967
#                  K-Means                 0.013506   30845.870523
#                  Kernel RBF K-Means      0.017841   11742.147770
#
#                                          Calinski std  Silhouette mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                0.237620         0.048742
#                  Batch CoHiRF-DBSCAN         0.000000        -1.000000
#                  Batch CoHiRF-KernelRBF      0.093583         0.044387
#                  Batch CoHiRF-SC-SRGF        1.269080         0.176404
#                  CoHiRF                      0.125896         0.195661
# ...                                               ...              ...
# shuttle          CoHiRF-DBSCAN             938.850704         0.947420
#                  CoHiRF-KernelRBF         4532.351396         0.474109
#                  DBSCAN                     12.888252         0.948136
#                  K-Means                   297.411898         0.960408
#                  Kernel RBF K-Means       2434.780882         0.389934
#
#                                          Silhouette std  Davies-Bouldin mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                  0.009521             0.411411
#                  Batch CoHiRF-DBSCAN           0.000000          1000.000000
#                  Batch CoHiRF-KernelRBF        0.027604             0.470840
#                  Batch CoHiRF-SC-SRGF          0.012153             1.578932
#                  CoHiRF                        0.014860             0.895849
# ...                                                 ...                  ...
# shuttle          CoHiRF-DBSCAN                 0.013002             0.043827
#                  CoHiRF-KernelRBF              0.131954             1.191542
#                  DBSCAN                        0.000715             1.738127
#                  K-Means                       0.008693             0.556971
#                  Kernel RBF K-Means            0.010019             0.877214
#
#                                          Davies-Bouldin std  NMI mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                      0.084283       NaN
#                  Batch CoHiRF-DBSCAN               0.000000       NaN
#                  Batch CoHiRF-KernelRBF            0.074694       NaN
#                  Batch CoHiRF-SC-SRGF              0.133080       NaN
#                  CoHiRF                            0.082582       NaN
# ...                                                     ...       ...
# shuttle          CoHiRF-DBSCAN                     0.003614       NaN
#                  CoHiRF-KernelRBF                  0.132182       NaN
#                  DBSCAN                            0.306075       NaN
#                  K-Means                           0.011138       NaN
#                  Kernel RBF K-Means                0.035017       NaN
#
#                                          NMI std                ARI  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                NaN  0.360 $\pm$ 0.014
#                  Batch CoHiRF-DBSCAN         NaN  0.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF      NaN  0.078 $\pm$ 0.055
#                  Batch CoHiRF-SC-SRGF        NaN  0.785 $\pm$ 0.076
#                  CoHiRF                      NaN  0.866 $\pm$ 0.007
# ...                                          ...                ...
# shuttle          CoHiRF-DBSCAN               NaN  0.692 $\pm$ 0.008
#                  CoHiRF-KernelRBF            NaN  0.460 $\pm$ 0.119
#                  DBSCAN                      NaN  0.709 $\pm$ 0.013
#                  K-Means                     NaN  0.608 $\pm$ 0.000
#                  Kernel RBF K-Means          NaN  0.250 $\pm$ 0.084
#
#                                                         AMI  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF             0.507 $\pm$ 0.021
#                  Batch CoHiRF-DBSCAN     -0.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF   0.080 $\pm$ 0.018
#                  Batch CoHiRF-SC-SRGF     0.665 $\pm$ 0.098
#                  CoHiRF                   0.771 $\pm$ 0.030
# ...                                                     ...
# shuttle          CoHiRF-DBSCAN            0.604 $\pm$ 0.072
#                  CoHiRF-KernelRBF         0.458 $\pm$ 0.063
#                  DBSCAN                   0.643 $\pm$ 0.002
#                  K-Means                  0.473 $\pm$ 0.014
#                  Kernel RBF K-Means       0.388 $\pm$ 0.018
#
#                                                          Calinski  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                   4.274 $\pm$ 0.238
#                  Batch CoHiRF-DBSCAN           -1.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF         1.575 $\pm$ 0.094
#                  Batch CoHiRF-SC-SRGF          14.184 $\pm$ 1.269
#                  CoHiRF                        15.094 $\pm$ 0.126
# ...                                                           ...
# shuttle          CoHiRF-DBSCAN             1661.915 $\pm$ 938.851
#                  CoHiRF-KernelRBF        10955.562 $\pm$ 4532.351
#                  DBSCAN                     7504.082 $\pm$ 12.888
#                  K-Means                  30845.871 $\pm$ 297.412
#                  Kernel RBF K-Means      11742.148 $\pm$ 2434.781
#
#                                                  Silhouette  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF             0.049 $\pm$ 0.010
#                  Batch CoHiRF-DBSCAN     -1.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF   0.044 $\pm$ 0.028
#                  Batch CoHiRF-SC-SRGF     0.176 $\pm$ 0.012
#                  CoHiRF                   0.196 $\pm$ 0.015
# ...                                                     ...
# shuttle          CoHiRF-DBSCAN            0.947 $\pm$ 0.013
#                  CoHiRF-KernelRBF         0.474 $\pm$ 0.132
#                  DBSCAN                   0.948 $\pm$ 0.001
#                  K-Means                  0.960 $\pm$ 0.009
#                  Kernel RBF K-Means       0.390 $\pm$ 0.010
#
#                                                Davies-Bouldin  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF               0.411 $\pm$ 0.084
#                  Batch CoHiRF-DBSCAN     1000.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF     0.471 $\pm$ 0.075
#                  Batch CoHiRF-SC-SRGF       1.579 $\pm$ 0.133
#                  CoHiRF                     0.896 $\pm$ 0.083
# ...                                                       ...
# shuttle          CoHiRF-DBSCAN              0.044 $\pm$ 0.004
#                  CoHiRF-KernelRBF           1.192 $\pm$ 0.132
#                  DBSCAN                     1.738 $\pm$ 0.306
#                  K-Means                    0.557 $\pm$ 0.011
#                  Kernel RBF K-Means         0.877 $\pm$ 0.035
#
#                                                          NMI
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF            No Run $\pm$ No Run
#                  Batch CoHiRF-DBSCAN     No Run $\pm$ No Run
#                  Batch CoHiRF-KernelRBF  No Run $\pm$ No Run
#                  Batch CoHiRF-SC-SRGF    No Run $\pm$ No Run
#                  CoHiRF                  No Run $\pm$ No Run
# ...                                                      ...
# shuttle          CoHiRF-DBSCAN           No Run $\pm$ No Run
#                  CoHiRF-KernelRBF        No Run $\pm$ No Run
#                  DBSCAN                  No Run $\pm$ No Run
#                  K-Means                 No Run $\pm$ No Run
#                  Kernel RBF K-Means      No Run $\pm$ No Run
#
# [276 rows x 18 columns]

# %%
# Add mean time columns to the existing df_metrics dataframe
# Using the same filtering approach as the original df_metrics
df = df_runs_parents.copy()
df = df.loc[df["standardize"] == True]
df = df.loc[df["model"].isin(model_names.keys())]
df = df.replace({"model": model_names})
df = df.replace({"dataset_name": dataset_names})
# Filter to only runs with hpo_seed in range(5)
df = df.loc[df["hpo_seed"].isin(range(5))]

# Calculate mean and std times for each dataset-model combination across all metrics
df_times = (
    df.groupby(["dataset_name", "model"])
    .agg({"best/elapsed_time": ["mean", "std"], "fit_model_return_elapsed_time": ["mean", "std"]})
    .rename(columns={"best/elapsed_time": "Best Time", "fit_model_return_elapsed_time": "HPO Time"})
)

# Flatten multiindex columns
df_times.columns = [' '.join(col).strip() for col in df_times.columns.values]
# Set the same index structure as df_metrics
df_times.index.names = ["Dataset", "Model"]

df_times["Best Time"] = (
	df_times["Best Time mean"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
	+ " $\\pm$ " 
	+ df_times["Best Time std"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
)
df_times["HPO Time"] = (
	df_times["HPO Time mean"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
	+ " $\\pm$ "
	+ df_times["HPO Time std"].apply(lambda x: f"{x:4.3f}" if not pd.isna(x) else "No Run")
)

# Join with the existing df_metrics (verify we have the same number of rows!)
df_metrics = df_metrics.join(df_times, how="outer")

# %%
# # Create a time-based dataframe with elapsed times for each metric optimization
# # Using the same filtering approach as the original df_metrics
# df_filtered = df_runs_parents.loc[df_runs_parents['standardize'] == True].copy()
# df_filtered = df_filtered.loc[df_filtered['model'].isin(model_names.keys())]
# df_filtered = df_filtered.replace({"model": model_names})
# df_filtered = df_filtered.replace({"dataset_name": dataset_names})

# # Create separate dataframes for each metric optimization with time columns
# df_ari_time = df_filtered.loc[df_filtered['hpo_metric'] == 'adjusted_rand'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'ARI_best_time', 'fit_model_return_elapsed_time': 'ARI_total_time'})

# df_ami_time = df_filtered.loc[df_filtered['hpo_metric'] == 'adjusted_mutual_info'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'AMI_best_time', 'fit_model_return_elapsed_time': 'AMI_total_time'})

# df_nmi_time = df_filtered.loc[df_filtered['hpo_metric'] == 'normalized_mutual_info'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'NMI_best_time', 'fit_model_return_elapsed_time': 'NMI_total_time'})

# df_calinski_time = df_filtered.loc[df_filtered['hpo_metric'] == 'calinski_harabasz_score'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'Calinski_best_time', 'fit_model_return_elapsed_time': 'Calinski_total_time'})

# df_silhouette_time = df_filtered.loc[df_filtered['hpo_metric'] == 'silhouette'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'Silhouette_best_time', 'fit_model_return_elapsed_time': 'Silhouette_total_time'})

# df_davies_bouldin_time = df_filtered.loc[df_filtered['hpo_metric'] == 'davies_bouldin_score'][
#     ['dataset_name', 'model', 'best/elapsed_time', 'fit_model_return_elapsed_time']
# ].rename(columns={'best/elapsed_time': 'Davies-Bouldin_best_time', 'fit_model_return_elapsed_time': 'Davies-Bouldin_total_time'})

# # Remove missing values before setting index
# df_ari_time = df_ari_time.dropna(subset=["ARI_best_time", "ARI_total_time"])
# df_ami_time = df_ami_time.dropna(subset=["AMI_best_time", "AMI_total_time"])
# df_nmi_time = df_nmi_time.dropna(subset=["NMI_best_time", "NMI_total_time"])
# df_calinski_time = df_calinski_time.dropna(subset=["Calinski_best_time", "Calinski_total_time"])
# df_silhouette_time = df_silhouette_time.dropna(subset=["Silhouette_best_time", "Silhouette_total_time"])
# df_davies_bouldin_time = df_davies_bouldin_time.dropna(subset=["Davies-Bouldin_best_time", "Davies-Bouldin_total_time"])

# # Set multi-index for all dataframes
# df_ari_time = df_ari_time.set_index(["dataset_name", "model"])
# df_ami_time = df_ami_time.set_index(["dataset_name", "model"])
# df_nmi_time = df_nmi_time.set_index(["dataset_name", "model"])
# df_calinski_time = df_calinski_time.set_index(["dataset_name", "model"])
# df_silhouette_time = df_silhouette_time.set_index(["dataset_name", "model"])
# df_davies_bouldin_time = df_davies_bouldin_time.set_index(["dataset_name", "model"])

# # Combine all time metrics into a single dataframe using outer join
# df_time_metrics = df_ari_time.join(df_ami_time, how="outer").join(df_nmi, how="outer").join(df_calinski_time, how="outer").join(df_silhouette_time, how="outer").join(df_davies_bouldin_time, how="outer")

# # Rename index levels
# df_time_metrics.index.names = ["Dataset", "Model"]

# %%
df_metrics
# Out:
#                                          ARI mean   ARI std      AMI mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF            0.359896  0.014291  5.065753e-01
#                  Batch CoHiRF-DBSCAN     0.000000  0.000000 -1.355437e-14
#                  Batch CoHiRF-KernelRBF  0.078146  0.055388  8.028088e-02
#                  Batch CoHiRF-SC-SRGF    0.785098  0.075567  6.652103e-01
#                  CoHiRF                  0.865875  0.006962  7.713592e-01
# ...                                           ...       ...           ...
# shuttle          CoHiRF-DBSCAN           0.691670  0.007741  6.041114e-01
#                  CoHiRF-KernelRBF        0.460048  0.119175  4.577238e-01
#                  DBSCAN                  0.708522  0.012708  6.430448e-01
#                  K-Means                 0.608404  0.000000  4.727386e-01
#                  Kernel RBF K-Means      0.250069  0.083577  3.884542e-01
#
#                                           AMI std  Calinski mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF            0.021294       4.273626
#                  Batch CoHiRF-DBSCAN     0.000000      -1.000000
#                  Batch CoHiRF-KernelRBF  0.017931       1.575115
#                  Batch CoHiRF-SC-SRGF    0.097561      14.183740
#                  CoHiRF                  0.029894      15.094428
# ...                                           ...            ...
# shuttle          CoHiRF-DBSCAN           0.072497    1661.914919
#                  CoHiRF-KernelRBF        0.062942   10955.561513
#                  DBSCAN                  0.001591    7504.081967
#                  K-Means                 0.013506   30845.870523
#                  Kernel RBF K-Means      0.017841   11742.147770
#
#                                          Calinski std  Silhouette mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                0.237620         0.048742
#                  Batch CoHiRF-DBSCAN         0.000000        -1.000000
#                  Batch CoHiRF-KernelRBF      0.093583         0.044387
#                  Batch CoHiRF-SC-SRGF        1.269080         0.176404
#                  CoHiRF                      0.125896         0.195661
# ...                                               ...              ...
# shuttle          CoHiRF-DBSCAN             938.850704         0.947420
#                  CoHiRF-KernelRBF         4532.351396         0.474109
#                  DBSCAN                     12.888252         0.948136
#                  K-Means                   297.411898         0.960408
#                  Kernel RBF K-Means       2434.780882         0.389934
#
#                                          Silhouette std  Davies-Bouldin mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                  0.009521             0.411411
#                  Batch CoHiRF-DBSCAN           0.000000          1000.000000
#                  Batch CoHiRF-KernelRBF        0.027604             0.470840
#                  Batch CoHiRF-SC-SRGF          0.012153             1.578932
#                  CoHiRF                        0.014860             0.895849
# ...                                                 ...                  ...
# shuttle          CoHiRF-DBSCAN                 0.013002             0.043827
#                  CoHiRF-KernelRBF              0.131954             1.191542
#                  DBSCAN                        0.000715             1.738127
#                  K-Means                       0.008693             0.556971
#                  Kernel RBF K-Means            0.010019             0.877214
#
#                                          Davies-Bouldin std  ...  \
# Dataset          Model                                       ...
# alizadeh-2000-v2 Batch CoHiRF                      0.084283  ...
#                  Batch CoHiRF-DBSCAN               0.000000  ...
#                  Batch CoHiRF-KernelRBF            0.074694  ...
#                  Batch CoHiRF-SC-SRGF              0.133080  ...
#                  CoHiRF                            0.082582  ...
# ...                                                     ...  ...
# shuttle          CoHiRF-DBSCAN                     0.003614  ...
#                  CoHiRF-KernelRBF                  0.132182  ...
#                  DBSCAN                            0.306075  ...
#                  K-Means                           0.011138  ...
#                  Kernel RBF K-Means                0.035017  ...
#
#                                                          Calinski  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                   4.274 $\pm$ 0.238
#                  Batch CoHiRF-DBSCAN           -1.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF         1.575 $\pm$ 0.094
#                  Batch CoHiRF-SC-SRGF          14.184 $\pm$ 1.269
#                  CoHiRF                        15.094 $\pm$ 0.126
# ...                                                           ...
# shuttle          CoHiRF-DBSCAN             1661.915 $\pm$ 938.851
#                  CoHiRF-KernelRBF        10955.562 $\pm$ 4532.351
#                  DBSCAN                     7504.082 $\pm$ 12.888
#                  K-Means                  30845.871 $\pm$ 297.412
#                  Kernel RBF K-Means      11742.148 $\pm$ 2434.781
#
#                                                  Silhouette  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF             0.049 $\pm$ 0.010
#                  Batch CoHiRF-DBSCAN     -1.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF   0.044 $\pm$ 0.028
#                  Batch CoHiRF-SC-SRGF     0.176 $\pm$ 0.012
#                  CoHiRF                   0.196 $\pm$ 0.015
# ...                                                     ...
# shuttle          CoHiRF-DBSCAN            0.947 $\pm$ 0.013
#                  CoHiRF-KernelRBF         0.474 $\pm$ 0.132
#                  DBSCAN                   0.948 $\pm$ 0.001
#                  K-Means                  0.960 $\pm$ 0.009
#                  Kernel RBF K-Means       0.390 $\pm$ 0.010
#
#                                                Davies-Bouldin  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF               0.411 $\pm$ 0.084
#                  Batch CoHiRF-DBSCAN     1000.000 $\pm$ 0.000
#                  Batch CoHiRF-KernelRBF     0.471 $\pm$ 0.075
#                  Batch CoHiRF-SC-SRGF       1.579 $\pm$ 0.133
#                  CoHiRF                     0.896 $\pm$ 0.083
# ...                                                       ...
# shuttle          CoHiRF-DBSCAN              0.044 $\pm$ 0.004
#                  CoHiRF-KernelRBF           1.192 $\pm$ 0.132
#                  DBSCAN                     1.738 $\pm$ 0.306
#                  K-Means                    0.557 $\pm$ 0.011
#                  Kernel RBF K-Means         0.877 $\pm$ 0.035
#
#                                                          NMI Best Time mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF            No Run $\pm$ No Run       0.142813
#                  Batch CoHiRF-DBSCAN     No Run $\pm$ No Run       2.309132
#                  Batch CoHiRF-KernelRBF  No Run $\pm$ No Run       0.394981
#                  Batch CoHiRF-SC-SRGF    No Run $\pm$ No Run       1.953276
#                  CoHiRF                  No Run $\pm$ No Run       0.054494
# ...                                                      ...            ...
# shuttle          CoHiRF-DBSCAN           No Run $\pm$ No Run     146.100549
#                  CoHiRF-KernelRBF        No Run $\pm$ No Run      11.999437
#                  DBSCAN                  No Run $\pm$ No Run      31.611373
#                  K-Means                 No Run $\pm$ No Run       0.073332
#                  Kernel RBF K-Means      No Run $\pm$ No Run       1.726301
#
#                                         Best Time std HPO Time mean  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                0.068740    154.716981
#                  Batch CoHiRF-DBSCAN         0.231695    138.359086
#                  Batch CoHiRF-KernelRBF      0.464414    167.077405
#                  Batch CoHiRF-SC-SRGF        0.851366    265.944189
#                  CoHiRF                      0.032927    142.623437
# ...                                               ...           ...
# shuttle          CoHiRF-DBSCAN             136.031869  12001.592468
#                  CoHiRF-KernelRBF            6.496682   1136.000458
#                  DBSCAN                     13.034294   3234.574771
#                  K-Means                     0.062088    478.330452
#                  Kernel RBF K-Means          0.338268    577.008266
#
#                                         HPO Time std              Best Time  \
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF               4.251098      0.143 $\pm$ 0.069
#                  Batch CoHiRF-DBSCAN        5.834786      2.309 $\pm$ 0.232
#                  Batch CoHiRF-KernelRBF     7.737474      0.395 $\pm$ 0.464
#                  Batch CoHiRF-SC-SRGF      32.207204      1.953 $\pm$ 0.851
#                  CoHiRF                     4.180228      0.054 $\pm$ 0.033
# ...                                              ...                    ...
# shuttle          CoHiRF-DBSCAN           7286.835987  146.101 $\pm$ 136.032
#                  CoHiRF-KernelRBF         864.371411     11.999 $\pm$ 6.497
#                  DBSCAN                  1047.159839    31.611 $\pm$ 13.034
#                  K-Means                  836.361835      0.073 $\pm$ 0.062
#                  Kernel RBF K-Means       793.429985      1.726 $\pm$ 0.338
#
#                                                          HPO Time
# Dataset          Model
# alizadeh-2000-v2 Batch CoHiRF                 154.717 $\pm$ 4.251
#                  Batch CoHiRF-DBSCAN          138.359 $\pm$ 5.835
#                  Batch CoHiRF-KernelRBF       167.077 $\pm$ 7.737
#                  Batch CoHiRF-SC-SRGF        265.944 $\pm$ 32.207
#                  CoHiRF                       142.623 $\pm$ 4.180
# ...                                                           ...
# shuttle          CoHiRF-DBSCAN           12001.592 $\pm$ 7286.836
#                  CoHiRF-KernelRBF          1136.000 $\pm$ 864.371
#                  DBSCAN                   3234.575 $\pm$ 1047.160
#                  K-Means                    478.330 $\pm$ 836.362
#                  Kernel RBF K-Means         577.008 $\pm$ 793.430
#
# [276 rows x 24 columns]

# %% [markdown]
# The following will provide the latex code for a clean table, we only need to make a little adjustement in the first line to delete the "key" and have only one header. For the longtable environment (full data) we need to add the "\*" at the end of lines we dont want to have a page break. We also should replace the entire begin{table} ... end{table} by begin{longtable} ... end{longtable} in the latex file, if you want to put caption and labels you should break the line after with '\\' (put both on the same line!)

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        environment="longtable",
    )
)
# Out:
# \begin{longtable}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \endfirsthead
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \endhead
# \midrule
# \multicolumn{9}{r}{Continued on next page} \\
# \midrule
# \endfoot
# \bottomrule
# \endlastfoot
# \multirow[c]{14}{*}{alizadeh-2000-v2} & Batch CoHiRF & 0.360 $\pm$ 0.014 & 0.507 $\pm$ 0.021 & 4.274 $\pm$ 0.238 & 0.049 $\pm$ 0.010 & \bfseries 0.411 $\pm$ 0.084 & 0.143 $\pm$ 0.069 & 154.717 $\pm$ 4.251 \\
#  & Batch CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & -0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 2.309 $\pm$ 0.232 & 138.359 $\pm$ 5.835 \\
#  & Batch CoHiRF-KernelRBF & 0.078 $\pm$ 0.055 & 0.080 $\pm$ 0.018 & 1.575 $\pm$ 0.094 & 0.044 $\pm$ 0.028 & 0.471 $\pm$ 0.075 & 0.395 $\pm$ 0.464 & 167.077 $\pm$ 7.737 \\
#  & Batch CoHiRF-SC-SRGF & 0.785 $\pm$ 0.076 & 0.665 $\pm$ 0.098 & 14.184 $\pm$ 1.269 & 0.176 $\pm$ 0.012 & 1.579 $\pm$ 0.133 & 1.953 $\pm$ 0.851 & 265.944 $\pm$ 32.207 \\
#  & CoHiRF & 0.866 $\pm$ 0.007 & 0.771 $\pm$ 0.030 & \underline{15.094 $\pm$ 0.126} & 0.196 $\pm$ 0.015 & 0.896 $\pm$ 0.083 & 0.054 $\pm$ 0.033 & 142.623 $\pm$ 4.180 \\
#  & CoHiRF Top-Down & \bfseries 0.905 $\pm$ 0.039 & \bfseries 0.880 $\pm$ 0.059 & \bfseries 15.151 $\pm$ 0.000 & \bfseries 0.221 $\pm$ 0.043 & 1.212 $\pm$ 0.366 & 0.122 $\pm$ 0.092 & 147.768 $\pm$ 5.161 \\
#  & CoHiRF Top-Down Inv & 0.873 $\pm$ 0.031 & 0.830 $\pm$ 0.046 & \bfseries 15.151 $\pm$ 0.000 & 0.188 $\pm$ 0.000 & 1.494 $\pm$ 0.234 & 0.156 $\pm$ 0.106 & 153.880 $\pm$ 5.356 \\
#  & CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & -0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.633 $\pm$ 0.119 & 142.112 $\pm$ 4.615 \\
#  & CoHiRF-KernelRBF & 0.096 $\pm$ 0.047 & 0.094 $\pm$ 0.016 & 1.726 $\pm$ 0.464 & 0.028 $\pm$ 0.014 & \underline{0.448 $\pm$ 0.054} & 0.196 $\pm$ 0.130 & 156.616 $\pm$ 8.218 \\
#  & CoHiRF-SC-SRGF & 0.633 $\pm$ 0.042 & 0.758 $\pm$ 0.031 & 7.422 $\pm$ 0.041 & 0.094 $\pm$ 0.001 & 1.550 $\pm$ 0.019 & 1.503 $\pm$ 1.527 & 254.264 $\pm$ 14.525 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.047 $\pm$ 0.004 & 137.501 $\pm$ 3.432 \\
#  & K-Means & 0.838 $\pm$ 0.014 & 0.767 $\pm$ 0.037 & \bfseries 15.151 $\pm$ 0.000 & \underline{0.204 $\pm$ 0.036} & 0.934 $\pm$ 0.021 & 0.012 $\pm$ 0.003 & 137.865 $\pm$ 3.673 \\
#  & Kernel RBF K-Means & 0.044 $\pm$ 0.015 & 0.092 $\pm$ 0.016 & 1.409 $\pm$ 0.106 & 0.014 $\pm$ 0.007 & 1.718 $\pm$ 0.026 & 0.056 $\pm$ 0.002 & 140.113 $\pm$ 4.360 \\
#  & SC-SRGF & \underline{0.891 $\pm$ 0.125} & \underline{0.854 $\pm$ 0.093} & 12.338 $\pm$ 0.000 & 0.194 $\pm$ 0.000 & 0.936 $\pm$ 0.014 & 0.132 $\pm$ 0.061 & 142.764 $\pm$ 4.481 \\
# \cline{1-9}
# \multirow[c]{14}{*}{alizadeh-2000-v3} & Batch CoHiRF & 0.345 $\pm$ 0.029 & 0.484 $\pm$ 0.016 & 4.346 $\pm$ 0.325 & 0.052 $\pm$ 0.014 & \bfseries 0.403 $\pm$ 0.061 & 0.135 $\pm$ 0.039 & 154.529 $\pm$ 4.869 \\
#  & Batch CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & -0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 2.194 $\pm$ 0.170 & 142.468 $\pm$ 5.785 \\
#  & Batch CoHiRF-KernelRBF & 0.054 $\pm$ 0.010 & 0.066 $\pm$ 0.027 & 1.595 $\pm$ 0.182 & 0.052 $\pm$ 0.024 & \underline{0.449 $\pm$ 0.038} & 0.324 $\pm$ 0.343 & 164.356 $\pm$ 7.150 \\
#  & Batch CoHiRF-SC-SRGF & 0.403 $\pm$ 0.018 & 0.529 $\pm$ 0.058 & 14.194 $\pm$ 1.270 & 0.177 $\pm$ 0.012 & 1.645 $\pm$ 0.161 & 1.699 $\pm$ 0.904 & 264.497 $\pm$ 29.204 \\
#  & CoHiRF & 0.458 $\pm$ 0.019 & 0.599 $\pm$ 0.021 & \bfseries 15.161 $\pm$ 0.000 & 0.189 $\pm$ 0.001 & 0.874 $\pm$ 0.035 & 0.048 $\pm$ 0.023 & 145.170 $\pm$ 4.986 \\
#  & CoHiRF Top-Down & \underline{0.509 $\pm$ 0.015} & \underline{0.693 $\pm$ 0.059} & \underline{15.142 $\pm$ 0.044} & \bfseries 0.250 $\pm$ 0.025 & 1.281 $\pm$ 0.093 & 0.118 $\pm$ 0.089 & 143.143 $\pm$ 4.139 \\
#  & CoHiRF Top-Down Inv & 0.467 $\pm$ 0.049 & 0.594 $\pm$ 0.026 & \bfseries 15.161 $\pm$ 0.000 & \underline{0.205 $\pm$ 0.035} & 1.407 $\pm$ 0.187 & 0.192 $\pm$ 0.220 & 152.675 $\pm$ 5.363 \\
#  & CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & -0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.646 $\pm$ 0.122 & 141.051 $\pm$ 5.471 \\
#  & CoHiRF-KernelRBF & 0.056 $\pm$ 0.019 & 0.091 $\pm$ 0.008 & 1.917 $\pm$ 0.655 & 0.022 $\pm$ 0.030 & 0.524 $\pm$ 0.066 & 0.198 $\pm$ 0.119 & 157.771 $\pm$ 5.139 \\
#  & CoHiRF-SC-SRGF & 0.443 $\pm$ 0.013 & 0.628 $\pm$ 0.019 & 7.411 $\pm$ 0.060 & 0.093 $\pm$ 0.002 & 1.562 $\pm$ 0.047 & 0.928 $\pm$ 1.146 & 245.332 $\pm$ 13.850 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.055 $\pm$ 0.019 & 138.187 $\pm$ 4.092 \\
#  & K-Means & \underline{0.509 $\pm$ 0.016} & 0.678 $\pm$ 0.047 & \bfseries 15.161 $\pm$ 0.000 & 0.204 $\pm$ 0.036 & 0.929 $\pm$ 0.013 & 0.013 $\pm$ 0.008 & 138.098 $\pm$ 5.324 \\
#  & Kernel RBF K-Means & 0.057 $\pm$ 0.007 & 0.090 $\pm$ 0.025 & 1.878 $\pm$ 0.510 & 0.020 $\pm$ 0.005 & 1.689 $\pm$ 0.019 & 0.057 $\pm$ 0.013 & 139.990 $\pm$ 3.348 \\
#  & SC-SRGF & \bfseries 0.519 $\pm$ 0.000 & \bfseries 0.702 $\pm$ 0.048 & 12.341 $\pm$ 0.000 & 0.194 $\pm$ 0.000 & 0.931 $\pm$ 0.011 & 0.124 $\pm$ 0.055 & 144.219 $\pm$ 6.544 \\
# \cline{1-9}
# \multirow[c]{14}{*}{armstrong-2002-v1} & Batch CoHiRF & 0.225 $\pm$ 0.071 & 0.267 $\pm$ 0.061 & 2.933 $\pm$ 0.333 & 0.003 $\pm$ 0.007 & \bfseries 0.401 $\pm$ 0.025 & 0.125 $\pm$ 0.039 & 90.402 $\pm$ 3.605 \\
#  & Batch CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 2.880 $\pm$ 0.259 & 81.404 $\pm$ 2.704 \\
#  & Batch CoHiRF-KernelRBF & 0.062 $\pm$ 0.020 & 0.059 $\pm$ 0.018 & 1.707 $\pm$ 0.501 & 0.024 $\pm$ 0.018 & \underline{0.499 $\pm$ 0.076} & 0.500 $\pm$ 1.004 & 99.823 $\pm$ 4.469 \\
#  & Batch CoHiRF-SC-SRGF & 0.425 $\pm$ 0.087 & 0.441 $\pm$ 0.076 & 5.142 $\pm$ 0.639 & 0.093 $\pm$ 0.026 & 1.745 $\pm$ 0.126 & 2.173 $\pm$ 1.508 & 219.112 $\pm$ 42.973 \\
#  & CoHiRF & 0.664 $\pm$ 0.111 & 0.594 $\pm$ 0.088 & 6.153 $\pm$ 0.705 & 0.212 $\pm$ 0.072 & 0.862 $\pm$ 0.176 & 0.055 $\pm$ 0.020 & 83.250 $\pm$ 3.069 \\
#  & CoHiRF Top-Down & 0.737 $\pm$ 0.064 & \underline{0.692 $\pm$ 0.079} & 6.208 $\pm$ 0.443 & \bfseries 0.289 $\pm$ 0.000 & 0.661 $\pm$ 0.084 & 0.125 $\pm$ 0.083 & 85.467 $\pm$ 3.387 \\
#  & CoHiRF Top-Down Inv & \underline{0.760 $\pm$ 0.083} & 0.651 $\pm$ 0.063 & \bfseries 6.512 $\pm$ 0.003 & 0.184 $\pm$ 0.072 & 1.283 $\pm$ 0.134 & 0.168 $\pm$ 0.106 & 90.489 $\pm$ 4.768 \\
#  & CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.696 $\pm$ 0.107 & 79.607 $\pm$ 3.763 \\
#  & CoHiRF-KernelRBF & 0.060 $\pm$ 0.028 & 0.065 $\pm$ 0.030 & 1.379 $\pm$ 0.118 & 0.013 $\pm$ 0.011 & 0.573 $\pm$ 0.053 & 0.143 $\pm$ 0.088 & 93.060 $\pm$ 4.523 \\
#  & CoHiRF-SC-SRGF & 0.372 $\pm$ 0.039 & 0.445 $\pm$ 0.017 & 3.424 $\pm$ 0.055 & 0.027 $\pm$ 0.005 & 2.003 $\pm$ 0.224 & 2.140 $\pm$ 1.544 & 190.756 $\pm$ 11.710 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.065 $\pm$ 0.033 & 74.223 $\pm$ 1.656 \\
#  & K-Means & \bfseries 0.787 $\pm$ 0.167 & \bfseries 0.799 $\pm$ 0.030 & \underline{6.477 $\pm$ 0.032} & \underline{0.244 $\pm$ 0.062} & 0.903 $\pm$ 0.046 & 0.007 $\pm$ 0.002 & 74.288 $\pm$ 1.689 \\
#  & Kernel RBF K-Means & 0.041 $\pm$ 0.018 & 0.078 $\pm$ 0.009 & 1.283 $\pm$ 0.095 & 0.016 $\pm$ 0.006 & 1.844 $\pm$ 0.040 & 0.032 $\pm$ 0.003 & 75.694 $\pm$ 1.136 \\
#  & SC-SRGF & 0.313 $\pm$ 0.046 & 0.421 $\pm$ 0.096 & 4.812 $\pm$ 0.029 & 0.067 $\pm$ 0.004 & 1.344 $\pm$ 0.022 & 0.125 $\pm$ 0.048 & 82.755 $\pm$ 2.381 \\
# \cline{1-9}
# \multirow[c]{15}{*}{binary-alpha-digits} & Batch CoHiRF & 0.129 $\pm$ 0.004 & 0.334 $\pm$ 0.008 & 8.495 $\pm$ 0.474 & -0.046 $\pm$ 0.009 & 1.279 $\pm$ 0.012 & 3.343 $\pm$ 3.585 & 229.223 $\pm$ 108.711 \\
#  & Batch CoHiRF-DBSCAN & 0.006 $\pm$ 0.008 & 0.032 $\pm$ 0.033 & 1.473 $\pm$ 0.131 & \underline{0.080 $\pm$ 0.025} & \bfseries 0.837 $\pm$ 0.037 & 0.284 $\pm$ 0.238 & 58.526 $\pm$ 3.098 \\
#  & Batch CoHiRF-KernelRBF & 0.002 $\pm$ 0.001 & 0.008 $\pm$ 0.003 & 1.322 $\pm$ 0.096 & 0.001 $\pm$ 0.001 & 2.035 $\pm$ 0.076 & 5.491 $\pm$ 9.362 & 275.575 $\pm$ 162.247 \\
#  & Batch CoHiRF-SC-SRGF & 0.113 $\pm$ 0.021 & 0.299 $\pm$ 0.019 & 20.400 $\pm$ 1.815 & 0.054 $\pm$ 0.032 & 1.840 $\pm$ 0.229 & 11.215 $\pm$ 11.186 & 673.653 $\pm$ 270.001 \\
#  & CoHiRF & 0.204 $\pm$ 0.009 & 0.409 $\pm$ 0.010 & 71.618 $\pm$ 1.274 & 0.050 $\pm$ 0.000 & 1.245 $\pm$ 0.025 & 1.369 $\pm$ 2.014 & 105.977 $\pm$ 60.248 \\
#  & CoHiRF Top-Down & 0.097 $\pm$ 0.005 & 0.339 $\pm$ 0.009 & \underline{72.568 $\pm$ 0.009} & 0.052 $\pm$ 0.003 & 3.476 $\pm$ 0.049 & 0.125 $\pm$ 0.068 & 58.463 $\pm$ 1.849 \\
#  & CoHiRF Top-Down Inv & 0.203 $\pm$ 0.010 & 0.419 $\pm$ 0.007 & 72.392 $\pm$ 0.112 & 0.050 $\pm$ 0.000 & 1.669 $\pm$ 0.028 & 0.910 $\pm$ 1.101 & 98.026 $\pm$ 40.261 \\
#  & CoHiRF-1000 & 0.202 $\pm$ 0.005 & 0.402 $\pm$ 0.008 & 71.799 $\pm$ 0.646 & 0.049 $\pm$ 0.001 & 1.512 $\pm$ 0.051 & 1.311 $\pm$ 1.773 & 95.498 $\pm$ 46.685 \\
#  & CoHiRF-DBSCAN & 0.009 $\pm$ 0.005 & 0.035 $\pm$ 0.026 & 1.353 $\pm$ 0.109 & 0.011 $\pm$ 0.035 & \underline{0.862 $\pm$ 0.035} & 0.189 $\pm$ 0.041 & 57.093 $\pm$ 1.612 \\
#  & CoHiRF-KernelRBF & 0.002 $\pm$ 0.001 & 0.010 $\pm$ 0.003 & 1.422 $\pm$ 0.335 & 0.001 $\pm$ 0.001 & 1.995 $\pm$ 0.040 & 7.088 $\pm$ 9.868 & 409.435 $\pm$ 263.802 \\
#  & CoHiRF-SC-SRGF & 0.125 $\pm$ 0.008 & 0.403 $\pm$ 0.013 & 40.709 $\pm$ 1.945 & 0.039 $\pm$ 0.001 & 2.857 $\pm$ 0.163 & 50.364 $\pm$ 20.930 & 4213.418 $\pm$ 740.064 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.002 $\pm$ 0.003 & 1.574 $\pm$ 3.525 & -0.561 $\pm$ 0.602 & 600.462 $\pm$ 547.090 & 0.053 $\pm$ 0.036 & 44.413 $\pm$ 2.076 \\
#  & K-Means & \underline{0.293 $\pm$ 0.006} & \underline{0.524 $\pm$ 0.009} & \bfseries 72.580 $\pm$ 0.001 & 0.059 $\pm$ 0.001 & 2.820 $\pm$ 0.012 & 0.051 $\pm$ 0.020 & 47.400 $\pm$ 2.055 \\
#  & Kernel RBF K-Means & 0.002 $\pm$ 0.001 & 0.009 $\pm$ 0.002 & 1.357 $\pm$ 0.162 & 0.001 $\pm$ 0.000 & 11.235 $\pm$ 0.075 & 0.075 $\pm$ 0.011 & 49.456 $\pm$ 1.751 \\
#  & SC-SRGF & \bfseries 0.308 $\pm$ 0.007 & \bfseries 0.570 $\pm$ 0.007 & 60.837 $\pm$ 2.527 & \bfseries 0.086 $\pm$ 0.000 & 2.473 $\pm$ 0.223 & 24.219 $\pm$ 17.587 & 1759.575 $\pm$ 428.415 \\
# \cline{1-9}
# \multirow[c]{14}{*}{bittner-2000} & Batch CoHiRF & 0.125 $\pm$ 0.037 & 0.157 $\pm$ 0.049 & 2.761 $\pm$ 0.319 & 0.032 $\pm$ 0.012 & \bfseries 0.365 $\pm$ 0.025 & 0.096 $\pm$ 0.057 & 160.084 $\pm$ 4.539 \\
#  & Batch CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.913 $\pm$ 0.056 & 153.356 $\pm$ 3.464 \\
#  & Batch CoHiRF-KernelRBF & 0.088 $\pm$ 0.015 & 0.098 $\pm$ 0.011 & 1.918 $\pm$ 0.217 & 0.041 $\pm$ 0.020 & \underline{0.499 $\pm$ 0.083} & 0.224 $\pm$ 0.180 & 171.649 $\pm$ 4.442 \\
#  & Batch CoHiRF-SC-SRGF & 0.078 $\pm$ 0.041 & 0.139 $\pm$ 0.064 & 5.168 $\pm$ 0.307 & 0.097 $\pm$ 0.006 & 1.343 $\pm$ 0.268 & 1.172 $\pm$ 0.985 & 246.154 $\pm$ 21.881 \\
#  & CoHiRF & 0.120 $\pm$ 0.039 & 0.172 $\pm$ 0.014 & 5.690 $\pm$ 0.061 & 0.178 $\pm$ 0.021 & 0.553 $\pm$ 0.086 & 0.074 $\pm$ 0.036 & 150.680 $\pm$ 4.180 \\
#  & CoHiRF Top-Down & \underline{0.180 $\pm$ 0.097} & 0.196 $\pm$ 0.076 & 5.690 $\pm$ 0.087 & \bfseries 0.209 $\pm$ 0.007 & 0.817 $\pm$ 0.288 & 0.144 $\pm$ 0.095 & 154.846 $\pm$ 4.990 \\
#  & CoHiRF Top-Down Inv & 0.124 $\pm$ 0.017 & \underline{0.205 $\pm$ 0.026} & \bfseries 5.754 $\pm$ 0.000 & 0.179 $\pm$ 0.028 & 0.617 $\pm$ 0.056 & 0.259 $\pm$ 0.167 & 163.690 $\pm$ 6.866 \\
#  & CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.596 $\pm$ 0.099 & 146.799 $\pm$ 3.067 \\
#  & CoHiRF-KernelRBF & 0.104 $\pm$ 0.049 & 0.136 $\pm$ 0.043 & 1.569 $\pm$ 0.146 & 0.054 $\pm$ 0.066 & 0.530 $\pm$ 0.053 & 0.191 $\pm$ 0.118 & 158.762 $\pm$ 4.244 \\
#  & CoHiRF-SC-SRGF & 0.058 $\pm$ 0.023 & 0.103 $\pm$ 0.023 & 2.998 $\pm$ 0.125 & 0.057 $\pm$ 0.005 & 1.638 $\pm$ 0.060 & 1.282 $\pm$ 1.413 & 259.234 $\pm$ 12.460 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.049 $\pm$ 0.008 & 143.705 $\pm$ 3.548 \\
#  & K-Means & \bfseries 0.182 $\pm$ 0.058 & \bfseries 0.234 $\pm$ 0.043 & \underline{5.715 $\pm$ 0.056} & \underline{0.203 $\pm$ 0.017} & 0.623 $\pm$ 0.004 & 0.011 $\pm$ 0.002 & 143.020 $\pm$ 4.946 \\
#  & Kernel RBF K-Means & 0.090 $\pm$ 0.038 & 0.137 $\pm$ 0.034 & 1.334 $\pm$ 0.128 & 0.043 $\pm$ 0.021 & 0.905 $\pm$ 0.014 & 0.062 $\pm$ 0.017 & 148.491 $\pm$ 2.636 \\
#  & SC-SRGF & 0.132 $\pm$ 0.035 & \underline{0.205 $\pm$ 0.046} & 4.982 $\pm$ 0.099 & 0.075 $\pm$ 0.013 & 0.644 $\pm$ 0.000 & 0.105 $\pm$ 0.036 & 149.118 $\pm$ 7.488 \\
# \cline{1-9}
# \multirow[c]{14}{*}{bredel-2005} & Batch CoHiRF & 0.235 $\pm$ 0.040 & 0.253 $\pm$ 0.043 & 2.333 $\pm$ 0.069 & 0.013 $\pm$ 0.006 & \bfseries 0.420 $\pm$ 0.024 & 0.100 $\pm$ 0.029 & 127.741 $\pm$ 4.873 \\
#  & Batch CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 2.276 $\pm$ 0.219 & 118.556 $\pm$ 1.399 \\
#  & Batch CoHiRF-KernelRBF & 0.107 $\pm$ 0.066 & 0.092 $\pm$ 0.012 & 1.538 $\pm$ 0.137 & 0.024 $\pm$ 0.025 & \underline{0.507 $\pm$ 0.051} & 0.224 $\pm$ 0.213 & 137.172 $\pm$ 6.963 \\
#  & Batch CoHiRF-SC-SRGF & 0.398 $\pm$ 0.090 & 0.363 $\pm$ 0.055 & 4.140 $\pm$ 0.428 & 0.062 $\pm$ 0.006 & 1.562 $\pm$ 0.235 & 1.851 $\pm$ 1.872 & 222.026 $\pm$ 29.960 \\
#  & CoHiRF & 0.631 $\pm$ 0.054 & 0.442 $\pm$ 0.063 & 4.535 $\pm$ 0.450 & \bfseries 0.291 $\pm$ 0.000 & 0.646 $\pm$ 0.080 & 0.051 $\pm$ 0.020 & 117.699 $\pm$ 3.289 \\
#  & CoHiRF Top-Down & 0.625 $\pm$ 0.068 & \underline{0.482 $\pm$ 0.052} & \bfseries 4.752 $\pm$ 0.036 & \bfseries 0.291 $\pm$ 0.000 & 0.564 $\pm$ 0.000 & 0.146 $\pm$ 0.083 & 124.835 $\pm$ 3.050 \\
#  & CoHiRF Top-Down Inv & \bfseries 0.650 $\pm$ 0.093 & 0.436 $\pm$ 0.028 & 4.745 $\pm$ 0.022 & 0.145 $\pm$ 0.086 & 0.700 $\pm$ 0.090 & 0.191 $\pm$ 0.159 & 129.508 $\pm$ 5.788 \\
#  & CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.717 $\pm$ 0.279 & 116.491 $\pm$ 4.163 \\
#  & CoHiRF-KernelRBF & 0.081 $\pm$ 0.022 & 0.092 $\pm$ 0.015 & 1.501 $\pm$ 0.209 & 0.001 $\pm$ 0.005 & \underline{0.507 $\pm$ 0.046} & 0.168 $\pm$ 0.138 & 128.977 $\pm$ 5.947 \\
#  & CoHiRF-SC-SRGF & 0.326 $\pm$ 0.025 & 0.413 $\pm$ 0.027 & 2.970 $\pm$ 0.182 & 0.036 $\pm$ 0.004 & 1.979 $\pm$ 0.128 & 1.668 $\pm$ 1.462 & 231.743 $\pm$ 12.202 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.061 $\pm$ 0.030 & 111.836 $\pm$ 2.300 \\
#  & K-Means & 0.582 $\pm$ 0.079 & 0.457 $\pm$ 0.075 & \underline{4.748 $\pm$ 0.020} & \underline{0.241 $\pm$ 0.069} & 0.893 $\pm$ 0.020 & 0.010 $\pm$ 0.002 & 112.852 $\pm$ 5.267 \\
#  & Kernel RBF K-Means & 0.077 $\pm$ 0.014 & 0.100 $\pm$ 0.023 & 1.340 $\pm$ 0.167 & 0.031 $\pm$ 0.016 & 1.293 $\pm$ 0.035 & 0.047 $\pm$ 0.003 & 114.638 $\pm$ 3.945 \\
#  & SC-SRGF & \underline{0.640 $\pm$ 0.034} & \bfseries 0.538 $\pm$ 0.047 & 4.630 $\pm$ 0.088 & 0.071 $\pm$ 0.001 & 0.948 $\pm$ 0.004 & 0.130 $\pm$ 0.057 & 118.755 $\pm$ 3.830 \\
# \cline{1-9}
# \multirow[c]{14}{*}{chowdary-2006} & Batch CoHiRF & 0.415 $\pm$ 0.074 & 0.325 $\pm$ 0.039 & \bfseries 92.598 $\pm$ 58.876 & 0.248 $\pm$ 0.084 & \bfseries 0.147 $\pm$ 0.081 & 0.209 $\pm$ 0.112 & 41.614 $\pm$ 3.488 \\
#  & Batch CoHiRF-DBSCAN & 0.068 $\pm$ 0.053 & 0.099 $\pm$ 0.047 & 37.353 $\pm$ 0.000 & 0.398 $\pm$ 0.366 & 0.369 $\pm$ 0.157 & 0.073 $\pm$ 0.036 & 26.751 $\pm$ 1.500 \\
#  & Batch CoHiRF-KernelRBF & 0.050 $\pm$ 0.016 & 0.090 $\pm$ 0.047 & 45.379 $\pm$ 64.930 & 0.090 $\pm$ 0.067 & 0.201 $\pm$ 0.110 & 0.226 $\pm$ 0.206 & 37.772 $\pm$ 2.822 \\
#  & Batch CoHiRF-SC-SRGF & 0.438 $\pm$ 0.086 & 0.473 $\pm$ 0.019 & 32.397 $\pm$ 3.211 & 0.448 $\pm$ 0.122 & 1.592 $\pm$ 0.084 & 2.521 $\pm$ 1.737 & 196.271 $\pm$ 40.487 \\
#  & CoHiRF & 0.535 $\pm$ 0.432 & 0.226 $\pm$ 0.226 & \underline{60.051 $\pm$ 0.000} & 0.769 $\pm$ 0.011 & 0.168 $\pm$ 0.000 & 0.031 $\pm$ 0.011 & 23.496 $\pm$ 0.721 \\
#  & CoHiRF Top-Down & 0.679 $\pm$ 0.347 & 0.630 $\pm$ 0.292 & 56.150 $\pm$ 5.347 & \bfseries 0.774 $\pm$ 0.000 & \underline{0.159 $\pm$ 0.012} & 0.075 $\pm$ 0.036 & 27.240 $\pm$ 1.301 \\
#  & CoHiRF Top-Down Inv & \underline{0.880 $\pm$ 0.019} & \underline{0.783 $\pm$ 0.013} & \underline{60.051 $\pm$ 0.000} & 0.742 $\pm$ 0.007 & 0.422 $\pm$ 0.003 & 0.183 $\pm$ 0.134 & 32.440 $\pm$ 3.053 \\
#  & CoHiRF-DBSCAN & 0.063 $\pm$ 0.007 & 0.067 $\pm$ 0.055 & 47.579 $\pm$ 22.864 & 0.675 $\pm$ 0.021 & 0.168 $\pm$ 0.000 & 0.024 $\pm$ 0.003 & 23.143 $\pm$ 0.995 \\
#  & CoHiRF-KernelRBF & 0.155 $\pm$ 0.152 & 0.177 $\pm$ 0.133 & 23.377 $\pm$ 24.772 & 0.032 $\pm$ 0.039 & 0.370 $\pm$ 0.097 & 0.116 $\pm$ 0.098 & 32.623 $\pm$ 2.496 \\
#  & CoHiRF-SC-SRGF & 0.702 $\pm$ 0.042 & 0.647 $\pm$ 0.058 & 30.348 $\pm$ 5.508 & 0.174 $\pm$ 0.006 & 1.450 $\pm$ 0.044 & 1.713 $\pm$ 1.668 & 130.320 $\pm$ 11.670 \\
#  & DBSCAN & 0.375 $\pm$ 0.011 & 0.327 $\pm$ 0.013 & 27.190 $\pm$ 2.510 & 0.598 $\pm$ 0.022 & 0.946 $\pm$ 0.000 & 0.003 $\pm$ 0.000 & 18.056 $\pm$ 0.666 \\
#  & K-Means & 0.854 $\pm$ 0.022 & 0.756 $\pm$ 0.025 & \underline{60.051 $\pm$ 0.000} & \underline{0.771 $\pm$ 0.008} & 0.332 $\pm$ 0.255 & 0.003 $\pm$ 0.001 & 18.274 $\pm$ 0.721 \\
#  & Kernel RBF K-Means & 0.057 $\pm$ 0.034 & 0.051 $\pm$ 0.012 & 2.426 $\pm$ 0.552 & 0.078 $\pm$ 0.037 & 2.706 $\pm$ 0.096 & 0.012 $\pm$ 0.002 & 18.872 $\pm$ 0.843 \\
#  & SC-SRGF & \bfseries 0.924 $\pm$ 0.000 & \bfseries 0.859 $\pm$ 0.000 & 23.009 $\pm$ 4.973 & 0.222 $\pm$ 0.007 & 1.101 $\pm$ 0.022 & 0.179 $\pm$ 0.093 & 29.310 $\pm$ 2.845 \\
# \cline{1-9}
# \multirow[c]{15}{*}{coil-20} & Batch CoHiRF & 0.381 $\pm$ 0.008 & 0.632 $\pm$ 0.010 & 62.639 $\pm$ 4.789 & 0.107 $\pm$ 0.018 & 1.532 $\pm$ 0.065 & 0.541 $\pm$ 0.153 & 172.626 $\pm$ 7.695 \\
#  & Batch CoHiRF-DBSCAN & 0.335 $\pm$ 0.055 & 0.588 $\pm$ 0.051 & \bfseries 291.162 $\pm$ 71.197 & -0.001 $\pm$ 0.008 & \bfseries 0.077 $\pm$ 0.041 & 1.305 $\pm$ 1.005 & 175.064 $\pm$ 19.429 \\
#  & Batch CoHiRF-KernelRBF & 0.004 $\pm$ 0.006 & 0.023 $\pm$ 0.020 & 1.804 $\pm$ 0.276 & 0.005 $\pm$ 0.002 & 2.404 $\pm$ 0.100 & 10.855 $\pm$ 17.100 & 510.956 $\pm$ 280.500 \\
#  & Batch CoHiRF-SC-SRGF & 0.198 $\pm$ 0.024 & 0.498 $\pm$ 0.019 & 111.238 $\pm$ 14.325 & 0.050 $\pm$ 0.016 & 1.374 $\pm$ 0.087 & 6.045 $\pm$ 4.788 & 502.966 $\pm$ 77.945 \\
#  & CoHiRF & 0.355 $\pm$ 0.041 & 0.627 $\pm$ 0.017 & 287.989 $\pm$ 0.164 & \underline{0.220 $\pm$ 0.095} & 1.597 $\pm$ 0.166 & 0.290 $\pm$ 0.087 & 151.293 $\pm$ 4.393 \\
#  & CoHiRF Top-Down & 0.244 $\pm$ 0.021 & 0.571 $\pm$ 0.016 & 288.092 $\pm$ 0.002 & 0.181 $\pm$ 0.012 & 1.795 $\pm$ 0.248 & 0.327 $\pm$ 0.215 & 151.457 $\pm$ 6.068 \\
#  & CoHiRF Top-Down Inv & 0.336 $\pm$ 0.011 & 0.633 $\pm$ 0.009 & 288.060 $\pm$ 0.037 & 0.181 $\pm$ 0.002 & 1.940 $\pm$ 0.006 & 0.305 $\pm$ 0.180 & 155.954 $\pm$ 7.481 \\
#  & CoHiRF-1000 & 0.338 $\pm$ 0.009 & 0.632 $\pm$ 0.006 & 288.053 $\pm$ 0.078 & 0.180 $\pm$ 0.004 & 1.725 $\pm$ 0.039 & 0.264 $\pm$ 0.053 & 142.514 $\pm$ 3.021 \\
#  & CoHiRF-DBSCAN & \underline{0.684 $\pm$ 0.040} & 0.756 $\pm$ 0.052 & 45.358 $\pm$ 69.153 & 0.148 $\pm$ 0.030 & \underline{0.429 $\pm$ 0.223} & 0.321 $\pm$ 0.042 & 151.694 $\pm$ 4.712 \\
#  & CoHiRF-KernelRBF & 0.007 $\pm$ 0.009 & 0.020 $\pm$ 0.020 & 7.272 $\pm$ 10.222 & 0.003 $\pm$ 0.002 & 2.548 $\pm$ 0.084 & 7.423 $\pm$ 12.185 & 563.079 $\pm$ 301.382 \\
#  & CoHiRF-SC-SRGF & 0.208 $\pm$ 0.015 & 0.628 $\pm$ 0.014 & 92.939 $\pm$ 5.423 & 0.072 $\pm$ 0.006 & 2.106 $\pm$ 0.077 & 68.928 $\pm$ 51.055 & 6550.924 $\pm$ 1263.977 \\
#  & DBSCAN & 0.143 $\pm$ 0.000 & 0.563 $\pm$ 0.000 & 56.906 $\pm$ 0.000 & -0.005 $\pm$ 0.000 & 1.175 $\pm$ 0.019 & 0.049 $\pm$ 0.006 & 132.351 $\pm$ 3.358 \\
#  & K-Means & 0.664 $\pm$ 0.005 & \underline{0.803 $\pm$ 0.003} & \underline{288.095 $\pm$ 0.000} & \bfseries 0.225 $\pm$ 0.002 & 1.737 $\pm$ 0.018 & 0.085 $\pm$ 0.032 & 135.341 $\pm$ 4.313 \\
#  & Kernel RBF K-Means & 0.004 $\pm$ 0.003 & 0.019 $\pm$ 0.012 & 1.795 $\pm$ 0.427 & 0.001 $\pm$ 0.000 & 12.297 $\pm$ 0.107 & 0.094 $\pm$ 0.011 & 135.192 $\pm$ 5.138 \\
#  & SC-SRGF & \bfseries 0.779 $\pm$ 0.006 & \bfseries 0.928 $\pm$ 0.003 & 84.948 $\pm$ 0.314 & 0.160 $\pm$ 0.001 & 1.581 $\pm$ 0.414 & 39.291 $\pm$ 16.565 & 2507.799 $\pm$ 517.402 \\
# \cline{1-9}
# \multirow[c]{10}{*}{criteo-uplift-balanced} & Batch CoHiRF & 0.207 $\pm$ 0.026 & 0.184 $\pm$ 0.009 & 67140.709 $\pm$ 5693.386 & No Run $\pm$ No Run & No Run $\pm$ No Run & 18.507 $\pm$ 19.798 & 2934.583 $\pm$ 638.620 \\
#  & Batch CoHiRF-DBSCAN & 0.061 $\pm$ 0.010 & 0.069 $\pm$ 0.008 & 6322.492 $\pm$ 2981.317 & No Run $\pm$ No Run & No Run $\pm$ No Run & 221.815 $\pm$ 338.091 & 14024.411 $\pm$ 7281.496 \\
#  & Batch CoHiRF-DBSCAN-Random & 0.053 $\pm$ 0.017 & 0.081 $\pm$ 0.005 & 10125.168 $\pm$ 4419.414 & No Run $\pm$ No Run & No Run $\pm$ No Run & 114.781 $\pm$ 142.552 & 18489.898 $\pm$ 10080.976 \\
#  & Batch CoHiRF-DBSCAN-Stratified & 0.064 $\pm$ 0.014 & 0.077 $\pm$ 0.007 & 13733.735 $\pm$ 10121.863 & No Run $\pm$ No Run & No Run $\pm$ No Run & 434.737 $\pm$ 663.150 & 37253.148 $\pm$ 18804.306 \\
#  & Batch CoHiRF-KernelRBF & 0.173 $\pm$ 0.021 & 0.181 $\pm$ 0.009 & 98686.688 $\pm$ 50259.567 & No Run $\pm$ No Run & No Run $\pm$ No Run & 75.929 $\pm$ 47.073 & 5600.669 $\pm$ 825.290 \\
#  & Batch CoHiRF-KernelRBF-Random & 0.185 $\pm$ 0.046 & 0.186 $\pm$ 0.002 & 90666.369 $\pm$ 33325.105 & No Run $\pm$ No Run & No Run $\pm$ No Run & 40.655 $\pm$ 11.314 & 5056.488 $\pm$ 390.698 \\
#  & Batch CoHiRF-KernelRBF-Stratified & 0.174 $\pm$ 0.031 & \underline{0.188 $\pm$ 0.002} & \underline{111779.858 $\pm$ 32026.844} & No Run $\pm$ No Run & No Run $\pm$ No Run & 39.605 $\pm$ 9.698 & 5259.951 $\pm$ 508.768 \\
#  & Batch CoHiRF-Random & \underline{0.239 $\pm$ 0.025} & 0.183 $\pm$ 0.004 & 68213.703 $\pm$ 6821.142 & No Run $\pm$ No Run & No Run $\pm$ No Run & 4.027 $\pm$ 0.651 & 2553.361 $\pm$ 111.267 \\
#  & Batch CoHiRF-Stratified & 0.205 $\pm$ 0.007 & 0.175 $\pm$ 0.004 & 84130.016 $\pm$ 21142.843 & No Run $\pm$ No Run & No Run $\pm$ No Run & 11.139 $\pm$ 0.378 & 2993.926 $\pm$ 107.076 \\
#  & K-Means & \bfseries 0.258 $\pm$ 0.032 & \bfseries 0.204 $\pm$ 0.003 & \bfseries 340138.205 $\pm$ 0.201 & No Run $\pm$ No Run & No Run $\pm$ No Run & 0.890 $\pm$ 0.437 & 2136.368 $\pm$ 65.248 \\
# \cline{1-9}
# \multirow[c]{14}{*}{ecoli} & Batch CoHiRF & 0.610 $\pm$ 0.031 & 0.565 $\pm$ 0.034 & 86.247 $\pm$ 6.939 & 0.242 $\pm$ 0.267 & 1.211 $\pm$ 0.103 & 0.211 $\pm$ 0.330 & 31.196 $\pm$ 8.773 \\
#  & Batch CoHiRF-DBSCAN & 0.404 $\pm$ 0.088 & 0.336 $\pm$ 0.051 & 67.693 $\pm$ 2.754 & \bfseries 0.836 $\pm$ 0.000 & \bfseries 0.116 $\pm$ 0.000 & 0.262 $\pm$ 0.964 & 18.254 $\pm$ 1.188 \\
#  & Batch CoHiRF-KernelRBF & 0.583 $\pm$ 0.056 & 0.524 $\pm$ 0.055 & 48.256 $\pm$ 7.249 & 0.719 $\pm$ 0.261 & 1.013 $\pm$ 0.367 & 0.256 $\pm$ 0.355 & 39.740 $\pm$ 9.159 \\
#  & Batch CoHiRF-SC-SRGF & 0.679 $\pm$ 0.022 & 0.611 $\pm$ 0.020 & 97.847 $\pm$ 12.942 & 0.302 $\pm$ 0.030 & 1.118 $\pm$ 0.062 & 5.509 $\pm$ 4.352 & 355.169 $\pm$ 98.230 \\
#  & CoHiRF & \underline{0.724 $\pm$ 0.020} & \bfseries 0.683 $\pm$ 0.005 & 167.933 $\pm$ 7.158 & \underline{0.780 $\pm$ 0.124} & \underline{0.293 $\pm$ 0.252} & 0.046 $\pm$ 0.015 & 16.676 $\pm$ 1.370 \\
#  & CoHiRF Top-Down & 0.717 $\pm$ 0.020 & 0.674 $\pm$ 0.016 & \underline{170.153 $\pm$ 5.242} & \bfseries 0.836 $\pm$ 0.000 & \bfseries 0.116 $\pm$ 0.000 & 0.161 $\pm$ 0.084 & 22.035 $\pm$ 2.877 \\
#  & CoHiRF Top-Down Inv & 0.718 $\pm$ 0.013 & 0.670 $\pm$ 0.009 & 148.557 $\pm$ 7.879 & 0.430 $\pm$ 0.071 & 0.769 $\pm$ 0.054 & 0.239 $\pm$ 0.391 & 29.096 $\pm$ 26.095 \\
#  & CoHiRF-DBSCAN & 0.568 $\pm$ 0.046 & 0.374 $\pm$ 0.145 & 68.924 $\pm$ 0.000 & \bfseries 0.836 $\pm$ 0.000 & \bfseries 0.116 $\pm$ 0.000 & 0.056 $\pm$ 0.056 & 14.713 $\pm$ 0.533 \\
#  & CoHiRF-KernelRBF & 0.668 $\pm$ 0.044 & 0.614 $\pm$ 0.034 & 88.747 $\pm$ 13.714 & 0.501 $\pm$ 0.122 & 0.655 $\pm$ 0.359 & 0.146 $\pm$ 0.223 & 30.396 $\pm$ 5.212 \\
#  & CoHiRF-SC-SRGF & 0.723 $\pm$ 0.011 & 0.668 $\pm$ 0.015 & 99.576 $\pm$ 12.660 & 0.347 $\pm$ 0.021 & 1.096 $\pm$ 0.080 & 4.823 $\pm$ 2.437 & 299.834 $\pm$ 37.448 \\
#  & DBSCAN & 0.540 $\pm$ 0.040 & 0.451 $\pm$ 0.037 & 68.924 $\pm$ 0.000 & \bfseries 0.836 $\pm$ 0.000 & \bfseries 0.116 $\pm$ 0.000 & 0.014 $\pm$ 0.000 & 10.643 $\pm$ 0.597 \\
#  & K-Means & \bfseries 0.730 $\pm$ 0.002 & \underline{0.681 $\pm$ 0.002} & \bfseries 176.248 $\pm$ 0.000 & 0.451 $\pm$ 0.095 & 0.655 $\pm$ 0.109 & 0.003 $\pm$ 0.001 & 9.612 $\pm$ 0.176 \\
#  & Kernel RBF K-Means & 0.687 $\pm$ 0.043 & 0.596 $\pm$ 0.026 & 105.547 $\pm$ 4.183 & 0.292 $\pm$ 0.101 & 1.213 $\pm$ 0.112 & 0.028 $\pm$ 0.007 & 11.685 $\pm$ 1.200 \\
#  & SC-SRGF & 0.713 $\pm$ 0.008 & 0.676 $\pm$ 0.008 & 128.087 $\pm$ 10.908 & 0.482 $\pm$ 0.126 & 1.048 $\pm$ 0.168 & 1.712 $\pm$ 0.621 & 107.123 $\pm$ 15.567 \\
# \cline{1-9}
# \multirow[c]{14}{*}{garber-2001} & Batch CoHiRF & 0.167 $\pm$ 0.050 & 0.164 $\pm$ 0.031 & 3.287 $\pm$ 0.090 & 0.113 $\pm$ 0.008 & \bfseries 0.431 $\pm$ 0.050 & 0.832 $\pm$ 0.494 & 393.396 $\pm$ 15.517 \\
#  & Batch CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 2.384 $\pm$ 0.308 & 342.667 $\pm$ 11.202 \\
#  & Batch CoHiRF-KernelRBF & 0.094 $\pm$ 0.041 & 0.079 $\pm$ 0.034 & 2.342 $\pm$ 0.757 & 0.053 $\pm$ 0.076 & 0.516 $\pm$ 0.111 & 0.889 $\pm$ 1.037 & 398.957 $\pm$ 17.937 \\
#  & Batch CoHiRF-SC-SRGF & 0.259 $\pm$ 0.061 & 0.176 $\pm$ 0.026 & 4.278 $\pm$ 0.432 & 0.101 $\pm$ 0.023 & 2.134 $\pm$ 0.342 & 2.637 $\pm$ 1.986 & 475.379 $\pm$ 37.114 \\
#  & CoHiRF & \underline{0.292 $\pm$ 0.022} & 0.220 $\pm$ 0.025 & \underline{6.108 $\pm$ 0.097} & 0.326 $\pm$ 0.005 & 0.687 $\pm$ 0.205 & 0.200 $\pm$ 0.090 & 344.136 $\pm$ 6.666 \\
#  & CoHiRF Top-Down & 0.267 $\pm$ 0.053 & 0.246 $\pm$ 0.072 & 5.988 $\pm$ 0.112 & \underline{0.327 $\pm$ 0.006} & 0.521 $\pm$ 0.000 & 0.149 $\pm$ 0.085 & 343.099 $\pm$ 4.978 \\
#  & CoHiRF Top-Down Inv & 0.290 $\pm$ 0.012 & 0.225 $\pm$ 0.050 & \bfseries 6.182 $\pm$ 0.069 & 0.305 $\pm$ 0.048 & 1.260 $\pm$ 0.414 & 0.269 $\pm$ 0.174 & 347.736 $\pm$ 7.108 \\
#  & CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.787 $\pm$ 0.324 & 341.659 $\pm$ 10.463 \\
#  & CoHiRF-KernelRBF & 0.099 $\pm$ 0.053 & 0.088 $\pm$ 0.012 & 1.843 $\pm$ 0.357 & 0.016 $\pm$ 0.017 & \underline{0.509 $\pm$ 0.033} & 0.743 $\pm$ 1.061 & 382.672 $\pm$ 12.713 \\
#  & CoHiRF-SC-SRGF & \bfseries 0.437 $\pm$ 0.054 & \bfseries 0.323 $\pm$ 0.016 & 3.922 $\pm$ 0.107 & 0.054 $\pm$ 0.019 & 1.909 $\pm$ 0.118 & 1.613 $\pm$ 1.551 & 462.721 $\pm$ 15.303 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.067 $\pm$ 0.015 & 328.920 $\pm$ 4.465 \\
#  & K-Means & 0.248 $\pm$ 0.044 & 0.241 $\pm$ 0.027 & 5.606 $\pm$ 1.264 & \bfseries 0.333 $\pm$ 0.000 & 0.825 $\pm$ 0.022 & 0.025 $\pm$ 0.006 & 329.200 $\pm$ 6.094 \\
#  & Kernel RBF K-Means & 0.054 $\pm$ 0.021 & 0.098 $\pm$ 0.015 & 1.315 $\pm$ 0.099 & 0.035 $\pm$ 0.024 & 1.734 $\pm$ 0.030 & 0.113 $\pm$ 0.003 & 342.050 $\pm$ 10.857 \\
#  & SC-SRGF & 0.204 $\pm$ 0.035 & \underline{0.251 $\pm$ 0.023} & 4.966 $\pm$ 0.066 & 0.059 $\pm$ 0.003 & 1.130 $\pm$ 0.016 & 0.156 $\pm$ 0.066 & 339.447 $\pm$ 12.270 \\
# \cline{1-9}
# \multirow[c]{14}{*}{golub-1999-v2} & Batch CoHiRF & 0.172 $\pm$ 0.052 & 0.209 $\pm$ 0.023 & 2.525 $\pm$ 0.102 & 0.029 $\pm$ 0.028 & \bfseries 0.415 $\pm$ 0.024 & 0.339 $\pm$ 0.298 & 155.459 $\pm$ 5.299 \\
#  & Batch CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 2.820 $\pm$ 0.153 & 142.027 $\pm$ 6.098 \\
#  & Batch CoHiRF-KernelRBF & 0.060 $\pm$ 0.022 & 0.058 $\pm$ 0.015 & 1.540 $\pm$ 0.353 & 0.030 $\pm$ 0.020 & \underline{0.516 $\pm$ 0.038} & 0.962 $\pm$ 1.230 & 173.540 $\pm$ 11.922 \\
#  & Batch CoHiRF-SC-SRGF & 0.289 $\pm$ 0.047 & 0.263 $\pm$ 0.034 & 2.860 $\pm$ 0.395 & 0.069 $\pm$ 0.024 & 1.813 $\pm$ 0.378 & 2.108 $\pm$ 1.789 & 281.365 $\pm$ 42.169 \\
#  & CoHiRF & \underline{0.389 $\pm$ 0.089} & 0.405 $\pm$ 0.051 & \underline{4.423 $\pm$ 0.125} & 0.257 $\pm$ 0.048 & 0.756 $\pm$ 0.165 & 0.156 $\pm$ 0.027 & 144.442 $\pm$ 2.735 \\
#  & CoHiRF Top-Down & 0.334 $\pm$ 0.092 & 0.336 $\pm$ 0.098 & 4.348 $\pm$ 0.189 & \bfseries 0.294 $\pm$ 0.000 & 0.561 $\pm$ 0.000 & 0.208 $\pm$ 0.158 & 144.099 $\pm$ 3.496 \\
#  & CoHiRF Top-Down Inv & \bfseries 0.447 $\pm$ 0.047 & 0.376 $\pm$ 0.031 & 4.412 $\pm$ 0.069 & 0.161 $\pm$ 0.067 & 1.160 $\pm$ 0.166 & 0.204 $\pm$ 0.142 & 149.978 $\pm$ 6.358 \\
#  & CoHiRF-DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 1.711 $\pm$ 0.097 & 141.724 $\pm$ 5.425 \\
#  & CoHiRF-KernelRBF & 0.060 $\pm$ 0.019 & 0.061 $\pm$ 0.015 & 1.495 $\pm$ 0.308 & 0.019 $\pm$ 0.020 & 0.533 $\pm$ 0.060 & 0.313 $\pm$ 0.129 & 160.992 $\pm$ 6.574 \\
#  & CoHiRF-SC-SRGF & 0.352 $\pm$ 0.043 & \underline{0.451 $\pm$ 0.035} & 3.163 $\pm$ 0.071 & 0.046 $\pm$ 0.010 & 2.577 $\pm$ 0.146 & 2.415 $\pm$ 1.679 & 257.774 $\pm$ 12.362 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.050 $\pm$ 0.013 & 129.037 $\pm$ 4.572 \\
#  & K-Means & 0.344 $\pm$ 0.096 & \bfseries 0.455 $\pm$ 0.074 & \bfseries 4.453 $\pm$ 0.058 & \underline{0.277 $\pm$ 0.000} & 0.979 $\pm$ 0.048 & 0.011 $\pm$ 0.003 & 131.550 $\pm$ 4.848 \\
#  & Kernel RBF K-Means & 0.038 $\pm$ 0.013 & 0.085 $\pm$ 0.026 & 1.176 $\pm$ 0.058 & 0.026 $\pm$ 0.009 & 1.832 $\pm$ 0.012 & 0.050 $\pm$ 0.002 & 135.033 $\pm$ 5.424 \\
#  & SC-SRGF & 0.298 $\pm$ 0.030 & \bfseries 0.455 $\pm$ 0.022 & 4.402 $\pm$ 0.113 & 0.087 $\pm$ 0.009 & 1.346 $\pm$ 0.010 & 0.154 $\pm$ 0.060 & 139.056 $\pm$ 4.958 \\
# \cline{1-9}
# \multirow[c]{13}{*}{har} & Batch CoHiRF & 0.407 $\pm$ 0.048 & 0.507 $\pm$ 0.012 & 959.234 $\pm$ 71.358 & 0.077 $\pm$ 0.051 & 1.971 $\pm$ 0.045 & 0.928 $\pm$ 0.424 & 373.429 $\pm$ 40.347 \\
#  & Batch CoHiRF-DBSCAN & 0.184 $\pm$ 0.007 & 0.225 $\pm$ 0.026 & 9.846 $\pm$ 2.098 & 0.141 $\pm$ 0.065 & \underline{0.380 $\pm$ 0.040} & 1.698 $\pm$ 1.507 & 412.425 $\pm$ 37.259 \\
#  & Batch CoHiRF-KernelRBF & 0.000 $\pm$ 0.000 & 0.007 $\pm$ 0.010 & 1.988 $\pm$ 0.496 & 0.005 $\pm$ 0.003 & 3.338 $\pm$ 0.116 & 27.188 $\pm$ 44.977 & 1832.413 $\pm$ 1316.658 \\
#  & Batch CoHiRF-SC-SRGF & \bfseries 0.511 $\pm$ 0.008 & \bfseries 0.664 $\pm$ 0.015 & \underline{7870.115 $\pm$ 1.710} & \bfseries 0.394 $\pm$ 0.000 & 0.640 $\pm$ 0.011 & 781.023 $\pm$ 536.814 & 50311.387 $\pm$ 11103.727 \\
#  & CoHiRF & 0.334 $\pm$ 0.002 & 0.547 $\pm$ 0.000 & \bfseries 7880.814 $\pm$ 0.000 & \bfseries 0.394 $\pm$ 0.000 & 1.071 $\pm$ 0.000 & 0.910 $\pm$ 0.255 & 369.068 $\pm$ 44.217 \\
#  & CoHiRF Top-Down & 0.399 $\pm$ 0.089 & 0.561 $\pm$ 0.031 & \bfseries 7880.814 $\pm$ 0.000 & \bfseries 0.394 $\pm$ 0.000 & 1.071 $\pm$ 0.000 & 1.246 $\pm$ 0.776 & 385.480 $\pm$ 57.080 \\
#  & CoHiRF Top-Down Inv & 0.443 $\pm$ 0.066 & 0.561 $\pm$ 0.012 & \bfseries 7880.814 $\pm$ 0.000 & \bfseries 0.394 $\pm$ 0.000 & 1.071 $\pm$ 0.000 & 1.280 $\pm$ 0.496 & 396.316 $\pm$ 54.497 \\
#  & CoHiRF-1000 & 0.338 $\pm$ 0.006 & 0.547 $\pm$ 0.000 & \bfseries 7880.814 $\pm$ 0.000 & \bfseries 0.394 $\pm$ 0.000 & 0.975 $\pm$ 0.120 & 0.630 $\pm$ 0.207 & 350.132 $\pm$ 43.007 \\
#  & CoHiRF-DBSCAN & 0.286 $\pm$ 0.015 & 0.265 $\pm$ 0.024 & 9.675 $\pm$ 1.535 & \underline{0.203 $\pm$ 0.167} & \bfseries 0.328 $\pm$ 0.026 & 3.555 $\pm$ 1.412 & 529.619 $\pm$ 31.133 \\
#  & CoHiRF-KernelRBF & 0.001 $\pm$ 0.000 & 0.002 $\pm$ 0.001 & 2.151 $\pm$ 0.483 & 0.004 $\pm$ 0.001 & 3.213 $\pm$ 0.245 & 75.295 $\pm$ 111.012 & 3999.278 $\pm$ 3052.612 \\
#  & DBSCAN & 0.088 $\pm$ 0.001 & 0.209 $\pm$ 0.002 & 639.269 $\pm$ 16.950 & -0.061 $\pm$ 0.012 & 1.246 $\pm$ 0.003 & 0.550 $\pm$ 0.038 & 342.176 $\pm$ 28.852 \\
#  & K-Means & \underline{0.478 $\pm$ 0.034} & \underline{0.593 $\pm$ 0.024} & \bfseries 7880.814 $\pm$ 0.000 & \bfseries 0.394 $\pm$ 0.000 & 1.071 $\pm$ 0.000 & 0.236 $\pm$ 0.165 & 333.302 $\pm$ 33.825 \\
#  & Kernel RBF K-Means & 0.000 $\pm$ 0.000 & 0.001 $\pm$ 0.000 & 2.297 $\pm$ 0.610 & 0.000 $\pm$ 0.000 & 38.187 $\pm$ 0.284 & 0.514 $\pm$ 0.088 & 348.236 $\pm$ 36.157 \\
# \cline{1-9}
# \multirow[c]{14}{*}{iris} & Batch CoHiRF & 0.424 $\pm$ 0.043 & 0.529 $\pm$ 0.011 & 94.770 $\pm$ 5.058 & 0.170 $\pm$ 0.053 & 1.079 $\pm$ 0.087 & 0.196 $\pm$ 0.143 & 27.609 $\pm$ 3.807 \\
#  & Batch CoHiRF-DBSCAN & 0.531 $\pm$ 0.036 & 0.684 $\pm$ 0.047 & 149.184 $\pm$ 55.576 & 0.520 $\pm$ 0.057 & 0.733 $\pm$ 0.355 & 0.052 $\pm$ 0.014 & 16.448 $\pm$ 0.610 \\
#  & Batch CoHiRF-KernelRBF & 0.687 $\pm$ 0.090 & 0.704 $\pm$ 0.073 & 121.522 $\pm$ 26.880 & 0.396 $\pm$ 0.162 & 0.889 $\pm$ 0.169 & 0.351 $\pm$ 1.119 & 28.475 $\pm$ 4.454 \\
#  & Batch CoHiRF-SC-SRGF & 0.753 $\pm$ 0.055 & 0.734 $\pm$ 0.032 & 234.232 $\pm$ 8.028 & 0.574 $\pm$ 0.007 & 0.558 $\pm$ 0.032 & 6.902 $\pm$ 3.891 & 476.697 $\pm$ 90.705 \\
#  & CoHiRF & 0.727 $\pm$ 0.101 & 0.765 $\pm$ 0.060 & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & 0.555 $\pm$ 0.055 & 0.027 $\pm$ 0.009 & 14.549 $\pm$ 0.397 \\
#  & CoHiRF Top-Down & \bfseries 0.868 $\pm$ 0.079 & \bfseries 0.864 $\pm$ 0.041 & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & 0.554 $\pm$ 0.054 & 0.088 $\pm$ 0.030 & 19.031 $\pm$ 1.082 \\
#  & CoHiRF Top-Down Inv & 0.776 $\pm$ 0.105 & 0.809 $\pm$ 0.074 & \underline{239.168 $\pm$ 4.182} & \bfseries 0.579 $\pm$ 0.000 & 0.596 $\pm$ 0.000 & 0.178 $\pm$ 0.088 & 23.755 $\pm$ 2.402 \\
#  & CoHiRF-DBSCAN & 0.561 $\pm$ 0.000 & 0.728 $\pm$ 0.000 & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & \bfseries 0.376 $\pm$ 0.049 & 0.469 $\pm$ 1.046 & 13.804 $\pm$ 0.567 \\
#  & CoHiRF-KernelRBF & \underline{0.813 $\pm$ 0.084} & 0.829 $\pm$ 0.048 & 216.155 $\pm$ 48.782 & 0.575 $\pm$ 0.009 & 0.529 $\pm$ 0.066 & 0.082 $\pm$ 0.108 & 20.849 $\pm$ 2.699 \\
#  & CoHiRF-SC-SRGF & 0.726 $\pm$ 0.032 & 0.718 $\pm$ 0.030 & 160.846 $\pm$ 14.294 & 0.344 $\pm$ 0.028 & 0.666 $\pm$ 0.047 & 2.022 $\pm$ 1.544 & 176.195 $\pm$ 26.379 \\
#  & DBSCAN & 0.561 $\pm$ 0.000 & 0.728 $\pm$ 0.000 & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & \underline{0.512 $\pm$ 0.023} & 0.014 $\pm$ 0.000 & 9.625 $\pm$ 0.197 \\
#  & K-Means & 0.618 $\pm$ 0.035 & 0.728 $\pm$ 0.000 & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & 0.596 $\pm$ 0.000 & 0.002 $\pm$ 0.000 & 9.008 $\pm$ 0.154 \\
#  & Kernel RBF K-Means & 0.641 $\pm$ 0.022 & 0.728 $\pm$ 0.000 & 228.040 $\pm$ 29.064 & \underline{0.578 $\pm$ 0.002} & 0.741 $\pm$ 0.110 & 0.007 $\pm$ 0.001 & 9.549 $\pm$ 0.214 \\
#  & SC-SRGF & 0.777 $\pm$ 0.078 & \underline{0.850 $\pm$ 0.025} & \bfseries 241.038 $\pm$ 0.000 & \bfseries 0.579 $\pm$ 0.000 & 0.594 $\pm$ 0.001 & 0.507 $\pm$ 0.202 & 38.979 $\pm$ 4.577 \\
# \cline{1-9}
# \multirow[c]{14}{*}{khan-2001} & Batch CoHiRF & 0.101 $\pm$ 0.015 & 0.235 $\pm$ 0.037 & 6.758 $\pm$ 3.254 & 0.085 $\pm$ 0.011 & \underline{0.281 $\pm$ 0.060} & 0.240 $\pm$ 0.153 & 105.465 $\pm$ 3.851 \\
#  & Batch CoHiRF-DBSCAN & 0.001 $\pm$ 0.001 & 0.003 $\pm$ 0.004 & 1493.219 $\pm$ 2046.044 & -0.591 $\pm$ 0.561 & 600.003 $\pm$ 547.719 & 1.962 $\pm$ 1.610 & 90.644 $\pm$ 2.886 \\
#  & Batch CoHiRF-KernelRBF & 0.045 $\pm$ 0.019 & 0.066 $\pm$ 0.024 & 1494.967 $\pm$ 2044.448 & 0.048 $\pm$ 0.037 & 0.316 $\pm$ 0.288 & 0.510 $\pm$ 0.912 & 112.465 $\pm$ 7.089 \\
#  & Batch CoHiRF-SC-SRGF & 0.144 $\pm$ 0.036 & 0.218 $\pm$ 0.049 & 12.283 $\pm$ 0.479 & 0.139 $\pm$ 0.011 & 1.926 $\pm$ 0.190 & 2.912 $\pm$ 1.924 & 232.559 $\pm$ 35.834 \\
#  & CoHiRF & 0.185 $\pm$ 0.010 & 0.346 $\pm$ 0.039 & 14.665 $\pm$ 0.205 & \bfseries 0.196 $\pm$ 0.020 & 1.042 $\pm$ 0.062 & 0.057 $\pm$ 0.031 & 92.310 $\pm$ 2.429 \\
#  & CoHiRF Top-Down & 0.198 $\pm$ 0.010 & 0.424 $\pm$ 0.085 & 14.757 $\pm$ 0.007 & \underline{0.189 $\pm$ 0.003} & 1.109 $\pm$ 0.269 & 0.144 $\pm$ 0.114 & 97.400 $\pm$ 3.674 \\
#  & CoHiRF Top-Down Inv & 0.245 $\pm$ 0.055 & 0.398 $\pm$ 0.028 & 14.752 $\pm$ 0.017 & 0.188 $\pm$ 0.000 & 1.376 $\pm$ 0.116 & 0.274 $\pm$ 0.143 & 103.314 $\pm$ 4.062 \\
#  & CoHiRF-DBSCAN & 0.010 $\pm$ 0.017 & 0.019 $\pm$ 0.020 & \bfseries 3734.547 $\pm$ 0.000 & 0.025 $\pm$ 0.003 & \bfseries 0.007 $\pm$ 0.000 & 0.033 $\pm$ 0.010 & 87.972 $\pm$ 3.189 \\
#  & CoHiRF-KernelRBF & 0.039 $\pm$ 0.007 & 0.078 $\pm$ 0.022 & \underline{2241.324 $\pm$ 2044.680} & 0.020 $\pm$ 0.006 & 0.331 $\pm$ 0.298 & 0.218 $\pm$ 0.217 & 103.259 $\pm$ 6.709 \\
#  & CoHiRF-SC-SRGF & \bfseries 0.404 $\pm$ 0.017 & \bfseries 0.552 $\pm$ 0.034 & 9.081 $\pm$ 0.000 & 0.123 $\pm$ 0.000 & 1.496 $\pm$ 0.001 & 1.721 $\pm$ 1.493 & 200.455 $\pm$ 9.113 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.008 $\pm$ 0.000 & 3.199 $\pm$ 0.000 & 0.157 $\pm$ 0.000 & 0.775 $\pm$ 0.000 & 0.023 $\pm$ 0.036 & 82.608 $\pm$ 3.257 \\
#  & K-Means & 0.300 $\pm$ 0.037 & 0.498 $\pm$ 0.021 & 14.763 $\pm$ 0.004 & 0.188 $\pm$ 0.000 & 1.018 $\pm$ 0.026 & 0.010 $\pm$ 0.008 & 85.110 $\pm$ 2.342 \\
#  & Kernel RBF K-Means & 0.034 $\pm$ 0.009 & 0.062 $\pm$ 0.011 & 1.581 $\pm$ 0.222 & 0.020 $\pm$ 0.006 & 2.219 $\pm$ 0.049 & 0.044 $\pm$ 0.031 & 86.936 $\pm$ 3.957 \\
#  & SC-SRGF & \underline{0.364 $\pm$ 0.039} & \underline{0.523 $\pm$ 0.007} & 10.359 $\pm$ 0.482 & 0.129 $\pm$ 0.003 & 1.068 $\pm$ 0.015 & 0.182 $\pm$ 0.078 & 94.799 $\pm$ 3.027 \\
# \cline{1-9}
# \multirow[c]{13}{*}{mnist} & Batch CoHiRF & \underline{0.262 $\pm$ 0.011} & 0.351 $\pm$ 0.005 & 425.387 $\pm$ 24.292 & -0.007 $\pm$ 0.011 & 2.600 $\pm$ 0.045 & 6.672 $\pm$ 4.041 & 3677.351 $\pm$ 1600.152 \\
#  & Batch CoHiRF-DBSCAN & 0.036 $\pm$ 0.022 & 0.111 $\pm$ 0.047 & 16.883 $\pm$ 4.071 & -0.065 $\pm$ 0.031 & \bfseries 0.490 $\pm$ 0.054 & 85.266 $\pm$ 105.172 & 8452.126 $\pm$ 2096.038 \\
#  & Batch CoHiRF-KernelRBF & 0.003 $\pm$ 0.006 & 0.005 $\pm$ 0.010 & 20.538 $\pm$ 40.929 & 0.001 $\pm$ 0.000 & 3.017 $\pm$ 0.658 & 265.027 $\pm$ 434.564 & 17360.414 $\pm$ 9820.961 \\
#  & Batch CoHiRF-SC-SRGF & 0.171 $\pm$ 0.007 & 0.302 $\pm$ 0.004 & 838.136 $\pm$ 177.847 & 0.077 $\pm$ 0.003 & 1.652 $\pm$ 0.281 & 529.287 $\pm$ 497.452 & 42476.464 $\pm$ 12487.228 \\
#  & CoHiRF & 0.163 $\pm$ 0.022 & 0.280 $\pm$ 0.020 & 2117.601 $\pm$ 430.072 & 0.790 $\pm$ 0.242 & 1.659 $\pm$ 1.481 & 11.759 $\pm$ 5.550 & 3269.537 $\pm$ 1552.664 \\
#  & CoHiRF Top-Down & 0.252 $\pm$ 0.015 & \underline{0.395 $\pm$ 0.025} & 2644.486 $\pm$ 223.131 & \bfseries 0.875 $\pm$ 0.057 & 0.790 $\pm$ 1.063 & 14.572 $\pm$ 7.708 & 3179.938 $\pm$ 1563.374 \\
#  & CoHiRF Top-Down Inv & 0.222 $\pm$ 0.030 & 0.356 $\pm$ 0.046 & \underline{2794.775 $\pm$ 0.358} & 0.265 $\pm$ 0.133 & 3.422 $\pm$ 0.254 & 16.117 $\pm$ 8.173 & 3194.728 $\pm$ 1341.141 \\
#  & CoHiRF-1000 & 0.146 $\pm$ 0.013 & 0.280 $\pm$ 0.028 & 2741.517 $\pm$ 62.372 & \underline{0.843 $\pm$ 0.101} & 2.711 $\pm$ 0.546 & 9.301 $\pm$ 7.070 & 2984.199 $\pm$ 1522.985 \\
#  & CoHiRF-DBSCAN & 0.076 $\pm$ 0.041 & 0.172 $\pm$ 0.050 & 17.457 $\pm$ 5.217 & 0.013 $\pm$ 0.121 & \underline{0.671 $\pm$ 0.080} & 219.335 $\pm$ 274.504 & 15588.519 $\pm$ 4905.455 \\
#  & CoHiRF-KernelRBF & 0.004 $\pm$ 0.008 & 0.046 $\pm$ 0.089 & 2.201 $\pm$ 2.298 & 0.001 $\pm$ 0.001 & 2.998 $\pm$ 0.008 & 658.262 $\pm$ 1075.461 & 33262.015 $\pm$ 28464.266 \\
#  & DBSCAN & 0.063 $\pm$ 0.000 & 0.238 $\pm$ 0.004 & 1287.036 $\pm$ 10.985 & -0.113 $\pm$ 0.001 & 1.611 $\pm$ 0.003 & 27.578 $\pm$ 1.758 & 4861.954 $\pm$ 1500.047 \\
#  & K-Means & \bfseries 0.344 $\pm$ 0.005 & \bfseries 0.505 $\pm$ 0.001 & \bfseries 2795.031 $\pm$ 0.001 & 0.431 $\pm$ 0.416 & 2.544 $\pm$ 0.072 & 4.226 $\pm$ 3.049 & 3388.629 $\pm$ 1703.331 \\
#  & Kernel RBF K-Means & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & 1.234 $\pm$ 0.131 & 0.000 $\pm$ 0.000 & 66.822 $\pm$ 0.397 & 5.652 $\pm$ 2.138 & 3452.337 $\pm$ 1659.642 \\
# \cline{1-9}
# \multirow[c]{13}{*}{nursery} & Batch CoHiRF & 0.057 $\pm$ 0.012 & 0.144 $\pm$ 0.014 & 147.465 $\pm$ 46.081 & -0.002 $\pm$ 0.004 & 1.779 $\pm$ 0.026 & 0.857 $\pm$ 1.117 & 99.038 $\pm$ 46.900 \\
#  & Batch CoHiRF-DBSCAN & 0.025 $\pm$ 0.005 & 0.143 $\pm$ 0.021 & 142.063 $\pm$ 27.702 & -0.019 $\pm$ 0.016 & \bfseries 1.014 $\pm$ 0.115 & 2.394 $\pm$ 5.125 & 136.323 $\pm$ 56.867 \\
#  & Batch CoHiRF-KernelRBF & 0.078 $\pm$ 0.038 & 0.154 $\pm$ 0.024 & 192.777 $\pm$ 70.623 & 0.021 $\pm$ 0.005 & 1.998 $\pm$ 0.034 & 4.164 $\pm$ 7.094 & 511.822 $\pm$ 332.019 \\
#  & Batch CoHiRF-SC-SRGF & 0.095 $\pm$ 0.029 & 0.157 $\pm$ 0.021 & 257.486 $\pm$ 85.360 & 0.004 $\pm$ 0.004 & 2.320 $\pm$ 0.101 & 2279.696 $\pm$ 2616.421 & 80754.362 $\pm$ 53725.938 \\
#  & CoHiRF & 0.268 $\pm$ 0.052 & 0.381 $\pm$ 0.082 & 930.024 $\pm$ 14.734 & 0.101 $\pm$ 0.008 & 1.430 $\pm$ 0.095 & 0.290 $\pm$ 0.068 & 69.145 $\pm$ 38.992 \\
#  & CoHiRF Top-Down & \bfseries 0.438 $\pm$ 0.144 & \bfseries 0.581 $\pm$ 0.106 & \bfseries 1023.966 $\pm$ 0.000 & 0.078 $\pm$ 0.004 & 2.888 $\pm$ 0.024 & 0.857 $\pm$ 0.470 & 95.405 $\pm$ 44.734 \\
#  & CoHiRF Top-Down Inv & 0.290 $\pm$ 0.094 & 0.333 $\pm$ 0.060 & \underline{1023.910 $\pm$ 0.082} & 0.076 $\pm$ 0.000 & 2.589 $\pm$ 0.376 & 0.886 $\pm$ 0.686 & 97.630 $\pm$ 41.364 \\
#  & CoHiRF-1000 & 0.270 $\pm$ 0.123 & 0.351 $\pm$ 0.102 & 959.279 $\pm$ 102.840 & 0.075 $\pm$ 0.002 & 2.588 $\pm$ 0.083 & 0.482 $\pm$ 0.746 & 73.060 $\pm$ 40.993 \\
#  & CoHiRF-DBSCAN & 0.172 $\pm$ 0.143 & 0.352 $\pm$ 0.146 & 850.857 $\pm$ 126.666 & \bfseries 0.126 $\pm$ 0.020 & \underline{1.021 $\pm$ 0.130} & 2.603 $\pm$ 2.032 & 286.218 $\pm$ 29.426 \\
#  & CoHiRF-KernelRBF & 0.248 $\pm$ 0.077 & 0.352 $\pm$ 0.089 & 858.714 $\pm$ 114.401 & \underline{0.110 $\pm$ 0.017} & 1.219 $\pm$ 0.175 & 1.810 $\pm$ 1.687 & 777.801 $\pm$ 281.609 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & -1.000 $\pm$ 0.000 & 1000.000 $\pm$ 0.000 & 0.147 $\pm$ 0.014 & 116.562 $\pm$ 17.091 \\
#  & K-Means & \underline{0.415 $\pm$ 0.062} & \underline{0.403 $\pm$ 0.126} & \bfseries 1023.966 $\pm$ 0.000 & 0.075 $\pm$ 0.002 & 2.279 $\pm$ 0.018 & 0.037 $\pm$ 0.041 & 45.344 $\pm$ 39.548 \\
#  & Kernel RBF K-Means & 0.196 $\pm$ 0.078 & 0.261 $\pm$ 0.049 & 1003.679 $\pm$ 45.235 & 0.067 $\pm$ 0.006 & 2.485 $\pm$ 0.031 & 0.677 $\pm$ 0.274 & 87.318 $\pm$ 41.011 \\
# \cline{1-9}
# \multirow[c]{15}{*}{satimage} & Batch CoHiRF & 0.499 $\pm$ 0.006 & 0.561 $\pm$ 0.006 & 1593.344 $\pm$ 76.059 & 0.103 $\pm$ 0.022 & 1.454 $\pm$ 0.032 & 0.279 $\pm$ 0.268 & 51.310 $\pm$ 13.409 \\
#  & Batch CoHiRF-DBSCAN & 0.142 $\pm$ 0.039 & 0.291 $\pm$ 0.023 & 47.947 $\pm$ 45.273 & 0.309 $\pm$ 0.051 & \bfseries 0.590 $\pm$ 0.021 & 0.348 $\pm$ 0.162 & 58.354 $\pm$ 8.173 \\
#  & Batch CoHiRF-KernelRBF & 0.461 $\pm$ 0.030 & 0.507 $\pm$ 0.026 & 2139.014 $\pm$ 467.968 & 0.020 $\pm$ 0.028 & 1.581 $\pm$ 0.200 & 0.639 $\pm$ 0.801 & 340.167 $\pm$ 111.432 \\
#  & Batch CoHiRF-SC-SRGF & \underline{0.604 $\pm$ 0.008} & \bfseries 0.662 $\pm$ 0.002 & 2848.246 $\pm$ 284.738 & 0.470 $\pm$ 0.050 & 0.651 $\pm$ 0.011 & 138.694 $\pm$ 107.556 & 10260.195 $\pm$ 3018.042 \\
#  & CoHiRF & 0.483 $\pm$ 0.037 & 0.579 $\pm$ 0.026 & 5807.867 $\pm$ 20.689 & 0.441 $\pm$ 0.013 & 0.798 $\pm$ 0.029 & 0.264 $\pm$ 0.042 & 49.440 $\pm$ 13.038 \\
#  & CoHiRF Top-Down & 0.564 $\pm$ 0.029 & 0.595 $\pm$ 0.031 & 5781.054 $\pm$ 49.326 & \underline{0.482 $\pm$ 0.025} & 0.732 $\pm$ 0.016 & 0.224 $\pm$ 0.100 & 53.317 $\pm$ 17.870 \\
#  & CoHiRF Top-Down Inv & 0.541 $\pm$ 0.023 & 0.594 $\pm$ 0.017 & \bfseries 5817.742 $\pm$ 0.369 & 0.448 $\pm$ 0.024 & 0.811 $\pm$ 0.000 & 0.524 $\pm$ 0.287 & 64.538 $\pm$ 13.225 \\
#  & CoHiRF-1000 & 0.499 $\pm$ 0.051 & 0.542 $\pm$ 0.029 & \underline{5810.953 $\pm$ 11.043} & 0.481 $\pm$ 0.025 & 0.800 $\pm$ 0.029 & 0.216 $\pm$ 0.068 & 50.780 $\pm$ 12.774 \\
#  & CoHiRF-DBSCAN & 0.380 $\pm$ 0.012 & 0.352 $\pm$ 0.041 & 19.345 $\pm$ 2.581 & 0.181 $\pm$ 0.014 & \underline{0.625 $\pm$ 0.017} & 0.947 $\pm$ 0.554 & 108.773 $\pm$ 12.368 \\
#  & CoHiRF-KernelRBF & 0.493 $\pm$ 0.023 & 0.531 $\pm$ 0.020 & 2965.727 $\pm$ 1172.597 & 0.187 $\pm$ 0.164 & 1.097 $\pm$ 0.078 & 0.799 $\pm$ 0.315 & 563.554 $\pm$ 218.587 \\
#  & CoHiRF-SC-SRGF & 0.299 $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & 265.883 $\pm$ No Run & 4263.133 $\pm$ No Run \\
#  & DBSCAN & 0.352 $\pm$ 0.018 & 0.495 $\pm$ 0.006 & 1517.698 $\pm$ 1.565 & 0.322 $\pm$ 0.004 & 1.012 $\pm$ 0.386 & 0.131 $\pm$ 0.051 & 39.918 $\pm$ 11.456 \\
#  & K-Means & 0.558 $\pm$ 0.019 & \underline{0.627 $\pm$ 0.001} & 5490.745 $\pm$ 453.849 & \bfseries 0.490 $\pm$ 0.000 & 0.759 $\pm$ 0.000 & 0.022 $\pm$ 0.030 & 31.073 $\pm$ 13.880 \\
#  & Kernel RBF K-Means & 0.249 $\pm$ 0.058 & 0.536 $\pm$ 0.023 & 1743.924 $\pm$ 318.347 & 0.135 $\pm$ 0.132 & 1.077 $\pm$ 0.089 & 0.268 $\pm$ 0.090 & 47.511 $\pm$ 11.334 \\
#  & SC-SRGF & \bfseries 0.615 $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & 1709.322 $\pm$ No Run & 83482.103 $\pm$ No Run \\
# \cline{1-9}
# \multirow[c]{15}{*}{segment} & Batch CoHiRF & 0.488 $\pm$ 0.027 & 0.581 $\pm$ 0.015 & 524.240 $\pm$ 46.064 & 0.259 $\pm$ 0.029 & 1.237 $\pm$ 0.053 & 0.066 $\pm$ 0.041 & 25.752 $\pm$ 2.447 \\
#  & Batch CoHiRF-DBSCAN & 0.283 $\pm$ 0.025 & 0.476 $\pm$ 0.009 & 174.150 $\pm$ 78.855 & 0.827 $\pm$ 0.028 & \underline{0.109 $\pm$ 0.003} & 0.161 $\pm$ 0.149 & 26.993 $\pm$ 2.293 \\
#  & Batch CoHiRF-KernelRBF & 0.500 $\pm$ 0.004 & 0.571 $\pm$ 0.012 & 431.808 $\pm$ 113.297 & 0.318 $\pm$ 0.125 & 1.505 $\pm$ 0.184 & 1.107 $\pm$ 2.207 & 66.293 $\pm$ 10.499 \\
#  & Batch CoHiRF-SC-SRGF & 0.511 $\pm$ 0.018 & 0.630 $\pm$ 0.015 & 937.415 $\pm$ 0.000 & 0.440 $\pm$ 0.000 & 0.634 $\pm$ 0.053 & 19.666 $\pm$ 11.814 & 1242.450 $\pm$ 343.615 \\
#  & CoHiRF & 0.510 $\pm$ 0.050 & 0.635 $\pm$ 0.015 & 901.901 $\pm$ 67.357 & 0.774 $\pm$ 0.099 & 0.663 $\pm$ 0.360 & 0.108 $\pm$ 0.108 & 24.406 $\pm$ 2.336 \\
#  & CoHiRF Top-Down & 0.502 $\pm$ 0.024 & 0.660 $\pm$ 0.052 & 998.463 $\pm$ 55.107 & 0.796 $\pm$ 0.014 & 0.507 $\pm$ 0.221 & 0.121 $\pm$ 0.076 & 27.692 $\pm$ 3.003 \\
#  & CoHiRF Top-Down Inv & \underline{0.558 $\pm$ 0.026} & \underline{0.696 $\pm$ 0.011} & \underline{1067.710 $\pm$ 0.232} & 0.442 $\pm$ 0.025 & 0.950 $\pm$ 0.033 & 0.205 $\pm$ 0.177 & 33.837 $\pm$ 3.777 \\
#  & CoHiRF-1000 & 0.479 $\pm$ 0.013 & 0.652 $\pm$ 0.025 & 981.423 $\pm$ 65.649 & 0.789 $\pm$ 0.049 & 0.513 $\pm$ 0.375 & 0.065 $\pm$ 0.028 & 27.624 $\pm$ 2.701 \\
#  & CoHiRF-DBSCAN & 0.385 $\pm$ 0.066 & 0.512 $\pm$ 0.045 & 88.494 $\pm$ 21.974 & \bfseries 0.849 $\pm$ 0.000 & \bfseries 0.107 $\pm$ 0.002 & 0.150 $\pm$ 0.069 & 30.599 $\pm$ 2.389 \\
#  & CoHiRF-KernelRBF & 0.523 $\pm$ 0.042 & 0.614 $\pm$ 0.027 & 796.728 $\pm$ 137.738 & 0.378 $\pm$ 0.042 & 1.002 $\pm$ 0.053 & 0.193 $\pm$ 0.098 & 45.959 $\pm$ 6.482 \\
#  & CoHiRF-SC-SRGF & 0.547 $\pm$ 0.015 & 0.688 $\pm$ 0.031 & 603.373 $\pm$ 41.693 & 0.344 $\pm$ 0.041 & 0.882 $\pm$ 0.042 & 107.170 $\pm$ 58.376 & 6082.099 $\pm$ 1629.039 \\
#  & DBSCAN & 0.353 $\pm$ 0.024 & 0.560 $\pm$ 0.019 & 374.389 $\pm$ 69.620 & \underline{0.846 $\pm$ 0.000} & 0.335 $\pm$ 0.000 & 0.033 $\pm$ 0.021 & 17.483 $\pm$ 1.937 \\
#  & K-Means & \bfseries 0.569 $\pm$ 0.011 & 0.694 $\pm$ 0.008 & \bfseries 1067.878 $\pm$ 0.000 & 0.449 $\pm$ 0.003 & 0.833 $\pm$ 0.013 & 0.007 $\pm$ 0.002 & 15.112 $\pm$ 1.414 \\
#  & Kernel RBF K-Means & 0.417 $\pm$ 0.043 & 0.579 $\pm$ 0.009 & 722.460 $\pm$ 147.258 & 0.386 $\pm$ 0.007 & 0.938 $\pm$ 0.003 & 0.093 $\pm$ 0.028 & 21.563 $\pm$ 1.945 \\
#  & SC-SRGF & 0.529 $\pm$ 0.008 & \bfseries 0.702 $\pm$ 0.011 & 961.430 $\pm$ 47.726 & 0.400 $\pm$ 0.089 & 0.676 $\pm$ 0.000 & 73.679 $\pm$ 42.142 & 4557.790 $\pm$ 975.139 \\
# \cline{1-9}
# \multirow[c]{13}{*}{shuttle} & Batch CoHiRF & 0.519 $\pm$ 0.053 & 0.409 $\pm$ 0.007 & 8348.465 $\pm$ 444.922 & 0.338 $\pm$ 0.019 & 0.870 $\pm$ 0.102 & 0.426 $\pm$ 0.059 & 512.579 $\pm$ 854.818 \\
#  & Batch CoHiRF-DBSCAN & \underline{0.700 $\pm$ 0.025} & \underline{0.626 $\pm$ 0.012} & 1590.540 $\pm$ 568.306 & 0.881 $\pm$ 0.030 & \underline{0.057 $\pm$ 0.006} & 10.985 $\pm$ 5.967 & 1299.520 $\pm$ 863.328 \\
#  & Batch CoHiRF-KernelRBF & 0.356 $\pm$ 0.151 & 0.322 $\pm$ 0.028 & 7801.931 $\pm$ 570.226 & 0.509 $\pm$ 0.279 & 1.716 $\pm$ 0.418 & 2.521 $\pm$ 1.667 & 687.550 $\pm$ 800.481 \\
#  & Batch CoHiRF-SC-SRGF & 0.477 $\pm$ 0.073 & 0.429 $\pm$ 0.027 & 4879.433 $\pm$ 446.656 & 0.564 $\pm$ 0.007 & 1.278 $\pm$ 0.802 & 312.236 $\pm$ 173.586 & 27574.592 $\pm$ 4750.461 \\
#  & CoHiRF & 0.630 $\pm$ 0.035 & 0.497 $\pm$ 0.062 & 18061.719 $\pm$ 2629.748 & 0.933 $\pm$ 0.051 & 0.324 $\pm$ 0.186 & 11.356 $\pm$ 5.922 & 946.599 $\pm$ 829.349 \\
#  & CoHiRF Top-Down & 0.646 $\pm$ 0.025 & 0.525 $\pm$ 0.037 & 20315.311 $\pm$ 180.882 & \bfseries 0.969 $\pm$ 0.005 & 0.163 $\pm$ 0.139 & 16.898 $\pm$ 3.232 & 1285.315 $\pm$ 779.313 \\
#  & CoHiRF Top-Down Inv & 0.605 $\pm$ 0.053 & 0.448 $\pm$ 0.026 & \underline{20425.366 $\pm$ 149.915} & 0.653 $\pm$ 0.174 & 0.663 $\pm$ 0.067 & 13.334 $\pm$ 6.260 & 1041.339 $\pm$ 815.158 \\
#  & CoHiRF-1000 & 0.614 $\pm$ 0.062 & 0.515 $\pm$ 0.050 & 19507.122 $\pm$ 1357.957 & \underline{0.967 $\pm$ 0.006} & 0.400 $\pm$ 0.165 & 0.388 $\pm$ 0.567 & 479.257 $\pm$ 808.521 \\
#  & CoHiRF-DBSCAN & 0.692 $\pm$ 0.008 & 0.604 $\pm$ 0.072 & 1661.915 $\pm$ 938.851 & 0.947 $\pm$ 0.013 & \bfseries 0.044 $\pm$ 0.004 & 146.101 $\pm$ 136.032 & 12001.592 $\pm$ 7286.836 \\
#  & CoHiRF-KernelRBF & 0.460 $\pm$ 0.119 & 0.458 $\pm$ 0.063 & 10955.562 $\pm$ 4532.351 & 0.474 $\pm$ 0.132 & 1.192 $\pm$ 0.132 & 11.999 $\pm$ 6.497 & 1136.000 $\pm$ 864.371 \\
#  & DBSCAN & \bfseries 0.709 $\pm$ 0.013 & \bfseries 0.643 $\pm$ 0.002 & 7504.082 $\pm$ 12.888 & 0.948 $\pm$ 0.001 & 1.738 $\pm$ 0.306 & 31.611 $\pm$ 13.034 & 3234.575 $\pm$ 1047.160 \\
#  & K-Means & 0.608 $\pm$ 0.000 & 0.473 $\pm$ 0.014 & \bfseries 30845.871 $\pm$ 297.412 & 0.960 $\pm$ 0.009 & 0.557 $\pm$ 0.011 & 0.073 $\pm$ 0.062 & 478.330 $\pm$ 836.362 \\
#  & Kernel RBF K-Means & 0.250 $\pm$ 0.084 & 0.388 $\pm$ 0.018 & 11742.148 $\pm$ 2434.781 & 0.390 $\pm$ 0.010 & 0.877 $\pm$ 0.035 & 1.726 $\pm$ 0.338 & 577.008 $\pm$ 793.430 \\
# \cline{1-9}
# \end{longtable}

# %% [markdown]
# # KMeans

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = [
    "garber-2001",
    "alizadeh-2000-v2",
    "golub-1999-v2",
    "armstrong-2002-v1",
    "nursery",
    "segment",
]
models_to_keep = [
    "K-Means",
    "CoHiRF",
	"CoHiRF-1000",
    "Batch CoHiRF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{3}{*}{alizadeh-2000-v2} & Batch CoHiRF & 0.360 $\pm$ 0.014 & 0.507 $\pm$ 0.021 & 4.274 $\pm$ 0.238 & 0.049 $\pm$ 0.010 & \bfseries 0.411 $\pm$ 0.084 & 0.143 $\pm$ 0.069 & 154.717 $\pm$ 4.251 \\
#  & CoHiRF & \bfseries 0.866 $\pm$ 0.007 & \bfseries 0.771 $\pm$ 0.030 & \underline{15.094 $\pm$ 0.126} & \underline{0.196 $\pm$ 0.015} & \underline{0.896 $\pm$ 0.083} & 0.054 $\pm$ 0.033 & 142.623 $\pm$ 4.180 \\
#  & K-Means & \underline{0.838 $\pm$ 0.014} & \underline{0.767 $\pm$ 0.037} & \bfseries 15.151 $\pm$ 0.000 & \bfseries 0.204 $\pm$ 0.036 & 0.934 $\pm$ 0.021 & 0.012 $\pm$ 0.003 & 137.865 $\pm$ 3.673 \\
# \cline{1-9}
# \multirow[c]{3}{*}{armstrong-2002-v1} & Batch CoHiRF & 0.225 $\pm$ 0.071 & 0.267 $\pm$ 0.061 & 2.933 $\pm$ 0.333 & 0.003 $\pm$ 0.007 & \bfseries 0.401 $\pm$ 0.025 & 0.125 $\pm$ 0.039 & 90.402 $\pm$ 3.605 \\
#  & CoHiRF & \underline{0.664 $\pm$ 0.111} & \underline{0.594 $\pm$ 0.088} & \underline{6.153 $\pm$ 0.705} & \underline{0.212 $\pm$ 0.072} & \underline{0.862 $\pm$ 0.176} & 0.055 $\pm$ 0.020 & 83.250 $\pm$ 3.069 \\
#  & K-Means & \bfseries 0.787 $\pm$ 0.167 & \bfseries 0.799 $\pm$ 0.030 & \bfseries 6.477 $\pm$ 0.032 & \bfseries 0.244 $\pm$ 0.062 & 0.903 $\pm$ 0.046 & 0.007 $\pm$ 0.002 & 74.288 $\pm$ 1.689 \\
# \cline{1-9}
# \multirow[c]{3}{*}{garber-2001} & Batch CoHiRF & 0.167 $\pm$ 0.050 & 0.164 $\pm$ 0.031 & 3.287 $\pm$ 0.090 & 0.113 $\pm$ 0.008 & \bfseries 0.431 $\pm$ 0.050 & 0.832 $\pm$ 0.494 & 393.396 $\pm$ 15.517 \\
#  & CoHiRF & \bfseries 0.292 $\pm$ 0.022 & \underline{0.220 $\pm$ 0.025} & \bfseries 6.108 $\pm$ 0.097 & \underline{0.326 $\pm$ 0.005} & \underline{0.687 $\pm$ 0.205} & 0.200 $\pm$ 0.090 & 344.136 $\pm$ 6.666 \\
#  & K-Means & \underline{0.248 $\pm$ 0.044} & \bfseries 0.241 $\pm$ 0.027 & \underline{5.606 $\pm$ 1.264} & \bfseries 0.333 $\pm$ 0.000 & 0.825 $\pm$ 0.022 & 0.025 $\pm$ 0.006 & 329.200 $\pm$ 6.094 \\
# \cline{1-9}
# \multirow[c]{3}{*}{golub-1999-v2} & Batch CoHiRF & 0.172 $\pm$ 0.052 & 0.209 $\pm$ 0.023 & 2.525 $\pm$ 0.102 & 0.029 $\pm$ 0.028 & \bfseries 0.415 $\pm$ 0.024 & 0.339 $\pm$ 0.298 & 155.459 $\pm$ 5.299 \\
#  & CoHiRF & \bfseries 0.389 $\pm$ 0.089 & \underline{0.405 $\pm$ 0.051} & \underline{4.423 $\pm$ 0.125} & \underline{0.257 $\pm$ 0.048} & \underline{0.756 $\pm$ 0.165} & 0.156 $\pm$ 0.027 & 144.442 $\pm$ 2.735 \\
#  & K-Means & \underline{0.344 $\pm$ 0.096} & \bfseries 0.455 $\pm$ 0.074 & \bfseries 4.453 $\pm$ 0.058 & \bfseries 0.277 $\pm$ 0.000 & 0.979 $\pm$ 0.048 & 0.011 $\pm$ 0.003 & 131.550 $\pm$ 4.848 \\
# \cline{1-9}
# \multirow[c]{4}{*}{nursery} & Batch CoHiRF & 0.057 $\pm$ 0.012 & 0.144 $\pm$ 0.014 & 147.465 $\pm$ 46.081 & -0.002 $\pm$ 0.004 & \underline{1.779 $\pm$ 0.026} & 0.857 $\pm$ 1.117 & 99.038 $\pm$ 46.900 \\
#  & CoHiRF & 0.268 $\pm$ 0.052 & \underline{0.381 $\pm$ 0.082} & 930.024 $\pm$ 14.734 & \bfseries 0.101 $\pm$ 0.008 & \bfseries 1.430 $\pm$ 0.095 & 0.290 $\pm$ 0.068 & 69.145 $\pm$ 38.992 \\
#  & CoHiRF-1000 & \underline{0.270 $\pm$ 0.123} & 0.351 $\pm$ 0.102 & \underline{959.279 $\pm$ 102.840} & \underline{0.075 $\pm$ 0.002} & 2.588 $\pm$ 0.083 & 0.482 $\pm$ 0.746 & 73.060 $\pm$ 40.993 \\
#  & K-Means & \bfseries 0.415 $\pm$ 0.062 & \bfseries 0.403 $\pm$ 0.126 & \bfseries 1023.966 $\pm$ 0.000 & \underline{0.075 $\pm$ 0.002} & 2.279 $\pm$ 0.018 & 0.037 $\pm$ 0.041 & 45.344 $\pm$ 39.548 \\
# \cline{1-9}
# \multirow[c]{4}{*}{segment} & Batch CoHiRF & 0.488 $\pm$ 0.027 & 0.581 $\pm$ 0.015 & 524.240 $\pm$ 46.064 & 0.259 $\pm$ 0.029 & 1.237 $\pm$ 0.053 & 0.066 $\pm$ 0.041 & 25.752 $\pm$ 2.447 \\
#  & CoHiRF & \underline{0.510 $\pm$ 0.050} & 0.635 $\pm$ 0.015 & 901.901 $\pm$ 67.357 & \underline{0.774 $\pm$ 0.099} & \underline{0.663 $\pm$ 0.360} & 0.108 $\pm$ 0.108 & 24.406 $\pm$ 2.336 \\
#  & CoHiRF-1000 & 0.479 $\pm$ 0.013 & \underline{0.652 $\pm$ 0.025} & \underline{981.423 $\pm$ 65.649} & \bfseries 0.789 $\pm$ 0.049 & \bfseries 0.513 $\pm$ 0.375 & 0.065 $\pm$ 0.028 & 27.624 $\pm$ 2.701 \\
#  & K-Means & \bfseries 0.569 $\pm$ 0.011 & \bfseries 0.694 $\pm$ 0.008 & \bfseries 1067.878 $\pm$ 0.000 & 0.449 $\pm$ 0.003 & 0.833 $\pm$ 0.013 & 0.007 $\pm$ 0.002 & 15.112 $\pm$ 1.414 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Kernel KMeans

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = [
    "khan-2001",
    "bittner-2000",
    "iris",
    "satimage",
]
models_to_keep = [
    "Kernel RBF K-Means",
    "CoHiRF-KernelRBF",
    "Batch CoHiRF-KernelRBF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{3}{*}{bittner-2000} & Batch CoHiRF-KernelRBF & 0.088 $\pm$ 0.015 & 0.098 $\pm$ 0.011 & \bfseries 1.918 $\pm$ 0.217 & 0.041 $\pm$ 0.020 & \bfseries 0.499 $\pm$ 0.083 & 0.224 $\pm$ 0.180 & 171.649 $\pm$ 4.442 \\
#  & CoHiRF-KernelRBF & \bfseries 0.104 $\pm$ 0.049 & \underline{0.136 $\pm$ 0.043} & \underline{1.569 $\pm$ 0.146} & \bfseries 0.054 $\pm$ 0.066 & \underline{0.530 $\pm$ 0.053} & 0.191 $\pm$ 0.118 & 158.762 $\pm$ 4.244 \\
#  & Kernel RBF K-Means & \underline{0.090 $\pm$ 0.038} & \bfseries 0.137 $\pm$ 0.034 & 1.334 $\pm$ 0.128 & \underline{0.043 $\pm$ 0.021} & 0.905 $\pm$ 0.014 & 0.062 $\pm$ 0.017 & 148.491 $\pm$ 2.636 \\
# \cline{1-9}
# \multirow[c]{3}{*}{iris} & Batch CoHiRF-KernelRBF & \underline{0.687 $\pm$ 0.090} & 0.704 $\pm$ 0.073 & 121.522 $\pm$ 26.880 & 0.396 $\pm$ 0.162 & 0.889 $\pm$ 0.169 & 0.351 $\pm$ 1.119 & 28.475 $\pm$ 4.454 \\
#  & CoHiRF-KernelRBF & \bfseries 0.813 $\pm$ 0.084 & \bfseries 0.829 $\pm$ 0.048 & \underline{216.155 $\pm$ 48.782} & \underline{0.575 $\pm$ 0.009} & \bfseries 0.529 $\pm$ 0.066 & 0.082 $\pm$ 0.108 & 20.849 $\pm$ 2.699 \\
#  & Kernel RBF K-Means & 0.641 $\pm$ 0.022 & \underline{0.728 $\pm$ 0.000} & \bfseries 228.040 $\pm$ 29.064 & \bfseries 0.578 $\pm$ 0.002 & \underline{0.741 $\pm$ 0.110} & 0.007 $\pm$ 0.001 & 9.549 $\pm$ 0.214 \\
# \cline{1-9}
# \multirow[c]{3}{*}{khan-2001} & Batch CoHiRF-KernelRBF & \bfseries 0.045 $\pm$ 0.019 & \underline{0.066 $\pm$ 0.024} & \underline{1494.967 $\pm$ 2044.448} & \bfseries 0.048 $\pm$ 0.037 & \bfseries 0.316 $\pm$ 0.288 & 0.510 $\pm$ 0.912 & 112.465 $\pm$ 7.089 \\
#  & CoHiRF-KernelRBF & \underline{0.039 $\pm$ 0.007} & \bfseries 0.078 $\pm$ 0.022 & \bfseries 2241.324 $\pm$ 2044.680 & \underline{0.020 $\pm$ 0.006} & \underline{0.331 $\pm$ 0.298} & 0.218 $\pm$ 0.217 & 103.259 $\pm$ 6.709 \\
#  & Kernel RBF K-Means & 0.034 $\pm$ 0.009 & 0.062 $\pm$ 0.011 & 1.581 $\pm$ 0.222 & \underline{0.020 $\pm$ 0.006} & 2.219 $\pm$ 0.049 & 0.044 $\pm$ 0.031 & 86.936 $\pm$ 3.957 \\
# \cline{1-9}
# \multirow[c]{3}{*}{satimage} & Batch CoHiRF-KernelRBF & \underline{0.461 $\pm$ 0.030} & 0.507 $\pm$ 0.026 & \underline{2139.014 $\pm$ 467.968} & 0.020 $\pm$ 0.028 & 1.581 $\pm$ 0.200 & 0.639 $\pm$ 0.801 & 340.167 $\pm$ 111.432 \\
#  & CoHiRF-KernelRBF & \bfseries 0.493 $\pm$ 0.023 & \underline{0.531 $\pm$ 0.020} & \bfseries 2965.727 $\pm$ 1172.597 & \bfseries 0.187 $\pm$ 0.164 & \underline{1.097 $\pm$ 0.078} & 0.799 $\pm$ 0.315 & 563.554 $\pm$ 218.587 \\
#  & Kernel RBF K-Means & 0.249 $\pm$ 0.058 & \bfseries 0.536 $\pm$ 0.023 & 1743.924 $\pm$ 318.347 & \underline{0.135 $\pm$ 0.132} & \bfseries 1.077 $\pm$ 0.089 & 0.268 $\pm$ 0.090 & 47.511 $\pm$ 11.334 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # DBSCAN

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = ["ecoli", "binary-alpha-digits", "segment", "chowdary-2006", "shuttle"]
models_to_keep = [
    "DBSCAN",
    "CoHiRF-DBSCAN",
    "Batch CoHiRF-DBSCAN",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{3}{*}{binary-alpha-digits} & Batch CoHiRF-DBSCAN & \underline{0.006 $\pm$ 0.008} & \underline{0.032 $\pm$ 0.033} & \underline{1.473 $\pm$ 0.131} & \bfseries 0.080 $\pm$ 0.025 & \bfseries 0.837 $\pm$ 0.037 & 0.284 $\pm$ 0.238 & 58.526 $\pm$ 3.098 \\
#  & CoHiRF-DBSCAN & \bfseries 0.009 $\pm$ 0.005 & \bfseries 0.035 $\pm$ 0.026 & 1.353 $\pm$ 0.109 & \underline{0.011 $\pm$ 0.035} & \underline{0.862 $\pm$ 0.035} & 0.189 $\pm$ 0.041 & 57.093 $\pm$ 1.612 \\
#  & DBSCAN & 0.000 $\pm$ 0.000 & 0.002 $\pm$ 0.003 & \bfseries 1.574 $\pm$ 3.525 & -0.561 $\pm$ 0.602 & 600.462 $\pm$ 547.090 & 0.053 $\pm$ 0.036 & 44.413 $\pm$ 2.076 \\
# \cline{1-9}
# \multirow[c]{3}{*}{chowdary-2006} & Batch CoHiRF-DBSCAN & \underline{0.068 $\pm$ 0.053} & \underline{0.099 $\pm$ 0.047} & \underline{37.353 $\pm$ 0.000} & 0.398 $\pm$ 0.366 & \underline{0.369 $\pm$ 0.157} & 0.073 $\pm$ 0.036 & 26.751 $\pm$ 1.500 \\
#  & CoHiRF-DBSCAN & 0.063 $\pm$ 0.007 & 0.067 $\pm$ 0.055 & \bfseries 47.579 $\pm$ 22.864 & \bfseries 0.675 $\pm$ 0.021 & \bfseries 0.168 $\pm$ 0.000 & 0.024 $\pm$ 0.003 & 23.143 $\pm$ 0.995 \\
#  & DBSCAN & \bfseries 0.375 $\pm$ 0.011 & \bfseries 0.327 $\pm$ 0.013 & 27.190 $\pm$ 2.510 & \underline{0.598 $\pm$ 0.022} & 0.946 $\pm$ 0.000 & 0.003 $\pm$ 0.000 & 18.056 $\pm$ 0.666 \\
# \cline{1-9}
# \multirow[c]{3}{*}{ecoli} & Batch CoHiRF-DBSCAN & 0.404 $\pm$ 0.088 & 0.336 $\pm$ 0.051 & \underline{67.693 $\pm$ 2.754} & \bfseries \underline{0.836 $\pm$ 0.000} & \bfseries \underline{0.116 $\pm$ 0.000} & 0.262 $\pm$ 0.964 & 18.254 $\pm$ 1.188 \\
#  & CoHiRF-DBSCAN & \bfseries 0.568 $\pm$ 0.046 & \underline{0.374 $\pm$ 0.145} & \bfseries 68.924 $\pm$ 0.000 & \bfseries \underline{0.836 $\pm$ 0.000} & \bfseries \underline{0.116 $\pm$ 0.000} & 0.056 $\pm$ 0.056 & 14.713 $\pm$ 0.533 \\
#  & DBSCAN & \underline{0.540 $\pm$ 0.040} & \bfseries 0.451 $\pm$ 0.037 & \bfseries 68.924 $\pm$ 0.000 & \bfseries \underline{0.836 $\pm$ 0.000} & \bfseries \underline{0.116 $\pm$ 0.000} & 0.014 $\pm$ 0.000 & 10.643 $\pm$ 0.597 \\
# \cline{1-9}
# \multirow[c]{3}{*}{segment} & Batch CoHiRF-DBSCAN & 0.283 $\pm$ 0.025 & 0.476 $\pm$ 0.009 & \underline{174.150 $\pm$ 78.855} & 0.827 $\pm$ 0.028 & \underline{0.109 $\pm$ 0.003} & 0.161 $\pm$ 0.149 & 26.993 $\pm$ 2.293 \\
#  & CoHiRF-DBSCAN & \bfseries 0.385 $\pm$ 0.066 & \underline{0.512 $\pm$ 0.045} & 88.494 $\pm$ 21.974 & \bfseries 0.849 $\pm$ 0.000 & \bfseries 0.107 $\pm$ 0.002 & 0.150 $\pm$ 0.069 & 30.599 $\pm$ 2.389 \\
#  & DBSCAN & \underline{0.353 $\pm$ 0.024} & \bfseries 0.560 $\pm$ 0.019 & \bfseries 374.389 $\pm$ 69.620 & \underline{0.846 $\pm$ 0.000} & 0.335 $\pm$ 0.000 & 0.033 $\pm$ 0.021 & 17.483 $\pm$ 1.937 \\
# \cline{1-9}
# \multirow[c]{3}{*}{shuttle} & Batch CoHiRF-DBSCAN & \underline{0.700 $\pm$ 0.025} & \underline{0.626 $\pm$ 0.012} & 1590.540 $\pm$ 568.306 & 0.881 $\pm$ 0.030 & \underline{0.057 $\pm$ 0.006} & 10.985 $\pm$ 5.967 & 1299.520 $\pm$ 863.328 \\
#  & CoHiRF-DBSCAN & 0.692 $\pm$ 0.008 & 0.604 $\pm$ 0.072 & \underline{1661.915 $\pm$ 938.851} & \underline{0.947 $\pm$ 0.013} & \bfseries 0.044 $\pm$ 0.004 & 146.101 $\pm$ 136.032 & 12001.592 $\pm$ 7286.836 \\
#  & DBSCAN & \bfseries 0.709 $\pm$ 0.013 & \bfseries 0.643 $\pm$ 0.002 & \bfseries 7504.082 $\pm$ 12.888 & \bfseries 0.948 $\pm$ 0.001 & 1.738 $\pm$ 0.306 & 31.611 $\pm$ 13.034 & 3234.575 $\pm$ 1047.160 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # SC-SRGF

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = ["alizadeh-2000-v3", "alizadeh-2000-v2", "har", "satimage", "chowdary-2006"]
models_to_keep = [
    "SC-SRGF",
	"CoHiRF-SC-SRGF",
    "Batch CoHiRF-SC-SRGF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{2}{*}{alizadeh-2000-v2} & CoHiRF-SC-SRGF & \underline{0.633 $\pm$ 0.042} & \underline{0.758 $\pm$ 0.031} & \underline{7.422 $\pm$ 0.041} & \underline{0.094 $\pm$ 0.001} & \underline{1.550 $\pm$ 0.019} & 1.503 $\pm$ 1.527 & 254.264 $\pm$ 14.525 \\
#  & SC-SRGF & \bfseries 0.891 $\pm$ 0.125 & \bfseries 0.854 $\pm$ 0.093 & \bfseries 12.338 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & \bfseries 0.936 $\pm$ 0.014 & 0.132 $\pm$ 0.061 & 142.764 $\pm$ 4.481 \\
# \cline{1-9}
# \multirow[c]{2}{*}{alizadeh-2000-v3} & CoHiRF-SC-SRGF & \underline{0.443 $\pm$ 0.013} & \underline{0.628 $\pm$ 0.019} & \underline{7.411 $\pm$ 0.060} & \underline{0.093 $\pm$ 0.002} & \underline{1.562 $\pm$ 0.047} & 0.928 $\pm$ 1.146 & 245.332 $\pm$ 13.850 \\
#  & SC-SRGF & \bfseries 0.519 $\pm$ 0.000 & \bfseries 0.702 $\pm$ 0.048 & \bfseries 12.341 $\pm$ 0.000 & \bfseries 0.194 $\pm$ 0.000 & \bfseries 0.931 $\pm$ 0.011 & 0.124 $\pm$ 0.055 & 144.219 $\pm$ 6.544 \\
# \cline{1-9}
# \multirow[c]{2}{*}{chowdary-2006} & CoHiRF-SC-SRGF & \underline{0.702 $\pm$ 0.042} & \underline{0.647 $\pm$ 0.058} & \bfseries 30.348 $\pm$ 5.508 & \underline{0.174 $\pm$ 0.006} & \underline{1.450 $\pm$ 0.044} & 1.713 $\pm$ 1.668 & 130.320 $\pm$ 11.670 \\
#  & SC-SRGF & \bfseries 0.924 $\pm$ 0.000 & \bfseries 0.859 $\pm$ 0.000 & \underline{23.009 $\pm$ 4.973} & \bfseries 0.222 $\pm$ 0.007 & \bfseries 1.101 $\pm$ 0.022 & 0.179 $\pm$ 0.093 & 29.310 $\pm$ 2.845 \\
# \cline{1-9}
# \multirow[c]{2}{*}{satimage} & CoHiRF-SC-SRGF & \underline{0.299 $\pm$ No Run} & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & 265.883 $\pm$ No Run & 4263.133 $\pm$ No Run \\
#  & SC-SRGF & \bfseries 0.615 $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & No Run $\pm$ No Run & 1709.322 $\pm$ No Run & 83482.103 $\pm$ No Run \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # COIL 20

# %%
df_latex = df_metrics.copy()
columns_to_hide = [col for col in df_latex.columns if col not in (hpo_metrics_rename + ["Best Time", "HPO Time"])]
columns_to_hide += ["NMI"]
datasets_to_keep = ["coil-20", "mnist"]
models_to_keep = [
    "K-Means",
    "CoHiRF",
	"CoHiRF-1000",
    "Batch CoHiRF",
    "Kernel RBF K-Means",
    "CoHiRF-KernelRBF",
    "Batch CoHiRF-KernelRBF",
    "DBSCAN",
    "CoHiRF-DBSCAN",
    "Batch CoHiRF-DBSCAN",
    "SC-SRGF",
    "Batch CoHiRF-SC-SRGF",
]
df_latex = df_latex.loc[
    df_latex.index.get_level_values("Dataset").isin(datasets_to_keep)
    & df_latex.index.get_level_values("Model").isin(models_to_keep),
    :,
]
highlight_max_ari = partial(highlight_max, column_name="ARI mean")
highlight_max_ami = partial(highlight_max, column_name="AMI mean")
highlight_max_calinski = partial(highlight_max, column_name="Calinski mean")
highlight_max_silhouette = partial(highlight_max, column_name="Silhouette mean")
highlight_min_davies_bouldin = partial(highlight_min, column_name="Davies-Bouldin mean")
highlight_min_best_time = partial(highlight_min, column_name="Best Time mean")
highlight_min_hpo_time = partial(highlight_min, column_name="HPO Time mean")
underline_2nd_max_ari = partial(underline_2nd_max, column_name="ARI mean")
underline_2nd_max_ami = partial(underline_2nd_max, column_name="AMI mean")
underline_2nd_max_calinski = partial(underline_2nd_max, column_name="Calinski mean")
underline_2nd_max_silhouette = partial(underline_2nd_max, column_name="Silhouette mean")
underline_2nd_min_davies_bouldin = partial(underline_2nd_min, column_name="Davies-Bouldin mean")
underline_2nd_min_best_time = partial(underline_2nd_min, column_name="Best Time mean")
underline_2nd_min_hpo_time = partial(underline_2nd_min, column_name="HPO Time mean")
print(
    df_latex.style.apply(highlight_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(underline_2nd_max_ari, subset=["ARI", "ARI mean"], axis=None)
    .apply(highlight_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(underline_2nd_max_ami, subset=["AMI", "AMI mean"], axis=None)
    .apply(highlight_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(underline_2nd_max_calinski, subset=["Calinski", "Calinski mean"], axis=None)
    .apply(highlight_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(underline_2nd_max_silhouette, subset=["Silhouette", "Silhouette mean"], axis=None)
    .apply(highlight_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .apply(underline_2nd_min_davies_bouldin, subset=["Davies-Bouldin", "Davies-Bouldin mean"], axis=None)
    .hide(columns_to_hide, axis=1)
    .to_latex(
        hrules=True,
        clines="skip-last;data",
        convert_css=True,
        column_format="ll" + "l" * (len(df_latex.columns) - len(columns_to_hide)),
        # environment="longtable",
    )
)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  &  & ARI & AMI & Calinski & Silhouette & Davies-Bouldin & Best Time & HPO Time \\
# Dataset & Model &  &  &  &  &  &  &  \\
# \midrule
# \multirow[c]{11}{*}{coil-20} & Batch CoHiRF & 0.381 $\pm$ 0.008 & 0.632 $\pm$ 0.010 & 62.639 $\pm$ 4.789 & 0.107 $\pm$ 0.018 & 1.532 $\pm$ 0.065 & 0.541 $\pm$ 0.153 & 172.626 $\pm$ 7.695 \\
#  & Batch CoHiRF-DBSCAN & 0.335 $\pm$ 0.055 & 0.588 $\pm$ 0.051 & \bfseries 291.162 $\pm$ 71.197 & -0.001 $\pm$ 0.008 & \bfseries 0.077 $\pm$ 0.041 & 1.305 $\pm$ 1.005 & 175.064 $\pm$ 19.429 \\
#  & Batch CoHiRF-KernelRBF & 0.004 $\pm$ 0.006 & 0.023 $\pm$ 0.020 & 1.804 $\pm$ 0.276 & 0.005 $\pm$ 0.002 & 2.404 $\pm$ 0.100 & 10.855 $\pm$ 17.100 & 510.956 $\pm$ 280.500 \\
#  & CoHiRF & 0.355 $\pm$ 0.041 & 0.627 $\pm$ 0.017 & 287.989 $\pm$ 0.164 & \underline{0.220 $\pm$ 0.095} & 1.597 $\pm$ 0.166 & 0.290 $\pm$ 0.087 & 151.293 $\pm$ 4.393 \\
#  & CoHiRF-1000 & 0.338 $\pm$ 0.009 & 0.632 $\pm$ 0.006 & 288.053 $\pm$ 0.078 & 0.180 $\pm$ 0.004 & 1.725 $\pm$ 0.039 & 0.264 $\pm$ 0.053 & 142.514 $\pm$ 3.021 \\
#  & CoHiRF-DBSCAN & \underline{0.684 $\pm$ 0.040} & 0.756 $\pm$ 0.052 & 45.358 $\pm$ 69.153 & 0.148 $\pm$ 0.030 & \underline{0.429 $\pm$ 0.223} & 0.321 $\pm$ 0.042 & 151.694 $\pm$ 4.712 \\
#  & CoHiRF-KernelRBF & 0.007 $\pm$ 0.009 & 0.020 $\pm$ 0.020 & 7.272 $\pm$ 10.222 & 0.003 $\pm$ 0.002 & 2.548 $\pm$ 0.084 & 7.423 $\pm$ 12.185 & 563.079 $\pm$ 301.382 \\
#  & DBSCAN & 0.143 $\pm$ 0.000 & 0.563 $\pm$ 0.000 & 56.906 $\pm$ 0.000 & -0.005 $\pm$ 0.000 & 1.175 $\pm$ 0.019 & 0.049 $\pm$ 0.006 & 132.351 $\pm$ 3.358 \\
#  & K-Means & 0.664 $\pm$ 0.005 & \underline{0.803 $\pm$ 0.003} & \underline{288.095 $\pm$ 0.000} & \bfseries 0.225 $\pm$ 0.002 & 1.737 $\pm$ 0.018 & 0.085 $\pm$ 0.032 & 135.341 $\pm$ 4.313 \\
#  & Kernel RBF K-Means & 0.004 $\pm$ 0.003 & 0.019 $\pm$ 0.012 & 1.795 $\pm$ 0.427 & 0.001 $\pm$ 0.000 & 12.297 $\pm$ 0.107 & 0.094 $\pm$ 0.011 & 135.192 $\pm$ 5.138 \\
#  & SC-SRGF & \bfseries 0.779 $\pm$ 0.006 & \bfseries 0.928 $\pm$ 0.003 & 84.948 $\pm$ 0.314 & 0.160 $\pm$ 0.001 & 1.581 $\pm$ 0.414 & 39.291 $\pm$ 16.565 & 2507.799 $\pm$ 517.402 \\
# \cline{1-9}
# \multirow[c]{10}{*}{mnist} & Batch CoHiRF & \underline{0.262 $\pm$ 0.011} & \underline{0.351 $\pm$ 0.005} & 425.387 $\pm$ 24.292 & -0.007 $\pm$ 0.011 & 2.600 $\pm$ 0.045 & 6.672 $\pm$ 4.041 & 3677.351 $\pm$ 1600.152 \\
#  & Batch CoHiRF-DBSCAN & 0.036 $\pm$ 0.022 & 0.111 $\pm$ 0.047 & 16.883 $\pm$ 4.071 & -0.065 $\pm$ 0.031 & \bfseries 0.490 $\pm$ 0.054 & 85.266 $\pm$ 105.172 & 8452.126 $\pm$ 2096.038 \\
#  & Batch CoHiRF-KernelRBF & 0.003 $\pm$ 0.006 & 0.005 $\pm$ 0.010 & 20.538 $\pm$ 40.929 & 0.001 $\pm$ 0.000 & 3.017 $\pm$ 0.658 & 265.027 $\pm$ 434.564 & 17360.414 $\pm$ 9820.961 \\
#  & CoHiRF & 0.163 $\pm$ 0.022 & 0.280 $\pm$ 0.020 & 2117.601 $\pm$ 430.072 & \underline{0.790 $\pm$ 0.242} & 1.659 $\pm$ 1.481 & 11.759 $\pm$ 5.550 & 3269.537 $\pm$ 1552.664 \\
#  & CoHiRF-1000 & 0.146 $\pm$ 0.013 & 0.280 $\pm$ 0.028 & \underline{2741.517 $\pm$ 62.372} & \bfseries 0.843 $\pm$ 0.101 & 2.711 $\pm$ 0.546 & 9.301 $\pm$ 7.070 & 2984.199 $\pm$ 1522.985 \\
#  & CoHiRF-DBSCAN & 0.076 $\pm$ 0.041 & 0.172 $\pm$ 0.050 & 17.457 $\pm$ 5.217 & 0.013 $\pm$ 0.121 & \underline{0.671 $\pm$ 0.080} & 219.335 $\pm$ 274.504 & 15588.519 $\pm$ 4905.455 \\
#  & CoHiRF-KernelRBF & 0.004 $\pm$ 0.008 & 0.046 $\pm$ 0.089 & 2.201 $\pm$ 2.298 & 0.001 $\pm$ 0.001 & 2.998 $\pm$ 0.008 & 658.262 $\pm$ 1075.461 & 33262.015 $\pm$ 28464.266 \\
#  & DBSCAN & 0.063 $\pm$ 0.000 & 0.238 $\pm$ 0.004 & 1287.036 $\pm$ 10.985 & -0.113 $\pm$ 0.001 & 1.611 $\pm$ 0.003 & 27.578 $\pm$ 1.758 & 4861.954 $\pm$ 1500.047 \\
#  & K-Means & \bfseries 0.344 $\pm$ 0.005 & \bfseries 0.505 $\pm$ 0.001 & \bfseries 2795.031 $\pm$ 0.001 & 0.431 $\pm$ 0.416 & 2.544 $\pm$ 0.072 & 4.226 $\pm$ 3.049 & 3388.629 $\pm$ 1703.331 \\
#  & Kernel RBF K-Means & 0.000 $\pm$ 0.000 & 0.000 $\pm$ 0.000 & 1.234 $\pm$ 0.131 & 0.000 $\pm$ 0.000 & 66.822 $\pm$ 0.397 & 5.652 $\pm$ 2.138 & 3452.337 $\pm$ 1659.642 \\
# \cline{1-9}
# \bottomrule
# \end{tabular}

# %% [markdown]
# # Debug and explore

# %%
df = df_runs_raw_parents.copy()

# %%
df = df.loc[df["model"] == "BatchCoHiRF-DBSCAN-1iter-60"]
df = df.loc[df["dataset_id"] == 47039]

# %%
df
# Out:
#                                     status     start_time      end_time  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb  FINISHED  1759857341387  1.759883e+12
# 194290e427024ea0a13f9ae54a19ad1d  FINISHED  1759857342388  1.759875e+12
# 2d6bd7e8c4ba4385ba525787babef29a  FINISHED  1759746035261  1.759772e+12
# 3bb1b76f13684935a96c5f6921c1331d  FINISHED  1759857341387  1.759876e+12
# 3ce4ac0bd17943149fed033ad489646b  FINISHED  1759746035257  1.759761e+12
# 5136039b079740f39d60ff9070c2b98d  FINISHED  1759746035785  1.759792e+12
# 5d063fc4745a4d70add5329b0640e06f  FINISHED  1759746033001  1.759769e+12
# 71fea0d02579497b99daa7aaaf00a6bb    FAILED  1759510979843  1.759520e+12
# 85248d1527414425abd710547fe79470  FINISHED  1759671558525  1.759708e+12
# 859d7eb2686240689573db3e60bb46c5  FINISHED  1759746035685  1.759783e+12
# 89993364d250459d8f2578ead9929ae5  FINISHED  1759857342388  1.759882e+12
# 8b989d21fa4c41049baaafd50026be76  FINISHED  1759857342387  1.759879e+12
# 8da6383bc3444d08b2be16e7bd51ae39  FINISHED  1759746035367  1.759777e+12
# 9eb3e6a7cbac45688ec400ef1421c9aa  FINISHED  1759746035551  1.759772e+12
# b8cd3ab89c6e4aa5854d9537a571b2e9  FINISHED  1759746033260  1.759782e+12
# c6ce278404e54ad8a4b40e031455c02c  FINISHED  1759746036123  1.759769e+12
# e656864ccc5e4d73a66db9d5fa26575a  FINISHED  1759746033224  1.759768e+12
#
#                                   best/base_model_kwargs/eps  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb                         NaN
# 194290e427024ea0a13f9ae54a19ad1d                         NaN
# 2d6bd7e8c4ba4385ba525787babef29a                         NaN
# 3bb1b76f13684935a96c5f6921c1331d                         NaN
# 3ce4ac0bd17943149fed033ad489646b                         NaN
# 5136039b079740f39d60ff9070c2b98d                         NaN
# 5d063fc4745a4d70add5329b0640e06f                         NaN
# 71fea0d02579497b99daa7aaaf00a6bb                         NaN
# 85248d1527414425abd710547fe79470                         NaN
# 859d7eb2686240689573db3e60bb46c5                         NaN
# 89993364d250459d8f2578ead9929ae5                         NaN
# 8b989d21fa4c41049baaafd50026be76                         NaN
# 8da6383bc3444d08b2be16e7bd51ae39                         NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa                         NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9                         NaN
# c6ce278404e54ad8a4b40e031455c02c                         NaN
# e656864ccc5e4d73a66db9d5fa26575a                         NaN
#
#                                   best/base_model_kwargs/min_samples  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb                                 NaN
# 194290e427024ea0a13f9ae54a19ad1d                                 NaN
# 2d6bd7e8c4ba4385ba525787babef29a                                 NaN
# 3bb1b76f13684935a96c5f6921c1331d                                 NaN
# 3ce4ac0bd17943149fed033ad489646b                                 NaN
# 5136039b079740f39d60ff9070c2b98d                                 NaN
# 5d063fc4745a4d70add5329b0640e06f                                 NaN
# 71fea0d02579497b99daa7aaaf00a6bb                                 NaN
# 85248d1527414425abd710547fe79470                                 NaN
# 859d7eb2686240689573db3e60bb46c5                                 NaN
# 89993364d250459d8f2578ead9929ae5                                 NaN
# 8b989d21fa4c41049baaafd50026be76                                 NaN
# 8da6383bc3444d08b2be16e7bd51ae39                                 NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa                                 NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9                                 NaN
# c6ce278404e54ad8a4b40e031455c02c                                 NaN
# e656864ccc5e4d73a66db9d5fa26575a                                 NaN
#
#                                   best/base_model_kwargs/n_clusters  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb                                NaN
# 194290e427024ea0a13f9ae54a19ad1d                                NaN
# 2d6bd7e8c4ba4385ba525787babef29a                                NaN
# 3bb1b76f13684935a96c5f6921c1331d                                NaN
# 3ce4ac0bd17943149fed033ad489646b                                NaN
# 5136039b079740f39d60ff9070c2b98d                                NaN
# 5d063fc4745a4d70add5329b0640e06f                                NaN
# 71fea0d02579497b99daa7aaaf00a6bb                                NaN
# 85248d1527414425abd710547fe79470                                NaN
# 859d7eb2686240689573db3e60bb46c5                                NaN
# 89993364d250459d8f2578ead9929ae5                                NaN
# 8b989d21fa4c41049baaafd50026be76                                NaN
# 8da6383bc3444d08b2be16e7bd51ae39                                NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa                                NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9                                NaN
# c6ce278404e54ad8a4b40e031455c02c                                NaN
# e656864ccc5e4d73a66db9d5fa26575a                                NaN
#
#                                   best/base_model_kwargs/n_similarities  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb                                    NaN
# 194290e427024ea0a13f9ae54a19ad1d                                    NaN
# 2d6bd7e8c4ba4385ba525787babef29a                                    NaN
# 3bb1b76f13684935a96c5f6921c1331d                                    NaN
# 3ce4ac0bd17943149fed033ad489646b                                    NaN
# 5136039b079740f39d60ff9070c2b98d                                    NaN
# 5d063fc4745a4d70add5329b0640e06f                                    NaN
# 71fea0d02579497b99daa7aaaf00a6bb                                    NaN
# 85248d1527414425abd710547fe79470                                    NaN
# 859d7eb2686240689573db3e60bb46c5                                    NaN
# 89993364d250459d8f2578ead9929ae5                                    NaN
# 8b989d21fa4c41049baaafd50026be76                                    NaN
# 8da6383bc3444d08b2be16e7bd51ae39                                    NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa                                    NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9                                    NaN
# c6ce278404e54ad8a4b40e031455c02c                                    NaN
# e656864ccc5e4d73a66db9d5fa26575a                                    NaN
#
#                                   best/base_model_kwargs/sampling_ratio  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb                                    NaN
# 194290e427024ea0a13f9ae54a19ad1d                                    NaN
# 2d6bd7e8c4ba4385ba525787babef29a                                    NaN
# 3bb1b76f13684935a96c5f6921c1331d                                    NaN
# 3ce4ac0bd17943149fed033ad489646b                                    NaN
# 5136039b079740f39d60ff9070c2b98d                                    NaN
# 5d063fc4745a4d70add5329b0640e06f                                    NaN
# 71fea0d02579497b99daa7aaaf00a6bb                                    NaN
# 85248d1527414425abd710547fe79470                                    NaN
# 859d7eb2686240689573db3e60bb46c5                                    NaN
# 89993364d250459d8f2578ead9929ae5                                    NaN
# 8b989d21fa4c41049baaafd50026be76                                    NaN
# 8da6383bc3444d08b2be16e7bd51ae39                                    NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa                                    NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9                                    NaN
# c6ce278404e54ad8a4b40e031455c02c                                    NaN
# e656864ccc5e4d73a66db9d5fa26575a                                    NaN
#
#                                   best/base_model_kwargs/sc_n_clusters  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb                                   NaN
# 194290e427024ea0a13f9ae54a19ad1d                                   NaN
# 2d6bd7e8c4ba4385ba525787babef29a                                   NaN
# 3bb1b76f13684935a96c5f6921c1331d                                   NaN
# 3ce4ac0bd17943149fed033ad489646b                                   NaN
# 5136039b079740f39d60ff9070c2b98d                                   NaN
# 5d063fc4745a4d70add5329b0640e06f                                   NaN
# 71fea0d02579497b99daa7aaaf00a6bb                                   NaN
# 85248d1527414425abd710547fe79470                                   NaN
# 859d7eb2686240689573db3e60bb46c5                                   NaN
# 89993364d250459d8f2578ead9929ae5                                   NaN
# 8b989d21fa4c41049baaafd50026be76                                   NaN
# 8da6383bc3444d08b2be16e7bd51ae39                                   NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa                                   NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9                                   NaN
# c6ce278404e54ad8a4b40e031455c02c                                   NaN
# e656864ccc5e4d73a66db9d5fa26575a                                   NaN
#
#                                                  best/child_run_id  ...  \
# run_uuid                                                            ...
# 0687a0e95efb434482a8174cda90d4cb  11edf35ba2aa4e67bfbda1a2e60600a4  ...
# 194290e427024ea0a13f9ae54a19ad1d  5e6f3d3cf8c844f795bf7220090e113d  ...
# 2d6bd7e8c4ba4385ba525787babef29a  cc9f24b21561489abf2010dfb6f18b20  ...
# 3bb1b76f13684935a96c5f6921c1331d  92e2a42f740f494d955665bf6cd284df  ...
# 3ce4ac0bd17943149fed033ad489646b  8b7dfabd8ba441ecba1950ade4c28e41  ...
# 5136039b079740f39d60ff9070c2b98d  1d6e63c34e73416896a0976dba0d528f  ...
# 5d063fc4745a4d70add5329b0640e06f  5e35df5e5f6e4572b12190e51a2ad5e8  ...
# 71fea0d02579497b99daa7aaaf00a6bb                               NaN  ...
# 85248d1527414425abd710547fe79470  4ac471428c644046a870cb5b0f7bca53  ...
# 859d7eb2686240689573db3e60bb46c5  de08f3d88527492c83a42c20e2210558  ...
# 89993364d250459d8f2578ead9929ae5  a772a19da65e499cbad17dd007d6fdad  ...
# 8b989d21fa4c41049baaafd50026be76  b2d2b0d0712246cfad745dbb7899d61b  ...
# 8da6383bc3444d08b2be16e7bd51ae39  e6a643f701b24f83861e9394bda6bb93  ...
# 9eb3e6a7cbac45688ec400ef1421c9aa  55c40d0824794419ab1264fdf22d2b9f  ...
# b8cd3ab89c6e4aa5854d9537a571b2e9  db0a3e7d6be1454d9b543030f9b021d9  ...
# c6ce278404e54ad8a4b40e031455c02c  8fccad53ee50435c966c74355575dfd0  ...
# e656864ccc5e4d73a66db9d5fa26575a  9f41f743a9d346da8a45c9057981bf30  ...
#
#                                                                           EXCEPTION  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb                                                NaN
# 194290e427024ea0a13f9ae54a19ad1d                                                NaN
# 2d6bd7e8c4ba4385ba525787babef29a                                                NaN
# 3bb1b76f13684935a96c5f6921c1331d                                                NaN
# 3ce4ac0bd17943149fed033ad489646b                                                NaN
# 5136039b079740f39d60ff9070c2b98d                                                NaN
# 5d063fc4745a4d70add5329b0640e06f                                                NaN
# 71fea0d02579497b99daa7aaaf00a6bb  Best metric adjusted_rand not found in the bes...
# 85248d1527414425abd710547fe79470                                                NaN
# 859d7eb2686240689573db3e60bb46c5                                                NaN
# 89993364d250459d8f2578ead9929ae5                                                NaN
# 8b989d21fa4c41049baaafd50026be76                                                NaN
# 8da6383bc3444d08b2be16e7bd51ae39                                                NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa                                                NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9                                                NaN
# c6ce278404e54ad8a4b40e031455c02c                                                NaN
# e656864ccc5e4d73a66db9d5fa26575a                                                NaN
#
#                                       Last step finished  mlflow.parentRunId  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb           _on_train_end                 NaN
# 194290e427024ea0a13f9ae54a19ad1d           _on_train_end                 NaN
# 2d6bd7e8c4ba4385ba525787babef29a           _on_train_end                 NaN
# 3bb1b76f13684935a96c5f6921c1331d           _on_train_end                 NaN
# 3ce4ac0bd17943149fed033ad489646b           _on_train_end                 NaN
# 5136039b079740f39d60ff9070c2b98d           _on_train_end                 NaN
# 5d063fc4745a4d70add5329b0640e06f           _on_train_end                 NaN
# 71fea0d02579497b99daa7aaaf00a6bb  _before_evaluate_model                 NaN
# 85248d1527414425abd710547fe79470           _on_train_end                 NaN
# 859d7eb2686240689573db3e60bb46c5           _on_train_end                 NaN
# 89993364d250459d8f2578ead9929ae5           _on_train_end                 NaN
# 8b989d21fa4c41049baaafd50026be76           _on_train_end                 NaN
# 8da6383bc3444d08b2be16e7bd51ae39           _on_train_end                 NaN
# 9eb3e6a7cbac45688ec400ef1421c9aa           _on_train_end                 NaN
# b8cd3ab89c6e4aa5854d9537a571b2e9           _on_train_end                 NaN
# c6ce278404e54ad8a4b40e031455c02c           _on_train_end                 NaN
# e656864ccc5e4d73a66db9d5fa26575a           _on_train_end                 NaN
#
#                                   raised_exception                 dataset  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb             False  criteo-uplift-balanced
# 194290e427024ea0a13f9ae54a19ad1d             False  criteo-uplift-balanced
# 2d6bd7e8c4ba4385ba525787babef29a             False  criteo-uplift-balanced
# 3bb1b76f13684935a96c5f6921c1331d             False  criteo-uplift-balanced
# 3ce4ac0bd17943149fed033ad489646b             False  criteo-uplift-balanced
# 5136039b079740f39d60ff9070c2b98d             False  criteo-uplift-balanced
# 5d063fc4745a4d70add5329b0640e06f             False  criteo-uplift-balanced
# 71fea0d02579497b99daa7aaaf00a6bb              True  criteo-uplift-balanced
# 85248d1527414425abd710547fe79470             False  criteo-uplift-balanced
# 859d7eb2686240689573db3e60bb46c5             False  criteo-uplift-balanced
# 89993364d250459d8f2578ead9929ae5             False  criteo-uplift-balanced
# 8b989d21fa4c41049baaafd50026be76             False  criteo-uplift-balanced
# 8da6383bc3444d08b2be16e7bd51ae39             False  criteo-uplift-balanced
# 9eb3e6a7cbac45688ec400ef1421c9aa             False  criteo-uplift-balanced
# b8cd3ab89c6e4aa5854d9537a571b2e9             False  criteo-uplift-balanced
# c6ce278404e54ad8a4b40e031455c02c             False  criteo-uplift-balanced
# e656864ccc5e4d73a66db9d5fa26575a             False  criteo-uplift-balanced
#
#                                   openml_id  n_instances  n_features  \
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb      47039      1366544          14
# 194290e427024ea0a13f9ae54a19ad1d      47039      1366544          14
# 2d6bd7e8c4ba4385ba525787babef29a      47039      1366544          14
# 3bb1b76f13684935a96c5f6921c1331d      47039      1366544          14
# 3ce4ac0bd17943149fed033ad489646b      47039      1366544          14
# 5136039b079740f39d60ff9070c2b98d      47039      1366544          14
# 5d063fc4745a4d70add5329b0640e06f      47039      1366544          14
# 71fea0d02579497b99daa7aaaf00a6bb      47039      1366544          14
# 85248d1527414425abd710547fe79470      47039      1366544          14
# 859d7eb2686240689573db3e60bb46c5      47039      1366544          14
# 89993364d250459d8f2578ead9929ae5      47039      1366544          14
# 8b989d21fa4c41049baaafd50026be76      47039      1366544          14
# 8da6383bc3444d08b2be16e7bd51ae39      47039      1366544          14
# 9eb3e6a7cbac45688ec400ef1421c9aa      47039      1366544          14
# b8cd3ab89c6e4aa5854d9537a571b2e9      47039      1366544          14
# c6ce278404e54ad8a4b40e031455c02c      47039      1366544          14
# e656864ccc5e4d73a66db9d5fa26575a      47039      1366544          14
#
#                                   n_classes  n_categorical
# run_uuid
# 0687a0e95efb434482a8174cda90d4cb          4              2
# 194290e427024ea0a13f9ae54a19ad1d          4              2
# 2d6bd7e8c4ba4385ba525787babef29a          4              2
# 3bb1b76f13684935a96c5f6921c1331d          4              2
# 3ce4ac0bd17943149fed033ad489646b          4              2
# 5136039b079740f39d60ff9070c2b98d          4              2
# 5d063fc4745a4d70add5329b0640e06f          4              2
# 71fea0d02579497b99daa7aaaf00a6bb          4              2
# 85248d1527414425abd710547fe79470          4              2
# 859d7eb2686240689573db3e60bb46c5          4              2
# 89993364d250459d8f2578ead9929ae5          4              2
# 8b989d21fa4c41049baaafd50026be76          4              2
# 8da6383bc3444d08b2be16e7bd51ae39          4              2
# 9eb3e6a7cbac45688ec400ef1421c9aa          4              2
# b8cd3ab89c6e4aa5854d9537a571b2e9          4              2
# c6ce278404e54ad8a4b40e031455c02c          4              2
# e656864ccc5e4d73a66db9d5fa26575a          4              2
#
# [17 rows x 64 columns]

# %%
runs_to_delete_parents = list(df.index)
df = df_runs_raw.copy()
df = df.loc[df["mlflow.parentRunId"].isin(runs_to_delete_parents)]
runs_to_delete_children = list(df.index)
runs_to_delete = runs_to_delete_children + runs_to_delete_parents
run_uuid_query = [f"'{run_id}'" for run_id in runs_to_delete]
run_uuid_query = ", ".join(run_uuid_query)

# %%
query = f"""
UPDATE runs
SET lifecycle_stage = 'deleted'
WHERE run_uuid IN ({run_uuid_query}) 
"""
with engine.begin() as conn:
    conn.execute(text(query))

# %%
query = f"""
DELETE
FROM
	experiment_tags
WHERE
	experiment_id = ANY(
	SELECT
		experiment_id
	FROM
		experiments
	WHERE
		lifecycle_stage = 'deleted');

DELETE
FROM
	latest_metrics
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE
FROM
	metrics
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE
FROM
	params
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');

DELETE
FROM
	tags
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE 
FROM 
	runs
WHERE 
	lifecycle_stage = 'deleted';

DELETE 
FROM 
	experiments
WHERE 
	lifecycle_stage = 'deleted';
"""
with engine.begin() as conn:
    conn.execute(text(query))

# %% [markdown]
# for i, row in df_runs_raw.iterrows():
#     run_id = row.run_id
#     model_name = row['params.model_name']
#     with mlflow.start_run(run_id) as run:
#         mlflow.log_param('model_nickname', model_name)

# %%
# Display summary information about the metrics dataframe
print("Dataframe shape:", df_metrics.shape)
print("\nColumns:", df_metrics.columns.tolist())
print("\nIndex levels:", df_metrics.index.names)
print("\nFirst few rows:")
print(df_metrics.head(10))
print("\nData types:")
print(df_metrics.dtypes)
print("\nNon-null counts:")
print(df_metrics.count())
# Out:
# Dataframe shape: (335, 3)
#
# Columns: ['ARI', 'AMI', 'Calinski']
#
# Index levels: ['Dataset', 'Model']
#
# First few rows:
#                                                        ARI       AMI  \
# Dataset          Model
# alizadeh-2000-v2 AffinityPropagation              0.362816       NaN
#                  AverageAgglomerativeClustering   0.809591  0.676228
#                  BatchCoHiRF-SC-SRGF              0.794763  0.671212
#                  CoHiRF                           0.864606  0.757990
#                  CoHiRF-KernelRBF                 0.046212  0.085768
#                  CompleteAgglomerativeClustering  0.382805  0.612835
#                  DBSCAN                           0.000000  0.000000
#                  HDBSCAN                          0.165928  0.267066
#                  IRFLLRR                          0.512283       NaN
#                  KMeans                           0.830673  0.750678
#
#                                                    Calinski
# Dataset          Model
# alizadeh-2000-v2 AffinityPropagation                    NaN
#                  AverageAgglomerativeClustering    5.026906
#                  BatchCoHiRF-SC-SRGF              13.133888
#                  CoHiRF                           14.869219
#                  CoHiRF-KernelRBF                  1.183931
#                  CompleteAgglomerativeClustering   9.203236
#                  DBSCAN                           -1.000000
#                  HDBSCAN                           2.126514
#                  IRFLLRR                           4.530182
#                  KMeans                           15.150730
#
# Data types:
# ARI         float64
# AMI         float64
# Calinski    float64
# dtype: object
#
# Non-null counts:
# ARI         330
# AMI         311
# Calinski    308
# dtype: int64
