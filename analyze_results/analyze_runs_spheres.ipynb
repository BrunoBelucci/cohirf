# %%
from sqlalchemy import create_engine, text
import pandas as pd
from ml_experiments.analyze import get_df_runs_from_mlflow_sql, get_missing_entries, get_common_combinations, get_df_with_combinations
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from pathlib import Path
import os
import pickle

# %% [markdown]
# # Save Results

# %% [markdown]
# ## Load mlflow runs

# %%
results_dir = Path.cwd().parent / "results" / "spheres"
os.makedirs(results_dir, exist_ok=True)

# %%
db_port = 5001
db_name = 'cohirf'
url = f'postgresql://belucci@localhost:{db_port}/{db_name}'
engine = create_engine(url)
query = 'SELECT experiments.name from experiments'
experiment_names = pd.read_sql(query, engine)['name'].tolist()

# %%
experiment_names
# Out:
# ['Default',
#  'sfni-SpectralSubspaceRandomization',
#  'sfni-KMeans',
#  'sfni-BatchCoHiRF-SC-SRGF',
#  'sfni-BatchCoHiRF-1iter',
#  'sfni-CoHiRF',
#  'sphere-BatchCoHiRF-DBSCAN-1iter',
#  'sphere-DBSCAN',
#  'sphere-CoHiRF-DBSCAN',
#  'real-ari-BatchCoHiRF-1iter',
#  'real-ari-AverageAgglomerativeClustering',
#  'real-ari-BatchCoHiRF-DBSCAN-1iter',
#  'real-ari-AffinityPropagation',
#  'real-ari-BatchCoHiRF-SC-SRGF',
#  'real-ari-CoHiRF-DBSCAN',
#  'real-ari-CoHiRF-KernelRBF',
#  'real-ari-CoHiRF',
#  'real-ari-CompleteAgglomerativeClustering',
#  'real-ari-DBSCAN',
#  'real-ari-HDBSCAN',
#  'real-ari-IRFLLRR',
#  'real-ari-KMeans',
#  'real-ari-MeanShift',
#  'real-ari-OPTICS',
#  'real-ari-Proclus',
#  'real-ari-SingleAgglomerativeClustering',
#  'real-ari-SpectralClustering',
#  'real-ari-SpectralSubspaceRandomization',
#  'real-ari-WardAgglomerativeClustering',
#  'real-adjusted_mutual_info-BatchCoHiRF-DBSCAN-1iter',
#  'real-adjusted_mutual_info-DBSCAN',
#  'real-adjusted_mutual_info-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-CompleteAgglomerativeClustering',
#  'real-adjusted_mutual_info-AverageAgglomerativeClustering',
#  'real-adjusted_mutual_info-BatchCoHiRF-1iter',
#  'real-adjusted_mutual_info-CoHiRF',
#  'real-adjusted_mutual_info-CoHiRF-KernelRBF',
#  'real-adjusted_mutual_info-CoHiRF-DBSCAN',
#  'real-adjusted_mutual_info-AffinityPropagation',
#  'real-calinski_harabasz_score-CompleteAgglomerativeClustering',
#  'real-calinski_harabasz_score-AverageAgglomerativeClustering',
#  'real-calinski_harabasz_score-DBSCAN',
#  'real-calinski_harabasz_score-CoHiRF-DBSCAN',
#  'real-calinski_harabasz_score-CoHiRF-KernelRBF',
#  'real-calinski_harabasz_score-AffinityPropagation',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-calinski_harabasz_score-CoHiRF',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter',
#  'real-adjusted_mutual_info-IRFLLRR',
#  'real-adjusted_mutual_info-HDBSCAN',
#  'real-adjusted_mutual_info-KMeans',
#  'real-calinski_harabasz_score-HDBSCAN',
#  'real-calinski_harabasz_score-IRFLLRR',
#  'real-calinski_harabasz_score-KMeans',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-MeanShift',
#  'real-calinski_harabasz_score-MeanShift',
#  'real-adjusted_mutual_info-OPTICS',
#  'real-calinski_harabasz_score-OPTICS',
#  'real-adjusted_mutual_info-Proclus',
#  'real-calinski_harabasz_score-Proclus',
#  'real-adjusted_mutual_info-SingleAgglomerativeClustering',
#  'real-calinski_harabasz_score-SingleAgglomerativeClustering',
#  'real-adjusted_mutual_info-SpectralClustering',
#  'real-calinski_harabasz_score-SpectralClustering',
#  'real-adjusted_mutual_info-SpectralSubspaceRandomization',
#  'real-calinski_harabasz_score-SpectralSubspaceRandomization',
#  'real-adjusted_mutual_info-WardAgglomerativeClustering',
#  'real-silhouette-BatchCoHiRF-SC-SRGF',
#  'real-calinski_harabasz_score-WardAgglomerativeClustering',
#  'scale_samples-BatchCoHiRF-1iter',
#  'real-silhouette-CoHiRF-DBSCAN',
#  'real-adjusted_rand-SpectralClustering',
#  'scale_samples-CoHiRF',
#  'scale_samples-BatchCoHiRF-SC-SRGF',
#  'real-silhouette-AverageAgglomerativeClustering',
#  'scale_samples-SpectralSubspaceRandomization',
#  'real-silhouette-BatchCoHiRF-1iter',
#  'scale_samples-KMeans',
#  'real-silhouette-CoHiRF',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter',
#  'real-silhouette-CoHiRF-KernelRBF',
#  'real-silhouette-AffinityPropagation',
#  'real-davies_bouldin_score-AverageAgglomerativeClustering',
#  'real-davies_bouldin_score-AffinityPropagation',
#  'real-davies_bouldin_score-CoHiRF',
#  'real-davies_bouldin_score-CoHiRF-KernelRBF',
#  'real-davies_bouldin_score-BatchCoHiRF-DBSCAN-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-1iter',
#  'real-davies_bouldin_score-CoHiRF-DBSCAN',
#  'real-davies_bouldin_score-BatchCoHiRF-SC-SRGF',
#  'real-silhouette-CompleteAgglomerativeClustering',
#  'real-davies_bouldin_score-CompleteAgglomerativeClustering',
#  'real-silhouette-DBSCAN',
#  'real-davies_bouldin_score-DBSCAN',
#  'real-silhouette-HDBSCAN',
#  'real-davies_bouldin_score-HDBSCAN',
#  'real-silhouette-IRFLLRR',
#  'real-silhouette-KMeans',
#  'real-davies_bouldin_score-KMeans',
#  'real-davies_bouldin_score-IRFLLRR',
#  'real-silhouette-MeanShift',
#  'real-davies_bouldin_score-MeanShift',
#  'real-silhouette-OPTICS',
#  'real-silhouette-Proclus',
#  'real-davies_bouldin_score-Proclus',
#  'real-davies_bouldin_score-OPTICS',
#  'real-silhouette-SingleAgglomerativeClustering',
#  'real-davies_bouldin_score-SingleAgglomerativeClustering',
#  'real-silhouette-SpectralClustering',
#  'real-davies_bouldin_score-SpectralClustering',
#  'real-silhouette-SpectralSubspaceRandomization',
#  'real-davies_bouldin_score-SpectralSubspaceRandomization',
#  'real-silhouette-WardAgglomerativeClustering',
#  'real-davies_bouldin_score-WardAgglomerativeClustering',
#  'real-normalized_mutual_info-AffinityPropagation',
#  'real-normalized_mutual_info-AverageAgglomerativeClustering',
#  'real-normalized_mutual_info-BatchCoHiRF-1iter',
#  'real-normalized_mutual_info-BatchCoHiRF-DBSCAN-1iter',
#  'real-normalized_mutual_info-BatchCoHiRF-SC-SRGF',
#  'real-normalized_mutual_info-CoHiRF-DBSCAN',
#  'real-normalized_mutual_info-CoHiRF-KernelRBF',
#  'real-normalized_mutual_info-CoHiRF',
#  'real-normalized_mutual_info-CompleteAgglomerativeClustering',
#  'real-normalized_mutual_info-DBSCAN',
#  'real-normalized_mutual_info-HDBSCAN',
#  'real-normalized_mutual_info-IRFLLRR',
#  'real-normalized_mutual_info-KMeans',
#  'real-normalized_mutual_info-MeanShift',
#  'real-normalized_mutual_info-OPTICS',
#  'real-normalized_mutual_info-Proclus',
#  'real-normalized_mutual_info-SingleAgglomerativeClustering',
#  'real-normalized_mutual_info-SpectralClustering',
#  'real-normalized_mutual_info-SpectralSubspaceRandomization',
#  'real-normalized_mutual_info-WardAgglomerativeClustering',
#  'real-adjusted_rand-BatchCoHiRF-1iter',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF',
#  'real-adjusted_rand-CoHiRF-DBSCAN',
#  'real-adjusted_rand-CoHiRF-KernelRBF',
#  'real-adjusted_rand-CoHiRF',
#  'real-adjusted_rand-DBSCAN',
#  'real-adjusted_rand-KMeans',
#  'real-adjusted_rand-SpectralSubspaceRandomization',
#  'real-adjusted_rand-KernelRBFKMeans',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_mutual_info-KernelRBFKMeans',
#  'real-calinski_harabasz_score-KernelRBFKMeans',
#  'real-normalized_mutual_info-KernelRBFKMeans',
#  'real-silhouette-KernelRBFKMeans',
#  'real-davies_bouldin_score-KernelRBFKMeans',
#  'real-normalized_mutual_info-BatchCoHiRF-KernelRBF-1iter',
#  'real-davies_bouldin_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter',
#  'real-adjusted_mutual_info-BatchCoHiRF-KernelRBF-1iter',
#  'csv-adjusted_rand-BatchCoHiRF-SC-SRGF',
#  'csv-adjusted_rand-BatchCoHiRF-1iter',
#  'csv-adjusted_rand-BatchCoHiRF-DBSCAN-1iter',
#  'csv-adjusted_rand-BatchCoHiRF-KernelRBF-1iter',
#  'csv-adjusted_rand-CoHiRF-KernelRBF',
#  'csv-adjusted_rand-CoHiRF-DBSCAN',
#  'real-adjusted_rand-CoHiRF-SC-SRGF',
#  'real-normalized_mutual_info-CoHiRF-SC-SRGF',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF',
#  'real-silhouette-CoHiRF-SC-SRGF',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF',
#  'test-CoHiRF-DBSCAN',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN',
#  'real-calinski_harabasz_score-CoHiRF-DBSCAN-top-down-inv',
#  'dbscan-optimized2',
#  'kmeans-optimized',
#  'gnoise-KMeans',
#  'sfni-CoHiRF-top-down-inv',
#  'sfni-CoHiRF-1000',
#  'sfni-CoHiRF-top-down',
#  'smd-CoHiRF-1000',
#  'smd-KMeans',
#  'smd-CoHiRF',
#  'smd-CoHiRF-top-down-inv',
#  'smd-CoHiRF-top-down',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-1iter',
#  'csv-KMeans',
#  'csv-BatchCoHiRF-1iter-random',
#  'csv-BatchCoHiRF-DBSCAN-1iter-random',
#  'csv-BatchCoHiRF-KernelRBF-1iter-random',
#  'csv-BatchCoHiRF-SC-SRGF-1iter-random',
#  'real-adjusted_rand-CoHiRF-SC-SRGF-1R',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF-1R',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF-1R',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF-1R',
#  'real-silhouette-CoHiRF-SC-SRGF-1R',
#  'real-adjusted_rand-CoHiRF-SC-SRGF-2R',
#  'real-adjusted_mutual_info-CoHiRF-SC-SRGF-2R',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF-2R',
#  'real-davies_bouldin_score-CoHiRF-SC-SRGF-2R',
#  'real-silhouette-CoHiRF-SC-SRGF-2R',
#  'real-adjusted_rand-CoHiRF-DBSCAN-top-down-inv',
#  'real-silhouette-CoHiRF-DBSCAN-top-down-inv',
#  'real-adjusted_rand-CoHiRF-DBSCAN-top-down',
#  'real-calinski_harabasz_score-CoHiRF-DBSCAN-top-down',
#  'real-silhouette-CoHiRF-DBSCAN-top-down',
#  'real-adjusted_rand-CoHiRF-KernelRBF-top-down-inv',
#  'real-calinski_harabasz_score-CoHiRF-KernelRBF-top-down-inv',
#  'real-silhouette-CoHiRF-KernelRBF-top-down-inv',
#  'real-adjusted_rand-CoHiRF-KernelRBF-top-down',
#  'real-calinski_harabasz_score-CoHiRF-KernelRBF-top-down',
#  'real-silhouette-CoHiRF-KernelRBF-top-down',
#  'real-adjusted_rand-CoHiRF-SC-SRGF-1R-top-down-inv',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF-1R-top-down-inv',
#  'real-silhouette-CoHiRF-SC-SRGF-1R-top-down-inv',
#  'real-adjusted_rand-CoHiRF-SC-SRGF-1R-top-down',
#  'real-calinski_harabasz_score-CoHiRF-SC-SRGF-1R-top-down',
#  'real-silhouette-CoHiRF-SC-SRGF-1R-top-down',
#  'real-calinski_harabasz_score-CoHiRF-1000',
#  'real-adjusted_rand-CoHiRF-1000',
#  'real-silhouette-CoHiRF-1000',
#  'real-adjusted_rand-CoHiRF-top-down',
#  'real-calinski_harabasz_score-CoHiRF-top-down',
#  'real-silhouette-CoHiRF-top-down',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-random-top-down',
#  'real-adjusted_rand-BatchCoHiRF-1iter-random-top-down',
#  'real-silhouette-BatchCoHiRF-1iter-random-top-down',
#  'real-adjusted_rand-BatchCoHiRF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-random',
#  'real-silhouette-BatchCoHiRF-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-random-top-down',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-random-top-down',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter-random-top-down',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-random-top-down',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-random-top-down',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter-random-top-down',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-1R-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF-1R-1iter-random',
#  'real-silhouette-BatchCoHiRF-SC-SRGF-1R-1iter-random',
#  'real-adjusted_rand-BatchCoHiRF-SC-SRGF-2R-1iter-random',
#  'real-calinski_harabasz_score-BatchCoHiRF-SC-SRGF-2R-1iter-random',
#  'real-silhouette-BatchCoHiRF-SC-SRGF-2R-1iter-random',
#  'csv-BatchCoHiRF-SC-SRGF-1R-1iter-random',
#  'csv-test',
#  'csv-BatchCoHiRF-SC-SRGF-2R-1iter-random',
#  'real-test',
#  'real-adjusted_rand-BatchCoHiRF-1iter-random-nolaststop',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-random-nolaststop',
#  'real-silhouette-BatchCoHiRF-1iter-random-nolaststop',
#  'real-adjusted_rand-BatchCoHiRF-1iter-random-top-down-nolaststop',
#  'real-calinski_harabasz_score-BatchCoHiRF-1iter-random-top-down-nolaststop',
#  'real-silhouette-BatchCoHiRF-1iter-random-top-down-nolaststop',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-random-nolaststop',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-random-nolaststop',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter-random-nolaststop',
#  'real-adjusted_rand-BatchCoHiRF-DBSCAN-1iter-random-top-down-nolaststop',
#  'real-calinski_harabasz_score-BatchCoHiRF-DBSCAN-1iter-random-top-down-nolaststop',
#  'real-silhouette-BatchCoHiRF-DBSCAN-1iter-random-top-down-nolaststop',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-random-nolaststop',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-random-nolaststop',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter-random-nolaststop',
#  'real-adjusted_rand-BatchCoHiRF-KernelRBF-1iter-random-top-down-nolaststop',
#  'real-calinski_harabasz_score-BatchCoHiRF-KernelRBF-1iter-random-top-down-nolaststop',
#  'real-silhouette-BatchCoHiRF-KernelRBF-1iter-random-top-down-nolaststop',
#  'scale_samples-BatchCoHiRF-SC-SRGF-1R-1iter-random']

# %%
experiments_names = [exp for exp in experiment_names if exp.startswith("sphere-")]

# %%
experiments_names
# Out:
# ['sphere-BatchCoHiRF-DBSCAN-1iter', 'sphere-DBSCAN', 'sphere-CoHiRF-DBSCAN']

# %%
params_columns = [
    "model",
    "seed_model",
    "seed_dataset",
    "n_samples",
    "n_spheres",
    "radius_separation",
    "radius_std",
    "add_radius_as_feature",
    "best/child_run_id",
	"model_params/n_batches"
]

# %%
latest_metrics_columns = [
    'fit_model_return_elapsed_time',
    'max_memory_used',
    'n_clusters_',
    'rand_score',
    'adjusted_rand',
    'mutual_info',
    'adjusted_mutual_info',
    'normalized_mutual_info',
    'homogeneity',
    'completeness',
    'v_measure',
    'silhouette',
    'calinski_harabasz_score',
    'davies_bouldin_score',
    'inertia_score',
    'best/n_clusters_',
    'best/rand_score',
    'best/adjusted_rand',
    'best/mutual_info',
    'best/adjusted_mutual_info',
    'best/normalized_mutual_info',
    'best/homogeneity_completeness_v_measure',
    'best/silhouette',
    'best/calinski_harabasz_score',
    'best/davies_bouldin_score',
    'best/inertia_score',
    'best/homogeneity',
    'best/completeness',
    'best/v_measure',
	'best/elapsed_time',
]

# %%
tags_columns = [
    'raised_exception',
    'EXCEPTION',
    'mlflow.parentRunId',
]

# %%
# # parameters of each model, they are saved as tags for the parent run
# parameters = {
#     'RecursiveClustering': ['components_size', 'repetitions', 'kmeans_n_clusters'],
#     'KMeans': ['n_clusters'],
#     'HDBSCAN': ['min_cluster_size'],
#     'DBSCAN': ['eps', 'min_samples'],
#     'AffinityPropagation': ['damping'],
#     'OPTICS': ['min_samples'],
#     'SpectralSubspaceRandomization': ['n_similarities', 'sampling_ratio', 'sc_n_clusters'],
#     'WardAgglomerativeClustering': ['n_clusters'],
# }
# all_model_parameters = [p for model, params in parameters.items() for p in params]
# all_model_parameters = list(set(all_model_parameters))
# for param in all_model_parameters:
#     tags_columns.append(param)

# %%
runs_columns = ['run_uuid', 'status', 'start_time', 'end_time']
experiments_columns = []
other_table = 'params'
other_table_keys = params_columns
df_params = get_df_runs_from_mlflow_sql(engine, runs_columns=runs_columns, experiments_columns=experiments_columns, experiments_names=experiments_names, other_table=other_table, other_table_keys=other_table_keys)
df_latest_metrics = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='latest_metrics', other_table_keys=latest_metrics_columns)
df_tags = get_df_runs_from_mlflow_sql(engine, runs_columns=['run_uuid'], experiments_columns=experiments_columns, experiments_names=experiments_names, other_table='tags', other_table_keys=tags_columns)

# %%
df_runs_raw = df_params.join(df_latest_metrics)
df_runs_raw = df_runs_raw.join(df_tags)
df_runs_raw.to_csv(results_dir / 'df_runs_raw.csv', index=True)

# %%
df_runs_raw = pd.read_csv(results_dir / "df_runs_raw.csv", index_col=0)
df_runs_raw_parents = df_runs_raw.copy()
df_runs_raw_parents = df_runs_raw_parents.loc[df_runs_raw_parents['mlflow.parentRunId'].isna()]

# %%
df_runs_raw_parents
# Out:
#                                     status     start_time      end_time  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718  FINISHED  1751688599887  1.751689e+12
# 010ff6575e2e49909f025645b25a8b15  FINISHED  1751677307277  1.751682e+12
# 022ea18b909642aa9eb04fd7e05b9815  FINISHED  1751647859039  1.751648e+12
# 02bfe3a9137644758c13c16a88a7e8a2   RUNNING  1751704511923           NaN
# 03650862ffbf4bc9ad8e818760546ab0  FINISHED  1751697270701  1.751703e+12
# ...                                    ...            ...           ...
# f1b5d82f33234fa0914134f51e94947c  FINISHED  1751711890053  1.751716e+12
# f21ae1f0dd3145ed8dc094be3e31e2c1  FINISHED  1751648180477  1.751648e+12
# f2fa5e234b8c4050ad8ca84e2df2953e  FINISHED  1751648965064  1.751649e+12
# fc1a84403e504a65a61f2eec1a529abc  FINISHED  1751648240860  1.751648e+12
# fd67f2cbc5a043f7abcbe572fc949db5  FINISHED  1751685319541  1.751692e+12
#
#                                   add_radius_as_feature  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718                  False
# 010ff6575e2e49909f025645b25a8b15                  False
# 022ea18b909642aa9eb04fd7e05b9815                  False
# 02bfe3a9137644758c13c16a88a7e8a2                  False
# 03650862ffbf4bc9ad8e818760546ab0                  False
# ...                                                 ...
# f1b5d82f33234fa0914134f51e94947c                  False
# f21ae1f0dd3145ed8dc094be3e31e2c1                  False
# f2fa5e234b8c4050ad8ca84e2df2953e                  False
# fc1a84403e504a65a61f2eec1a529abc                  False
# fd67f2cbc5a043f7abcbe572fc949db5                  False
#
#                                                  best/child_run_id  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718  b55674320e764124864960f6b9476bd8
# 010ff6575e2e49909f025645b25a8b15  796eca112374445bb6ce918a3bb91fa9
# 022ea18b909642aa9eb04fd7e05b9815  ee8deeea13374f5687ba01127287d6f2
# 02bfe3a9137644758c13c16a88a7e8a2                               NaN
# 03650862ffbf4bc9ad8e818760546ab0  f3fbfd4578dd4e9d97ca0d874790f445
# ...                                                            ...
# f1b5d82f33234fa0914134f51e94947c  648e4581e3f947bcaa0a2566ad736634
# f21ae1f0dd3145ed8dc094be3e31e2c1  c1d4d5e0cfb04e27ad1d05f3752016a6
# f2fa5e234b8c4050ad8ca84e2df2953e  7bc62e467fb54f3c846ba6bd822dfe5f
# fc1a84403e504a65a61f2eec1a529abc  1a1206d6ba5f495f84e238e697cb3e0b
# fd67f2cbc5a043f7abcbe572fc949db5  92b57cd4c6d14d07ae966ac98d02a889
#
#                                                      model  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718  BatchCoHiRF-DBSCAN-1iter
# 010ff6575e2e49909f025645b25a8b15  BatchCoHiRF-DBSCAN-1iter
# 022ea18b909642aa9eb04fd7e05b9815             CoHiRF-DBSCAN
# 02bfe3a9137644758c13c16a88a7e8a2                    DBSCAN
# 03650862ffbf4bc9ad8e818760546ab0             CoHiRF-DBSCAN
# ...                                                    ...
# f1b5d82f33234fa0914134f51e94947c             CoHiRF-DBSCAN
# f21ae1f0dd3145ed8dc094be3e31e2c1  BatchCoHiRF-DBSCAN-1iter
# f2fa5e234b8c4050ad8ca84e2df2953e             CoHiRF-DBSCAN
# fc1a84403e504a65a61f2eec1a529abc                    DBSCAN
# fd67f2cbc5a043f7abcbe572fc949db5             CoHiRF-DBSCAN
#
#                                   model_params/n_batches  n_samples  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718                     NaN     200000
# 010ff6575e2e49909f025645b25a8b15                     NaN    2000000
# 022ea18b909642aa9eb04fd7e05b9815                     NaN        200
# 02bfe3a9137644758c13c16a88a7e8a2                     NaN    2000000
# 03650862ffbf4bc9ad8e818760546ab0                     NaN    2000000
# ...                                                  ...        ...
# f1b5d82f33234fa0914134f51e94947c                     NaN     200000
# f21ae1f0dd3145ed8dc094be3e31e2c1                     NaN       2000
# f2fa5e234b8c4050ad8ca84e2df2953e                     NaN        200
# fc1a84403e504a65a61f2eec1a529abc                     NaN      20000
# fd67f2cbc5a043f7abcbe572fc949db5                     NaN    2000000
#
#                                   n_spheres  radius_separation  ...  \
# run_uuid                                                        ...
# 00acc4c5442149c7bb9f2a061df23718          2                0.5  ...
# 010ff6575e2e49909f025645b25a8b15          2                0.5  ...
# 022ea18b909642aa9eb04fd7e05b9815          2                0.5  ...
# 02bfe3a9137644758c13c16a88a7e8a2          2                0.5  ...
# 03650862ffbf4bc9ad8e818760546ab0          2                0.5  ...
# ...                                     ...                ...  ...
# f1b5d82f33234fa0914134f51e94947c          2                0.5  ...
# f21ae1f0dd3145ed8dc094be3e31e2c1          2                0.5  ...
# f2fa5e234b8c4050ad8ca84e2df2953e          2                0.5  ...
# fc1a84403e504a65a61f2eec1a529abc          2                0.5  ...
# fd67f2cbc5a043f7abcbe572fc949db5          2                0.5  ...
#
#                                   max_memory_used  mutual_info  n_clusters_  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718          414.876     0.000000          1.0
# 010ff6575e2e49909f025645b25a8b15          623.808     0.693147          2.0
# 022ea18b909642aa9eb04fd7e05b9815          383.796     0.000000          1.0
# 02bfe3a9137644758c13c16a88a7e8a2              NaN          NaN          NaN
# 03650862ffbf4bc9ad8e818760546ab0          621.816          NaN          NaN
# ...                                           ...          ...          ...
# f1b5d82f33234fa0914134f51e94947c          411.904     0.693147          2.0
# f21ae1f0dd3145ed8dc094be3e31e2c1          392.892     0.000000          1.0
# f2fa5e234b8c4050ad8ca84e2df2953e          384.832     0.000000          1.0
# fc1a84403e504a65a61f2eec1a529abc         6553.616     0.000000          1.0
# fd67f2cbc5a043f7abcbe572fc949db5          623.088          NaN          NaN
#
#                                   normalized_mutual_info  rand_score  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718                     0.0    0.499997
# 010ff6575e2e49909f025645b25a8b15                     1.0    1.000000
# 022ea18b909642aa9eb04fd7e05b9815                     0.0    0.497487
# 02bfe3a9137644758c13c16a88a7e8a2                     NaN         NaN
# 03650862ffbf4bc9ad8e818760546ab0                     NaN         NaN
# ...                                                  ...         ...
# f1b5d82f33234fa0914134f51e94947c                     1.0    1.000000
# f21ae1f0dd3145ed8dc094be3e31e2c1                     0.0    0.499750
# f2fa5e234b8c4050ad8ca84e2df2953e                     0.0    0.497487
# fc1a84403e504a65a61f2eec1a529abc                     0.0    0.499975
# fd67f2cbc5a043f7abcbe572fc949db5                     NaN         NaN
#
#                                   silhouette  v_measure  EXCEPTION  \
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718   -1.000000        0.0        NaN
# 010ff6575e2e49909f025645b25a8b15    0.110352        1.0        NaN
# 022ea18b909642aa9eb04fd7e05b9815   -1.000000        0.0        NaN
# 02bfe3a9137644758c13c16a88a7e8a2         NaN        NaN        NaN
# 03650862ffbf4bc9ad8e818760546ab0         NaN        NaN        NaN
# ...                                      ...        ...        ...
# f1b5d82f33234fa0914134f51e94947c    0.103791        1.0        NaN
# f21ae1f0dd3145ed8dc094be3e31e2c1   -1.000000        0.0        NaN
# f2fa5e234b8c4050ad8ca84e2df2953e   -1.000000        0.0        NaN
# fc1a84403e504a65a61f2eec1a529abc   -1.000000        0.0        NaN
# fd67f2cbc5a043f7abcbe572fc949db5         NaN        NaN        NaN
#
#                                   mlflow.parentRunId  raised_exception
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718                 NaN             False
# 010ff6575e2e49909f025645b25a8b15                 NaN             False
# 022ea18b909642aa9eb04fd7e05b9815                 NaN             False
# 02bfe3a9137644758c13c16a88a7e8a2                 NaN               NaN
# 03650862ffbf4bc9ad8e818760546ab0                 NaN             False
# ...                                              ...               ...
# f1b5d82f33234fa0914134f51e94947c                 NaN             False
# f21ae1f0dd3145ed8dc094be3e31e2c1                 NaN             False
# f2fa5e234b8c4050ad8ca84e2df2953e                 NaN             False
# fc1a84403e504a65a61f2eec1a529abc                 NaN             False
# fd67f2cbc5a043f7abcbe572fc949db5                 NaN             False
#
# [93 rows x 41 columns]

# %% [markdown]
# ## Delete duplicate runs (if any) and complete some models that cannot run with some datasets

# %%
non_duplicate_columns = [
    "model",
    "seed_model",
    "seed_dataset",
    "n_samples",
    "n_spheres",
    "radius_separation",
    "radius_std",
    "add_radius_as_feature",
]
df_runs_parents = df_runs_raw_parents.dropna(axis=0, how="all", subset=["best/adjusted_rand"]).copy()
df_runs_parents = df_runs_parents.loc[(~df_runs_parents.duplicated(non_duplicate_columns))]
# fill missing values with "None"
df_runs_parents = df_runs_parents.fillna("None")

# %%
df = df_runs_parents.copy()
df = df.loc[df['model'] == 'BatchCoHiRF-DBSCAN-1iter']
df = df[["n_samples", "model_params/n_batches"]]

# %%
df
# Out:
#                                   n_samples model_params/n_batches
# run_uuid
# 00acc4c5442149c7bb9f2a061df23718     200000                   None
# 010ff6575e2e49909f025645b25a8b15    2000000                   None
# 0ebc142211d54235bc37e897b924a311    2000000                   None
# 0ed8dcea82c94c1bb58c7a661efbff4d      20000                   None
# 1bc352e0bcf9447fa8b2f905c3e9ea24        200                   None
# 1e20875f264b446397b64c0825537ea8   20000000                 1000.0
# 211c9000f511420cb8cd1988289f3388       2000                   None
# 3a501221bc6e4cf5b9803c4a8ee4f88f     200000                   None
# 3f40b4417f8648a6a3781e13b9364e59   20000000                 1000.0
# 5670999ff4464c4a87017880d4344f8c   20000000                 1000.0
# 5d927bac51f6475aa49d3ccaee75ce31        200                   None
# 5ef05294f8fc44d88fe44bc4bb87e31a   20000000                 1000.0
# 6fc194bae5b64b4ab0a340f868ab1481    2000000                   None
# 7036bab84eac4a0191d24bbc8be62da4    2000000                  100.0
# 734ed11e80854255b62017ee4f386612      20000                   None
# 8973d2f7cb8a4d00bbeea31ba45b4c0e        200                   None
# 89c25dc27614453ebb0430426a700e75     200000                   None
# 90020ed672f9405cbb3ac850abb563dd        200                   None
# 9b10a272077a4fe6ad7def1dd29170a0    2000000                   None
# 9e71c2e9f7da469c8442c1049da011b0   20000000                 1000.0
# 9ed49b58baa146a7986240892341fe87      20000                   None
# 9f3acdd416184978a158a0a06fccd508     200000                   None
# a377c0025d3d4766a2b5334aed9f5626       2000                   None
# adb941e62d0d4d32ae5f417d28f62ec4     200000                   None
# b325f27fc0974081a1dd6cc4d203ad43       2000                   None
# be1928333e09488f9b54009f6bb4aeaf        200                   None
# c72af619654844cc88e183f57f31ed9a      20000                   None
# d960a3df125e486582b1aef5e712b1d4      20000                   None
# e925cd990a674767b422d45b45cc8cc1       2000                   None
# f21ae1f0dd3145ed8dc094be3e31e2c1       2000                   None

# %% [markdown]
# # Missing

# %%
model_nickname = df_runs_parents['model'].unique().tolist()
model_nickname.sort()
model_nickname
# Out:
# ['BatchCoHiRF-DBSCAN-1iter', 'CoHiRF-DBSCAN', 'DBSCAN']

# %%
model_nickname = [
    # 'BatchCoHiRF-DBSCAN-1iter', 
	# 'CoHiRF-DBSCAN', 
	'DBSCAN'
]

# %%
non_duplicate_columns = [
    "model",
    # "seed_model",
    "n_samples",
    "seed_dataset",
    # "n_spheres",
    # "radius_separation",
    # "radius_std",
    # "add_radius_as_feature",
    
]

# %%
n_samples = [200, 2000, 20000, 200000] #2000000, 20000000]  # , 200000]
seed_dataset = [i for i in range(5)]
columns_names = non_duplicate_columns
should_contain_values = [model_nickname, n_samples, seed_dataset]
df_missing = get_missing_entries(df_runs_parents, columns_names, should_contain_values)

# %%
df_missing
# Out:
#     model  n_samples  seed_dataset
# 0  DBSCAN     200000             0
# 1  DBSCAN     200000             1
# 2  DBSCAN     200000             2
# 3  DBSCAN     200000             3
# 4  DBSCAN     200000             4

# %%
df_missing["hpo_seed"] = df_missing["seed_dataset"]

# %%
# Join df_runs_raw_parents into df_missing using non_duplicate_columns to get the EXCEPTION column
df_missing_with_exception = df_missing.merge(
    df_runs_raw_parents[non_duplicate_columns + ["raised_exception"]],
    how="left",
    left_on=["model", "n_samples", "seed_dataset"],
    right_on=["model", "n_samples", "seed_dataset"],
)
df_missing_with_exception[["model", "n_samples", "seed_dataset", "raised_exception"]]
# Out:
#      model  n_samples  seed_dataset raised_exception
# 0   DBSCAN     200000             0              NaN
# 1   DBSCAN     200000             0              NaN
# 2   DBSCAN     200000             0              NaN
# 3   DBSCAN     200000             1              NaN
# 4   DBSCAN     200000             1              NaN
# 5   DBSCAN     200000             1              NaN
# 6   DBSCAN     200000             2              NaN
# 7   DBSCAN     200000             2              NaN
# 8   DBSCAN     200000             2              NaN
# 9   DBSCAN     200000             3              NaN
# 10  DBSCAN     200000             3              NaN
# 11  DBSCAN     200000             3              NaN
# 12  DBSCAN     200000             4              NaN
# 13  DBSCAN     200000             4              NaN
# 14  DBSCAN     200000             4              NaN

# %%
missing_dict = {}
for model in df_missing['model'].unique():
    sub = df_missing[df_missing["model"] == model].drop(columns=["model"])
    missing_dict[model] = sub.to_dict(orient="records")
if len(missing_dict) != 0:
    with open(results_dir / 'missing_dict.pkl', 'wb') as f:
        pickle.dump(missing_dict, f)

# %% [markdown]
# # Get common combinations

# %%
model_nickname = [
    'BatchCoHiRF-DBSCAN-1iter', 
	# 'BatchCoHiRF-DBSCAN',
	'CoHiRF-DBSCAN', 
	'DBSCAN'
]
df = df_runs_parents.copy()
df = df.loc[df["model"].isin(model_nickname)]
column = 'model'
combination_columns = [
    "n_samples",
    "seed_dataset",
]
common_combinations = get_common_combinations(df, column, combination_columns)

# %%
df_common = get_df_with_combinations(df, combination_columns, common_combinations)

# %%
model_nickname = [
    'BatchCoHiRF-DBSCAN-1iter', 
	# 'BatchCoHiRF-DBSCAN',
]
df = df_runs_parents.copy()
df = df.loc[df["model"].isin(model_nickname)]
df = df.loc[df["n_samples"] == 200000]
column = 'model'
combination_columns = [
    "n_samples",
    "seed_dataset",
]
common_combinations = get_common_combinations(df, column, combination_columns)
df_common2 = get_df_with_combinations(df, combination_columns, common_combinations)

# %%
df_common = pd.concat([df_common, df_common2], ignore_index=True)

# %%
df = df_runs_parents.copy()
df = df.loc[df["model"] == 'CoHiRF-DBSCAN']
df = df.loc[df["n_samples"] == 2000]
df
# Out:
#                                     status     start_time      end_time  \
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3  FINISHED  1751647791255  1.751648e+12
# 23b57531d2c24f1482cdfbb26138018e  FINISHED  1751647922441  1.751648e+12
# 30210220fdea40e49abdbf8af687755d  FINISHED  1751648578619  1.751649e+12
# c333514035e34d0094718bb8bb6db5e9  FINISHED  1751648534207  1.751649e+12
# e734bd2225de4654b067666a658dbc80  FINISHED  1751648286801  1.751648e+12
#
#                                   add_radius_as_feature  \
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3                  False
# 23b57531d2c24f1482cdfbb26138018e                  False
# 30210220fdea40e49abdbf8af687755d                  False
# c333514035e34d0094718bb8bb6db5e9                  False
# e734bd2225de4654b067666a658dbc80                  False
#
#                                                  best/child_run_id  \
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3  4272a769044745b1af9d6388cc6bd809
# 23b57531d2c24f1482cdfbb26138018e  e7e9958c5e384449aafe7437737d905e
# 30210220fdea40e49abdbf8af687755d  0086096badae4255be1622029f7218dc
# c333514035e34d0094718bb8bb6db5e9  68b211c84962460596146cc39fe41bcd
# e734bd2225de4654b067666a658dbc80  ee9b32829a4d4431aff1b9ea412ceb08
#
#                                           model  n_samples  n_spheres  \
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3  CoHiRF-DBSCAN       2000          2
# 23b57531d2c24f1482cdfbb26138018e  CoHiRF-DBSCAN       2000          2
# 30210220fdea40e49abdbf8af687755d  CoHiRF-DBSCAN       2000          2
# c333514035e34d0094718bb8bb6db5e9  CoHiRF-DBSCAN       2000          2
# e734bd2225de4654b067666a658dbc80  CoHiRF-DBSCAN       2000          2
#
#                                   radius_separation  radius_std  ...  \
# run_uuid                                                         ...
# 216be1b38e7d49be9d71f0b1706633a3                0.5        0.01  ...
# 23b57531d2c24f1482cdfbb26138018e                0.5        0.01  ...
# 30210220fdea40e49abdbf8af687755d                0.5        0.01  ...
# c333514035e34d0094718bb8bb6db5e9                0.5        0.01  ...
# e734bd2225de4654b067666a658dbc80                0.5        0.01  ...
#
#                                   max_memory_used  mutual_info  n_clusters_  \
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3          399.760     0.693147        442.0
# 23b57531d2c24f1482cdfbb26138018e          400.072     0.000000          1.0
# 30210220fdea40e49abdbf8af687755d          400.236     0.693147          2.0
# c333514035e34d0094718bb8bb6db5e9          400.204     0.000000          1.0
# e734bd2225de4654b067666a658dbc80          400.600     0.000000          1.0
#
#                                   normalized_mutual_info  rand_score  \
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3                0.356746    0.754682
# 23b57531d2c24f1482cdfbb26138018e                0.000000    0.499750
# 30210220fdea40e49abdbf8af687755d                1.000000    1.000000
# c333514035e34d0094718bb8bb6db5e9                0.000000    0.499750
# e734bd2225de4654b067666a658dbc80                0.000000    0.499750
#
#                                   silhouette  v_measure  EXCEPTION  \
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3   -0.144231   0.356746       None
# 23b57531d2c24f1482cdfbb26138018e   -1.000000   0.000000       None
# 30210220fdea40e49abdbf8af687755d    0.100361   1.000000       None
# c333514035e34d0094718bb8bb6db5e9   -1.000000   0.000000       None
# e734bd2225de4654b067666a658dbc80   -1.000000   0.000000       None
#
#                                   mlflow.parentRunId  raised_exception
# run_uuid
# 216be1b38e7d49be9d71f0b1706633a3                None             False
# 23b57531d2c24f1482cdfbb26138018e                None             False
# 30210220fdea40e49abdbf8af687755d                None             False
# c333514035e34d0094718bb8bb6db5e9                None             False
# e734bd2225de4654b067666a658dbc80                None             False
#
# [5 rows x 40 columns]

# %% [markdown]
# # Plots

# %%
df = df_runs_parents.copy()
models_names = {
    "BatchCoHiRF-DBSCAN-1iter": "BatchCoHiRF-DBSCAN",
    # "BatchCoHiRF-DBSCAN": "BatchCoHiRF-DBSCAN",
    # "CoHiRF-DBSCAN": "CoHiRF-DBSCAN",
    "DBSCAN": "DBSCAN",
}
df = df.loc[df["model"].isin(models_names.keys())]
df["n_samples"] = df["n_samples"].astype(int)
df = df.loc[df["n_samples"] >= 2000]
df = df.replace({"model": models_names})
df = df.sort_values(by="model")
df = df.rename(
    columns={
        "fit_model_return_elapsed_time": "Time (s)",
        "max_memory_used": "Memory (MB)",
        "n_samples": "Number of samples",
        "model": "Model",
        "best/adjusted_rand": "ARI",
    }
)

with mpl.rc_context(
    rc={
        "font.family": "serif",
        "font.serif": ["DejaVu Serif", "Liberation Serif", "Times", "serif"],  # Reliable serif fonts
        "mathtext.fontset": "dejavuserif",  # Use DejaVu for math text to avoid missing glyphs
        "axes.unicode_minus": False,  # Use ASCII minus instead of Unicode minus
        "font.size": 12,
        "axes.linewidth": 1.2,
        "axes.labelsize": 16,
        "axes.titlesize": 16,
        "xtick.labelsize": 16,
        "ytick.labelsize": 16,
        "legend.fontsize": 10,
        "legend.frameon": True,
        "legend.fancybox": False,
        "legend.shadow": False,
        "legend.framealpha": 0.9,
        "legend.edgecolor": "black",
        "grid.alpha": 0.3,
        "axes.grid": True,
        "grid.linewidth": 0.5,
    }
):
    cm = 1 / 2.54  # centimeters to inches
    scale = 3.0
    fig = plt.figure(figsize=(12 * scale * cm, 7 * scale * cm))
    palette = sns.color_palette("tab10", n_colors=len(df["Model"].unique()))
    # ARI plot
    ax = sns.lineplot(
        data=df,
        x="Number of samples",
        y="ARI",
        hue="Model",
        style="Model",
        markers=True,
        markersize=10,
        errorbar=("ci", 95),
        palette=palette,
        legend=True,
        # err_style="bars",
    )
    # ax.set_xscale("log", base=10)
    ax.set_xscale("log")
    ax.set_ylabel("Adjusted Rand Index (ARI)", fontweight='bold')
    ax.set_xlabel("Number of samples", fontweight='bold')
    ax.legend(title='', loc='upper center', ncol=4, fontsize=13, frameon=True, bbox_to_anchor=(0.5, 1.08))
    ax.tick_params(direction="in", length=4, width=1.2)
    for spine in ["left", "right", "top", "bottom"]:
        ax.spines[spine].set_linewidth(1.4)
        ax.spines[spine].set_color("black")
    ax.grid(True, alpha=0.7, linestyle="-", linewidth=0.5)
    fig.savefig(results_dir / f"hpo_sphere_ari_cohirf.pdf", dpi=300, bbox_inches='tight')
    plt.show()

# %%
df = df_runs_parents.copy()
models_names = {
    "BatchCoHiRF-DBSCAN-1iter": "BatchCoHiRF-DBSCAN",
    # "BatchCoHiRF-DBSCAN": "BatchCoHiRF-DBSCAN",
    # "CoHiRF-DBSCAN": "CoHiRF-DBSCAN",
    "DBSCAN": "DBSCAN",
}
df = df.loc[df["model"].isin(models_names.keys())]
df = df.loc[df["n_samples"] >= 2000]
df = df.replace({"model": models_names})
df = df.sort_values(by="model")
df = df.rename(
    columns={
        "best/elapsed_time": "Time (s)",
        "max_memory_used": "Memory (MB)",
        "n_samples": "Number of samples",
        "model": "Model",
        "best/adjusted_rand": "ARI",
    }
)

with mpl.rc_context(
    rc={
        "font.family": "serif",
        "font.serif": ["DejaVu Serif", "Liberation Serif", "Times", "serif"],  # Reliable serif fonts
        "mathtext.fontset": "dejavuserif",  # Use DejaVu for math text to avoid missing glyphs
        "axes.unicode_minus": False,  # Use ASCII minus instead of Unicode minus
        "font.size": 12,
        "axes.linewidth": 1.2,
        "axes.labelsize": 16,
        "axes.titlesize": 16,
        "xtick.labelsize": 16,
        "ytick.labelsize": 16,
        "legend.fontsize": 10,
        "legend.frameon": True,
        "legend.fancybox": False,
        "legend.shadow": False,
        "legend.framealpha": 0.9,
        "legend.edgecolor": "black",
        "grid.alpha": 0.3,
        "axes.grid": True,
        "grid.linewidth": 0.5,
    }
):
    cm = 1 / 2.54  # centimeters to inches
    scale = 3.0
    fig, axs = plt.subplots(2, 1, sharex=True, figsize=(12 * scale * cm, 14 * scale * cm))
    axs = axs.flatten()
    palette = sns.color_palette("tab10", n_colors=len(df["Model"].unique()))
    # Time plot
    ax = sns.lineplot(
        data=df,
        x="Number of samples",
        y="Time (s)",
        hue="Model",
        style="Model",
        markers=True,
        markersize=10,
        errorbar=("ci", 95),
        palette=palette,
        legend=True,
        ax=axs[0],
    )
    # ax.set_yscale("log")
    # ARI plot
    ax2 = sns.lineplot(
        data=df,
        x="Number of samples",
        y="ARI",
        hue="Model",
        style="Model",
        markers=True,
        markersize=10,
        errorbar=("ci", 95),
        palette=palette,
        legend=True,
        ax=axs[1],
    )
    ax.set_xscale("log")
    ax2.set_xscale("log")
    ax.set_ylabel("Time (s)", fontweight='bold')
    ax2.set_ylabel("Adjusted Rand Index (ARI)", fontweight='bold')
    ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
    # Remove duplicate legends
    handles, labels = ax.get_legend_handles_labels()
    # fig.legend(handles, labels, loc="upper center", ncol=4, fontsize=13, frameon=False, bbox_to_anchor=(0.5, 1.02))
    # ax.get_legend().remove()
    ax.legend(title="", loc="upper center", ncol=4, fontsize=13, frameon=True, bbox_to_anchor=(0.5, 1.08))
    ax2.get_legend().remove()
    plt.xlabel("Number of samples")
    ax.tick_params(direction="in", length=4, width=1.2)
    ax.grid(True, which="both", linestyle="--", linewidth=0.5)
    ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
    for spine in ["left", "right", "top", "bottom"]:
        ax.spines[spine].set_linewidth(1.4)
        ax.spines[spine].set_color("black")
        ax2.spines[spine].set_linewidth(1.4)
        ax2.spines[spine].set_color("black")
    # Reduce vertical space between subplots
    plt.subplots_adjust(hspace=0.05)
    fig.savefig(results_dir / f"hpo_sphere_ari_cohirf_best_time.pdf", dpi=300, bbox_inches="tight")
    plt.show()

# %%
results_dir
# Out:
# PosixPath('/home/belucci/code/cohirf/results/spheres')

# %%
df["Number of samples"].unique()
# Out:
# array([  200000,     2000,    20000, 20000000,  2000000])

# %%
df = df_runs_parents.copy()
models_names = {
	"BatchCoHiRF-DBSCAN-1iter": "BatchCoHiRF-DBSCAN",
	# "BatchCoHiRF-DBSCAN": "BatchCoHiRF-DBSCAN",
	# "CoHiRF-DBSCAN": "CoHiRF-DBSCAN",
	"DBSCAN": "DBSCAN",
}
df = df.loc[df["model"].isin(models_names.keys())]
df = df.loc[df["n_samples"] >= 2000]
df = df.replace({"model": models_names})
df = df.sort_values(by="model")
df = df.rename(
	columns={
		"fit_model_return_elapsed_time": "Time (s)",
		"max_memory_used": "Memory (MB)",
		"n_samples": "Number of samples",
		"model": "Model",
		"best/adjusted_rand": "ARI",
	}
)

plt.style.use("seaborn-v0_8-whitegrid")
with mpl.rc_context(
	rc={
		"figure.constrained_layout.use": True,
		"savefig.bbox": "tight",
		"figure.figsize": (12, 7),
		"legend.loc": "upper left",
		"legend.frameon": True,
		"font.size": 14,
		"axes.titlesize": 16,
		"axes.labelsize": 15,
		"xtick.labelsize": 13,
		"ytick.labelsize": 13,
		"axes.grid": True,
		"grid.color": "grey",
		"grid.alpha": 0.3,
	}
):
	fig, axs = plt.subplots(2, 1, sharex=True)
	axs = axs.flatten()
	palette = sns.color_palette("tab10", n_colors=len(df["Model"].unique()))
	# Time plot
	ax = sns.lineplot(
		data=df,
		x="Number of samples",
		y="Time (s)",
		hue="Model",
		style="Model",
		markers=True,
		dashes=False,
		errorbar="ci",
		ax=axs[0],
		palette=palette,
	)
	ax.set_yscale("log")
	ax.set_ylabel("Time (s)")
	ax.grid(True, which="both", linestyle="--", linewidth=0.5)
	# ARI plot
	ax2 = sns.lineplot(
		data=df,
		x="Number of samples",
		y="ARI",
		hue="Model",
		style="Model",
		markers=True,
		dashes=False,
		errorbar="ci",
		ax=axs[1],
		palette=palette,
	)
	ax2.set_xscale("log")
	ax2.set_ylabel("Adjusted Rand Index (ARI)")
	ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
	# Remove duplicate legends
	handles, labels = ax.get_legend_handles_labels()
	fig.legend(handles, labels, loc="upper center", ncol=4, fontsize=13, frameon=False, bbox_to_anchor=(0.5, 1.08))
	ax.get_legend().remove()
	ax2.get_legend().remove()
	plt.xlabel("Number of samples")
	plt.tight_layout()
	plt.savefig(
	    results_dir / f"hpo_sphere_ari_cohirf.pdf", dpi=300
	)
	plt.show()
# Out:
# /tmp/ipykernel_2521/298200728.py:81: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
df = df_runs_parents.copy()
models_names = {
    "BatchCoHiRF-DBSCAN-1iter": "BatchCoHiRF-DBSCAN",
    # "BatchCoHiRF-DBSCAN": "BatchCoHiRF-DBSCAN",
    # "CoHiRF-DBSCAN": "CoHiRF-DBSCAN",
    "DBSCAN": "DBSCAN",
}
df = df.loc[df["model"].isin(models_names.keys())]
df = df.replace({"model": models_names})
df = df.sort_values(by="model")
df = df.rename(
    columns={
        "best/elapsed_time": "Time (s)",
        "max_memory_used": "Memory (MB)",
        "n_samples": "Number of samples",
        "model": "Model",
        "best/adjusted_rand": "ARI",
    }
)

plt.style.use("seaborn-v0_8-whitegrid")
with mpl.rc_context(
    rc={
        "figure.constrained_layout.use": True,
        "savefig.bbox": "tight",
        "figure.figsize": (12, 7),
        "legend.loc": "upper left",
        "legend.frameon": True,
        "font.size": 14,
        "axes.titlesize": 16,
        "axes.labelsize": 15,
        "xtick.labelsize": 13,
        "ytick.labelsize": 13,
        "axes.grid": True,
        "grid.color": "grey",
        "grid.alpha": 0.3,
    }
):
    fig, axs = plt.subplots(2, 1, sharex=True)
    axs = axs.flatten()
    palette = sns.color_palette("tab10", n_colors=len(df["Model"].unique()))
    # Time plot
    ax = sns.lineplot(
        data=df,
        x="Number of samples",
        y="Time (s)",
        hue="Model",
        style="Model",
        markers=True,
        dashes=False,
        errorbar="ci",
        ax=axs[0],
        palette=palette,
    )
    ax.set_yscale("log")
    ax.set_ylabel("Time (s)")
    ax.grid(True, which="both", linestyle="--", linewidth=0.5)
    # ARI plot
    ax2 = sns.lineplot(
        data=df,
        x="Number of samples",
        y="ARI",
        hue="Model",
        style="Model",
        markers=True,
        dashes=False,
        errorbar="ci",
        ax=axs[1],
        palette=palette,
    )
    ax2.set_xscale("log")
    ax2.set_ylabel("Adjusted Rand Index (ARI)")
    ax2.grid(True, which="both", linestyle="--", linewidth=0.5)
    # Remove duplicate legends
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles, labels, loc="upper center", ncol=4, fontsize=13, frameon=False, bbox_to_anchor=(0.5, 1.08))
    ax.get_legend().remove()
    ax2.get_legend().remove()
    plt.xlabel("Number of samples")
    plt.tight_layout()
    plt.savefig(results_dir / f"best_hpo_sphere_ari_cohirf.pdf", dpi=300)
    plt.show()
# Out:
# /tmp/ipykernel_72286/3000254923.py:80: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# # Debug and explore

# %%
df = df_runs_raw.copy()
# df = df.loc[df['model_nickname'].isin(['IRFLLRR', 'Proclus', 'SpectralSubspaceRandomization'])]

# %%
runs_to_delete = list(df.index)

# %%
print(runs_to_delete, len(runs_to_delete))
# Out:
# ['0007d75ba74d46108c24a2f84dcbf8e4', '000aa1c139e84063bb8c72b62c663e04', '0020de9a8ddb4f4bb205652af303c21f', '0051fdb1338c401fb10fcce3bbf1f76c', '005dc019eb1b455c9073634bad661061', '006503c18f5a40c9b6f5138415db598f', '006dc411d9df4c8abc08d0939687cb0a', '008b8b32dcab428abd871eca700bbc07', '009f9bf63cb54404bc3cb9139bc8e5fd', '00e987fcf7ac4dea8e8ae70131a9093e', '00ea900451f043fd8038de0f0830f867', '0107b81032b9424780f7fff1f373703b', '0118f8758035407eae47d5abef4b78a6', '01241e2701f043ce98d7797a5564edb4', '01287578f1e74b1fb0ff0536d67b8dc3', '012e7eab64c24a10802b9b0dd69260fa', '0148b5ba150d488697b22706ecfdd549', '0158bb2319554785ad687f0d7dad67b3', '017161e9300646b79497a5771104b729', '019fb764c08f4d8b9536cfc862bb79e0', '01ad969fc2ec435ba2a33ff1e9f8bd03', '01b9b038f39c4029897ef132d2d41fb6', '01be9f85b3b54025b2ba71cbc33b4bf6', '01c463193b404c3ea7a70cb76140af6f', '01cddc8f9a804c6f94aadc1be386ec02', '01d02c060d2f47448c9cd84a996d0a07', '01da3bc0cc0543d3b71f4f34376a04b6', '01f1d826a12a40f0a4527d38722ff679', '020272dccf2146478e2a0bc005d06788', '0215d438124e426dad18f7aa8dd98437', '0223f6bf9a6c469ca5e1b8e91dbfcc71', '022e75c24ffc4924b0e9fb1e44910801', '022f6ef3f6d545d085c460d2081cee9b', '023991c958ae465a8e7216bb80fcb1da', '024ade192f3a436891173daae5b25fcf', '028267eb0b254ea38eca8b7dea3c551b', '02b5d599bb414158abc5c36e80797574', '02bd2ac42051485183405a0c213583a8', '02bf0e0ce3b345d381a077f561273eb6', '036af89ac8cb4e79a27a17bdea5b5ee8', '0384b066451a4232b4c5e30f085217d1', '0387c1cf04d447e0a37d5bf564ae6e61', '03a11fc68a134a92a5918dccb5c0a6f5', '03ad9644f94d4867864d7913ef2f9544', '03ae724b79694de2ac5922c4dccbc991', '03b5cac40132483d8690c9218728dc37', '03d1e23a3f2d43ffa57e6ce3fd620b55', '040ef2f6c989420eab2f91ef11636905', '0413b397212f4cef91a1876359bbe4bd', '047043cd271846bda1f42be0332799dd', '04735a88542c44e9bed97f45e58b50b3', '0492ba5eda554c9d8f804704e1a736ee', '049db92009c64c0db439838c3517ad4d', '04f75ac22d564fb7a0638a739a3b110d', '0504de204e3c4438b32eaf5c3cc02ec3', '05144fc0b7c34660ad0863bd1fcaedca', '052da368c5e0450b952e03ae66509b0b', '054f60aba2254a2d9c5ac2c7319e16ad', '056211825c07400c81a117a3088114fb', '056685bd92a8429cafcd471a8e76fe6c', '05788d80a07b465c90afd2a65ee8750d', '057c1c3cbd5f41b19f0f414f5ab2d407', '059051a1b92849778a9e9104c7fa7b38', '05beaa8d18ab4aa7b205a5178f5d73b6', '05c4b346f6d1422db24fb179216b4899', '05d73be3817243febc0d612f41a1dcf3', '05e2a25a53274c5ba02bbe2cc57dbc66', '05e489a9109c41ddba0fa67798008b1b', '05fa6a79281d4c54be7102fe1ecdcf2d', '05fe4b07c42447bd892769209b7c614b', '062aba0220bb4d8e88599daf51f5f869', '0637268916804f1586b95471ef407afa', '0640e516f90245218073c65d70d00b68', '0658c572f5ce4ba0afaa2a7b2d90e52d', '0660a77155574aba99a213e0b2467a8c', '066edc0f4db44d10b2651fc9fd955aa3', '06814196b838449c90918bd6359d20d9', '069a640f76c24096b7d7d707fe088def', '06a0708538a446bca904056378e1a306', '06a412d7410d45088c8191f251af737b', '06bf36dd73784f00903160f763e206dc', '06c21bf2f11b45538e5247b9eed63b48', '06c5f23a2eec469e8c64cff1cd41fa6c', '06c7ef10b5484b7482d6a258d989fe85', '06cd49f3b4c340b784f3c6191ee03113', '06e0969c00f14475a49c7bfff8f74cf9', '06ee4969c9d44046aec2f11267dcf24a', '06f5ec3033b54d9e9440794f3a5e6ec0', '071910220e2147199db282e63f85cda0', '07582a6416c84ba48220fa89fb4f1e4e', '07598e0732184a03b06996ed0fdcc8d1', '0767a5a3fd454cc8910a7e37a88b1ebc', '07778e1a35fa43638616df55da798313', '07872fbc6c6a48d8ab436a110819e37f', '0796e7d8997e40e4b737ff7d86c5832e', '07b6e826059f43c4af19fff4c1d48585', '07c4f1338b174ede82316aad1b56143a', '07e136790ac24963a60d02ff922f813d', '07e7965f7bc84a099f8687966d345b1e', '07f5cc2a94ee4850b070d90c07475932', '0804d73e101e4b14b03d152db751af64', '081be36ba11747ad883f7195f9fe0097', '082d57c90f0747d49a243069886a8b6b', '083e6478d3c5420c9baf23f91091c431', '0866909ee50546e08b07a78af73e51ba', '088424595589490c8ca82b2d312ed369', '08a01db89c144db88a706144e4261246', '08a8d82a0e3641d9a4f64f6a1570b47e', '08da201c92c64eb1812fc8544e8da48a', '08db423e308047c1a33c6aaa25a0f769', '08dc3b8a91b84596b92c030af44b00f2', '08 ...

# %%
run_uuid_query = [f"'{run_id}'" for run_id in runs_to_delete]
run_uuid_query = ', '.join(run_uuid_query)

# %%
query = f"""
UPDATE runs
SET lifecycle_stage = 'deleted'
WHERE run_uuid IN ({run_uuid_query}) 
"""
with engine.begin() as conn:
    conn.execute(text(query))

# %%
query = f"""
DELETE
FROM
	experiment_tags
WHERE
	experiment_id = ANY(
	SELECT
		experiment_id
	FROM
		experiments
	WHERE
		lifecycle_stage = 'deleted');

DELETE
FROM
	latest_metrics
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE
FROM
	metrics
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE
FROM
	params
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');

DELETE
FROM
	tags
WHERE
	run_uuid = ANY(
	SELECT
		run_uuid
	FROM
		runs
	WHERE
		lifecycle_stage = 'deleted');
	
DELETE 
FROM 
	runs
WHERE 
	lifecycle_stage = 'deleted';

DELETE 
FROM 
	experiments
WHERE 
	lifecycle_stage = 'deleted';
"""
with engine.begin() as conn:
    conn.execute(text(query))

# %% [markdown]
# for i, row in df_runs_raw.iterrows():
#     run_id = row.run_id
#     model_name = row['params.model_name']
#     with mlflow.start_run(run_id) as run:
#         mlflow.log_param('model_nickname', model_name)
